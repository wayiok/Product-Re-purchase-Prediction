# %% [markdown]
# ## IMPORTS

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# !pip install tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.colab import drive
drive.mount('/content/gdrive')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Import necessary libraries

import torch

# Load pre-trained BERT model and tokenizer
trainFolder = "gdrive/My Drive/MLDM - Carrefour Project/data-train"

import os
for dirname, _, filenames in os.walk(f'{trainFolder}'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.67.1)
# Mounted at /content/gdrive
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/test_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_10.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_2.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_3.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_4.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_5.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_6.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_7.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_8.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_9.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe_fixed.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data_bert1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/submission_01.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations_combined.npy

# %%
# Import libraries
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Description
#
# This project uses three datasets:
#
# #### `train_data.csv`:
# This dataset contains two years (2022 & 2023) of historical transactions for 100,000 Carrefour customers. It has 10 columns:
#
# * ***date***: Date of the transaction
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: Product purchased
# * ***has_loyality_card***: Flag indicating whether the customer has a loyalty card
# * ***store_id***: Store where the purchase was made
# * ***is_promo***: Flag indicating whether there was a discount on the product
# * ***quantity***: Quantity purchased of the product
# * ***format***: Ecommerce activity format (clcv, lex, or DRIVE)
#   - clcv : courses livrées chez vous
#   - lex : livraison express
#   - DRIVE.
# * ***orderChannelCode***: Indicates whether the online activity was made through the website or mobile app

# %% [markdown]
# #### `products_data.csv`:
# This dataset contains detailed information about the products. The following columns are relevant to this project:
#
# * ***product_id*** : Product name
# * ***product_description*** : Product description
# * ***department_key***: Department key
# * ***class_key***: Class key
# * ***subclass_key***: Subclass key
# * ***sector***: sector name
# * ***brand_key***: Brand name
# * ***shelf_level1***: Top-level shelf category
# * ***shelf_level2***: Second-level shelf category
# * ***shelf_level3***: Third-level shelf category
# * ***shelf_level4***: Fourth-level shelf category
# * ***sector***: Sector
# * ***bio***: Flag indicating whether the product is organic
# * ***sugar_free***: Flag indicating whether the product is sugar-free
# * ***aspartame_free***: Flag indicating whether the product is aspartame-free
# * ***gluten_free***: Flag indicating whether the product is gluten-free
# * ***halal***: Flag indicating whether the product is halal
# * ***casher***: Flag indicating whether the product is kosher
# * ***eco_friendly***: Flag indicating whether the product is eco-friendly
# * ***local_french***: Flag indicating whether the product is locally produced in France
# * ***artificial_coloring_free***: Flag indicating whether the product is free of artificial coloring
# * ***taste_enhancer_free***: Flag indicating whether the product is free of taste enhancers
# * ***naturality***: Naturality score
# * ***antibiotic_free***: Flag indicating whether the product is antibiotic-free
# * ***reduced_sugar***: Flag indicating whether the product has reduced sugar content
# * ***vegetarian***: Flag indicating whether the product is vegetarian
# * ***pesticide_free***: Flag indicating whether the product is pesticide-free
# * ***grain_free***: Flag indicating whether the product is grain-free
# * ***no_added_sugar***: Flag indicating whether the product has no added sugar
# * ***salt_reduced***: Flag indicating whether the product has reduced salt content
# * ***nitrite_free***: Flag indicating whether the product is nitrite-free
# * ***fed_without_ogm***: Flag indicating whether the animals were fed without GMOs
# * ***no_added_salt***: Flag indicating whether the product has no added salt
# * ***no_artificial_flavours***: Flag indicating whether the product has no artificial flavors
# * ***porc***: Flag indicating whether the product contains pork
# * ***vegan***: Flag indicating whether the product is vegan
# * ***frozen***: Flag indicating whether the product is frozen
# * ***fat_free***: Flag indicating whether the product is fat-free
# * ***reduced_fats***: Flag indicating whether the product has reduced fat content
# * ***fresh***: Flag indicating whether the product is fresh
# * ***alcool***: Flag indicating whether the product contains alcohol
# * ***lactose_free***: Flag indicating whether the product is lactose-free
# * ***phenylalanine_free***: Flag indicating whether the product is phenylalanine-free
# * ***palm_oil_free***: Flag indicating whether the product is palm oil-free
# * ***ecoscore***: Ecoscore
# * ***produits_du_monde***: Flag indicating whether the product is an international product
# * ***regional_product***: Flag indicating whether the product is a regional product
# * ***national_brand***: Flag indicating whether the product is a national brand
# * ***first_price_brand***: Flag indicating whether the product is a first-price brand
# * ***carrefour_brand***: Flag indicating whether the product is a Carrefour brand

# %% [markdown]
# #### `test_data.csv`:
# This dataset contains the actual purchases of the first 80,000 customers in 2024. It has three columns:
#
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: the id of the purchased product

# %% [markdown]
# ### Load data
#
# * Load *train_data.csv*, *products_data.csv* and *test_data.csv* using pandas.

# %%
# This code reads the data from CSV files named "train_data_part_i.csv" for all i from 1 to 10
# and concatenates them into a single pandas DataFrame
train_dataframes = []
for i in tqdm(range(1, 11)): ## 1 - 11
    train_dataframes.append(pd.read_csv(f'{trainFolder}/train_data_part_{i}.csv'))
train_data = pd.concat(train_dataframes, ignore_index=True)

# free up memory by deleting the dataframes we no longer need
del train_dataframes
# Out:
# 100%|██████████| 10/10 [03:25<00:00, 20.56s/it]

# %%
#train_data = train_data.sample(frac=0.1, random_state=1)  # frac=0.1 takes 10% of the data

# %%
# This code reads the data from a CSV file named "products_data.csv" into a pandas DataFrame
products_data = pd.read_csv(f'{trainFolder}/products_data.csv')
# Out:
# <ipython-input-5-d8cc84ca7717>:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   products_data = pd.read_csv(f'{trainFolder}/products_data.csv')

# %%
# This code reads the data from a CSV file named "test_data.csv" into a pandas DataFrame
test_data = pd.read_csv(f'{trainFolder}/test_data.csv')

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 0         2023-11-15  Transaction_1730125     Household_39   Product_5362
# 1         2022-07-20  Transaction_1560535     Household_39  Product_67174
# 2         2022-07-20  Transaction_1560535     Household_39  Product_82254
# 3         2023-11-15  Transaction_1730125     Household_39   Product_3895
# 4         2022-07-20  Transaction_1560535     Household_39  Product_34014
# ...              ...                  ...              ...            ...
# 87037457  2022-01-07  Transaction_1162379  Household_96742  Product_28756
# 87037458  2023-08-17  Transaction_2306043  Household_96742  Product_62786
# 87037459  2022-10-12  Transaction_1524531  Household_96742  Product_16362
# 87037460  2023-03-10  Transaction_1972306  Household_96742  Product_78870
# 87037461  2022-05-12  Transaction_1971250  Household_96742  Product_10052
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 0                         0     Store_2         0       1.0  DRIVE
# 1                         0     Store_2         0       2.0  DRIVE
# 2                         0     Store_2         0       2.0  DRIVE
# 3                         0     Store_2         0       1.0  DRIVE
# 4                         0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 87037457                  0  Store_2542         0       1.0  DRIVE
# 87037458                  0  Store_2542         0       1.0  DRIVE
# 87037459                  0  Store_2542         0       1.0  DRIVE
# 87037460                  0  Store_2542         0       1.0  DRIVE
# 87037461                  0  Store_2542         0       1.0  DRIVE
#
#          order_channel
# 0           MOBILE_APP
# 1              WEBSITE
# 2              WEBSITE
# 3           MOBILE_APP
# 4              WEBSITE
# ...                ...
# 87037457    MOBILE_APP
# 87037458    MOBILE_APP
# 87037459    MOBILE_APP
# 87037460    MOBILE_APP
# 87037461    MOBILE_APP
#
# [87037462 rows x 10 columns]

# %%
# prompt: print from train_date rows with customer id Household_80001
import pandas as pd

# Create a list of customer IDs within the specified range
#customer_ids_new = [f'Household_{i}' for i in range(80001, 100002)]
#customer_ids_new = [f'Household_{i}' for i in range(10001, 20000)]
customer_ids_new = [f'Household_{i}' for i in range(20001, 30000)]

# prompt: keep in train_data and test_data the rows that have the cusomer_id in customer_ids

# Filter train_data
train_data = train_data[train_data['customer_id'].isin(customer_ids_new)]

# Filter test_data
test_data = test_data[test_data['customer_id'].isin(customer_ids_new)]

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 17514314  2023-02-09   Transaction_318310  Household_20188  Product_51237
# 17514315  2022-05-09   Transaction_238974  Household_20188  Product_32922
# 17514316  2023-02-09   Transaction_318310  Household_20188  Product_45500
# 17514317  2022-05-09   Transaction_238974  Household_20188  Product_16016
# 17514318  2023-03-25  Transaction_1477910  Household_20617  Product_64825
# ...              ...                  ...              ...            ...
# 26166778  2022-05-24  Transaction_1485371  Household_29503  Product_74143
# 26166779  2023-12-04  Transaction_2332026  Household_29503  Product_32349
# 26166780  2023-03-09  Transaction_1339911  Household_23691   Product_3153
# 26166781  2023-12-27   Transaction_605731  Household_27440  Product_19524
# 26166782  2023-09-20  Transaction_1404547  Household_27440  Product_50995
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 17514314                  0     Store_2         0       1.0  DRIVE
# 17514315                  0     Store_2         0       1.0  DRIVE
# 17514316                  0     Store_2         0       1.0  DRIVE
# 17514317                  0     Store_2         0       1.0  DRIVE
# 17514318                  0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 26166778                  0  Store_2542         0       1.0  DRIVE
# 26166779                  0  Store_2542         0       1.0  DRIVE
# 26166780                  0  Store_2544         0       1.0    LEX
# 26166781                  0  Store_2545         0       1.0   CLCV
# 26166782                  0  Store_2545         0       3.0   CLCV
#
#             order_channel
# 17514314          WEBSITE
# 17514315          WEBSITE
# 17514316          WEBSITE
# 17514317          WEBSITE
# 17514318       MOBILE_APP
# ...                   ...
# 26166778          WEBSITE
# 26166779          WEBSITE
# 26166780  PRISE EN COMPTE
# 26166781       MOBILE_APP
# 26166782       MOBILE_APP
#
# [8651417 rows x 10 columns]

# %%
test_data
# Out:
#                 transaction_id      customer_id     product_id
# 25         Transaction_2024_10  Household_21933  Product_55825
# 26         Transaction_2024_10  Household_21933   Product_9723
# 27         Transaction_2024_10  Household_21933   Product_3914
# 28         Transaction_2024_10  Household_21933  Product_59618
# 29         Transaction_2024_10  Household_21933  Product_30800
# ...                        ...              ...            ...
# 966102  Transaction_2024_29356  Household_29999  Product_48044
# 966103  Transaction_2024_29356  Household_29999  Product_49717
# 966104  Transaction_2024_29356  Household_29999  Product_54686
# 966105  Transaction_2024_29356  Household_29999  Product_45025
# 966106  Transaction_2024_29356  Household_29999   Product_1556
#
# [151901 rows x 3 columns]

# %%
train_data = train_data.drop(columns=['transaction_id','has_loyality_card', 'store_id','format','order_channel'])

# %% [markdown]
# ## Training Data Preproccesing

# %%
train_data['date'] = pd.to_datetime(train_data['date'])

# Add recency attribute
latest_date = train_data['date'].max()  # Find the latest date in the dataset
train_data['recency'] = (latest_date - train_data['date']).dt.days  # Calculate days since last purchase

# Group by customer_id and product_id to calculate quantity and most recent purchase
customer_product_data = train_data.groupby(['customer_id', 'product_id']).agg({
    'quantity': 'sum',
    'recency': 'min'  # Minimum days since purchase (most recent)
}).reset_index()

# Normalize quantity and recency scores
customer_product_data['quantity_score'] = customer_product_data['quantity'] / customer_product_data['quantity'].max()
customer_product_data['recency_score'] = 1 - (customer_product_data['recency'] / customer_product_data['recency'].max())  # Recent = higher score

best_alpha = 0.97

# Calculate the final score with this alpha value
customer_product_data['final_score'] = (
    best_alpha * customer_product_data['quantity_score'] +
    (1 - best_alpha) * customer_product_data['recency_score']
)

# Rank products for each customer with unique ranks
customer_product_data['rank'] = customer_product_data.sort_values(
    by=['customer_id', 'final_score', 'quantity', 'product_id'],  # Add secondary sort keys
    ascending=[True, False, False, True]  # Ensure consistent order
).groupby('customer_id').cumcount() + 1  # Assign unique incremental ranks


# Sort the DataFrame by customer_id and rank
customer_product_data = customer_product_data.sort_values(by=['customer_id', 'rank'])

# Filter out products with a rank greater than 200 for each customer
#customer_product_data = customer_product_data[customer_product_data['rank'] <= 20]

# %%
customer_product_data
# Out:
#              customer_id     product_id  quantity  recency  quantity_score  \
# 167      Household_20001  Product_73736      17.0       93        0.004615
# 139      Household_20001  Product_64479      10.0       93        0.002714
# 192      Household_20001   Product_8528       8.0       93        0.002172
# 123      Household_20001  Product_59115       7.0       93        0.001900
# 8        Household_20001  Product_12215       6.0       93        0.001629
# ...                  ...            ...       ...      ...             ...
# 3328689  Household_29999  Product_44450       2.0      726        0.000543
# 3328801  Household_29999  Product_55513       2.0      726        0.000543
# 3328804  Household_29999  Product_55641       2.0      726        0.000543
# 3328889  Household_29999  Product_62656       2.0      726        0.000543
# 3328911  Household_29999  Product_64616       2.0      726        0.000543
#
#          recency_score  final_score  rank
# 167           0.872428     0.030649     1
# 139           0.872428     0.028806     2
# 192           0.872428     0.028279     3
# 123           0.872428     0.028016     4
# 8             0.872428     0.027753     5
# ...                ...          ...   ...
# 3328689       0.004115     0.000650   809
# 3328801       0.004115     0.000650   810
# 3328804       0.004115     0.000650   811
# 3328889       0.004115     0.000650   812
# 3328911       0.004115     0.000650   813
#
# [3329097 rows x 8 columns]

# %%
# Extract temporal features
train_data['month'] = train_data['date'].dt.month
train_data['day_of_week'] = train_data['date'].dt.dayofweek
train_data['is_weekend'] = train_data['day_of_week'].isin([5, 6]).astype(int)

# Calculate recency: days since the last purchase for each customer
train_data['days_since_last_purchase'] = train_data.groupby('customer_id')['date'].transform(
    lambda x: (x.max() - x).dt.days
)

# Drop the 'date' column if it's no longer needed
train_data = train_data.drop(columns=['date'], errors='ignore')

# %%
# Aggregate customer-specific features
customer_features = train_data.groupby(['customer_id']).agg(
    purchase_frequency=('product_id', 'count'),  # Total number of purchases
    avg_quantity=('quantity', 'mean'),          # Average quantity purchased
    promo_ratio=('is_promo', 'mean'),           # Proportion of purchases made with promotions
    unique_products=('product_id', 'nunique')   # Number of unique products purchased
).reset_index()

# Merge these features into train_data and test_data
train_data = train_data.merge(customer_features, on='customer_id', how='left')

# %%
train_data.tail()
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 8651412  Household_29503  Product_74143         0       1.0      586      5
# 8651413  Household_29503  Product_32349         0       1.0       27     12
# 8651414  Household_23691   Product_3153         0       1.0      297      3
# 8651415  Household_27440  Product_19524         0       1.0        4     12
# 8651416  Household_27440  Product_50995         0       3.0      102      9
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 8651412            1           0                       576
# 8651413            0           0                        17
# 8651414            3           0                       292
# 8651415            2           0                         0
# 8651416            2           0                        98
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 8651412                 570      1.061404     0.021053              209
# 8651413                 570      1.061404     0.021053              209
# 8651414                 222      1.490991     0.130631              186
# 8651415                1037      1.591128     0.062681              414
# 8651416                1037      1.591128     0.062681              414

# %%
products_data.tail()
# Out:
#           product_id             product_description department_key  \
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82964  Product_31161              CHARGE BUT 13K CRF  Department_75
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82964  Class_7520  SubClass_75201  ACTIVITES PERIPHERIQUES   CARREFOUR
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1               shelf_level2  \
# 82961     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82963            Animalerie                     Chiens
# 82964  Maison et Décoration          Bouteilles de gaz
# 82965  Maison et Décoration          Bouteilles de gaz
#
#                          shelf_level3                     shelf_level4  bio  \
# 82961             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82962             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82963  Colliers, Laisses et Vêtements          Vêtements et Chaussures    0
# 82964                             NaN                              NaN    0
# 82965                             NaN                              NaN    0
#
#        sugar_free  aspartame_free  gluten_free  halal  casher  eco_friendly  \
# 82961           0               0            0      0       0             0
# 82962           0               0            0      0       0             0
# 82963           0               0            0      0       0             0
# 82964           0               0            0      0       0             0
# 82965           0               0            0      0       0             0
#
#        local_french  artificial_coloring_free  taste_enhancer_free  \
# 82961             0                         0                    0
# 82962             0                         0                    0
# 82963             0                         0                    0
# 82964             0                         0                    0
# 82965             0                         0                    0
#
#        naturality  antibiotic_free  reduced_sugar  vegetarian  pesticide_free  \
# 82961           0                0              0           0               0
# 82962           0                0              0           0               0
# 82963           0                0              0           0               0
# 82964           0                0              0           0               0
# 82965           0                0              0           0               0
#
#        grain_free  no_added_sugar  salt_reduced  nitrite_free  \
# 82961           0               0             0             0
# 82962           0               0             0             0
# 82963           0               0             0             0
# 82964           0               0             0             0
# 82965           0               0             0             0
#
#        fed_without_ogm  no_added_salt  no_artificial_flavours  porc  vegan  \
# 82961                0              0                       0     0      0
# 82962                0              0                       0     0      0
# 82963                0              0                       0     0      0
# 82964                0              0                       0     0      0
# 82965                0              0                       0     0      0
#
#        frozen  fat_free  reduced_fats  fresh  alcool  lactose_free  \
# 82961       0         0             0      0       0             0
# 82962       0         0             0      0       0             0
# 82963       0         0             0      0       0             0
# 82964       0         0             0      0       0             0
# 82965       0         0             0      0       0             0
#
#        phenylalanine_free  palm_oil_free ecoscore  produits_du_monde  \
# 82961                   0              0      NaN                  0
# 82962                   0              0      NaN                  0
# 82963                   0              0      NaN                  0
# 82964                   0              0      NaN                  0
# 82965                   0              0      NaN                  0
#
#        regional_product  national_brand  first_price_brand  carrefour_brand
# 82961                 0               0                  0                1
# 82962                 0               0                  0                1
# 82963                 0               0                  0                1
# 82964                 0               0                  0                1
# 82965                 0               0                  0                1

# %% [markdown]
# # Identifyng Missing Products

# %%
# Convert product_id columns to sets for quick set operations
train_product_ids = set(train_data["product_id"].unique())
products_product_ids = set(products_data["product_id"].unique())

# Find products in products_data that are not in train_data
missing_from_train = products_product_ids - train_product_ids

print(f"Number of products not in train_data: {len(missing_from_train)}")

if len(missing_from_train) > 0:
    print("These product IDs are in products_data but not in train_data:")
    for pid in missing_from_train:
        print(pid)
else:
    print("All products in products_data appear in train_data.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Product_64892
# Product_48642
# Product_30418
# Product_9036
# Product_60065
# Product_63835
# Product_35939
# Product_11240
# Product_52674
# Product_76720
# Product_12400
# Product_55020
# Product_40000
# Product_1494
# Product_10421
# Product_19535
# Product_5171
# Product_563
# Product_20941
# Product_80469
# Product_6479
# Product_75754
# Product_16272
# Product_81435
# Product_60641
# Product_74381
# Product_1594
# Product_15617
# Product_71502
# Product_37095
# Product_55497
# Product_17556
# Product_82159
# Product_15746
# Product_44176
# Product_1707
# Product_68255
# Product_73949
# Product_57172
# Product_1995
# Product_43175
# Product_23137
# Product_74186
# Product_74148
# Product_618
# Product_54773
# Product_16163
# Product_40172
# Product_50322
# Product_47821
# Product_35111
# Product_55435
# Product_24213
# Product_17094
# Product_33797
# Product_78848
# Product_14935
# Product_38242
# Product_5676
# Product_20416
# Product_24000
# Product_51397
# Product_27096
# Product_54044
# Product_15583
# Product_14576
# Product_27796
# Product_23619
# Product_45738
# Product_55962
# Product_52914
# Product_70119
# Product_29103
# Product_67437
# Product_28367
# Product_70614
# Product_18178
# Product_56433
# Product_51470
# Product_1127
# Product_60346
# Product_50235
# Product_18467
# Product_57834
# Product_2539
# Product_24552
# Product_4721
# Product_49991
# Product_5826
# Product_60136
# Product_50616
# Product_45470
# Product_56039
# Product_37815
# Product_79629
# Product_36697
# Product_4575
# Product_37046
# Product_7636
# Product_58601
# Product_74176
# Product_60055
# Product_17064
# Product_74331
# Product_36005
# Product_69913
# Product_9380
# Product_32723
# Product_74871
# Product_60413
# Product_1620
# Product_25771
# Product_15880
# Product_61000
# Product_74002
# Product_81092
# Product_50841
# Product_78576
# Product_77181
# Product_28598
# Product_62607
# Product_23640
# Product_40969
# Product_30164
# Product_6248
# Product_65954
# Product_56938
# Product_56517
# Product_8375
# Product_81792
# Product_48994
# Product_12677
# Product_70972
# Product_45783
# Product_72991
# Product_82107
# Product_52295
# Product_14496
# Product_80410
# Product_72479
# Product_58172
# Product_63148
# Product_18988
# Product_8847
# Product_40918
# Product_50356
# Product_16958
# Product_76685
# Product_2890
# Product_58730
# Product_15517
# Product_16381
# Product_17869
# Product_20771
# Product_47819
# Product_30071
# Product_40571
# Product_45754
# Product_15095
# Product_13393
# Product_16582
# Product_28271
# Product_109
# Product_380
# Product_18217
# Product_32772
# Product_9610
# Product_43770
# Product_21494
# Product_6668
# Product_68225
# Product_15205
# Product_45403
# Product_76448
# Product_48242
# Product_4503
# Product_67353
# Product_5039
# Product_10301
# Product_27151
# Product_18982
# Product_7148
# Product_31490
# Product_38943
# Product_45407
# Product_7353
# Product_10071
# Product_53804
# Product_61398
# Product_40888
# Product_9383
# Product_73397
# Product_45632
# Product_11195
# Product_60488
# Product_53817
# Product_57938
# Product_22605
# Product_74332
# Product_67758
# Product_34245
# Product_62054
# Product_44995
# Product_533
# Product_79283
# Product_55376
# Product_39277
# Product_18646
# Product_32929
# Product_77653
# Product_81898
# Product_36795
# Product_19240
# Product_32672
# Product_31626
# Product_10737
# Product_8162
# Product_22169
# Product_439
# Product_52604
# Product_61990
# Product_26102
# Product_74545
# Product_45889
# Product_5564
# Product_31616
# Product_69273
# Product_40720
# Product_18102
# Product_63964
# Product_55975
# Product_20616
# Product_48662
# Product_57024
# Product_50773
# Product_31625
# Product_75546
# Product_55191
# Product_77799
# Product_6934
# Product_23608
# Product_3586
# Product_15443
# Product_57969
# Product_68308
# Product_34158
# Product_76489
# Product_58298
# Product_14570
# Product_31658
# Product_58666
# Product_48306
# Product_17221
# Product_15186
# Product_23461
# Product_81075
# Product_18197
# Product_36279
# Product_27840
# Product_12862
# Product_7922
# Product_51747
# Product_71635
# Product_69796
# Product_60609
# Product_10169
# Product_16094
# Product_22964
# Product_43889
# Product_41795
# Product_46852
# Product_20938
# Product_11213
# Product_5855
# Product_69863
# Product_56155
# Product_40879
# Product_18752
# Product_15836
# Product_76972
# Product_551
# Product_20868
# Product_65871
# Product_3819
# Product_81802
# Product_38047
# Product_76099
# Product_64422
# Product_63864
# Product_18207
# Product_24290
# Product_60905
# Product_78028
# Product_15212
# Product_3859
# Product_41110
# Product_42577
# Product_41932
# Product_49343
# Product_46864
# Product_54439
# Product_37606
# Product_50057
# Product_7317
# Product_57530
# Product_99
# Product_30842
# Product_68481
# Product_9854
# Product_29806
# Product_64423
# Product_62435
# Product_81721
# Product_71939
# Product_2792
# Product_392
# Product_66591
# Product_22490
# Product_75073
# Product_9031
# Product_62509
# Product_16319
# Product_41783
# Product_15710
# Product_5166
# Product_59767
# Product_80988
# Product_8357
# Product_27858
# Product_55639
# Product_42484
# Product_3430
# Product_29289
# Product_70921
# Product_68176
# Product_18343
# Product_25472
# Product_6146
# Product_59741
# Product_8236
# Product_28458
# Product_73509
# Product_5949
# Product_36133
# Product_49736
# Product_32120
# Product_20399
# Product_718
# Product_13284
# Product_72841
# Product_43787
# Product_81286
# Product_29877
# Product_25697
# Product_80846
# Product_19516
# Product_12905
# Product_55279
# Product_1301
# Product_74401
# Product_38137
# Product_65313
# Product_57146
# Product_47416
# Product_53791
# Product_39092
# Product_57054
# Product_51618
# Product_16335
# Product_61002
# Product_58357
# Product_13840
# Product_82343
# Product_43680
# Product_10673
# Product_16643
# Product_65690
# Product_61576
# Product_2587
# Product_37637
# Product_24426
# Product_9230
# Product_1347
# Product_44013
# Product_60955
# Product_55489
# Product_42143
# Product_15973
# Product_40978
# Product_46435
# Product_44713
# Product_59670
# Product_10468
# Product_28356
# Product_13307
# Product_59199
# Product_65279
# Product_37335
# Product_82263
# Product_1236
# Product_61491
# Product_65908
# Product_15094
# Product_1527
# Product_64839
# Product_37186
# Product_50669
# Product_14824
# Product_69238
# Product_2906
# Product_4319
# Product_37330
# Product_4849
# Product_18732
# Product_76492
# Product_79160
# Product_17790
# Product_20851
# Product_36406
# Product_9984
# Product_41707
# Product_23765
# Product_63225
# Product_47407
# Product_53115
# Product_15758
# Product_22932
# Product_7711
# Product_63302
# Product_33651
# Product_24517
# Product_68574
# Product_80565
# Product_25343
# Product_14435
# Product_13738
# Product_80101
# Product_48250
# Product_54279
# Product_70027
# Product_15826
# Product_78634
# Product_13322
# Product_66880
# Product_37695
# Product_33286
# Product_64178
# Product_25679
# Product_13428
# Product_50754
# Product_24072
# Product_75239
# Product_140
# Product_77844
# Product_65204
# Product_12133
# Product_17523
# Product_76331
# Product_63361
# Product_11155
# Product_82189
# Product_19214
# Product_55838
# Product_75634
# Product_45984
# Product_2084
# Product_1337
# Product_7110
# Product_636
# Product_71118
# Product_78778
# Product_66035
# Product_50276
# Product_25969
# Product_75051
# Product_42799
# Product_68734
# Product_34746
# Product_26032
# Product_15394
# Product_10721
# Product_73264
# Product_55840
# Product_211
# Product_54090
# Product_78303
# Product_43728
# Product_23389
# Product_63695
# Product_56869
# Product_9474
# Product_9043
# Product_9463
# Product_41207
# Product_63029
# Product_19489
# Product_25349
# Product_9134
# Product_74416
# Product_53295
# Product_61328
# Product_15778
# Product_44130
# Product_76558
# Product_51884
# Product_49780
# Product_70382
# Product_33407
# Product_35819
# Product_53254
# Product_62712
# Product_70564
# Product_7954
# Product_75564
# Product_3652
# Product_79961
# Product_33526
# Product_50464
# Product_44146
# Product_61745
# Product_53551
# Product_63758
# Product_31718
# Product_42904
# Product_10211
# Product_74991
# Product_59051
# Product_9311
# Product_1897
# Product_12842
# Product_21715
# Product_78710
# Product_67120
# Product_66460
# Product_81504
# Product_69898
# Product_56348
# Product_63944
# Product_38861
# Product_26481
# Product_76821
# Product_81674
# Product_37559
# Product_73511
# Product_10321
# Product_19857
# Product_25135
# Product_47894
# Product_50459
# Product_21552
# Product_78495
# Product_15148
# Product_12879
# Product_57740
# Product_72178
# Product_20359
# Product_17955
# Product_41130
# Product_40112
# Product_56262
# Product_56808
# Product_69263
# Product_46916
# Product_282
# Product_55791
# Product_12973
# Product_41510
# Product_9422
# Product_57356
# Product_49216
# Product_81270
# Product_79719
# Product_25331
# Product_53998
# Product_41687
# Product_61131
# Product_1881
# Product_20793
# Product_61325
# Product_64755
# Product_49959
# Product_33052
# Product_13692
# Product_42056
# Product_11058
# Product_40364
# Product_29716
# Product_20457
# Product_25447
# Product_35849
# Product_46597
# Product_16636
# Product_79312
# Product_47254
# Product_56119
# Product_51203
# Product_36971
# Product_72966
# Product_67781
# Product_2875
# Product_50240
# Product_32703
# Product_34440
# Product_21015
# Product_23142
# Product_24876
# Product_67908
# Product_25268
# Product_18010
# Product_61174
# Product_42287
# Product_34363
# Product_36003
# Product_4004
# Product_30712
# Product_30816
# Product_6114
# Product_61616
# Product_7888
# Product_3747
# Product_15893
# Product_11000
# Product_64316
# Product_82163
# Product_49297
# Product_6603
# Product_55152
# Product_38275
# Product_14217
# Product_59530
# Product_40466
# Product_52720
# Product_64682
# Product_60792
# Product_76496
# Product_33116
# Product_71481
# Product_27014
# Product_22065
# Product_35269
# Product_11278
# Product_12982
# Product_43534
# Product_43383
# Product_15800
# Product_70882
# Product_5455
# Product_3804
# Product_17733
# Product_67077
# Product_79055
# Product_268
# Product_3849
# Product_62464
# Product_82128
# Product_19631
# Product_46637
# Product_33731
# Product_21668
# Product_54687
# Product_39150
# Product_69631
# Product_44743
# Product_8551
# Product_27785
# Product_35377
# Product_37324
# Product_55643
# Product_4295
# Product_81993
# Product_32303
# Product_10461
# Product_43756
# Product_20167
# Product_760
# Product_63067
# Product_53350
# Product_33957
# Product_60126
# Product_43938
# Product_63431
# Product_62366
# Product_14370
# Product_29362
# Product_40271
# Product_74128
# Product_1113
# Product_69421
# Product_7252
# Product_35659
# Product_81257
# Product_22957
# Product_54223
# Product_9673
# Product_4813
# Product_73445
# Product_54333
# Product_66745
# Product_22327
# Product_18059
# Product_37014
# Product_52091
# Product_53892
# Product_5290
# Product_52684
# Product_31198
# Product_67581
# Product_74766
# Product_79092
# Product_65305
# Product_19209
# Product_96
# Product_34894
# Product_72747
# Product_43792
# Product_6501
# Product_17256
# Product_19006
# Product_7655
# Product_11589
# Product_67724
# Product_43698
# Product_68376
# Product_6386
# Product_13281
# Product_37772
# Product_16246
# Product_24950
# Product_21242
# Product_8794
# Product_82359
# Product_11749
# Product_41417
# Product_16648
# Product_22903
# Product_39582
# Product_37024
# Product_81404
# Product_73873
# Product_39987
# Product_31401
# Product_26193
# Product_29349
# Product_48547
# Product_8105
# Product_17050
# Product_18472
# Product_16498
# Product_56134
# Product_72799
# Product_31463
# Product_81960
# Product_42220
# Product_82611
# Product_46355
# Product_71896
# Product_4465
# Product_78144
# Product_48053
# Product_76805
# Product_75352
# Product_81616
# Product_78794
# Product_19094
# Product_37531
# Product_19131
# Product_43561
# Product_35043
# Product_7550
# Product_43782
# Product_2009
# Product_56229
# Product_46906
# Product_69576
# Product_41667
# Product_58405
# Product_4222
# Product_21328
# Product_36588
# Product_21828
# Product_3947
# Product_39518
# Product_81289
# Product_77827
# Product_44387
# Product_44602
# Product_9828
# Product_65615
# Product_41047
# Product_27420
# Product_59729
# Product_1477
# Product_59165
# Product_15871
# Product_39789
# Product_14273
# Product_65006
# Product_8886
# Product_20689
# Product_68891
# Product_36369
# Product_27585
# Product_77191
# Product_40213
# Product_30473
# Product_24432
# Product_10070
# Product_16540
# Product_28330
# Product_34904
# Product_28003
# Product_30221
# Product_49384
# Product_60040
# Product_44446
# Product_80844
# Product_6569
# Product_48327
# Product_80479
# Product_30676
# Product_10102
# Product_55897
# Product_54189
# Product_55766
# Product_79261
# Product_22625
# Product_38566
# Product_58978
# Product_81490
# Product_74155
# Product_29513
# Product_5475
# Product_16619
# Product_12026
# Product_37459
# Product_20634
# Product_23410
# Product_21702
# Product_32599
# Product_10594
# Product_8323
# Product_71849
# Product_60222
# Product_63884
# Product_55206
# Product_77196
# Product_6575
# Product_56626
# Product_46229
# Product_58484
# Product_45974
# Product_16083
# Product_57817
# Product_71133
# Product_25905
# Product_48983
# Product_79006
# Product_74583
# Product_34951
# Product_70088
# Product_47305
# Product_51395
# Product_2536
# Product_17554
# Product_37234
# Product_8503
# Product_77470
# Product_71299
# Product_10646
# Product_78252
# Product_59422
# Product_9241
# Product_11477
# Product_23464
# Product_73188
# Product_47506
# Product_418
# Product_61865
# Product_23852
# Product_41870
# Product_49340
# Product_41842
# Product_63941
# Product_40235
# Product_61728
# Product_67985
# Product_25330
# Product_25621
# Product_30674
# Product_69866
# Product_52769
# Product_63544
# Product_34177
# Product_68126
# Product_78464
# Product_58965
# Product_14151
# Product_3265
# Product_17069
# Product_45317
# Product_56159
# Product_82276
# Product_41027
# Product_25014
# Product_63266
# Product_65179
# Product_64144
# Product_49270
# Product_12942
# Product_40950
# Product_52996
# Product_42275
# Product_32105
# Product_79548
# Product_27416
# Product_44311
# Product_32409
# Product_39656
# Product_80588
# Product_65951
# Product_31704
# Product_72720
# Product_60626
# Product_44810
# Product_26402
# Product_25055
# Product_81323
# Product_28222
# Product_1093
# Product_15811
# Product_59731
# Product_60522
# Product_49544
# Product_10927
# Product_76507
# Product_11796
# Product_1333
# Product_69527
# Product_12148
# Product_27299
# Product_3155
# Product_67439
# Product_20966
# Product_16244
# Product_63498
# Product_55539
# Product_12333
# Product_54981
# Product_75574
# Product_82371
# Product_71977
# Product_65355
# Product_61093
# Product_60781
# Product_1280
# Product_29434
# Product_48408
# Product_6764
# Product_73983
# Product_35085
# Product_22377
# Product_62752
# Product_1590
# Product_65798
# Product_19272
# Product_29695
# Product_57373
# Product_25870
# Product_51444
# Product_61310
# Product_70407
# Product_29737
# Product_16081
# Product_9344
# Product_22144
# Product_67096
# Product_51001
# Product_64372
# Product_77580
# Product_26314
# Product_43255
# Product_48984
# Product_77147
# Product_16686
# Product_27666
# Product_71042
# Product_63136
# Product_62085
# Product_64542
# Product_30180
# Product_69596
# Product_24536
# Product_49061
# Product_81117
# Product_33001
# Product_32692
# Product_46542
# Product_44187
# Product_14845
# Product_2177
# Product_16674
# Product_6237
# Product_59049
# Product_52474
# Product_34266
# Product_41835
# Product_7508
# Product_30025
# Product_72361
# Product_41365
# Product_21021
# Product_36048
# Product_47947
# Product_45006
# Product_66040
# Product_69760
# Product_5170
# Product_1115
# Product_53107
# Product_13425
# Product_33949
# Product_63547
# Product_46569
# Product_2770
# Product_23590
# Product_68561
# Product_63074
# Product_39048
# Product_22417
# Product_19233
# Product_38890
# Product_22701
# Product_31505
# Product_37495
# Product_41718
# Product_5761
# Product_54945
# Product_7698
# Product_23973
# Product_44454
# Product_65314
# Product_27766
# Product_16200
# Product_74810
# Product_81483
# Product_45711
# Product_40043
# Product_46202
# Product_23282
# Product_8407
# Product_57000
# Product_4590
# Product_67681
# Product_36557
# Product_36442
# Product_19954
# Product_51543
# Product_74886
# Product_78980
# Product_71802
# Product_45269
# Product_34632
# Product_9529
# Product_13897
# Product_10220
# Product_16003
# Product_57616
# Product_43520
# Product_10538
# Product_19039
# Product_20217
# Product_75819
# Product_82195
# Product_46809
# Product_32684
# Product_24546
# Product_65408
# Product_14556
# Product_46709
# Product_21241
# Product_42530
# Product_10204
# Product_69818
# Product_26159
# Product_26718
# Product_76498
# Product_65892
# Product_66387
# Product_27834
# Product_62301
# Product_60985
# Product_52328
# Product_66294
# Product_35177
# Product_8857
# Product_40126
# Product_37392
# Product_55552
# Product_67507
# Product_45774
# Product_31396
# Product_72873
# Product_69544
# Product_49290
# Product_81545
# Product_79078
# Product_22781
# Product_34124
# Product_58335
# Product_22410
# Product_60710
# Product_19313
# Product_59440
# Product_44677
# Product_51862
# Product_61614
# Product_34020
# Product_46849
# Product_15480
# Product_521
# Product_42967
# Product_75547
# Product_23271
# Product_37596
# Product_52884
# Product_63320
# Product_2771
# Product_49707
# Product_19722
# Product_42853
# Product_73413
# Product_28505
# Product_22805
# Product_27803
# Product_60928
# Product_36988
# Product_73696
# Product_37649
# Product_1901
# Product_55553
# Product_13682
# Product_52301
# Product_79919
# Product_52836
# Product_58353
# Product_7564
# Product_45909
# Product_72797
# Product_27249
# Product_82043
# Product_51806
# Product_47575
# Product_54793
# Product_30956
# Product_11069
# Product_64471
# Product_81017
# Product_30301
# Product_40260
# Product_25282
# Product_56450
# Product_77625
# Product_31789
# Product_29523
# Product_44833
# Product_14204
# Product_56256
# Product_49431
# Product_43805
# Product_22012
# Product_28284
# Product_10848
# Product_64953
# Product_45603
# Product_44497
# Product_37345
# Product_13952
# Product_75822
# Product_33223
# Product_22524
# Product_5392
# Product_53862
# Product_42688
# Product_44409
# Product_5460
# Product_72044
# Product_76458
# Product_41205
# Product_50364
# Product_28716
# Product_23537
# Product_25248
# Product_80924
# Product_22481
# Product_64899
# Product_35635
# Product_62232
# Product_66599
# Product_2147
# Product_10080
# Product_75743
# Product_35196
# Product_30722
# Product_23938
# Product_35751
# Product_7493
# Product_39779
# Product_47185
# Product_20003
# Product_48813
# Product_75205
# Product_38679
# Product_32832
# Product_45215
# Product_70712
# Product_42728
# Product_4244
# Product_45244
# Product_7440
# Product_20560
# Product_36244
# Product_20016
# Product_24219
# Product_75856
# Product_80016
# Product_3387
# Product_55
# Product_41597
# Product_8360
# Product_2904
# Product_80453
# Product_12364
# Product_29763
# Product_66568
# Product_41115
# Product_41858
# Product_35803
# Product_61338
# Product_26341
# Product_38004
# Product_52040
# Product_46509
# Product_39316
# Product_68743
# Product_54542
# Product_19996
# Product_456
# Product_30635
# Product_70662
# Product_79596
# Product_75085
# Product_66585
# Product_55128
# Product_22598
# Product_48613
# Product_13743
# Product_63453
# Product_82767
# Product_76532
# Product_64163
# Product_22614
# Product_53937
# Product_48776
# Product_55597
# Product_47227
# Product_8009
# Product_48454
# Product_58393
# Product_76770
# Product_72801
# Product_21728
# Product_60342
# Product_41957
# Product_41255
# Product_56553
# Product_56656
# Product_11946
# Product_4844
# Product_6197
# Product_11270
# Product_55782
# Product_41644
# Product_2806
# Product_32486
# Product_34251
# Product_75034
# Product_56801
# Product_10569
# Product_42639
# Product_73614
# Product_59920
# Product_13918
# Product_82717
# Product_76442
# Product_47396
# Product_47170
# Product_61418
# Product_73128
# Product_55769
# Product_58702
# Product_3504
# Product_42860
# Product_82713
# Product_43089
# Product_79675
# Product_67306
# Product_15673
# Product_28634
# Product_77453
# Product_35987
# Product_61661
# Product_48481
# Product_76819
# Product_64436
# Product_41129
# Product_53700
# Product_51260
# Product_12462
# Product_67872
# Product_26701
# Product_49538
# Product_80545
# Product_63539
# Product_59218
# Product_60851
# Product_25372
# Product_78762
# Product_44243
# Product_45788
# Product_59009
# Product_67156
# Product_4669
# Product_13655
# Product_25985
# Product_65064
# Product_30266
# Product_16603
# Product_134
# Product_82252
# Product_77297
# Product_65186
# Product_42490
# Product_76707
# Product_12501
# Product_44654
# Product_30668
# Product_68365
# Product_24823
# Product_12120
# Product_68567
# Product_76425
# Product_34105
# Product_59207
# Product_61935
# Product_70410
# Product_40680
# Product_44278
# Product_26924
# Product_78738
# Product_53109
# Product_76636
# Product_46059
# Product_30735
# Product_39212
# Product_41376
# Product_73467
# Product_27533
# Product_23797
# Product_23414
# Product_5585
# Product_79320
# Product_30250
# Product_14387
# Product_22291
# Product_17264
# Product_72963
# Product_70943
# Product_931
# Product_19485
# Product_22860
# Product_61301
# Product_5522
# Product_13972
# Product_72008
# Product_36432
# Product_50808
# Product_8071
# Product_26235
# Product_48368
# Product_27606
# Product_20541
# Product_11173
# Product_11541
# Product_44918
# Product_57945
# Product_2986
# Product_30330
# Product_67421
# Product_22972
# Product_53438
# Product_49114
# Product_26619
# Product_74009
# Product_158
# Product_6797
# Product_42831
# Product_68648
# Product_29225
# Product_45379
# Product_3600
# Product_23825
# Product_23551
# Product_51763
# Product_7025
# Product_34194
# Product_21470
# Product_61568
# Product_13461
# Product_71557
# Product_62177
# Product_75906
# Product_11781
# Product_47224
# Product_68852
# Product_23371
# Product_59911
# Product_70674
# Product_33670
# Product_80724
# Product_17119
# Product_24270
# Product_75896
# Product_12914
# Product_65213
# Product_16311
# Product_42818
# Product_10525
# Product_65903
# Product_59292
# Product_70815
# Product_37162
# Product_8839
# Product_79058
# Product_66475
# Product_12314
# Product_49191
# Product_15061
# Product_70950
# Product_50196
# Product_66611
# Product_36007
# Product_71163
# Product_1327
# Product_7971
# Product_46685
# Product_40450
# Product_74121
# Product_58733
# Product_911
# Product_43157
# Product_71241
# Product_57211
# Product_46469
# Product_62318
# Product_79127
# Product_65248
# Product_42901
# Product_51345
# Product_17316
# Product_15795
# Product_38856
# Product_63889
# Product_4807
# Product_54089
# Product_82644
# Product_16845
# Product_37033
# Product_10370
# Product_35840
# Product_50799
# Product_11405
# Product_63414
# Product_17351
# Product_16927
# Product_40206
# Product_33366
# Product_8399
# Product_19728
# Product_73312
# Product_34753
# Product_30507
# Product_18464
# Product_44681
# Product_3221
# Product_9981
# Product_74005
# Product_47455
# Product_43592
# Product_9011
# Product_81126
# Product_65205
# Product_38195
# Product_20646
# Product_73462
# Product_12188
# Product_78623
# Product_71617
# Product_50495
# Product_20149
# Product_48294
# Product_2674
# Product_27711
# Product_36696
# Product_11002
# Product_66195
# Product_10695
# Product_34503
# Product_5088
# Product_57819
# Product_51951
# Product_21110
# Product_59135
# Product_34988
# Product_52788
# Product_5018
# Product_31786
# Product_80637
# Product_6528
# Product_61387
# Product_59327
# Product_50032
# Product_23403
# Product_74101
# Product_21317
# Product_23943
# Product_3842
# Product_5880
# Product_25699
# Product_51854
# Product_5463
# Product_60155
# Product_44420
# Product_5815
# Product_21262
# Product_31320
# Product_18454
# Product_14416
# Product_30940
# Product_30155
# Product_72590
# Product_35430
# Product_45721
# Product_57480
# Product_13768
# Product_61250
# Product_6287
# Product_37288
# Product_2767
# Product_51162
# Product_52297
# Product_32068
# Product_35995
# Product_44421
# Product_2397
# Product_28450
# Product_64611
# Product_36700
# Product_56793
# Product_27571
# Product_42073
# Product_69504
# Product_51144
# Product_71145
# Product_11038
# Product_54722
# Product_82552
# Product_58897
# Product_49523
# Product_32456
# Product_48409
# Product_74063
# Product_53983
# Product_61689
# Product_21349
# Product_53478
# Product_55312
# Product_78629
# Product_38015
# Product_7055
# Product_22538
# Product_60218
# Product_24382
# Product_44507
# Product_13165
# Product_45805
# Product_80507
# Product_65680
# Product_30723
# Product_3647
# Product_27373
# Product_45839
# Product_24505
# Product_75499
# Product_50814
# Product_33846
# Product_6866
# Product_73322
# Product_36140
# Product_51779
# Product_49637
# Product_20739
# Product_9466
# Product_11851
# Product_4889
# Product_37997
# Product_80348
# Product_64187
# Product_38889
# Product_44531
# Product_59299
# Product_78652
# Product_71081
# Product_59826
# Product_79425
# Product_38206
# Product_5810
# Product_66983
# Product_43614
# Product_53853
# Product_71833
# Product_19834
# Product_421
# Product_46669
# Product_9462
# Product_79361
# Product_15729
# Product_8024
# Product_51942
# Product_40478
# Product_35660
# Product_40337
# Product_65007
# Product_42433
# Product_76826
# Product_56569
# Product_72453
# Product_31550
# Product_34696
# Product_57958
# Product_55551
# Product_29857
# Product_64027
# Product_64549
# Product_11291
# Product_51120
# Product_6909
# Product_28690
# Product_55644
# Product_48337
# Product_31867
# Product_450
# Product_34389
# Product_25011
# Product_66901
# Product_8078
# Product_34728
# Product_58218
# Product_7162
# Product_24075
# Product_24806
# Product_76954
# Product_14589
# Product_58561
# Product_58723
# Product_46326
# Product_16598
# Product_40244
# Product_22469
# Product_41822
# Product_42763
# Product_1339
# Product_32447
# Product_13507
# Product_51944
# Product_2856
# Product_46055
# Product_13523
# Product_30244
# Product_27400
# Product_7729
# Product_72432
# Product_41176
# Product_32640
# Product_28082
# Product_15452
# Product_51904
# Product_29594
# Product_41570
# Product_17460
# Product_39888
# Product_63359
# Product_18451
# Product_6374
# Product_46482
# Product_17031
# Product_53269
# Product_24804
# Product_51861
# Product_58343
# Product_9881
# Product_64752
# Product_71338
# Product_50280
# Product_55103
# Product_65093
# Product_54174
# Product_16260
# Product_77593
# Product_78790
# Product_21635
# Product_47812
# Product_71551
# Product_82302
# Product_35604
# Product_79431
# Product_18260
# Product_7823
# Product_64322
# Product_54491
# Product_41738
# Product_75427
# Product_70731
# Product_68571
# Product_48289
# Product_9047
# Product_64167
# Product_78416
# Product_26407
# Product_15003
# Product_9362
# Product_33728
# Product_57526
# Product_28805
# Product_52974
# Product_15470
# Product_8682
# Product_10145
# Product_74312
# Product_63471
# Product_51294
# Product_3380
# Product_40896
# Product_46486
# Product_56747
# Product_48260
# Product_16141
# Product_4891
# Product_53579
# Product_81237
# Product_57243
# Product_50792
# Product_73370
# Product_54425
# Product_53562
# Product_15477
# Product_8916
# Product_74773
# Product_18858
# Product_78375
# Product_12401
# Product_1216
# Product_46815
# Product_22960
# Product_72673
# Product_35580
# Product_29407
# Product_75528
# Product_28025
# Product_19304
# Product_55405
# Product_19672
# Product_27621
# Product_5316
# Product_23650
# Product_55845
# Product_29194
# Product_53648
# Product_62727
# Product_228
# Product_7891
# Product_4415
# Product_12481
# Product_60297
# Product_13328
# Product_25026
# Product_11133
# Product_73578
# Product_10620
# Product_78231
# Product_67755
# Product_26470
# Product_46410
# Product_28266
# Product_52688
# Product_38617
# Product_67618
# Product_41321
# Product_58267
# Product_55565
# Product_1639
# Product_52203
# Product_28249
# Product_60734
# Product_25655
# Product_59544
# Product_16751
# Product_66146
# Product_27341
# Product_8428
# Product_51770
# Product_9568
# Product_66336
# Product_1407
# Product_8065
# Product_38872
# Product_10438
# Product_71512
# Product_64648
# Product_58571
# Product_30283
# Product_73909
# Product_41091
# Product_69946
# Product_23
# Product_5825
# Product_42400
# Product_21735
# Product_79985
# Product_20097
# Product_29410
# Product_57191
# Product_39205
# Product_78604
# Product_69255
# Product_68351
# Product_16182
# Product_13103
# Product_36572
# Product_61850
# Product_35857
# Product_56042
# Product_47895
# Product_5428
# Product_41844
# Product_56390
# Product_70676
# Product_20161
# Product_61838
# Product_61559
# Product_80697
# Product_20246
# Product_49466
# Product_56898
# Product_31726
# Product_33093
# Product_2293
# Product_30377
# Product_69396
# Product_14692
# Product_82339
# Product_47937
# Product_15864
# Product_28942
# Product_6499
# Product_69392
# Product_26467
# Product_9245
# Product_31653
# Product_20164
# Product_37664
# Product_43334
# Product_28049
# Product_1351
# Product_68641
# Product_50839
# Product_23250
# Product_48112
# Product_31810
# Product_37079
# Product_48427
# Product_58580
# Product_40077
# Product_49584
# Product_19769
# Product_43563
# Product_36813
# Product_72678
# Product_76896
# Product_63645
# Product_50761
# Product_14625
# Product_68747
# Product_31454
# Product_74045
# Product_24368
# Product_45519
# Product_79315
# Product_43584
# Product_75117
# Product_19725
# Product_58946
# Product_16440
# Product_27069
# Product_72745
# Product_16326
# Product_53327
# Product_78049
# Product_77659
# Product_54996
# Product_34627
# Product_5533
# Product_24487
# Product_67544
# Product_77300
# Product_32453
# Product_65539
# Product_62670
# Product_50698
# Product_54083
# Product_4116
# Product_32319
# Product_66947
# Product_62939
# Product_72939
# Product_585
# Product_74304
# Product_18224
# Product_8671
# Product_59285
# Product_5059
# Product_19071
# Product_7648
# Product_60607
# Product_50755
# Product_21694
# Product_55935
# Product_72308
# Product_8511
# Product_59743
# Product_32283
# Product_49069
# Product_75926
# Product_35512
# Product_14827
# Product_5338
# Product_15278
# Product_5687
# Product_23629
# Product_4426
# Product_45441
# Product_53997
# Product_76255
# Product_3596
# Product_44105
# Product_66220
# Product_16456
# Product_81918
# Product_44884
# Product_786
# Product_79982
# Product_19451
# Product_3579
# Product_19814
# Product_64602
# Product_61149
# Product_56375
# Product_19260
# Product_63011
# Product_32392
# Product_3921
# Product_28840
# Product_58411
# Product_9868
# Product_39170
# Product_15719
# Product_63746
# Product_41223
# Product_33318
# Product_70138
# Product_40966
# Product_72982
# Product_80397
# Product_66357
# Product_47999
# Product_28818
# Product_7963
# Product_23443
# Product_319
# Product_47131
# Product_25148
# Product_32999
# Product_1429
# Product_62918
# Product_10100
# Product_18269
# Product_63793
# Product_39587
# Product_28784
# Product_3305
# Product_31340
# Product_1142
# Product_34810
# Product_25556
# Product_35714
# Product_31142
# Product_4840
# Product_74780
# Product_11703
# Product_27575
# Product_741
# Product_53999
# Product_46596
# Product_2956
# Product_57562
# Product_70141
# Product_18881
# Product_12016
# Product_43177
# Product_68216
# Product_29034
# Product_6477
# Product_61558
# Product_76269
# Product_66455
# Product_8283
# Product_47036
# Product_57342
# Product_79267
# Product_67487
# Product_51995
# Product_29211
# Product_61827
# Product_81384
# Product_72320
# Product_44961
# Product_45676
# Product_56199
# Product_46087
# Product_3958
# Product_20319
# Product_58258
# Product_39145
# Product_64554
# Product_79707
# Product_82109
# Product_81288
# Product_43586
# Product_33623
# Product_30072
# Product_54842
# Product_11814
# Product_75324
# Product_12265
# Product_13689
# Product_35290
# Product_56696
# Product_57665
# Product_14084
# Product_73854
# Product_51014
# Product_59995
# Product_40164
# Product_70139
# Product_56057
# Product_81430
# Product_79207
# Product_60833
# Product_12567
# Product_42018
# Product_22276
# Product_79906
# Product_4264
# Product_47953
# Product_14392
# Product_73633
# Product_74200
# Product_79098
# Product_41171
# Product_12402
# Product_19883
# Product_73133
# Product_62067
# Product_16947
# Product_78045
# Product_23504
# Product_902
# Product_71170
# Product_11783
# Product_4883
# Product_25295
# Product_75379
# Product_28958
# Product_43388
# Product_62421
# Product_16918
# Product_16299
# Product_20147
# Product_71716
# Product_22644
# Product_5352
# Product_74347
# Product_17919
# Product_19208
# Product_66537
# Product_78207
# Product_60216
# Product_26723
# Product_39027
# Product_10631
# Product_32906
# Product_42466
# Product_81775
# Product_82002
# Product_27506
# Product_59863
# Product_1208
# Product_26114
# Product_18854
# Product_54313
# Product_75553
# Product_46239
# Product_58896
# Product_15265
# Product_1767
# Product_50847
# Product_71524
# Product_52635
# Product_11145
# Product_69389
# Product_61867
# Product_47021
# Product_34196
# Product_58549
# Product_35812
# Product_22392
# Product_60874
# Product_11201
# Product_11282
# Product_73070
# Product_26624
# Product_30889
# Product_74912
# Product_41559
# Product_14225
# Product_213
# Product_52623
# Product_64866
# Product_44524
# Product_21024
# Product_24997
# Product_57439
# Product_50650
# Product_54176
# Product_24126
# Product_43578
# Product_21537
# Product_64079
# Product_29849
# Product_78956
# Product_55950
# Product_4873
# Product_62000
# Product_7593
# Product_49913
# Product_30660
# Product_23200
# Product_29524
# Product_51748
# Product_23837
# Product_10243
# Product_11406
# Product_3108
# Product_50694
# Product_73899
# Product_67279
# Product_16145
# Product_1414
# Product_78780
# Product_69266
# Product_48634
# Product_2387
# Product_5603
# Product_53963
# Product_74751
# Product_75220
# Product_37802
# Product_17052
# Product_7692
# Product_23796
# Product_68953
# Product_15784
# Product_50483
# Product_44128
# Product_2135
# Product_1751
# Product_7242
# Product_13441
# Product_21722
# Product_81690
# Product_63969
# Product_41891
# Product_6932
# Product_51848
# Product_38863
# Product_81035
# Product_65055
# Product_75046
# Product_59101
# Product_13200
# Product_5714
# Product_26841
# Product_53357
# Product_75473
# Product_4537
# Product_15606
# Product_68224
# Product_23539
# Product_60141
# Product_12168
# Product_21038
# Product_23621
# Product_69757
# Product_70898
# Product_33928
# Product_18221
# Product_60243
# Product_35465
# Product_78199
# Product_8779
# Product_8451
# Product_65396
# Product_14414
# Product_64782
# Product_41378
# Product_65090
# Product_34471
# Product_47258
# Product_21294
# Product_76584
# Product_7271
# Product_74713
# Product_7135
# Product_40753
# Product_82337
# Product_78758
# Product_50528
# Product_62785
# Product_60971
# Product_17587
# Product_77053
# Product_57216
# Product_43363
# Product_14384
# Product_49201
# Product_51076
# Product_41579
# Product_77558
# Product_11969
# Product_63715
# Product_78650
# Product_71592
# Product_31027
# Product_21196
# Product_1545
# Product_62112
# Product_64016
# Product_20995
# Product_1255
# Product_53783
# Product_33216
# Product_37551
# Product_78104
# Product_54022
# Product_80549
# Product_70217
# Product_48045
# Product_64231
# Product_70963
# Product_17712
# Product_36702
# Product_52244
# Product_81345
# Product_26089
# Product_59227
# Product_82219
# Product_44315
# Product_74252
# Product_5035
# Product_4564
# Product_24531
# Product_77408
# Product_27623
# Product_71229
# Product_81569
# Product_33843
# Product_69227
# Product_57812
# Product_62347
# Product_8103
# Product_8652
# Product_19112
# Product_38612
# Product_2058
# Product_74457
# Product_44461
# Product_77935
# Product_29642
# Product_14660
# Product_64743
# Product_38602
# Product_65235
# Product_61507
# Product_33485
# Product_20445
# Product_77332
# Product_40350
# Product_80175
# Product_6084
# Product_27441
# Product_10298
# Product_60382
# Product_68518
# Product_8219
# Product_18741
# Product_3414
# Product_80318
# Product_35590
# Product_18660
# Product_47776
# Product_12042
# Product_7661
# Product_63538
# Product_58636
# Product_30447
# Product_54610
# Product_7231
# Product_31016
# Product_27460
# Product_16370
# Product_80659
# Product_60697
# Product_18645
# Product_1602
# Product_10338
# Product_61475
# Product_375
# Product_47454
# Product_39322
# Product_27984
# Product_74210
# Product_12635
# Product_56368
# Product_54762
# Product_40625
# Product_752
# Product_22717
# Product_13612
# Product_9433
# Product_19909
# Product_16788
# Product_114
# Product_60530
# Product_47248
# Product_36475
# Product_42880
# Product_56521
# Product_39080
# Product_41857
# Product_68125
# Product_59587
# Product_7079
# Product_11631
# Product_8647
# Product_29553
# Product_9970
# Product_6796
# Product_30018
# Product_34954
# Product_48659
# Product_63010
# Product_26807
# Product_58852
# Product_50837
# Product_10611
# Product_53400
# Product_8006
# Product_77670
# Product_34739
# Product_67242
# Product_68880
# Product_79883
# Product_16403
# Product_57026
# Product_74446
# Product_14920
# Product_49928
# Product_49483
# Product_48066
# Product_41375
# Product_31005
# Product_34915
# Product_14443
# Product_48562
# Product_7955
# Product_71304
# Product_42337
# Product_16899
# Product_47421
# Product_53649
# Product_57634
# Product_74816
# Product_19057
# Product_25136
# Product_44266
# Product_21850
# Product_30053
# Product_62333
# Product_12854
# Product_32329
# Product_43196
# Product_22530
# Product_60765
# Product_38482
# Product_78746
# Product_18952
# Product_40870
# Product_32005
# Product_38950
# Product_72948
# Product_26340
# Product_15025
# Product_74614
# Product_74209
# Product_2914
# Product_55134
# Product_72446
# Product_24527
# Product_74630
# Product_68578
# Product_34278
# Product_39992
# Product_52327
# Product_40740
# Product_22470
# Product_30618
# Product_82188
# Product_48761
# Product_50387
# Product_63851
# Product_76329
# Product_22412
# Product_36837
# Product_30617
# Product_26680
# Product_11505
# Product_4641
# Product_62700
# Product_45831
# Product_4746
# Product_31969
# Product_59590
# Product_38754
# Product_4406
# Product_2230
# Product_40427
# Product_7146
# Product_55029
# Product_79392
# Product_1015
# Product_18501
# Product_58070
# Product_25992
# Product_27516
# Product_55414
# Product_15966
# Product_59424
# Product_59462
# Product_53592
# Product_15398
# Product_24878
# Product_71890
# Product_27930
# Product_70766
# Product_9012
# Product_3605
# Product_47019
# Product_50502
# Product_23401
# Product_72176
# Product_29544
# Product_51847
# Product_38085
# Product_10440
# Product_39612
# Product_61928
# Product_12838
# Product_72484
# Product_9546
# Product_6085
# Product_68436
# Product_9957
# Product_55789
# Product_18998
# Product_5881
# Product_18458
# Product_70728
# Product_50611
# Product_11744
# Product_43197
# Product_12084
# Product_57575
# Product_36469
# Product_2435
# Product_33844
# Product_76910
# Product_43365
# Product_4404
# Product_52629
# Product_14012
# Product_49900
# Product_14734
# Product_3706
# Product_12674
# Product_29047
# Product_74896
# Product_24768
# Product_20498
# Product_63827
# Product_8813
# Product_9506
# Product_35777
# Product_73822
# Product_71194
# Product_1152
# Product_1982
# Product_29549
# Product_33042
# Product_11490
# Product_54583
# Product_30108
# Product_5790
# Product_40487
# Product_7465
# Product_71104
# Product_72552
# Product_59500
# Product_29085
# Product_70755
# Product_24598
# Product_31024
# Product_76615
# Product_42571
# Product_21677
# Product_57877
# Product_56209
# Product_46668
# Product_80667
# Product_16895
# Product_44303
# Product_49690
# Product_53432
# Product_66056
# Product_2891
# Product_7841
# Product_78502
# Product_22390
# Product_4357
# Product_37182
# Product_51022
# Product_26854
# Product_17663
# Product_64675
# Product_80711
# Product_44741
# Product_13288
# Product_23798
# Product_67571
# Product_38726
# Product_37524
# Product_18867
# Product_78423
# Product_10949
# Product_54915
# Product_82749
# Product_58892
# Product_23987
# Product_31897
# Product_30226
# Product_61430
# Product_26377
# Product_59980
# Product_6203
# Product_31025
# Product_13482
# Product_57865
# Product_2692
# Product_21440
# Product_39879
# Product_54112
# Product_25851
# Product_18842
# Product_23636
# Product_61164
# Product_36643
# Product_26452
# Product_55346
# Product_27458
# Product_26826
# Product_21719
# Product_66894
# Product_21577
# Product_40806
# Product_42028
# Product_29399
# Product_4629
# Product_19731
# Product_47265
# Product_48498
# Product_42505
# Product_42883
# Product_82550
# Product_31301
# Product_78383
# Product_48906
# Product_28766
# Product_80616
# Product_38333
# Product_68431
# Product_35697
# Product_63992
# Product_3078
# Product_33191
# Product_6768
# Product_26589
# Product_44739
# Product_18814
# Product_35125
# Product_18029
# Product_60003
# Product_54809
# Product_54858
# Product_9943
# Product_14196
# Product_38277
# Product_65028
# Product_62797
# Product_7424
# Product_57532
# Product_76846
# Product_75045
# Product_15873
# Product_24103
# Product_58763
# Product_48542
# Product_65109
# Product_17526
# Product_63949
# Product_18118
# Product_67324
# Product_7033
# Product_56595
# Product_48636
# Product_52849
# Product_814
# Product_56558
# Product_75345
# Product_6294
# Product_11746
# Product_42888
# Product_79231
# Product_35940
# Product_63189
# Product_62190
# Product_17969
# Product_70104
# Product_61055
# Product_18997
# Product_62016
# Product_53636
# Product_81983
# Product_66081
# Product_41969
# Product_72359
# Product_50300
# Product_63014
# Product_24639
# Product_68105
# Product_28699
# Product_54810
# Product_28341
# Product_51819
# Product_52346
# Product_12577
# Product_21740
# Product_75269
# Product_54317
# Product_60773
# Product_39039
# Product_60318
# Product_78268
# Product_23793
# Product_61336
# Product_77741
# Product_56695
# Product_69235
# Product_48350
# Product_27794
# Product_68461
# Product_10508
# Product_14275
# Product_40902
# Product_36605
# Product_34842
# Product_38065
# Product_64783
# Product_56882
# Product_22107
# Product_19737
# Product_49381
# Product_35904
# Product_30038
# Product_58520
# Product_53367
# Product_32945
# Product_122
# Product_1840
# Product_27447
# Product_48640
# Product_1167
# Product_37272
# Product_63216
# Product_14235
# Product_32405
# Product_7688
# Product_42048
# Product_79287
# Product_57431
# Product_39674
# Product_23119
# Product_22374
# Product_46422
# Product_43763
# Product_58874
# Product_21344
# Product_54227
# Product_78120
# Product_28612
# Product_44401
# Product_7257
# Product_28566
# Product_7851
# Product_76127
# Product_66763
# Product_60639
# Product_18807
# Product_34186
# Product_76322
# Product_72235
# Product_54247
# Product_17229
# Product_50618
# Product_8279
# Product_42499
# Product_5704
# Product_42351
# Product_35116
# Product_52136
# Product_62801
# Product_43397
# Product_49181
# Product_32759
# Product_66136
# Product_36811
# Product_31112
# Product_53068
# Product_4922
# Product_50730
# Product_334
# Product_58648
# Product_55280
# Product_57890
# Product_74715
# Product_73692
# Product_26832
# Product_64206
# Product_22849
# Product_14695
# Product_1877
# Product_27509
# Product_14819
# Product_76435
# Product_55589
# Product_42065
# Product_13006
# Product_18625
# Product_72245
# Product_65078
# Product_25737
# Product_54104
# Product_48730
# Product_62589
# Product_20604
# Product_74298
# Product_58635
# Product_38610
# Product_60418
# Product_29612
# Product_9467
# Product_41950
# Product_29659
# Product_22251
# Product_66244
# Product_60818
# Product_69731
# Product_4016
# Product_4068
# Product_39994
# Product_79689
# Product_38757
# Product_49531
# Product_48098
# Product_6812
# Product_78911
# Product_26117
# Product_76297
# Product_6417
# Product_40696
# Product_69317
# Product_69553
# Product_44205
# Product_8224
# Product_69979
# Product_15991
# Product_25212
# Product_61585
# Product_13807
# Product_42676
# Product_26357
# Product_45075
# Product_27919
# Product_62539
# Product_14664
# Product_57667
# Product_17682
# Product_71213
# Product_56017
# Product_60026
# Product_49200
# Product_59782
# Product_65426
# Product_12702
# Product_32507
# Product_30517
# Product_14178
# Product_16376
# Product_30815
# Product_52002
# Product_75858
# Product_5794
# Product_46155
# Product_9349
# Product_63525
# Product_14653
# Product_77057
# Product_23835
# Product_41697
# Product_27731
# Product_74265
# Product_61494
# Product_61409
# Product_45239
# Product_71522
# Product_75376
# Product_22994
# Product_65947
# Product_80513
# Product_28221
# Product_49267
# Product_72059
# Product_7136
# Product_43801
# Product_40438
# Product_12633
# Product_74949
# Product_7266
# Product_41654
# Product_61111
# Product_70914
# Product_12978
# Product_28241
# Product_63876
# Product_62178
# Product_66257
# Product_16649
# Product_41978
# Product_65100
# Product_58002
# Product_77920
# Product_27857
# Product_50620
# Product_5283
# Product_51889
# Product_22348
# Product_17173
# Product_503
# Product_52378
# Product_45265
# Product_51362
# Product_76698
# Product_17574
# Product_1172
# Product_19951
# Product_69361
# Product_65453
# Product_32036
# Product_73713
# Product_33348
# Product_35126
# Product_36847
# Product_46301
# Product_42928
# Product_30864
# Product_77574
# Product_32862
# Product_74747
# Product_20754
# Product_71272
# Product_41989
# Product_2219
# Product_64094
# Product_52802
# Product_48897
# Product_28653
# Product_63953
# Product_82067
# Product_37139
# Product_46104
# Product_57861
# Product_42084
# Product_51157
# Product_20437
# Product_18884
# Product_31624
# Product_15296
# Product_39553
# Product_54932
# Product_3952
# Product_14108
# Product_61324
# Product_54037
# Product_9604
# Product_47513
# Product_35205
# Product_42974
# Product_8771
# Product_17330
# Product_80358
# Product_48680
# Product_76178
# Product_23415
# Product_351
# Product_17748
# Product_64832
# Product_16964
# Product_67152
# Product_74951
# Product_75206
# Product_23167
# Product_30083
# Product_29893
# Product_59334
# Product_62051
# Product_73971
# Product_32365
# Product_22758
# Product_79076
# Product_56883
# Product_82381
# Product_33208
# Product_56371
# Product_66385
# Product_4755
# Product_38383
# Product_7554
# Product_24491
# Product_12804
# Product_22985
# Product_70598
# Product_16211
# Product_13264
# Product_67753
# Product_960
# Product_31663
# Product_878
# Product_54178
# Product_51986
# Product_43771
# Product_81892
# Product_47345
# Product_20615
# Product_53542
# Product_50779
# Product_82103
# Product_81011
# Product_11343
# Product_35408
# Product_19513
# Product_48439
# Product_82212
# Product_61772
# Product_79436
# Product_47558
# Product_77380
# Product_36770
# Product_5760
# Product_23533
# Product_48632
# Product_43803
# Product_76376
# Product_35374
# Product_19481
# Product_10957
# Product_49499
# Product_38982
# Product_45454
# Product_69851
# Product_42403
# Product_59250
# Product_52761
# Product_214
# Product_13883
# Product_71628
# Product_47764
# Product_54525
# Product_14511
# Product_38003
# Product_24095
# Product_62958
# Product_8090
# Product_76668
# Product_54257
# Product_81377
# Product_24029
# Product_75670
# Product_60785
# Product_28463
# Product_68933
# Product_31780
# Product_40774
# Product_41960
# Product_32963
# Product_18509
# Product_19618
# Product_17347
# Product_40586
# Product_51902
# Product_64618
# Product_68165
# Product_14056
# Product_78856
# Product_34704
# Product_20253
# Product_61305
# Product_55591
# Product_5384
# Product_15988
# Product_34415
# Product_29133
# Product_63893
# Product_49769
# Product_2721
# Product_1011
# Product_34678
# Product_46746
# Product_6662
# Product_36583
# Product_48311
# Product_9074
# Product_6642
# Product_7330
# Product_16980
# Product_19266
# Product_35826
# Product_72630
# Product_15825
# Product_74860
# Product_25618
# Product_30039
# Product_36158
# Product_21376
# Product_43466
# Product_17405
# Product_65836
# Product_29687
# Product_40403
# Product_41227
# Product_35885
# Product_59000
# Product_53519
# Product_45460
# Product_24978
# Product_60291
# Product_33338
# Product_6160
# Product_33473
# Product_26152
# Product_73973
# Product_6701
# Product_25883
# Product_21593
# Product_77385
# Product_23983
# Product_61108
# Product_53697
# Product_66170
# Product_79447
# Product_56165
# Product_66058
# Product_69318
# Product_58932
# Product_31651
# Product_4740
# Product_80091
# Product_918
# Product_72398
# Product_23931
# Product_4495
# Product_56015
# Product_16544
# Product_38474
# Product_34508
# Product_79432
# Product_60391
# Product_16452
# Product_61647
# Product_38691
# Product_81188
# Product_80414
# Product_35926
# Product_75146
# Product_13293
# Product_69288
# Product_39543
# Product_47912
# Product_37763
# Product_55606
# Product_67212
# Product_1334
# Product_75664
# Product_58474
# Product_26232
# Product_53326
# Product_77236
# Product_4448
# Product_55805
# Product_42197
# Product_43736
# Product_816
# Product_865
# Product_36256
# Product_30163
# Product_32855
# Product_30510
# Product_64944
# Product_78612
# Product_28379
# Product_27483
# Product_923
# Product_62540
# Product_39086
# Product_21392
# Product_70771
# Product_55110
# Product_2997
# Product_61921
# Product_44808
# Product_48945
# Product_50208
# Product_76587
# Product_34114
# Product_70557
# Product_54140
# Product_61511
# Product_77504
# Product_48581
# Product_21248
# Product_67916
# Product_12712
# Product_32000
# Product_82709
# Product_20271
# Product_53772
# Product_14635
# Product_80153
# Product_2468
# Product_41617
# Product_39058
# Product_36599
# Product_9030
# Product_12747
# Product_53403
# Product_12311
# Product_48190
# Product_10266
# Product_33198
# Product_52729
# Product_66750
# Product_22568
# Product_21257
# Product_14932
# Product_39577
# Product_33947
# Product_47116
# Product_69749
# Product_81642
# Product_23827
# Product_64096
# Product_44334
# Product_28702
# Product_74310
# Product_55756
# Product_66382
# Product_23592
# Product_42972
# Product_34010
# Product_4760
# Product_74149
# Product_64633
# Product_65706
# Product_3984
# Product_55120
# Product_9151
# Product_19199
# Product_50804
# Product_81588
# Product_12399
# Product_48179
# Product_21871
# Product_15982
# Product_80673
# Product_26479
# Product_57038
# Product_71091
# Product_8339
# Product_28984
# Product_22040
# Product_24386
# Product_44025
# Product_38875
# Product_72027
# Product_49175
# Product_68377
# Product_31924
# Product_69638
# Product_72071
# Product_50367
# Product_40232
# Product_466
# Product_31366
# Product_22267
# Product_2762
# Product_17902
# Product_172
# Product_82105
# Product_67769
# Product_50157
# Product_57961
# Product_37707
# Product_7487
# Product_26529
# Product_75513
# Product_38040
# Product_24028
# Product_59892
# Product_51283
# Product_56204
# Product_9713
# Product_2287
# Product_63047
# Product_15618
# Product_71384
# Product_39834
# Product_2235
# Product_82065
# Product_74513
# Product_55466
# Product_25155
# Product_35998
# Product_69581
# Product_20756
# Product_61255
# Product_26798
# Product_54072
# Product_62940
# Product_7966
# Product_74905
# Product_54170
# Product_3925
# Product_68797
# Product_55628
# Product_42098
# Product_31805
# Product_57047
# Product_20426
# Product_61471
# Product_46575
# Product_23763
# Product_66256
# Product_70822
# Product_63744
# Product_43742
# Product_40601
# Product_45520
# Product_853
# Product_4622
# Product_6347
# Product_5678
# Product_17752
# Product_8173
# Product_22014
# Product_60101
# Product_7285
# Product_69159
# Product_7944
# Product_39158
# Product_77630
# Product_24378
# Product_51346
# Product_48301
# Product_71904
# Product_69859
# Product_55009
# Product_29541
# Product_2304
# Product_35378
# Product_39841
# Product_35613
# Product_82459
# Product_39378
# Product_4288
# Product_68345
# Product_50504
# Product_4420
# Product_26169
# Product_53699
# Product_80217
# Product_28746
# Product_3852
# Product_58662
# Product_40700
# Product_952
# Product_37218
# Product_76477
# Product_1394
# Product_30406
# Product_53953
# Product_6031
# Product_52790
# Product_6721
# Product_80814
# Product_3535
# Product_64670
# Product_68833
# Product_26911
# Product_28102
# Product_61323
# Product_62199
# Product_4558
# Product_15757
# Product_20786
# Product_46396
# Product_33507
# Product_53272
# Product_24890
# Product_27525
# Product_24672
# Product_35948
# Product_5490
# Product_55931
# Product_69840
# Product_37819
# Product_43851
# Product_82414
# Product_9574
# Product_60027
# Product_15423
# Product_48737
# Product_2120
# Product_43428
# Product_71924
# Product_33016
# Product_6997
# Product_42305
# Product_25019
# Product_24460
# Product_47164
# Product_43501
# Product_50474
# Product_82311
# Product_35741
# Product_79988
# Product_50402
# Product_3864
# Product_20785
# Product_63299
# Product_56667
# Product_71780
# Product_80682
# Product_64380
# Product_43894
# Product_23279
# Product_23249
# Product_67074
# Product_23145
# Product_23072
# Product_60749
# Product_76020
# Product_55436
# Product_38342
# Product_57918
# Product_25607
# Product_18172
# Product_65592
# Product_41329
# Product_46362
# Product_82040
# Product_65811
# Product_38984
# Product_18116
# Product_61767
# Product_23315
# Product_42286
# Product_21674
# Product_49890
# Product_79285
# Product_36357
# Product_29533
# Product_38786
# Product_61266
# Product_42638
# Product_27547
# Product_18249
# Product_74515
# Product_31484
# Product_33181
# Product_17177
# Product_54980
# Product_14551
# Product_22314
# ...
# Product_38735
# Product_41823
# Product_42958
# Product_10560
# Product_44046
# Product_57219
# Product_45452
# Product_18064
# Product_15882
# Product_12750
# Product_15359
# Product_22970
# Product_32473
# Product_10495
# Product_2312
# Product_74263
# Product_66060
# Product_39283
# Product_249
# Product_27638
# Product_72722
# Product_68065
# Product_55584
# Product_60690
# Product_1755
# Product_11954
# Product_9203
# Product_67078
# Product_61937
# Product_39199
# Product_12324
# Product_37191
# Product_71102
# Product_13636
# Product_28865
# Product_37472
# Product_8679
# Product_46111
# Product_31021
# Product_37386
# Product_80415
# Product_77616
# Product_5524
# Product_21779
# Product_58188
# Product_56845
# Product_4374
# Product_11985
# Product_35254
# Product_44727
# Product_65830
# Product_77082
# Product_9618
# Product_1551
# Product_53039
# Product_18961
# Product_61552
# Product_52448
# Product_45786
# Product_21788
# Product_28006
# Product_28453
# Product_32184
# Product_40973
# Product_7089
# Product_69471
# Product_58471
# Product_81601
# Product_40081
# Product_9410
# Product_29073
# Product_51016
# Product_73758
# Product_23351
# Product_42745
# Product_2996
# Product_61561
# Product_64636
# Product_43745
# Product_55485
# Product_34885
# Product_57355
# Product_17124
# Product_43352
# Product_78284
# Product_79507
# Product_64922
# Product_52010
# Product_52735
# Product_7233
# Product_78691
# Product_35373
# Product_44418
# Product_12791
# Product_10824
# Product_22885
# Product_21848
# Product_65115
# Product_34001
# Product_28873
# Product_52560
# Product_79697
# Product_41821
# Product_33675
# Product_40214
# Product_12840
# Product_60070
# Product_8891
# Product_5821
# Product_19259
# Product_64659
# Product_70772
# Product_5527
# Product_38795
# Product_81527
# Product_31177
# Product_69154
# Product_19632
# Product_1296
# Product_17036
# Product_39201
# Product_51480
# Product_18628
# Product_61531
# Product_51015
# Product_38600
# Product_26168
# Product_37681
# Product_40224
# Product_8955
# Product_64514
# Product_77386
# Product_57040
# Product_77031
# Product_63505
# Product_58711
# Product_82585
# Product_57421
# Product_9008
# Product_33713
# Product_44715
# Product_71075
# Product_80635
# Product_49136
# Product_52374
# Product_65363
# Product_60386
# Product_61396
# Product_50378
# Product_35912
# Product_27083
# Product_13266
# Product_61489
# Product_79402
# Product_1453
# Product_80527
# Product_28171
# Product_18474
# Product_78524
# Product_16221
# Product_29163
# Product_37154
# Product_12578
# Product_18567
# Product_2458
# Product_56485
# Product_76731
# Product_46455
# Product_24279
# Product_2196
# Product_33138
# Product_55760
# Product_39490
# Product_29564
# Product_571
# Product_32112
# Product_41509
# Product_22595
# Product_50443
# Product_80742
# Product_80650
# Product_37843
# Product_77090
# Product_10108
# Product_49939
# Product_49006
# Product_67105
# Product_16822
# Product_16799
# Product_75053
# Product_75646
# Product_46539
# Product_10607
# Product_53886
# Product_17046
# Product_73172
# Product_71915
# Product_17987
# Product_51145
# Product_37589
# Product_49602
# Product_46284
# Product_60738
# Product_25866
# Product_51911
# Product_71053
# Product_75617
# Product_33692
# Product_30151
# Product_63850
# Product_48895
# Product_27596
# Product_59732
# Product_63927
# Product_42922
# Product_72264
# Product_7723
# Product_28160
# Product_58599
# Product_69419
# Product_64065
# Product_43953
# Product_65460
# Product_4430
# Product_54707
# Product_57494
# Product_82315
# Product_52916
# Product_52557
# Product_73804
# Product_17385
# Product_22789
# Product_63617
# Product_62263
# Product_64412
# Product_6117
# Product_5563
# Product_46810
# Product_7305
# Product_37119
# Product_30731
# Product_64411
# Product_42992
# Product_64349
# Product_27484
# Product_318
# Product_43134
# Product_9536
# Product_43912
# Product_21473
# Product_21496
# Product_66127
# Product_15421
# Product_49328
# Product_9530
# Product_39851
# Product_18305
# Product_60813
# Product_7308
# Product_57957
# Product_14017
# Product_82636
# Product_38318
# Product_6313
# Product_52982
# Product_30437
# Product_68439
# Product_65644
# Product_60963
# Product_31646
# Product_43795
# Product_5273
# Product_3467
# Product_5154
# Product_8620
# Product_44109
# Product_41165
# Product_59182
# Product_57607
# Product_21808
# Product_10664
# Product_72174
# Product_40929
# Product_39536
# Product_68091
# Product_35658
# Product_81844
# Product_62094
# Product_23885
# Product_62772
# Product_26793
# Product_24139
# Product_4435
# Product_19302
# Product_79089
# Product_31059
# Product_31866
# Product_81225
# Product_15187
# Product_28202
# Product_48103
# Product_15475
# Product_72158
# Product_12628
# Product_73783
# Product_2391
# Product_63083
# Product_74915
# Product_21305
# Product_44680
# Product_75628
# Product_42906
# Product_9520
# Product_49434
# Product_31399
# Product_49425
# Product_37043
# Product_32612
# Product_68713
# Product_74364
# Product_76335
# Product_14736
# Product_19533
# Product_31600
# Product_44316
# Product_76677
# Product_47033
# Product_56147
# Product_1696
# Product_66166
# Product_45858
# Product_47605
# Product_25826
# Product_59981
# Product_26367
# Product_68455
# Product_82633
# Product_21837
# Product_38916
# Product_62817
# Product_9709
# Product_23834
# Product_33972
# Product_17787
# Product_26923
# Product_24328
# Product_57838
# Product_52616
# Product_74726
# Product_75516
# Product_1203
# Product_22048
# Product_74293
# Product_34400
# Product_11020
# Product_54108
# Product_47382
# Product_12737
# Product_20789
# Product_45918
# Product_76243
# Product_50508
# Product_22197
# Product_3019
# Product_55625
# Product_31936
# Product_46917
# Product_31506
# Product_70396
# Product_65505
# Product_12852
# Product_75056
# Product_20716
# Product_60213
# Product_70245
# Product_34246
# Product_39607
# Product_74305
# Product_65356
# Product_39922
# Product_24124
# Product_73580
# Product_67314
# Product_45249
# Product_1316
# Product_12310
# Product_79157
# Product_29507
# Product_1834
# Product_59329
# Product_63935
# Product_76878
# Product_33953
# Product_6536
# Product_43335
# Product_49503
# Product_49194
# Product_30328
# Product_6278
# Product_17231
# Product_79435
# Product_4666
# Product_79616
# Product_30457
# Product_70390
# Product_8472
# Product_59864
# Product_9408
# Product_49843
# Product_67906
# Product_68018
# Product_70587
# Product_42786
# Product_482
# Product_67109
# Product_153
# Product_39569
# Product_66521
# Product_21513
# Product_64517
# Product_30620
# Product_52800
# Product_59740
# Product_70892
# Product_49568
# Product_49560
# Product_75572
# Product_31395
# Product_81968
# Product_73072
# Product_52938
# Product_35082
# Product_30686
# Product_31526
# Product_1251
# Product_31710
# Product_18322
# Product_18149
# Product_64251
# Product_13305
# Product_33339
# Product_59354
# Product_48010
# Product_19115
# Product_48262
# Product_17896
# Product_69880
# Product_54896
# Product_8529
# Product_45048
# Product_2650
# Product_7450
# Product_40397
# Product_8796
# Product_43504
# Product_15898
# Product_17196
# Product_46130
# Product_47781
# Product_5653
# Product_71180
# Product_15552
# Product_35866
# Product_32982
# Product_82488
# Product_17166
# Product_7143
# Product_23036
# Product_76771
# Product_50893
# Product_10137
# Product_18304
# Product_61606
# Product_5853
# Product_7983
# Product_8823
# Product_44676
# Product_78928
# Product_60283
# Product_33711
# Product_82475
# Product_56597
# Product_6739
# Product_38241
# Product_570
# Product_81379
# Product_36307
# Product_14444
# Product_55736
# Product_80977
# Product_16348
# Product_72458
# Product_81876
# Product_30489
# Product_22434
# Product_34119
# Product_53336
# Product_59786
# Product_61138
# Product_6067
# Product_16052
# Product_58271
# Product_25367
# Product_80106
# Product_14987
# Product_14160
# Product_846
# Product_80973
# Product_74137
# Product_36417
# Product_63293
# Product_28816
# Product_38416
# Product_6995
# Product_3677
# Product_71506
# Product_10919
# Product_36494
# Product_28845
# Product_2801
# Product_36800
# Product_15160
# Product_108
# Product_15541
# Product_51907
# Product_59687
# Product_17092
# Product_28957
# Product_48274
# Product_25131
# Product_5169
# Product_28382
# Product_72438
# Product_25002
# Product_40809
# Product_62401
# Product_29209
# Product_54434
# Product_69861
# Product_17399
# Product_35246
# Product_16620
# Product_47292
# Product_63316
# Product_19389
# Product_75160
# Product_17607
# Product_4271
# Product_64640
# Product_23422
# Product_8605
# Product_52024
# Product_29919
# Product_48794
# Product_38802
# Product_291
# Product_20557
# Product_52919
# Product_45599
# Product_29179
# Product_70127
# Product_33304
# Product_44935
# Product_67073
# Product_54039
# Product_65585
# Product_49171
# Product_82282
# Product_40111
# Product_51424
# Product_52164
# Product_719
# Product_47824
# Product_69688
# Product_17417
# Product_70383
# Product_36639
# Product_33333
# Product_56423
# Product_69018
# Product_62720
# Product_9402
# Product_65587
# Product_577
# Product_22778
# Product_25908
# Product_6153
# Product_47009
# Product_54226
# Product_20228
# Product_57864
# Product_75520
# Product_70500
# Product_36504
# Product_47542
# Product_3782
# Product_38053
# Product_5245
# Product_37369
# Product_7423
# Product_59563
# Product_81480
# Product_12363
# Product_1111
# Product_69870
# Product_5959
# Product_39743
# Product_72802
# Product_64872
# Product_78000
# Product_3233
# Product_68148
# Product_24847
# Product_74140
# Product_64526
# Product_29587
# Product_66768
# Product_79330
# Product_47907
# Product_56994
# Product_667
# Product_55888
# Product_17532
# Product_50040
# Product_42149
# Product_35508
# Product_8059
# Product_726
# Product_44789
# Product_49782
# Product_12058
# Product_55151
# Product_61408
# Product_47580
# Product_32839
# Product_29983
# Product_38144
# Product_8206
# Product_22835
# Product_67014
# Product_64083
# Product_51994
# Product_66368
# Product_5536
# Product_52083
# Product_6815
# Product_15028
# Product_65639
# Product_38202
# Product_6667
# Product_75769
# Product_44052
# Product_28214
# Product_3672
# Product_13931
# Product_76429
# Product_14452
# Product_7481
# Product_71387
# Product_62906
# Product_68531
# Product_1480
# Product_39928
# Product_33666
# Product_54191
# Product_57141
# Product_56127
# Product_82784
# Product_14028
# Product_54053
# Product_59791
# Product_13426
# Product_40317
# Product_61563
# Product_65501
# Product_32946
# Product_49054
# Product_41094
# Product_43341
# Product_21822
# Product_42681
# Product_5239
# Product_35716
# Product_44221
# Product_5469
# Product_62619
# Product_31052
# Product_47847
# Product_41043
# Product_72711
# Product_56586
# Product_13652
# Product_9687
# Product_12763
# Product_76588
# Product_2520
# Product_76955
# Product_39795
# Product_79333
# Product_3796
# Product_42869
# Product_18115
# Product_30614
# Product_56150
# Product_4736
# Product_38504
# Product_76785
# Product_74516
# Product_61994
# Product_41307
# Product_35500
# Product_53376
# Product_78798
# Product_52302
# Product_55538
# Product_5869
# Product_74
# Product_28705
# Product_4038
# Product_41924
# Product_32515
# Product_22424
# Product_32955
# Product_17687
# Product_36352
# Product_21899
# Product_7269
# Product_49160
# Product_75180
# Product_54971
# Product_21564
# Product_4951
# Product_23013
# Product_67975
# Product_15789
# Product_47850
# Product_70565
# Product_2951
# Product_7138
# Product_61884
# Product_53616
# Product_53880
# Product_59679
# Product_16843
# Product_11202
# Product_40900
# Product_20252
# Product_81473
# Product_50045
# Product_52681
# Product_10586
# Product_333
# Product_21320
# Product_29001
# Product_35079
# Product_28927
# Product_46110
# Product_36036
# Product_48267
# Product_63632
# Product_43636
# Product_27481
# Product_27369
# Product_73030
# Product_7458
# Product_11468
# Product_68964
# Product_22160
# Product_73793
# Product_35701
# Product_43513
# Product_36134
# Product_52422
# Product_69047
# Product_44291
# Product_9647
# Product_5134
# Product_50692
# Product_17683
# Product_55803
# Product_40709
# Product_37554
# Product_64388
# Product_79918
# Product_15598
# Product_73234
# Product_36915
# Product_47389
# Product_42206
# Product_60825
# Product_47340
# Product_65001
# Product_811
# Product_61759
# Product_29855
# Product_6964
# Product_75838
# Product_11047
# Product_30175
# Product_28685
# Product_35572
# Product_68928
# Product_9755
# Product_28297
# Product_44247
# Product_36979
# Product_8908
# Product_81676
# Product_31084
# Product_29696
# Product_42761
# Product_82134
# Product_23679
# Product_14526
# Product_50617
# Product_2190
# Product_45507
# Product_81421
# Product_18266
# Product_39815
# Product_18856
# Product_1721
# Product_69948
# Product_31453
# Product_58664
# Product_27171
# Product_27556
# Product_77513
# Product_394
# Product_44183
# Product_62662
# Product_57229
# Product_41752
# Product_55088
# Product_21767
# Product_18909
# Product_38821
# Product_55815
# Product_23111
# Product_24074
# Product_61043
# Product_20338
# Product_28528
# Product_45374
# Product_34181
# Product_40188
# Product_78304
# Product_62203
# Product_74062
# Product_22792
# Product_19284
# Product_2153
# Product_20702
# Product_77974
# Product_4557
# Product_10214
# Product_25489
# Product_34112
# Product_19270
# Product_14610
# Product_46631
# Product_33426
# Product_38381
# Product_24448
# Product_8956
# Product_38940
# Product_39088
# Product_17149
# Product_49504
# Product_59694
# Product_67527
# Product_51569
# Product_40907
# Product_67415
# Product_54730
# Product_17593
# Product_40330
# Product_13720
# Product_9215
# Product_1942
# Product_78247
# Product_45308
# Product_51446
# Product_73924
# Product_23750
# Product_19230
# Product_2613
# Product_51921
# Product_81764
# Product_42707
# Product_45289
# Product_34391
# Product_62407
# Product_57758
# Product_54158
# Product_7072
# Product_46695
# Product_54780
# Product_14106
# Product_21953
# Product_34038
# Product_49190
# Product_45252
# Product_76471
# Product_63931
# Product_44840
# Product_42365
# Product_28347
# Product_10544
# Product_38233
# Product_45712
# Product_20696
# Product_71556
# Product_16998
# Product_76806
# Product_10023
# Product_64853
# Product_47546
# Product_52269
# Product_19648
# Product_32994
# Product_15110
# Product_73733
# Product_33101
# Product_18931
# Product_25703
# Product_44194
# Product_33227
# Product_26072
# Product_2487
# Product_75448
# Product_72949
# Product_7934
# Product_58266
# Product_61404
# Product_1729
# Product_37210
# Product_44701
# Product_74317
# Product_49955
# Product_1990
# Product_5278
# Product_27738
# Product_73086
# Product_29912
# Product_66492
# Product_57920
# Product_74819
# Product_17805
# Product_32966
# Product_9912
# Product_61330
# Product_77268
# Product_47989
# Product_37424
# Product_37356
# Product_35091
# Product_52817
# Product_50159
# Product_43535
# Product_29781
# Product_16053
# Product_54464
# Product_45219
# Product_59595
# Product_69819
# Product_15671
# Product_65222
# Product_29470
# Product_23045
# Product_79737
# Product_20021
# Product_45546
# Product_62749
# Product_59224
# Product_18073
# Product_81333
# Product_9904
# Product_50430
# Product_1793
# Product_62484
# Product_26429
# Product_65657
# Product_39846
# Product_14162
# Product_70021
# Product_44440
# Product_62418
# Product_47765
# Product_34373
# Product_25719
# Product_50815
# Product_12360
# Product_60758
# Product_53669
# Product_80836
# Product_28440
# Product_56959
# Product_52677
# Product_67294
# Product_22071
# Product_2930
# Product_82706
# Product_40932
# Product_32969
# Product_46619
# Product_68062
# Product_65470
# Product_62083
# Product_77673
# Product_33648
# Product_12937
# Product_3122
# Product_35608
# Product_419
# Product_64221
# Product_69005
# Product_6947
# Product_67729
# Product_32192
# Product_12503
# Product_62705
# Product_81836
# Product_21120
# Product_71761
# Product_14310
# Product_75403
# Product_75123
# Product_63019
# Product_78344
# Product_27721
# Product_67200
# Product_9166
# Product_6227
# Product_15241
# Product_56462
# Product_29699
# Product_31264
# Product_46913
# Product_10888
# Product_50710
# Product_38973
# Product_26313
# Product_51142
# Product_12857
# Product_73863
# Product_43006
# Product_25328
# Product_61440
# Product_60953
# Product_23611
# Product_62270
# Product_53216
# Product_28088
# Product_80011
# Product_32819
# Product_69536
# Product_42180
# Product_40017
# Product_70068
# Product_80880
# Product_72589
# Product_54766
# Product_12498
# Product_25157
# Product_81885
# Product_1083
# Product_10044
# Product_80914
# Product_71960
# Product_28441
# Product_45430
# Product_39130
# Product_37981
# Product_17400
# Product_16772
# Product_3328
# Product_2428
# Product_58795
# Product_1929
# Product_68508
# Product_60752
# Product_28431
# Product_67206
# Product_45852
# Product_13186
# Product_10045
# Product_80222
# Product_31443
# Product_63159
# Product_32220
# Product_19576
# Product_73404
# Product_13204
# Product_81481
# Product_71835
# Product_20236
# Product_26028
# Product_58126
# Product_19802
# Product_62344
# Product_66520
# Product_76053
# Product_67621
# Product_71655
# Product_15838
# Product_68163
# Product_43962
# Product_19468
# Product_10921
# Product_74795
# Product_31339
# Product_26881
# Product_76538
# Product_41331
# Product_21766
# Product_72260
# Product_9287
# Product_62917
# Product_1388
# Product_80369
# Product_39182
# Product_66735
# Product_69056
# Product_79586
# Product_24643
# Product_62560
# Product_21142
# Product_61242
# Product_1700
# Product_43976
# Product_56287
# Product_12157
# Product_66187
# Product_15209
# Product_62687
# Product_35357
# Product_76091
# Product_79747
# Product_9070
# Product_14272
# Product_64769
# Product_71376
# Product_21576
# Product_21645
# Product_15656
# Product_55929
# Product_80292
# Product_37552
# Product_30362
# Product_25667
# Product_54934
# Product_6497
# Product_10530

# %%
missing_products_info = products_data[products_data["product_id"].isin(missing_from_train)]

# Display the missing products dataframe
missing_products_info
# Out:
#           product_id             product_description department_key  \
# 13     Product_51620    33CL LIMONADE LA BEAUCERONNE  Department_10
# 18     Product_39850  75CL LORINA LIMONADE CITRON VT  Department_10
# 19     Product_31931   75CL BEAUCERONNE CITRON GLACE  Department_10
# 20     Product_69737      0.75 L LIMO GRENADINE 1888  Department_10
# 21      Product_1433        BELVOIR CITRONNADE 750ML  Department_10
# ...              ...                             ...            ...
# 82959  Product_40278  926107 COUSSIN UNI COT ROSE TU  Department_65
# 82960  Product_57956  885558 CUSHION 4 BLANC CAS2 TU  Department_65
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 13     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 18     Class_1000  SubClass_10000                      PGC      LORINA
# 19     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 20     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 21     Class_1000  SubClass_10000                      PGC     BELVOIR
# ...           ...             ...                      ...         ...
# 82959  Class_6573  SubClass_65730                  TEXTILE    TEX HOME
# 82960  Class_6573  SubClass_65730                  TEXTILE    TEX HOME
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1                         shelf_level2  \
# 13                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 18                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 19                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 20                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 21                 Boissons  Colas, Thés glacés, Sirops et Sodas
# ...                     ...                                  ...
# 82959  Maison et Décoration               Mobilier et Décoration
# 82960  Maison et Décoration               Mobilier et Décoration
# 82961     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82963            Animalerie                               Chiens
# 82965  Maison et Décoration                    Bouteilles de gaz
#
#                              shelf_level3                     shelf_level4  \
# 13             Limonades, Limes et Tonics                              NaN
# 18             Limonades, Limes et Tonics                              NaN
# 19             Limonades, Limes et Tonics                              NaN
# 20             Limonades, Limes et Tonics                              NaN
# 21             Limonades, Limes et Tonics                              NaN
# ...                                   ...                              ...
# 82959  Décorations et Parfums d'intérieur   Coussins et galettes de chaise
# 82960  Décorations et Parfums d'intérieur   Coussins et galettes de chaise
# 82961                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82963      Colliers, Laisses et Vêtements          Vêtements et Chaussures
# 82965                                 NaN                              NaN
#
#        bio  sugar_free  aspartame_free  gluten_free  halal  casher  \
# 13       0           0               0            0      0       0
# 18       0           0               0            0      0       0
# 19       0           0               0            0      0       0
# 20       0           0               0            0      0       0
# 21       0           0               0            0      0       0
# ...    ...         ...             ...          ...    ...     ...
# 82959    0           0               0            0      0       0
# 82960    0           0               0            0      0       0
# 82961    0           0               0            0      0       0
# 82963    0           0               0            0      0       0
# 82965    0           0               0            0      0       0
#
#        eco_friendly  local_french  artificial_coloring_free  \
# 13                0             0                         0
# 18                0             0                         0
# 19                0             0                         0
# 20                0             0                         0
# 21                0             0                         0
# ...             ...           ...                       ...
# 82959             0             0                         0
# 82960             0             0                         0
# 82961             0             0                         0
# 82963             0             0                         0
# 82965             0             0                         0
#
#        taste_enhancer_free  naturality  antibiotic_free  reduced_sugar  \
# 13                       0           0                0              0
# 18                       0           0                0              0
# 19                       0           0                0              0
# 20                       0           0                0              0
# 21                       0           0                0              0
# ...                    ...         ...              ...            ...
# 82959                    0           0                0              0
# 82960                    0           0                0              0
# 82961                    0           0                0              0
# 82963                    0           0                0              0
# 82965                    0           0                0              0
#
#        vegetarian  pesticide_free  grain_free  no_added_sugar  salt_reduced  \
# 13              0               0           0               0             0
# 18              0               0           0               0             0
# 19              0               0           0               0             0
# 20              0               0           0               0             0
# 21              0               0           0               0             0
# ...           ...             ...         ...             ...           ...
# 82959           0               0           0               0             0
# 82960           0               0           0               0             0
# 82961           0               0           0               0             0
# 82963           0               0           0               0             0
# 82965           0               0           0               0             0
#
#        nitrite_free  fed_without_ogm  no_added_salt  no_artificial_flavours  \
# 13                0                0              0                       0
# 18                0                0              0                       0
# 19                0                0              0                       0
# 20                0                0              0                       0
# 21                0                0              0                       0
# ...             ...              ...            ...                     ...
# 82959             0                0              0                       0
# 82960             0                0              0                       0
# 82961             0                0              0                       0
# 82963             0                0              0                       0
# 82965             0                0              0                       0
#
#        porc  vegan  frozen  fat_free  reduced_fats  fresh  alcool  \
# 13        0      0       0         0             0      0       0
# 18        0      0       0         0             0      0       0
# 19        0      0       0         0             0      0       0
# 20        0      0       0         0             0      0       0
# 21        0      0       0         0             0      0       0
# ...     ...    ...     ...       ...           ...    ...     ...
# 82959     0      0       0         0             0      0       0
# 82960     0      0       0         0             0      0       0
# 82961     0      0       0         0             0      0       0
# 82963     0      0       0         0             0      0       0
# 82965     0      0       0         0             0      0       0
#
#        lactose_free  phenylalanine_free  palm_oil_free ecoscore  \
# 13                0                   0              0      NaN
# 18                0                   0              0      NaN
# 19                0                   0              0      NaN
# 20                0                   0              0      NaN
# 21                0                   0              0      NaN
# ...             ...                 ...            ...      ...
# 82959             0                   0              0      NaN
# 82960             0                   0              0      NaN
# 82961             0                   0              0      NaN
# 82963             0                   0              0      NaN
# 82965             0                   0              0      NaN
#
#        produits_du_monde  regional_product  national_brand  first_price_brand  \
# 13                     0                 0               1                  0
# 18                     0                 0               1                  0
# 19                     0                 1               1                  0
# 20                     0                 1               1                  0
# 21                     0                 0               1                  0
# ...                  ...               ...             ...                ...
# 82959                  0                 0               0                  0
# 82960                  0                 0               0                  0
# 82961                  0                 0               0                  0
# 82963                  0                 0               0                  0
# 82965                  0                 0               0                  0
#
#        carrefour_brand
# 13                   0
# 18                   0
# 19                   0
# 20                   0
# 21                   0
# ...                ...
# 82959                1
# 82960                1
# 82961                1
# 82963                1
# 82965                1
#
# [30324 rows x 49 columns]

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %% [markdown]
# # Negative Sampling using Embeddings

# %%
train_data
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 0        Household_20188  Product_51237         0       1.0      325      2
# 1        Household_20188  Product_32922         0       1.0      601      5
# 2        Household_20188  Product_45500         0       1.0      325      2
# 3        Household_20188  Product_16016         0       1.0      601      5
# 4        Household_20617  Product_64825         0       1.0      281      3
# ...                  ...            ...       ...       ...      ...    ...
# 8651412  Household_29503  Product_74143         0       1.0      586      5
# 8651413  Household_29503  Product_32349         0       1.0       27     12
# 8651414  Household_23691   Product_3153         0       1.0      297      3
# 8651415  Household_27440  Product_19524         0       1.0        4     12
# 8651416  Household_27440  Product_50995         0       3.0      102      9
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 0                  3           0                       283
# 1                  0           0                       559
# 2                  3           0                       283
# 3                  0           0                       559
# 4                  5           1                       271
# ...              ...         ...                       ...
# 8651412            1           0                       576
# 8651413            0           0                        17
# 8651414            3           0                       292
# 8651415            2           0                         0
# 8651416            2           0                        98
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 0                      1062      1.146893     0.051789              535
# 1                      1062      1.146893     0.051789              535
# 2                      1062      1.146893     0.051789              535
# 3                      1062      1.146893     0.051789              535
# 4                       252      1.369048     0.119048              113
# ...                     ...           ...          ...              ...
# 8651412                 570      1.061404     0.021053              209
# 8651413                 570      1.061404     0.021053              209
# 8651414                 222      1.490991     0.130631              186
# 8651415                1037      1.591128     0.062681              414
# 8651416                1037      1.591128     0.062681              414
#
# [8651417 rows x 13 columns]

# %%
len(train_data)
# Out:
# 8651417

# %%
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np
import pandas as pd

# Generate a list of all unique product IDs
all_product_ids = set(product_embedding_dict.keys())

# Prepare for storing negative samples
negative_samples = []

# Group by customer for efficient processing
customer_groups = train_data.groupby('customer_id')

for customer_id, group in tqdm(customer_groups, desc="Generating hard negative samples"):
    # Purchased products for the current customer
    purchased_products = set(group['product_id'])

    # Non-purchased products for the current customer
    non_purchased_products = list(all_product_ids - purchased_products)

    # Skip if there are no products to compare
    if len(non_purchased_products) == 0 or len(purchased_products) == 0:
        continue

    # Get embeddings for purchased and non-purchased products
    purchased_embeddings = np.array([product_embedding_dict[pid] for pid in purchased_products])
    non_purchased_embeddings = np.array([product_embedding_dict[pid] for pid in non_purchased_products])

    # Reshape to ensure 2D arrays
    purchased_embeddings = purchased_embeddings.reshape(-1, purchased_embeddings.shape[-1])
    non_purchased_embeddings = non_purchased_embeddings.reshape(-1, non_purchased_embeddings.shape[-1])

    # Compute cosine similarity between non-purchased and purchased products
    similarity_scores = cosine_similarity(non_purchased_embeddings, purchased_embeddings)

    # Identify the most similar non-purchased products (hard.  negatives)
    most_similar_indices = np.argsort(-similarity_scores, axis=0)[:len(group)]
    #hard_negatives = {non_purchased_products[i] for i in most_similar_indices.flatten()}[:len(group)]
    # Flatten and select up to len(group) unique hard negatives
    hard_negatives = list({non_purchased_products[i] for i in most_similar_indices.flatten()})[:len(group)]


    # Append hard negatives as negative samples
    negative_samples.extend([{
        'customer_id': customer_id,
        'product_id': product_id,
        'quantity': 0  # Indicating negative sample
    } for product_id in hard_negatives])

# Convert negative samples to a DataFrame
negative_samples_df = pd.DataFrame(negative_samples)

# Append negative samples to the original training data
train_data = pd.concat([train_data, negative_samples_df], ignore_index=True)

# Update relevance column (1 for purchased, 0 for negatives)
train_data['relevance'] = (train_data['quantity'] > 0).astype(int)
# Out:
# Generating hard negative samples: 100%|██████████| 9999/9999 [11:53:27<00:00,  4.28s/it]

# %%
train_data.tail()
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 17302829  Household_29999  Product_34918       NaN       0.0      NaN    NaN
# 17302830  Household_29999  Product_51138       NaN       0.0      NaN    NaN
# 17302831  Household_29999  Product_46601       NaN       0.0      NaN    NaN
# 17302832  Household_29999  Product_42471       NaN       0.0      NaN    NaN
# 17302833  Household_29999  Product_29559       NaN       0.0      NaN    NaN
#
#           day_of_week  is_weekend  days_since_last_purchase  \
# 17302829          NaN         NaN                       NaN
# 17302830          NaN         NaN                       NaN
# 17302831          NaN         NaN                       NaN
# 17302832          NaN         NaN                       NaN
# 17302833          NaN         NaN                       NaN
#
#           purchase_frequency  avg_quantity  promo_ratio  unique_products  \
# 17302829                 NaN           NaN          NaN              NaN
# 17302830                 NaN           NaN          NaN              NaN
# 17302831                 NaN           NaN          NaN              NaN
# 17302832                 NaN           NaN          NaN              NaN
# 17302833                 NaN           NaN          NaN              NaN
#
#           relevance
# 17302829          0
# 17302830          0
# 17302831          0
# 17302832          0
# 17302833          0

# %%
# Check for missing values
print("Missing values in train_data:")
print(train_data.isnull().sum())

print("Missing values in test_data:")
print(test_data.isnull().sum())

# Fill remaining missing values with zeros as a safety measure
train_data = train_data.fillna(0)
test_data = test_data.fillna(0)
# Out:
# Missing values in train_data:
# customer_id                       0
# product_id                        0
# is_promo                    8651417
# quantity                          0
# recency                     8651417
# month                       8651417
# day_of_week                 8651417
# is_weekend                  8651417
# days_since_last_purchase    8651417
# purchase_frequency          8651417
# avg_quantity                8651417
# promo_ratio                 8651417
# unique_products             8651417
# relevance                         0
# dtype: int64
# Missing values in test_data:
# transaction_id    0
# customer_id       0
# product_id        0
# dtype: int64

# %%
train_data = train_data.drop(columns=['day_of_week','is_weekend','unique_products'])

# %%
# prompt: in train_data for household Household_9247 count how manyrelevance 1 and how many are 0.

# Assuming 'train_data' DataFrame is already loaded as in the provided code.

household_9247_data = train_data[train_data['customer_id'] == 'Household_76806']

relevance_counts = household_9247_data['relevance'].value_counts()

print(f"Relevance counts for Household_9247:")
relevance_counts
# Out:
# Relevance counts for Household_9247:
# Series([], Name: count, dtype: int64)

# %%
train_data.to_csv(os.path.join(trainFolder, 'train_data_all_3.csv'), index=False)

# %%
len(train_data)
# Out:
# 17302834

# %%
train_data
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 0         Household_20188  Product_51237       0.0       1.0    325.0    2.0
# 1         Household_20188  Product_32922       0.0       1.0    601.0    5.0
# 2         Household_20188  Product_45500       0.0       1.0    325.0    2.0
# 3         Household_20188  Product_16016       0.0       1.0    601.0    5.0
# 4         Household_20617  Product_64825       0.0       1.0    281.0    3.0
# ...                   ...            ...       ...       ...      ...    ...
# 17302829  Household_29999  Product_34918       0.0       0.0      0.0    0.0
# 17302830  Household_29999  Product_51138       0.0       0.0      0.0    0.0
# 17302831  Household_29999  Product_46601       0.0       0.0      0.0    0.0
# 17302832  Household_29999  Product_42471       0.0       0.0      0.0    0.0
# 17302833  Household_29999  Product_29559       0.0       0.0      0.0    0.0
#
#           days_since_last_purchase  purchase_frequency  avg_quantity  \
# 0                            283.0              1062.0      1.146893
# 1                            559.0              1062.0      1.146893
# 2                            283.0              1062.0      1.146893
# 3                            559.0              1062.0      1.146893
# 4                            271.0               252.0      1.369048
# ...                            ...                 ...           ...
# 17302829                       0.0                 0.0      0.000000
# 17302830                       0.0                 0.0      0.000000
# 17302831                       0.0                 0.0      0.000000
# 17302832                       0.0                 0.0      0.000000
# 17302833                       0.0                 0.0      0.000000
#
#           promo_ratio  relevance
# 0            0.051789          1
# 1            0.051789          1
# 2            0.051789          1
# 3            0.051789          1
# 4            0.119048          1
# ...               ...        ...
# 17302829     0.000000          0
# 17302830     0.000000          0
# 17302831     0.000000          0
# 17302832     0.000000          0
# 17302833     0.000000          0
#
# [17302834 rows x 11 columns]

# %%
products_data
