# %% [markdown]
# ## IMPORTS

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# !pip install tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.colab import drive
drive.mount('/content/gdrive')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Import necessary libraries

import torch

# Load pre-trained BERT model and tokenizer
trainFolder = "gdrive/My Drive/MLDM - Carrefour Project/data-train"

import os
for dirname, _, filenames in os.walk(f'{trainFolder}'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.67.1)
# Mounted at /content/gdrive
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/test_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_10.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_2.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_3.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_4.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_5.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_6.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_7.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_8.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_9.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe_fixed.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data_bert1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/submission_01.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations_combined.npy

# %%
# Import libraries
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Description
#
# This project uses three datasets:
#
# #### `train_data.csv`:
# This dataset contains two years (2022 & 2023) of historical transactions for 100,000 Carrefour customers. It has 10 columns:
#
# * ***date***: Date of the transaction
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: Product purchased
# * ***has_loyality_card***: Flag indicating whether the customer has a loyalty card
# * ***store_id***: Store where the purchase was made
# * ***is_promo***: Flag indicating whether there was a discount on the product
# * ***quantity***: Quantity purchased of the product
# * ***format***: Ecommerce activity format (clcv, lex, or DRIVE)
#   - clcv : courses livrées chez vous
#   - lex : livraison express
#   - DRIVE.
# * ***orderChannelCode***: Indicates whether the online activity was made through the website or mobile app

# %% [markdown]
# #### `products_data.csv`:
# This dataset contains detailed information about the products. The following columns are relevant to this project:
#
# * ***product_id*** : Product name
# * ***product_description*** : Product description
# * ***department_key***: Department key
# * ***class_key***: Class key
# * ***subclass_key***: Subclass key
# * ***sector***: sector name
# * ***brand_key***: Brand name
# * ***shelf_level1***: Top-level shelf category
# * ***shelf_level2***: Second-level shelf category
# * ***shelf_level3***: Third-level shelf category
# * ***shelf_level4***: Fourth-level shelf category
# * ***sector***: Sector
# * ***bio***: Flag indicating whether the product is organic
# * ***sugar_free***: Flag indicating whether the product is sugar-free
# * ***aspartame_free***: Flag indicating whether the product is aspartame-free
# * ***gluten_free***: Flag indicating whether the product is gluten-free
# * ***halal***: Flag indicating whether the product is halal
# * ***casher***: Flag indicating whether the product is kosher
# * ***eco_friendly***: Flag indicating whether the product is eco-friendly
# * ***local_french***: Flag indicating whether the product is locally produced in France
# * ***artificial_coloring_free***: Flag indicating whether the product is free of artificial coloring
# * ***taste_enhancer_free***: Flag indicating whether the product is free of taste enhancers
# * ***naturality***: Naturality score
# * ***antibiotic_free***: Flag indicating whether the product is antibiotic-free
# * ***reduced_sugar***: Flag indicating whether the product has reduced sugar content
# * ***vegetarian***: Flag indicating whether the product is vegetarian
# * ***pesticide_free***: Flag indicating whether the product is pesticide-free
# * ***grain_free***: Flag indicating whether the product is grain-free
# * ***no_added_sugar***: Flag indicating whether the product has no added sugar
# * ***salt_reduced***: Flag indicating whether the product has reduced salt content
# * ***nitrite_free***: Flag indicating whether the product is nitrite-free
# * ***fed_without_ogm***: Flag indicating whether the animals were fed without GMOs
# * ***no_added_salt***: Flag indicating whether the product has no added salt
# * ***no_artificial_flavours***: Flag indicating whether the product has no artificial flavors
# * ***porc***: Flag indicating whether the product contains pork
# * ***vegan***: Flag indicating whether the product is vegan
# * ***frozen***: Flag indicating whether the product is frozen
# * ***fat_free***: Flag indicating whether the product is fat-free
# * ***reduced_fats***: Flag indicating whether the product has reduced fat content
# * ***fresh***: Flag indicating whether the product is fresh
# * ***alcool***: Flag indicating whether the product contains alcohol
# * ***lactose_free***: Flag indicating whether the product is lactose-free
# * ***phenylalanine_free***: Flag indicating whether the product is phenylalanine-free
# * ***palm_oil_free***: Flag indicating whether the product is palm oil-free
# * ***ecoscore***: Ecoscore
# * ***produits_du_monde***: Flag indicating whether the product is an international product
# * ***regional_product***: Flag indicating whether the product is a regional product
# * ***national_brand***: Flag indicating whether the product is a national brand
# * ***first_price_brand***: Flag indicating whether the product is a first-price brand
# * ***carrefour_brand***: Flag indicating whether the product is a Carrefour brand

# %% [markdown]
# #### `test_data.csv`:
# This dataset contains the actual purchases of the first 80,000 customers in 2024. It has three columns:
#
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: the id of the purchased product

# %% [markdown]
# ### Load data
#
# * Load *train_data.csv*, *products_data.csv* and *test_data.csv* using pandas.

# %%
# This code reads the data from CSV files named "train_data_part_i.csv" for all i from 1 to 10
# and concatenates them into a single pandas DataFrame
train_dataframes = []
for i in tqdm(range(1, 11)): ## 1 - 11
    train_dataframes.append(pd.read_csv(f'{trainFolder}/train_data_part_{i}.csv'))
train_data = pd.concat(train_dataframes, ignore_index=True)

# free up memory by deleting the dataframes we no longer need
del train_dataframes
# Out:
# 100%|██████████| 10/10 [01:52<00:00, 11.25s/it]

# %%
#train_data = train_data.sample(frac=0.1, random_state=1)  # frac=0.1 takes 10% of the data

# %%
# This code reads the data from a CSV file named "products_data.csv" into a pandas DataFrame
products_data = pd.read_csv(f'{trainFolder}/products_data.csv')
# Out:
# <ipython-input-5-d8cc84ca7717>:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   products_data = pd.read_csv(f'{trainFolder}/products_data.csv')

# %%
# This code reads the data from a CSV file named "test_data.csv" into a pandas DataFrame
test_data = pd.read_csv(f'{trainFolder}/test_data.csv')

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 0         2023-11-15  Transaction_1730125     Household_39   Product_5362
# 1         2022-07-20  Transaction_1560535     Household_39  Product_67174
# 2         2022-07-20  Transaction_1560535     Household_39  Product_82254
# 3         2023-11-15  Transaction_1730125     Household_39   Product_3895
# 4         2022-07-20  Transaction_1560535     Household_39  Product_34014
# ...              ...                  ...              ...            ...
# 87037457  2022-01-07  Transaction_1162379  Household_96742  Product_28756
# 87037458  2023-08-17  Transaction_2306043  Household_96742  Product_62786
# 87037459  2022-10-12  Transaction_1524531  Household_96742  Product_16362
# 87037460  2023-03-10  Transaction_1972306  Household_96742  Product_78870
# 87037461  2022-05-12  Transaction_1971250  Household_96742  Product_10052
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 0                         0     Store_2         0       1.0  DRIVE
# 1                         0     Store_2         0       2.0  DRIVE
# 2                         0     Store_2         0       2.0  DRIVE
# 3                         0     Store_2         0       1.0  DRIVE
# 4                         0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 87037457                  0  Store_2542         0       1.0  DRIVE
# 87037458                  0  Store_2542         0       1.0  DRIVE
# 87037459                  0  Store_2542         0       1.0  DRIVE
# 87037460                  0  Store_2542         0       1.0  DRIVE
# 87037461                  0  Store_2542         0       1.0  DRIVE
#
#          order_channel
# 0           MOBILE_APP
# 1              WEBSITE
# 2              WEBSITE
# 3           MOBILE_APP
# 4              WEBSITE
# ...                ...
# 87037457    MOBILE_APP
# 87037458    MOBILE_APP
# 87037459    MOBILE_APP
# 87037460    MOBILE_APP
# 87037461    MOBILE_APP
#
# [87037462 rows x 10 columns]

# %%
# prompt: print from train_date rows with customer id Household_80001
import pandas as pd

# Create a list of customer IDs within the specified range
#customer_ids_new = [f'Household_{i}' for i in range(80001, 100002)]
#customer_ids_new = [f'Household_{i}' for i in range(10001, 20000)]
customer_ids_new = [f'Household_{i}' for i in range(40001, 50000)]

# prompt: keep in train_data and test_data the rows that have the cusomer_id in customer_ids

# Filter train_data
train_data = train_data[train_data['customer_id'].isin(customer_ids_new)]

# Filter test_data
test_data = test_data[test_data['customer_id'].isin(customer_ids_new)]

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 34913164  2022-01-30  Transaction_1600825  Household_40549  Product_63337
# 34913165  2022-06-25  Transaction_1414635  Household_40549  Product_67694
# 34913166  2022-02-06  Transaction_1001640  Household_40549  Product_38531
# 34913167  2022-02-27    Transaction_44329  Household_40549  Product_35862
# 34913168  2022-06-25  Transaction_1414635  Household_40549  Product_26610
# ...              ...                  ...              ...            ...
# 43664696  2023-10-30   Transaction_679766  Household_46292  Product_34316
# 43664697  2023-11-25  Transaction_1562111  Household_46292  Product_37636
# 43664698  2023-10-30   Transaction_679766  Household_46292  Product_42748
# 43664699  2023-11-25  Transaction_1562111  Household_46292  Product_77775
# 43664700  2023-10-10  Transaction_1942837  Household_46292  Product_64067
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 34913164                  0     Store_2         0       1.0  DRIVE
# 34913165                  0     Store_2         0       2.0  DRIVE
# 34913166                  0     Store_2         0       1.0  DRIVE
# 34913167                  0     Store_2         0       1.0  DRIVE
# 34913168                  0     Store_2         0       4.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 43664696                  1  Store_2544         0       1.0    LEX
# 43664697                  1  Store_2544         0       1.0    LEX
# 43664698                  1  Store_2544         0       1.0    LEX
# 43664699                  1  Store_2544         0       1.0    LEX
# 43664700                  1  Store_2544         0       1.0    LEX
#
#          order_channel
# 34913164       WEBSITE
# 34913165       WEBSITE
# 34913166       WEBSITE
# 34913167       WEBSITE
# 34913168       WEBSITE
# ...                ...
# 43664696        LIVREE
# 43664697        LIVREE
# 43664698        LIVREE
# 43664699        LIVREE
# 43664700        LIVREE
#
# [8750915 rows x 10 columns]

# %%
test_data
# Out:
#                  transaction_id      customer_id     product_id
# 16           Transaction_2024_6  Household_45734  Product_17821
# 17           Transaction_2024_6  Household_45734  Product_74733
# 18           Transaction_2024_6  Household_45734  Product_64067
# 19           Transaction_2024_6  Household_45734  Product_23487
# 20           Transaction_2024_8  Household_42109  Product_43475
# ...                         ...              ...            ...
# 1067712  Transaction_2024_17139  Household_49998  Product_41119
# 1067713  Transaction_2024_31805  Household_49999  Product_40951
# 1067714  Transaction_2024_31805  Household_49999  Product_51601
# 1067715  Transaction_2024_31805  Household_49999  Product_10655
# 1067716  Transaction_2024_31805  Household_49999  Product_42750
#
# [152359 rows x 3 columns]

# %%
train_data = train_data.drop(columns=['transaction_id','has_loyality_card', 'store_id','format','order_channel'])

# %% [markdown]
# ## Training Data Preproccesing

# %%
train_data['date'] = pd.to_datetime(train_data['date'])

# Add recency attribute
latest_date = train_data['date'].max()  # Find the latest date in the dataset
train_data['recency'] = (latest_date - train_data['date']).dt.days  # Calculate days since last purchase

# Group by customer_id and product_id to calculate quantity and most recent purchase
customer_product_data = train_data.groupby(['customer_id', 'product_id']).agg({
    'quantity': 'sum',
    'recency': 'min'  # Minimum days since purchase (most recent)
}).reset_index()

# Normalize quantity and recency scores
customer_product_data['quantity_score'] = customer_product_data['quantity'] / customer_product_data['quantity'].max()
customer_product_data['recency_score'] = 1 - (customer_product_data['recency'] / customer_product_data['recency'].max())  # Recent = higher score

best_alpha = 0.97

# Calculate the final score with this alpha value
customer_product_data['final_score'] = (
    best_alpha * customer_product_data['quantity_score'] +
    (1 - best_alpha) * customer_product_data['recency_score']
)

# Rank products for each customer with unique ranks
customer_product_data['rank'] = customer_product_data.sort_values(
    by=['customer_id', 'final_score', 'quantity', 'product_id'],  # Add secondary sort keys
    ascending=[True, False, False, True]  # Ensure consistent order
).groupby('customer_id').cumcount() + 1  # Assign unique incremental ranks


# Sort the DataFrame by customer_id and rank
customer_product_data = customer_product_data.sort_values(by=['customer_id', 'rank'])

# Filter out products with a rank greater than 200 for each customer
#customer_product_data = customer_product_data[customer_product_data['rank'] <= 20]

# %%
customer_product_data
# Out:
#              customer_id     product_id  quantity  recency  quantity_score  \
# 73       Household_40001  Product_28633     540.0        9        0.156250
# 221      Household_40001  Product_67559      79.0        9        0.022859
# 145      Household_40001  Product_47398      76.0        9        0.021991
# 215      Household_40001  Product_65763      57.0        9        0.016493
# 211      Household_40001  Product_65000      41.0        9        0.011863
# ...                  ...            ...       ...      ...             ...
# 3343151  Household_49999  Product_18513       1.0      729        0.000289
# 3343257  Household_49999  Product_33558       1.0      729        0.000289
# 3343317  Household_49999  Product_43313       1.0      729        0.000289
# 3343542  Household_49999  Product_81813       1.0      729        0.000289
# 3343552  Household_49999   Product_9231       1.0      729        0.000289
#
#          recency_score  final_score  rank
# 73            0.987654     0.181192     1
# 221           0.987654     0.051803     2
# 145           0.987654     0.050961     3
# 215           0.987654     0.045628     4
# 211           0.987654     0.041137     5
# ...                ...          ...   ...
# 3343151       0.000000     0.000281   455
# 3343257       0.000000     0.000281   456
# 3343317       0.000000     0.000281   457
# 3343542       0.000000     0.000281   458
# 3343552       0.000000     0.000281   459
#
# [3343559 rows x 8 columns]

# %%
# Extract temporal features
train_data['month'] = train_data['date'].dt.month
train_data['day_of_week'] = train_data['date'].dt.dayofweek
train_data['is_weekend'] = train_data['day_of_week'].isin([5, 6]).astype(int)

# Calculate recency: days since the last purchase for each customer
train_data['days_since_last_purchase'] = train_data.groupby('customer_id')['date'].transform(
    lambda x: (x.max() - x).dt.days
)

# Drop the 'date' column if it's no longer needed
train_data = train_data.drop(columns=['date'], errors='ignore')

# %%
# Aggregate customer-specific features
customer_features = train_data.groupby(['customer_id']).agg(
    purchase_frequency=('product_id', 'count'),  # Total number of purchases
    avg_quantity=('quantity', 'mean'),          # Average quantity purchased
    promo_ratio=('is_promo', 'mean'),           # Proportion of purchases made with promotions
    unique_products=('product_id', 'nunique')   # Number of unique products purchased
).reset_index()

# Merge these features into train_data and test_data
train_data = train_data.merge(customer_features, on='customer_id', how='left')

# %%
train_data.tail()
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 8750910  Household_46292  Product_34316         0       1.0       62     10
# 8750911  Household_46292  Product_37636         0       1.0       36     11
# 8750912  Household_46292  Product_42748         0       1.0       62     10
# 8750913  Household_46292  Product_77775         0       1.0       36     11
# 8750914  Household_46292  Product_64067         0       1.0       82     10
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 8750910            0           0                        59
# 8750911            5           1                        33
# 8750912            0           0                        59
# 8750913            5           1                        33
# 8750914            1           0                        79
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 8750910                1189      1.339781     0.022708              645
# 8750911                1189      1.339781     0.022708              645
# 8750912                1189      1.339781     0.022708              645
# 8750913                1189      1.339781     0.022708              645
# 8750914                1189      1.339781     0.022708              645

# %%
products_data.tail()
# Out:
#           product_id             product_description department_key  \
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82964  Product_31161              CHARGE BUT 13K CRF  Department_75
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82964  Class_7520  SubClass_75201  ACTIVITES PERIPHERIQUES   CARREFOUR
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1               shelf_level2  \
# 82961     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82963            Animalerie                     Chiens
# 82964  Maison et Décoration          Bouteilles de gaz
# 82965  Maison et Décoration          Bouteilles de gaz
#
#                          shelf_level3                     shelf_level4  bio  \
# 82961             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82962             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82963  Colliers, Laisses et Vêtements          Vêtements et Chaussures    0
# 82964                             NaN                              NaN    0
# 82965                             NaN                              NaN    0
#
#        sugar_free  aspartame_free  gluten_free  halal  casher  eco_friendly  \
# 82961           0               0            0      0       0             0
# 82962           0               0            0      0       0             0
# 82963           0               0            0      0       0             0
# 82964           0               0            0      0       0             0
# 82965           0               0            0      0       0             0
#
#        local_french  artificial_coloring_free  taste_enhancer_free  \
# 82961             0                         0                    0
# 82962             0                         0                    0
# 82963             0                         0                    0
# 82964             0                         0                    0
# 82965             0                         0                    0
#
#        naturality  antibiotic_free  reduced_sugar  vegetarian  pesticide_free  \
# 82961           0                0              0           0               0
# 82962           0                0              0           0               0
# 82963           0                0              0           0               0
# 82964           0                0              0           0               0
# 82965           0                0              0           0               0
#
#        grain_free  no_added_sugar  salt_reduced  nitrite_free  \
# 82961           0               0             0             0
# 82962           0               0             0             0
# 82963           0               0             0             0
# 82964           0               0             0             0
# 82965           0               0             0             0
#
#        fed_without_ogm  no_added_salt  no_artificial_flavours  porc  vegan  \
# 82961                0              0                       0     0      0
# 82962                0              0                       0     0      0
# 82963                0              0                       0     0      0
# 82964                0              0                       0     0      0
# 82965                0              0                       0     0      0
#
#        frozen  fat_free  reduced_fats  fresh  alcool  lactose_free  \
# 82961       0         0             0      0       0             0
# 82962       0         0             0      0       0             0
# 82963       0         0             0      0       0             0
# 82964       0         0             0      0       0             0
# 82965       0         0             0      0       0             0
#
#        phenylalanine_free  palm_oil_free ecoscore  produits_du_monde  \
# 82961                   0              0      NaN                  0
# 82962                   0              0      NaN                  0
# 82963                   0              0      NaN                  0
# 82964                   0              0      NaN                  0
# 82965                   0              0      NaN                  0
#
#        regional_product  national_brand  first_price_brand  carrefour_brand
# 82961                 0               0                  0                1
# 82962                 0               0                  0                1
# 82963                 0               0                  0                1
# 82964                 0               0                  0                1
# 82965                 0               0                  0                1

# %% [markdown]
# # Identifyng Missing Products

# %%
# Convert product_id columns to sets for quick set operations
train_product_ids = set(train_data["product_id"].unique())
products_product_ids = set(products_data["product_id"].unique())

# Find products in products_data that are not in train_data
missing_from_train = products_product_ids - train_product_ids

print(f"Number of products not in train_data: {len(missing_from_train)}")

if len(missing_from_train) > 0:
    print("These product IDs are in products_data but not in train_data:")
    for pid in missing_from_train:
        print(pid)
else:
    print("All products in products_data appear in train_data.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Product_5625
# Product_44256
# Product_32724
# Product_4201
# Product_31319
# Product_42718
# Product_72353
# Product_56349
# Product_59017
# Product_47542
# Product_81899
# Product_33603
# Product_81386
# Product_32971
# Product_483
# Product_17116
# Product_30657
# Product_54805
# Product_12936
# Product_2853
# Product_10106
# Product_33076
# Product_82598
# Product_67052
# Product_17869
# Product_31565
# Product_35749
# Product_33037
# Product_29366
# Product_68683
# Product_37824
# Product_32683
# Product_16688
# Product_3591
# Product_63966
# Product_12361
# Product_55198
# Product_4387
# Product_48943
# Product_39054
# Product_30507
# Product_15366
# Product_9885
# Product_31552
# Product_23444
# Product_36723
# Product_71538
# Product_50838
# Product_2965
# Product_54564
# Product_56297
# Product_3430
# Product_70706
# Product_31211
# Product_77240
# Product_33253
# Product_1658
# Product_38145
# Product_14370
# Product_38982
# Product_19743
# Product_70826
# Product_27585
# Product_65138
# Product_40338
# Product_54431
# Product_78005
# Product_44575
# Product_19002
# Product_19650
# Product_17802
# Product_12429
# Product_66856
# Product_51636
# Product_63260
# Product_55829
# Product_51524
# Product_58549
# Product_43756
# Product_22001
# Product_73044
# Product_3040
# Product_1619
# Product_52428
# Product_27273
# Product_39055
# Product_82285
# Product_37604
# Product_21649
# Product_64493
# Product_40114
# Product_14247
# Product_34746
# Product_68736
# Product_4518
# Product_57892
# Product_31130
# Product_68277
# Product_26460
# Product_77164
# Product_64833
# Product_74592
# Product_63083
# Product_76835
# Product_73229
# Product_2424
# Product_75499
# Product_4492
# Product_53429
# Product_5758
# Product_28296
# Product_70346
# Product_6669
# Product_64153
# Product_78836
# Product_37632
# Product_43907
# Product_27334
# Product_13069
# Product_22481
# Product_36216
# Product_43169
# Product_26346
# Product_80224
# Product_75409
# Product_44119
# Product_58216
# Product_20283
# Product_58353
# Product_38777
# Product_33689
# Product_62923
# Product_54286
# Product_31903
# Product_80546
# Product_11737
# Product_75144
# Product_65363
# Product_13197
# Product_16807
# Product_31584
# Product_41294
# Product_64460
# Product_75180
# Product_58828
# Product_50222
# Product_25742
# Product_70570
# Product_51176
# Product_68252
# Product_31143
# Product_59871
# Product_48438
# Product_50114
# Product_32204
# Product_58181
# Product_30761
# Product_12373
# Product_13116
# Product_40295
# Product_16927
# Product_68470
# Product_58674
# Product_49918
# Product_41794
# Product_59089
# Product_312
# Product_591
# Product_9730
# Product_35360
# Product_16064
# Product_74190
# Product_76892
# Product_6825
# Product_78705
# Product_49006
# Product_67522
# Product_34487
# Product_22196
# Product_60418
# Product_62305
# Product_42842
# Product_40768
# Product_61878
# Product_13635
# Product_42692
# Product_51583
# Product_63138
# Product_73224
# Product_62911
# Product_82690
# Product_57298
# Product_7212
# Product_71655
# Product_39426
# Product_63676
# Product_24019
# Product_20515
# Product_53606
# Product_72988
# Product_26255
# Product_68795
# Product_59879
# Product_64413
# Product_82793
# Product_31051
# Product_45849
# Product_78752
# Product_7226
# Product_37330
# Product_19619
# Product_17111
# Product_57741
# Product_64633
# Product_9421
# Product_80611
# Product_28950
# Product_67125
# Product_11678
# Product_42508
# Product_29852
# Product_34585
# Product_23303
# Product_41443
# Product_74504
# Product_18440
# Product_75455
# Product_43958
# Product_6482
# Product_27820
# Product_53458
# Product_2456
# Product_15930
# Product_44002
# Product_75934
# Product_39022
# Product_16920
# Product_19867
# Product_13938
# Product_4847
# Product_56482
# Product_54007
# Product_73670
# Product_10090
# Product_26582
# Product_42733
# Product_76125
# Product_4588
# Product_16535
# Product_30522
# Product_61918
# Product_35911
# Product_65869
# Product_39257
# Product_68412
# Product_37026
# Product_64722
# Product_5137
# Product_38470
# Product_27240
# Product_28904
# Product_34328
# Product_9149
# Product_34132
# Product_37466
# Product_65892
# Product_13348
# Product_63937
# Product_29132
# Product_41164
# Product_67450
# Product_12257
# Product_45865
# Product_5524
# Product_55910
# Product_30882
# Product_1742
# Product_77641
# Product_43899
# Product_5678
# Product_23952
# Product_54915
# Product_68748
# Product_24838
# Product_26836
# Product_15630
# Product_22703
# Product_18300
# Product_24963
# Product_57748
# Product_71584
# Product_72173
# Product_47905
# Product_12705
# Product_23592
# Product_68211
# Product_53608
# Product_36782
# Product_75212
# Product_76016
# Product_62050
# Product_68443
# Product_30481
# Product_13434
# Product_2177
# Product_71379
# Product_27973
# Product_26746
# Product_2838
# Product_15126
# Product_20012
# Product_68554
# Product_60391
# Product_73425
# Product_74938
# Product_64955
# Product_45376
# Product_80285
# Product_59491
# Product_39816
# Product_77318
# Product_32920
# Product_1257
# Product_57656
# Product_71829
# Product_71133
# Product_6253
# Product_3319
# Product_57396
# Product_31533
# Product_64603
# Product_1167
# Product_54527
# Product_61531
# Product_12565
# Product_78473
# Product_67914
# Product_48603
# Product_55867
# Product_68116
# Product_22189
# Product_76309
# Product_75531
# Product_68799
# Product_82786
# Product_48545
# Product_75441
# Product_4457
# Product_38043
# Product_66222
# Product_68168
# Product_15603
# Product_13167
# Product_82792
# Product_6848
# Product_59
# Product_34520
# Product_29777
# Product_30040
# Product_37648
# Product_61419
# Product_38372
# Product_39003
# Product_48068
# Product_77530
# Product_28266
# Product_44499
# Product_49087
# Product_70986
# Product_67314
# Product_35508
# Product_49274
# Product_42037
# Product_33561
# Product_31011
# Product_43863
# Product_1940
# Product_60711
# Product_11069
# Product_38038
# Product_21395
# Product_39390
# Product_49350
# Product_19714
# Product_7718
# Product_5605
# Product_13039
# Product_37467
# Product_6902
# Product_29284
# Product_74338
# Product_59172
# Product_11932
# Product_59093
# Product_80095
# Product_82045
# Product_21124
# Product_77258
# Product_61287
# Product_38627
# Product_53764
# Product_58563
# Product_72583
# Product_78429
# Product_15964
# Product_30017
# Product_24857
# Product_70854
# Product_49662
# Product_41840
# Product_19331
# Product_56510
# Product_2855
# Product_13243
# Product_8451
# Product_39085
# Product_49479
# Product_68685
# Product_32211
# Product_51051
# Product_48882
# Product_618
# Product_24445
# Product_78019
# Product_75447
# Product_9979
# Product_56668
# Product_19784
# Product_36486
# Product_14932
# Product_44957
# Product_22315
# Product_50310
# Product_79618
# Product_66321
# Product_29203
# Product_47535
# Product_53152
# Product_81304
# Product_57736
# Product_68999
# Product_37740
# Product_29455
# Product_12117
# Product_34859
# Product_37416
# Product_77778
# Product_70888
# Product_24075
# Product_24845
# Product_77800
# Product_69404
# Product_80055
# Product_40552
# Product_5116
# Product_28205
# Product_12650
# Product_62225
# Product_20615
# Product_18567
# Product_19375
# Product_33438
# Product_69554
# Product_37403
# Product_23893
# Product_66059
# Product_11476
# Product_7860
# Product_71428
# Product_55498
# Product_36251
# Product_29073
# Product_49160
# Product_69597
# Product_60609
# Product_79322
# Product_7958
# Product_53920
# Product_62389
# Product_69870
# Product_41933
# Product_50654
# Product_51743
# Product_81057
# Product_273
# Product_53476
# Product_63355
# Product_11772
# Product_47657
# Product_43724
# Product_315
# Product_65381
# Product_79765
# Product_31749
# Product_69540
# Product_35301
# Product_41039
# Product_49092
# Product_32686
# Product_45264
# Product_60125
# Product_53567
# Product_63845
# Product_1683
# Product_78241
# Product_49161
# Product_75680
# Product_23183
# Product_54087
# Product_48761
# Product_32717
# Product_42667
# Product_64867
# Product_56616
# Product_46380
# Product_8529
# Product_13030
# Product_34991
# Product_75093
# Product_55420
# Product_38696
# Product_4984
# Product_4126
# Product_41417
# Product_34858
# Product_53845
# Product_8224
# Product_32269
# Product_12846
# Product_4453
# Product_48069
# Product_70965
# Product_46852
# Product_82593
# Product_81191
# Product_21512
# Product_60040
# Product_33687
# Product_79275
# Product_30318
# Product_1216
# Product_77497
# Product_29682
# Product_67424
# Product_28875
# Product_67755
# Product_73371
# Product_46207
# Product_6533
# Product_9680
# Product_1572
# Product_62407
# Product_42438
# Product_14948
# Product_30699
# Product_21441
# Product_75632
# Product_74891
# Product_42257
# Product_49258
# Product_16177
# Product_10907
# Product_576
# Product_5247
# Product_10137
# Product_18613
# Product_73464
# Product_48025
# Product_26339
# Product_31145
# Product_57545
# Product_60207
# Product_57445
# Product_18219
# Product_26772
# Product_10053
# Product_71170
# Product_3213
# Product_73589
# Product_27265
# Product_49647
# Product_42291
# Product_73701
# Product_40312
# Product_39535
# Product_78765
# Product_79020
# Product_49830
# Product_65168
# Product_16728
# Product_19388
# Product_27441
# Product_3958
# Product_75245
# Product_364
# Product_45769
# Product_17910
# Product_62616
# Product_9219
# Product_38897
# Product_22934
# Product_72084
# Product_61255
# Product_48978
# Product_9598
# Product_24672
# Product_48418
# Product_2219
# Product_48412
# Product_79641
# Product_7394
# Product_74888
# Product_69796
# Product_31286
# Product_81846
# Product_12981
# Product_31383
# Product_46597
# Product_51064
# Product_15861
# Product_43189
# Product_60589
# Product_23497
# Product_71441
# Product_22078
# Product_11773
# Product_34766
# Product_3864
# Product_57200
# Product_54533
# Product_17631
# Product_28424
# Product_35996
# Product_76860
# Product_81121
# Product_16630
# Product_22996
# Product_47150
# Product_60977
# Product_31421
# Product_27860
# Product_54357
# Product_56705
# Product_79924
# Product_58633
# Product_74436
# Product_75136
# Product_974
# Product_73809
# Product_10555
# Product_24795
# Product_67854
# Product_15661
# Product_28071
# Product_57827
# Product_66355
# Product_73312
# Product_5026
# Product_41332
# Product_80628
# Product_78544
# Product_9672
# Product_56029
# Product_27248
# Product_23937
# Product_48987
# Product_26855
# Product_81949
# Product_1803
# Product_15203
# Product_16453
# Product_77394
# Product_36749
# Product_74176
# Product_60355
# Product_81358
# Product_66910
# Product_64393
# Product_52810
# Product_43495
# Product_60154
# Product_12418
# Product_81288
# Product_69398
# Product_2373
# Product_9104
# Product_38165
# Product_4203
# Product_31843
# Product_80959
# Product_51502
# Product_9414
# Product_14924
# Product_20770
# Product_72288
# Product_21584
# Product_7093
# Product_14158
# Product_71392
# Product_44103
# Product_30849
# Product_23732
# Product_7911
# Product_12136
# Product_30404
# Product_568
# Product_73622
# Product_79874
# Product_33563
# Product_6745
# Product_14377
# Product_5015
# Product_29207
# Product_20688
# Product_48562
# Product_4509
# Product_27548
# Product_69004
# Product_72062
# Product_42745
# Product_67594
# Product_16863
# Product_2365
# Product_81368
# Product_25990
# Product_32571
# Product_30661
# Product_2382
# Product_64609
# Product_24205
# Product_48880
# Product_23096
# Product_27506
# Product_62615
# Product_22126
# Product_56899
# Product_35532
# Product_60186
# Product_64716
# Product_8986
# Product_48542
# Product_56158
# Product_74715
# Product_71510
# Product_22646
# Product_11742
# Product_58259
# Product_64248
# Product_69711
# Product_35297
# Product_23928
# Product_7840
# Product_33142
# Product_47847
# Product_48090
# Product_51222
# Product_7309
# Product_45851
# Product_78410
# Product_35450
# Product_72161
# Product_49306
# Product_17196
# Product_38749
# Product_3136
# Product_3667
# Product_42759
# Product_80625
# Product_36821
# Product_77859
# Product_67056
# Product_36162
# Product_43854
# Product_40598
# Product_30463
# Product_7062
# Product_13982
# Product_53983
# Product_56322
# Product_31947
# Product_64417
# Product_72827
# Product_57595
# Product_11313
# Product_19673
# Product_74811
# Product_17408
# Product_4583
# Product_16909
# Product_66158
# Product_62801
# Product_82209
# Product_45774
# Product_76631
# Product_26768
# Product_73424
# Product_80106
# Product_53247
# Product_70631
# Product_70035
# Product_59129
# Product_20197
# Product_52112
# Product_46669
# Product_21827
# Product_56160
# Product_31322
# Product_54766
# Product_56061
# Product_76477
# Product_51819
# Product_12795
# Product_39240
# Product_2327
# Product_54306
# Product_36307
# Product_32502
# Product_77523
# Product_56224
# Product_41576
# Product_81058
# Product_34078
# Product_15597
# Product_44383
# Product_450
# Product_39674
# Product_74565
# Product_61182
# Product_54315
# Product_37345
# Product_16964
# Product_35093
# Product_67617
# Product_63057
# Product_61990
# Product_26924
# Product_11333
# Product_59694
# Product_45566
# Product_45909
# Product_52350
# Product_54838
# Product_66810
# Product_689
# Product_5666
# Product_75416
# Product_63198
# Product_38674
# Product_45159
# Product_49200
# Product_80682
# Product_8275
# Product_80787
# Product_80588
# Product_13073
# Product_27801
# Product_81495
# Product_79261
# Product_22284
# Product_42725
# Product_9309
# Product_20392
# Product_29182
# Product_46501
# Product_69154
# Product_14156
# Product_1908
# Product_49788
# Product_77554
# Product_5502
# Product_360
# Product_31601
# Product_70727
# Product_61500
# Product_60261
# Product_43065
# Product_12893
# Product_16022
# Product_14142
# Product_2699
# Product_74985
# Product_75160
# Product_48483
# Product_20801
# Product_1282
# Product_5035
# Product_71238
# Product_77601
# Product_8022
# Product_40022
# Product_40562
# Product_48409
# Product_66013
# Product_19713
# Product_54978
# Product_15150
# Product_29885
# Product_50672
# Product_35285
# Product_79376
# Product_63652
# Product_7549
# Product_52906
# Product_54508
# Product_794
# Product_35168
# Product_9685
# Product_55560
# Product_74152
# Product_72206
# Product_60350
# Product_6815
# Product_75374
# Product_64858
# Product_66448
# Product_57092
# Product_47439
# Product_70085
# Product_48095
# Product_31658
# Product_55975
# Product_49432
# Product_65044
# Product_47263
# Product_76469
# Product_9382
# Product_28882
# Product_39853
# Product_63166
# Product_75131
# Product_75742
# Product_21323
# Product_16937
# Product_67458
# Product_14027
# Product_27246
# Product_51503
# Product_8153
# Product_28088
# Product_51989
# Product_47480
# Product_48795
# Product_38096
# Product_64759
# Product_1649
# Product_46386
# Product_77863
# Product_62010
# Product_28458
# Product_69544
# Product_63756
# Product_54503
# Product_5431
# Product_2537
# Product_58533
# Product_18698
# Product_51068
# Product_31726
# Product_21542
# Product_42828
# Product_41615
# Product_68245
# Product_77865
# Product_11983
# Product_34541
# Product_27370
# Product_39462
# Product_59587
# Product_24036
# Product_80232
# Product_34950
# Product_67626
# Product_3167
# Product_10254
# Product_8796
# Product_21161
# Product_71766
# Product_207
# Product_19624
# Product_17051
# Product_66682
# Product_42709
# Product_72495
# Product_66179
# Product_40637
# Product_34155
# Product_82237
# Product_51838
# Product_69618
# Product_61466
# Product_18108
# Product_2144
# Product_63695
# Product_49920
# Product_38001
# Product_59200
# Product_36751
# Product_8237
# Product_3968
# Product_62309
# Product_58153
# Product_29019
# Product_74430
# Product_68532
# Product_69843
# Product_47012
# Product_81762
# Product_11848
# Product_79614
# Product_46770
# Product_55708
# Product_44251
# Product_50164
# Product_22965
# Product_10201
# Product_50014
# Product_67026
# Product_6007
# Product_27500
# Product_60632
# Product_66545
# Product_30191
# Product_18039
# Product_44792
# Product_55855
# Product_11645
# Product_6417
# Product_7615
# Product_11624
# Product_67565
# Product_54854
# Product_10600
# Product_74642
# Product_81996
# Product_38395
# Product_74271
# Product_68889
# Product_23403
# Product_27060
# Product_54027
# Product_4352
# Product_28285
# Product_43036
# Product_58925
# Product_46338
# Product_41215
# Product_53262
# Product_28983
# Product_81473
# Product_38009
# Product_60265
# Product_58523
# Product_3997
# Product_44961
# Product_23769
# Product_65204
# Product_16498
# Product_82488
# Product_52425
# Product_40261
# Product_45986
# Product_58988
# Product_54108
# Product_21286
# Product_16168
# Product_29471
# Product_36755
# Product_40516
# Product_35653
# Product_22907
# Product_72224
# Product_48988
# Product_45554
# Product_49260
# Product_9962
# Product_59658
# Product_68972
# Product_73988
# Product_75051
# Product_23902
# Product_79905
# Product_74753
# Product_38497
# Product_2986
# Product_13528
# Product_41559
# Product_38416
# Product_33143
# Product_40315
# Product_54909
# Product_31443
# Product_3829
# Product_76921
# Product_55382
# Product_65899
# Product_18854
# Product_16300
# Product_64538
# Product_60894
# Product_76878
# Product_46551
# Product_78748
# Product_33001
# Product_54428
# Product_56775
# Product_55256
# Product_49025
# Product_49106
# Product_52043
# Product_26841
# Product_48567
# Product_17089
# Product_54086
# Product_45499
# Product_41533
# Product_49069
# Product_7847
# Product_77386
# Product_48386
# Product_31201
# Product_54140
# Product_15669
# Product_46962
# Product_60283
# Product_72151
# Product_41138
# Product_41029
# Product_70412
# Product_21691
# Product_59460
# Product_13169
# Product_19182
# Product_43159
# Product_14847
# Product_75396
# Product_13010
# Product_2383
# Product_33041
# Product_31782
# Product_6428
# Product_10461
# Product_13983
# Product_76663
# Product_61050
# Product_78549
# Product_43555
# Product_7843
# Product_21622
# Product_38146
# Product_52805
# Product_25126
# Product_22013
# Product_32402
# Product_76170
# Product_50333
# Product_8835
# Product_37057
# Product_28701
# Product_80798
# Product_73253
# Product_46424
# Product_8504
# Product_69902
# Product_26495
# Product_54875
# Product_66155
# Product_40373
# Product_79662
# Product_57643
# Product_39736
# Product_65500
# Product_55637
# Product_67130
# Product_58287
# Product_45155
# Product_72342
# Product_41477
# Product_69993
# Product_13872
# Product_37347
# Product_30133
# Product_10185
# Product_9188
# Product_54835
# Product_58232
# Product_74289
# Product_64918
# Product_82345
# Product_1437
# Product_32477
# Product_54656
# Product_8292
# Product_27919
# Product_75448
# Product_47625
# Product_10061
# Product_81559
# Product_20364
# Product_1943
# Product_51028
# Product_70906
# Product_55075
# Product_69659
# Product_2351
# Product_75016
# Product_23542
# Product_3905
# Product_61055
# Product_79536
# Product_32521
# Product_62666
# Product_2296
# Product_68170
# Product_36969
# Product_1656
# Product_24415
# Product_48457
# Product_22890
# Product_38788
# Product_54341
# Product_55533
# Product_2195
# Product_53422
# Product_20114
# Product_10169
# Product_17048
# Product_30847
# Product_53252
# Product_56469
# Product_9882
# Product_20334
# Product_76194
# Product_45042
# Product_8617
# Product_52884
# Product_44840
# Product_33223
# Product_21619
# Product_47472
# Product_41663
# Product_11439
# Product_7818
# Product_46365
# Product_74208
# Product_2107
# Product_64349
# Product_62813
# Product_36336
# Product_69964
# Product_17093
# Product_43963
# Product_25449
# Product_59903
# Product_8725
# Product_53373
# Product_24918
# Product_50635
# Product_6058
# Product_74
# Product_31384
# Product_62897
# Product_18846
# Product_50354
# Product_9140
# Product_15659
# Product_59913
# Product_18915
# Product_44332
# Product_82605
# Product_75456
# Product_11589
# Product_55583
# Product_196
# Product_14820
# Product_81928
# Product_65957
# Product_57500
# Product_51992
# Product_59287
# Product_70566
# Product_24443
# Product_7500
# Product_20434
# Product_7228
# Product_46385
# Product_6574
# Product_65334
# Product_19012
# Product_22771
# Product_21975
# Product_62767
# Product_40778
# Product_76954
# Product_55133
# Product_16200
# Product_60507
# Product_15765
# Product_66811
# Product_72754
# Product_63493
# Product_32524
# Product_38388
# Product_53326
# Product_16389
# Product_21603
# Product_53224
# Product_12348
# Product_16967
# Product_67320
# Product_5816
# Product_72865
# Product_72712
# Product_4849
# Product_10939
# Product_28459
# Product_10695
# Product_73127
# Product_44659
# Product_79134
# Product_33187
# Product_65399
# Product_79701
# Product_23914
# Product_19042
# Product_53052
# Product_81019
# Product_79186
# Product_61797
# Product_71642
# Product_52035
# Product_60838
# Product_64404
# Product_53032
# Product_33859
# Product_77531
# Product_54964
# Product_7841
# Product_24612
# Product_54658
# Product_1780
# Product_27409
# Product_75898
# Product_24357
# Product_15403
# Product_64365
# Product_4560
# Product_81775
# Product_79689
# Product_43147
# Product_44965
# Product_55012
# Product_32710
# Product_49480
# Product_44178
# Product_56881
# Product_78080
# Product_37916
# Product_33928
# Product_63725
# Product_34141
# Product_30019
# Product_60150
# Product_17511
# Product_11493
# Product_26430
# Product_81106
# Product_65251
# Product_27635
# Product_51955
# Product_72893
# Product_48711
# Product_69616
# Product_54937
# Product_41748
# Product_45281
# Product_4562
# Product_51274
# Product_7070
# Product_64033
# Product_50582
# Product_23189
# Product_55169
# Product_3969
# Product_37996
# Product_5722
# Product_41984
# Product_28954
# Product_62552
# Product_64733
# Product_2977
# Product_77168
# Product_39048
# Product_33678
# Product_31861
# Product_25766
# Product_40916
# Product_7319
# Product_58701
# Product_43317
# Product_62079
# Product_42049
# Product_5808
# Product_72145
# Product_58049
# Product_67079
# Product_81185
# Product_26458
# Product_33688
# Product_15784
# Product_30698
# Product_16059
# Product_11229
# Product_6847
# Product_39882
# Product_29963
# Product_56612
# Product_22800
# Product_62667
# Product_12083
# Product_74971
# Product_59353
# Product_30487
# Product_14450
# Product_14502
# Product_73634
# Product_67036
# Product_37748
# Product_57068
# Product_2387
# Product_28068
# Product_25161
# Product_21811
# Product_43563
# Product_17113
# Product_43374
# Product_400
# Product_4851
# Product_49900
# Product_21854
# Product_66477
# Product_8742
# Product_3450
# Product_11641
# Product_81350
# Product_68750
# Product_34479
# Product_9859
# Product_7136
# Product_6230
# Product_29617
# Product_58766
# Product_36826
# Product_70226
# Product_17831
# Product_19136
# Product_43226
# Product_59720
# Product_33852
# Product_60301
# Product_37247
# Product_21142
# Product_1274
# Product_56983
# Product_41537
# Product_47180
# Product_11810
# Product_34594
# Product_26506
# Product_69845
# Product_30780
# Product_37609
# Product_1730
# Product_80357
# Product_49394
# Product_47208
# Product_69627
# Product_30810
# Product_5019
# Product_13885
# Product_79810
# Product_81515
# Product_3111
# Product_10563
# Product_7455
# Product_52873
# Product_39598
# Product_47327
# Product_42972
# Product_55342
# Product_30989
# Product_66275
# Product_66989
# Product_15432
# Product_20265
# Product_59009
# Product_43617
# Product_37523
# Product_43331
# Product_13363
# Product_60006
# Product_56818
# Product_6537
# Product_79243
# Product_17261
# Product_11829
# Product_64891
# Product_8445
# Product_64043
# Product_38256
# Product_59256
# Product_36411
# Product_2289
# Product_26100
# Product_8397
# Product_14501
# Product_18399
# Product_5569
# Product_62993
# Product_32882
# Product_32842
# Product_53592
# Product_55919
# Product_66259
# Product_7465
# Product_29797
# Product_60274
# Product_38754
# Product_38648
# Product_27139
# Product_39585
# Product_81911
# Product_21318
# Product_26572
# Product_70252
# Product_34805
# Product_6976
# Product_68102
# Product_17060
# Product_68439
# Product_43672
# Product_46178
# Product_41988
# Product_52128
# Product_80
# Product_77383
# Product_33250
# Product_41508
# Product_60375
# Product_45928
# Product_37483
# Product_36563
# Product_35083
# Product_36335
# Product_58742
# Product_3501
# Product_25472
# Product_59885
# Product_51621
# Product_31810
# Product_39147
# Product_29967
# Product_23816
# Product_56912
# Product_18859
# Product_57050
# Product_35908
# Product_33636
# Product_5231
# Product_26815
# Product_55872
# Product_13913
# Product_55293
# Product_15871
# Product_76363
# Product_79320
# Product_69644
# Product_97
# Product_31015
# Product_78423
# Product_43267
# Product_68460
# Product_14653
# Product_55558
# Product_61023
# Product_71674
# Product_71299
# Product_63171
# Product_45643
# Product_263
# Product_41429
# Product_62081
# Product_32378
# Product_65907
# Product_5146
# Product_78231
# Product_80589
# Product_20097
# Product_20320
# Product_7822
# Product_73226
# Product_41501
# Product_58252
# Product_78918
# Product_72208
# Product_64369
# Product_57981
# Product_34573
# Product_12957
# Product_40005
# Product_30309
# Product_73435
# Product_61682
# Product_11872
# Product_8323
# Product_21647
# Product_42584
# Product_78286
# Product_28814
# Product_27676
# Product_58036
# Product_70312
# Product_14521
# Product_4872
# Product_53219
# Product_59755
# Product_63281
# Product_11190
# Product_20375
# Product_15582
# Product_10653
# Product_43444
# Product_19315
# Product_5655
# Product_53993
# Product_71511
# Product_35290
# Product_74241
# Product_72833
# Product_71581
# Product_24491
# Product_80000
# Product_41111
# Product_61436
# Product_68587
# Product_32812
# Product_53671
# Product_45137
# Product_46196
# Product_29923
# Product_52212
# Product_13611
# Product_78270
# Product_46435
# Product_37326
# Product_314
# Product_56143
# Product_47969
# Product_5463
# Product_6577
# Product_81052
# Product_9215
# Product_52376
# Product_47066
# Product_65715
# Product_35676
# Product_18446
# Product_21216
# Product_54254
# Product_46917
# Product_31088
# Product_11566
# Product_35702
# Product_8370
# Product_66602
# Product_16657
# Product_6928
# Product_59155
# Product_71209
# Product_392
# Product_47325
# Product_30358
# Product_34045
# Product_44250
# Product_11267
# Product_70787
# Product_12157
# Product_76013
# Product_78452
# Product_31624
# Product_58195
# Product_13190
# Product_52774
# Product_15278
# Product_1992
# Product_5078
# Product_55912
# Product_78521
# Product_14172
# Product_31195
# Product_65677
# Product_69537
# Product_39582
# Product_24669
# Product_52718
# Product_15657
# Product_17215
# Product_17137
# Product_44446
# Product_21008
# Product_173
# Product_32189
# Product_76629
# Product_78430
# Product_80417
# Product_17754
# Product_13991
# Product_79432
# Product_24900
# Product_49486
# Product_68714
# Product_75454
# Product_51387
# Product_57163
# Product_61226
# Product_67416
# Product_11330
# Product_70527
# Product_24911
# Product_67724
# Product_46750
# Product_15003
# Product_43356
# Product_20742
# Product_67100
# Product_79878
# Product_17547
# Product_71890
# Product_52614
# Product_28217
# Product_61686
# Product_65353
# Product_82603
# Product_29220
# Product_44789
# Product_71333
# Product_22572
# Product_15123
# Product_75913
# Product_64883
# Product_35819
# Product_31962
# Product_41017
# Product_61981
# Product_38965
# Product_61655
# Product_33165
# Product_54389
# Product_26390
# Product_14177
# Product_9006
# Product_39692
# Product_79864
# Product_49272
# Product_69124
# Product_33090
# Product_16700
# Product_28347
# Product_54229
# Product_16283
# Product_48248
# Product_12254
# Product_39851
# Product_78386
# Product_64678
# Product_19923
# Product_5348
# Product_39019
# Product_65656
# Product_30308
# Product_15469
# Product_71969
# Product_52585
# Product_15283
# Product_11312
# Product_20643
# Product_37773
# Product_17431
# Product_13617
# Product_4255
# Product_6874
# Product_68476
# Product_79943
# Product_40233
# Product_22043
# Product_57316
# Product_71849
# Product_21363
# Product_22245
# Product_68620
# Product_43225
# Product_4171
# Product_13976
# Product_39857
# Product_44068
# Product_19285
# Product_2487
# Product_34471
# Product_12478
# Product_29022
# Product_36353
# Product_80133
# Product_81639
# Product_70523
# Product_74427
# Product_42212
# Product_22319
# Product_8694
# Product_42848
# Product_82204
# Product_69128
# Product_51065
# Product_30529
# Product_32750
# Product_71413
# Product_41132
# Product_58663
# Product_27170
# Product_29221
# Product_34981
# Product_34899
# Product_17018
# Product_24200
# Product_76191
# Product_36185
# Product_36869
# Product_16470
# Product_28938
# Product_8577
# Product_44398
# Product_22104
# Product_24943
# Product_9130
# Product_164
# Product_59328
# Product_16991
# Product_21491
# Product_51238
# Product_48347
# Product_82513
# Product_9716
# Product_51016
# Product_49244
# Product_11067
# Product_63824
# Product_51810
# Product_59652
# Product_80081
# Product_74155
# Product_70452
# Product_32279
# Product_67116
# Product_24250
# Product_24844
# Product_9052
# Product_38744
# Product_67747
# Product_2374
# Product_15287
# Product_14541
# Product_54784
# Product_2477
# Product_37455
# Product_11471
# Product_74297
# Product_10815
# Product_46476
# Product_4313
# Product_57959
# Product_61588
# Product_57033
# Product_51166
# Product_9523
# Product_18872
# Product_62231
# Product_66869
# Product_16955
# Product_10829
# Product_45648
# Product_23389
# Product_43794
# Product_80099
# Product_39905
# Product_39732
# Product_79352
# Product_54745
# Product_15671
# Product_28330
# Product_61690
# Product_68501
# Product_41897
# Product_42697
# Product_10982
# Product_69209
# Product_551
# Product_12724
# Product_34951
# Product_48225
# Product_79435
# Product_48210
# Product_63627
# Product_40603
# Product_82507
# Product_55538
# Product_32526
# Product_69273
# Product_40468
# Product_13586
# Product_72040
# Product_11362
# Product_52020
# Product_78674
# Product_50698
# Product_23852
# Product_18922
# Product_4607
# Product_58073
# Product_71450
# Product_14974
# Product_6572
# Product_10739
# Product_47685
# Product_62675
# Product_76729
# Product_26894
# Product_25489
# Product_9041
# Product_21072
# Product_14737
# Product_45277
# Product_14876
# Product_13256
# Product_49732
# Product_26223
# Product_53428
# Product_28944
# Product_78317
# Product_27145
# Product_52802
# Product_65459
# Product_27619
# Product_19564
# Product_48499
# Product_55627
# Product_64721
# Product_74584
# Product_21626
# Product_26630
# Product_32713
# Product_67674
# Product_26138
# Product_14203
# Product_16605
# Product_29758
# Product_20564
# Product_9343
# Product_3253
# Product_2884
# Product_43492
# Product_76355
# Product_45663
# Product_35984
# Product_8473
# Product_15312
# Product_28170
# Product_32397
# Product_77970
# Product_17473
# Product_41173
# Product_29278
# Product_80513
# Product_3183
# Product_18820
# Product_81480
# Product_72628
# Product_9169
# Product_9413
# Product_59814
# Product_68316
# Product_48093
# Product_1007
# Product_46255
# Product_75038
# Product_65359
# Product_54988
# Product_13526
# Product_19782
# Product_68608
# Product_31085
# Product_66345
# Product_18331
# Product_24618
# Product_58357
# Product_47381
# Product_38638
# Product_69167
# Product_37898
# Product_47077
# Product_1901
# Product_63161
# Product_46427
# Product_59863
# Product_41649
# Product_76024
# Product_27824
# Product_63631
# Product_47165
# Product_21911
# Product_1871
# Product_74553
# Product_23894
# Product_33196
# Product_34687
# Product_52024
# Product_24872
# Product_65336
# Product_23904
# Product_46487
# Product_22211
# Product_46803
# Product_30760
# Product_68974
# Product_10375
# Product_62233
# Product_62093
# Product_23918
# Product_80888
# Product_52700
# Product_58440
# Product_6432
# Product_54723
# Product_6267
# Product_77465
# Product_54996
# Product_79068
# Product_30109
# Product_6643
# Product_1403
# Product_61487
# Product_13134
# Product_26102
# Product_40182
# Product_34789
# Product_64254
# Product_5219
# Product_50430
# Product_6796
# Product_19230
# Product_56596
# Product_73624
# Product_46991
# Product_11266
# Product_75366
# Product_8059
# Product_15812
# Product_58746
# Product_30406
# Product_79694
# Product_50018
# Product_46490
# Product_9157
# Product_46950
# Product_25136
# Product_36696
# Product_14462
# Product_34877
# Product_57860
# Product_24141
# Product_21380
# Product_56851
# Product_11270
# Product_9587
# Product_45302
# Product_23856
# Product_74579
# Product_47700
# Product_18402
# Product_50552
# Product_55113
# Product_56808
# Product_27136
# Product_62169
# Product_62914
# Product_28254
# Product_35637
# Product_51015
# Product_20154
# Product_74705
# Product_5166
# Product_13007
# Product_43145
# Product_20955
# Product_72750
# Product_34429
# Product_45758
# Product_68997
# Product_74610
# Product_3436
# Product_16676
# Product_4045
# Product_17356
# Product_58730
# Product_59751
# Product_28019
# Product_9306
# Product_23657
# Product_73304
# Product_16852
# Product_51409
# Product_46036
# Product_27872
# Product_15726
# Product_35983
# Product_27774
# Product_30124
# Product_8118
# Product_21708
# Product_64390
# Product_63878
# Product_21048
# Product_60613
# Product_34910
# Product_25607
# Product_23755
# Product_18829
# Product_25826
# Product_30084
# Product_12459
# Product_66467
# Product_25058
# Product_42439
# Product_25088
# Product_66028
# Product_78509
# Product_57931
# Product_76341
# Product_81369
# Product_17687
# Product_13903
# Product_38690
# Product_10097
# Product_48244
# Product_40774
# Product_16420
# Product_66459
# Product_35894
# Product_9284
# Product_81253
# Product_63227
# Product_73365
# Product_61353
# Product_9171
# Product_3560
# Product_46569
# Product_5718
# Product_52091
# Product_13593
# Product_28471
# Product_81435
# Product_61701
# Product_73668
# Product_63603
# Product_60107
# Product_80165
# Product_46194
# Product_12854
# Product_56351
# Product_18704
# Product_80498
# Product_60808
# Product_32256
# Product_34194
# Product_77658
# Product_10817
# Product_29544
# Product_60535
# Product_51567
# Product_50987
# Product_74519
# Product_53587
# Product_11209
# Product_64681
# Product_814
# Product_66712
# Product_8641
# Product_66101
# Product_60334
# Product_41646
# Product_56743
# Product_62606
# Product_46014
# Product_29339
# Product_37528
# Product_55147
# Product_2604
# Product_41489
# Product_24636
# Product_71886
# Product_80449
# Product_67720
# Product_74512
# Product_15934
# Product_39955
# Product_34995
# Product_78454
# Product_54022
# Product_64251
# Product_69699
# Product_3344
# Product_52881
# Product_3243
# Product_38856
# Product_52380
# Product_25182
# Product_356
# Product_40278
# Product_65243
# Product_6225
# Product_14435
# Product_9651
# Product_22925
# Product_66666
# Product_51477
# Product_49013
# Product_45345
# Product_56394
# Product_70463
# Product_49661
# Product_19863
# Product_57609
# Product_78305
# Product_14526
# Product_62577
# Product_46893
# Product_25620
# Product_39211
# Product_7249
# Product_6182
# Product_26077
# Product_23092
# Product_22149
# Product_48112
# Product_67714
# Product_56348
# Product_4090
# Product_47345
# Product_44393
# Product_44557
# Product_47241
# Product_56024
# Product_9033
# Product_53723
# Product_456
# Product_23066
# Product_633
# Product_73941
# Product_74310
# Product_81716
# Product_11315
# Product_75933
# Product_54170
# Product_29324
# Product_44358
# Product_33138
# Product_9713
# Product_20559
# Product_27882
# Product_73322
# Product_7589
# Product_4997
# Product_62478
# Product_67526
# Product_63306
# Product_33762
# Product_10273
# Product_67633
# Product_61258
# Product_24376
# Product_14003
# Product_13665
# Product_54646
# Product_2129
# Product_16608
# Product_80444
# Product_80154
# Product_35581
# Product_31744
# Product_35538
# Product_65470
# Product_54381
# Product_6123
# Product_33057
# Product_18622
# Product_25917
# Product_49125
# Product_7520
# Product_17729
# Product_36499
# Product_9313
# Product_4308
# Product_65908
# Product_59235
# Product_12473
# Product_24336
# Product_7552
# Product_70963
# Product_3530
# Product_80667
# Product_70122
# Product_43789
# Product_44676
# Product_6483
# Product_77473
# Product_22944
# Product_67976
# Product_60070
# Product_71011
# Product_16538
# Product_45035
# Product_55802
# Product_49891
# Product_61725
# Product_63148
# Product_62426
# Product_47645
# Product_30347
# Product_35317
# Product_32011
# Product_58836
# Product_36252
# Product_41130
# Product_71014
# Product_4807
# Product_24654
# Product_77390
# Product_8069
# Product_52377
# Product_26895
# Product_8689
# Product_2627
# Product_13975
# Product_66590
# Product_82554
# Product_10257
# Product_56039
# Product_6208
# Product_42722
# Product_26045
# Product_44835
# Product_29533
# Product_28958
# Product_80636
# Product_51591
# Product_13698
# Product_53216
# Product_51048
# Product_20816
# Product_1818
# Product_82785
# Product_30012
# Product_12503
# Product_22324
# Product_25396
# Product_18472
# Product_83
# Product_31505
# Product_51120
# Product_48021
# Product_82468
# Product_68789
# Product_58454
# Product_38940
# Product_40244
# Product_40180
# Product_19665
# Product_10887
# Product_77560
# Product_73241
# Product_45069
# Product_80477
# Product_46066
# Product_78140
# Product_78657
# Product_47194
# Product_23291
# Product_42905
# Product_72671
# Product_78576
# Product_67188
# Product_22446
# Product_58738
# Product_28367
# Product_26980
# Product_38194
# Product_1240
# Product_72566
# Product_81557
# Product_23354
# Product_71223
# Product_8670
# Product_50852
# Product_51249
# Product_1441
# Product_79382
# Product_16018
# Product_77362
# Product_41248
# Product_34130
# Product_51876
# Product_50069
# Product_70138
# Product_52857
# Product_65080
# Product_76647
# Product_41348
# Product_11231
# Product_542
# Product_5169
# Product_75231
# Product_10138
# Product_47100
# Product_21282
# Product_81543
# Product_51194
# Product_27118
# Product_12307
# Product_77791
# Product_53426
# Product_71305
# Product_11935
# Product_42840
# Product_43780
# Product_62742
# Product_55688
# Product_40359
# Product_81340
# Product_42214
# Product_55977
# Product_15695
# Product_18789
# Product_68881
# Product_74442
# Product_56994
# Product_4065
# Product_3038
# Product_44935
# Product_4478
# Product_78147
# Product_18719
# Product_43881
# Product_16620
# Product_71607
# Product_17338
# Product_75874
# Product_80880
# Product_27639
# Product_19161
# Product_74727
# Product_1192
# Product_79272
# Product_43222
# Product_2593
# Product_6834
# Product_67564
# Product_68725
# Product_14934
# Product_19785
# Product_59049
# Product_4163
# Product_37694
# Product_40495
# Product_32258
# Product_5028
# Product_34127
# Product_78078
# Product_15572
# Product_11575
# Product_8880
# Product_73215
# Product_79915
# Product_35020
# Product_73874
# Product_1071
# Product_47239
# Product_19557
# Product_37142
# Product_34269
# Product_21086
# Product_53909
# Product_73858
# Product_60791
# Product_79483
# Product_42778
# Product_7687
# Product_25669
# Product_63648
# Product_62500
# Product_10308
# Product_30769
# Product_34503
# Product_48539
# Product_64710
# Product_13418
# Product_43521
# Product_79175
# Product_33030
# Product_30738
# Product_26483
# Product_72978
# Product_69810
# Product_68264
# Product_9426
# Product_60544
# Product_30897
# Product_64177
# Product_40632
# Product_48467
# Product_49277
# Product_45177
# Product_32453
# Product_21175
# Product_218
# Product_58484
# Product_60829
# Product_47423
# Product_18863
# Product_81697
# Product_20057
# Product_25196
# Product_43558
# Product_3736
# Product_72022
# Product_27889
# Product_14808
# Product_75352
# Product_78800
# Product_81976
# Product_82740
# Product_8965
# Product_60890
# Product_42992
# Product_82783
# Product_63742
# Product_29916
# Product_82192
# Product_55905
# Product_12894
# Product_72138
# Product_10352
# Product_60938
# Product_2310
# Product_10083
# Product_30329
# Product_2833
# Product_18628
# Product_21076
# Product_70856
# Product_82543
# Product_16246
# Product_57000
# Product_47448
# Product_78805
# Product_47606
# Product_24626
# Product_78625
# Product_33914
# Product_44317
# Product_6151
# Product_12852
# Product_37969
# Product_44325
# Product_72611
# Product_77455
# Product_76360
# Product_19430
# Product_76025
# Product_66638
# Product_76821
# Product_57069
# Product_7777
# Product_26168
# Product_58946
# Product_64615
# Product_17255
# Product_8355
# Product_35494
# Product_32543
# Product_68348
# Product_47107
# Product_13485
# Product_52673
# Product_71410
# Product_59485
# Product_48293
# Product_39657
# Product_73467
# Product_39215
# Product_49364
# Product_35849
# Product_6585
# Product_74831
# Product_21939
# Product_46459
# Product_37255
# Product_14011
# Product_48972
# Product_74121
# Product_67105
# Product_9349
# Product_30095
# Product_64487
# Product_14539
# Product_23351
# Product_1889
# Product_37757
# Product_72560
# Product_69687
# Product_47341
# Product_40262
# Product_9659
# Product_19706
# Product_12667
# Product_8353
# Product_14644
# Product_5843
# Product_33856
# Product_48460
# Product_26935
# Product_60781
# Product_56909
# Product_51778
# Product_25661
# Product_73462
# Product_36620
# Product_4040
# Product_8750
# Product_16079
# Product_75578
# Product_22981
# Product_67883
# Product_44543
# Product_40169
# Product_70531
# Product_30976
# Product_68314
# Product_70135
# Product_69442
# Product_50132
# Product_25184
# Product_73223
# Product_11579
# Product_11943
# Product_26675
# Product_7757
# Product_14928
# Product_28823
# Product_73753
# Product_34048
# Product_30061
# Product_76515
# Product_11843
# Product_32470
# Product_42812
# Product_48639
# Product_45319
# Product_27754
# Product_38093
# Product_43667
# Product_54122
# Product_36844
# Product_23572
# Product_80368
# Product_23496
# Product_7587
# Product_11078
# Product_46657
# Product_24499
# Product_56003
# Product_65396
# Product_36775
# Product_76700
# Product_22930
# Product_56732
# Product_44075
# Product_16705
# Product_57564
# Product_69082
# Product_10745
# Product_21746
# Product_3540
# Product_52486
# Product_8491
# Product_21120
# Product_28835
# Product_61422
# Product_60085
# Product_24485
# Product_34254
# Product_69767
# Product_82483
# Product_53670
# Product_63175
# Product_66729
# Product_375
# Product_46509
# Product_73065
# Product_62453
# Product_77053
# Product_51078
# Product_71499
# Product_76138
# Product_50085
# Product_38046
# Product_31732
# Product_51734
# Product_14692
# Product_25959
# Product_27311
# Product_59401
# Product_19917
# Product_76814
# Product_50793
# Product_7072
# Product_21658
# Product_72722
# Product_5904
# Product_42585
# Product_28942
# Product_8632
# Product_46881
# Product_62488
# Product_55263
# Product_10998
# Product_6079
# Product_36027
# Product_17826
# Product_63389
# Product_11261
# Product_51758
# Product_57119
# Product_77595
# Product_60259
# Product_5880
# Product_72797
# Product_16269
# Product_1822
# Product_12822
# Product_2987
# Product_44886
# Product_70499
# Product_14914
# Product_29505
# Product_42693
# Product_65228
# Product_123
# Product_20147
# Product_15073
# Product_43565
# Product_49966
# Product_9528
# Product_26434
# Product_13035
# Product_6957
# Product_54661
# Product_28134
# Product_10107
# Product_78348
# Product_50066
# Product_49504
# Product_26609
# Product_52721
# Product_56797
# Product_34974
# Product_35974
# Product_50449
# Product_29695
# Product_27980
# Product_64960
# Product_64482
# Product_1745
# Product_6608
# Product_47291
# Product_6499
# Product_55261
# Product_19926
# Product_3731
# Product_50186
# Product_40848
# Product_7541
# Product_40379
# Product_60935
# Product_14822
# Product_117
# Product_36569
# Product_53744
# Product_31119
# Product_1065
# Product_21424
# Product_44741
# Product_73438
# Product_78459
# Product_36645
# Product_50342
# Product_7684
# Product_39052
# Product_2526
# Product_37601
# Product_39394
# Product_71524
# Product_32945
# Product_10355
# Product_4035
# Product_81134
# Product_40292
# Product_28710
# Product_30480
# Product_730
# Product_28194
# Product_49223
# Product_53342
# Product_43734
# Product_77664
# Product_80083
# Product_69300
# Product_66001
# Product_76538
# Product_61330
# Product_20625
# Product_449
# Product_1513
# Product_42557
# Product_19487
# Product_12905
# Product_20296
# Product_1967
# Product_67732
# Product_21848
# Product_33351
# Product_61994
# Product_33626
# Product_32495
# Product_6081
# Product_35397
# Product_24716
# Product_47198
# Product_68165
# Product_21016
# Product_9529
# Product_18892
# Product_47941
# Product_62374
# Product_76532
# Product_69040
# Product_54072
# Product_27382
# Product_55692
# Product_19355
# Product_73383
# Product_26897
# Product_67436
# Product_1464
# Product_64385
# Product_53220
# Product_61172
# Product_32027
# Product_41385
# Product_19725
# Product_38884
# Product_7989
# Product_31817
# Product_82155
# Product_30755
# Product_2688
# Product_60413
# Product_9660
# Product_48766
# Product_46566
# Product_11763
# Product_77451
# Product_36860
# Product_56893
# Product_40125
# Product_12954
# Product_46204
# Product_80927
# Product_58295
# Product_79427
# Product_60971
# Product_16008
# Product_38106
# Product_82366
# Product_80297
# Product_55976
# Product_28997
# Product_50097
# Product_41035
# Product_43276
# Product_70539
# Product_79459
# Product_26782
# Product_26620
# Product_8916
# Product_45362
# Product_7625
# Product_21294
# Product_40740
# Product_41275
# Product_44774
# Product_78098
# Product_44755
# Product_26690
# Product_64821
# Product_37576
# Product_41114
# Product_28215
# Product_35106
# Product_11406
# Product_48191
# Product_44272
# Product_44244
# Product_33411
# Product_56085
# Product_15045
# Product_24351
# Product_49114
# Product_59810
# Product_37277
# Product_7788
# Product_61138
# Product_62390
# Product_63414
# Product_50084
# Product_74638
# Product_60003
# Product_24464
# Product_56225
# Product_1561
# Product_31924
# Product_71977
# Product_1722
# Product_27239
# Product_39034
# Product_43432
# Product_80479
# Product_37025
# Product_69501
# Product_39173
# Product_80413
# Product_9853
# Product_38828
# Product_62851
# Product_70277
# Product_64967
# Product_75081
# Product_81497
# Product_73879
# Product_41922
# Product_78750
# Product_82272
# Product_71376
# Product_30113
# Product_62304
# Product_80833
# Product_28877
# Product_78598
# Product_46522
# Product_31710
# Product_13582
# Product_40832
# Product_70972
# Product_15849
# Product_42181
# Product_11372
# Product_70109
# Product_32317
# Product_15013
# Product_36559
# Product_3677
# Product_40361
# Product_63823
# Product_62730
# Product_65714
# Product_80780
# Product_10841
# Product_19651
# Product_81892
# Product_39021
# Product_25428
# Product_37980
# Product_59183
# Product_26481
# Product_65762
# Product_24705
# Product_50972
# Product_42360
# Product_57610
# Product_851
# Product_52723
# Product_59916
# Product_31142
# Product_42493
# Product_76862
# Product_39280
# Product_81943
# Product_29377
# Product_2268
# Product_11746
# Product_22613
# Product_74859
# Product_44286
# Product_37120
# Product_15586
# Product_39448
# Product_66674
# Product_66733
# Product_43996
# Product_40858
# Product_38957
# Product_26699
# Product_32703
# Product_23526
# Product_17311
# Product_76257
# Product_35256
# Product_51780
# Product_17497
# Product_57148
# Product_76110
# Product_75767
# Product_61520
# Product_77344
# Product_62986
# Product_1626
# Product_8339
# Product_51248
# Product_6018
# Product_23987
# Product_54039
# Product_80443
# Product_53027
# Product_62043
# Product_27921
# Product_73119
# Product_19678
# Product_8217
# Product_136
# Product_7463
# Product_54571
# Product_64995
# Product_69855
# Product_7592
# Product_8526
# Product_20292
# Product_12898
# Product_62232
# Product_5393
# Product_10258
# Product_46838
# Product_54266
# Product_2086
# Product_25228
# Product_9474
# Product_29064
# Product_75361
# Product_13679
# Product_54896
# Product_26017
# Product_51959
# Product_34944
# Product_58118
# Product_52416
# Product_31844
# Product_45738
# Product_2643
# Product_52385
# Product_72755
# Product_37730
# Product_77525
# Product_6694
# Product_1212
# Product_64600
# Product_29137
# Product_53011
# Product_7954
# Product_6753
# Product_42976
# Product_80815
# Product_21517
# Product_50671
# Product_39205
# Product_82160
# Product_42261
# Product_62937
# Product_63204
# Product_22186
# Product_11940
# Product_46223
# Product_17143
# Product_34712
# Product_48343
# Product_18116
# Product_37915
# Product_69405
# Product_17398
# Product_7297
# Product_55862
# Product_49402
# Product_38890
# Product_42853
# Product_18327
# Product_8790
# Product_46837
# Product_68995
# Product_27146
# Product_7698
# Product_26182
# Product_32463
# Product_60059
# Product_22236
# Product_16221
# Product_50127
# Product_16445
# Product_24021
# Product_30486
# Product_79676
# Product_15588
# Product_11622
# Product_35966
# Product_14204
# Product_76078
# Product_2492
# Product_74387
# Product_52847
# Product_67765
# Product_31914
# Product_34563
# Product_96
# Product_47964
# Product_2634
# Product_41947
# Product_33188
# Product_54214
# Product_12192
# Product_57137
# Product_36756
# Product_56666
# Product_30437
# Product_33546
# Product_15322
# Product_51957
# Product_26061
# Product_61813
# Product_4899
# Product_41144
# Product_34046
# Product_14824
# Product_8492
# Product_59443
# Product_65358
# Product_42295
# Product_5278
# Product_71316
# Product_38179
# Product_48723
# Product_58944
# Product_60811
# Product_48018
# Product_44995
# Product_64824
# Product_79082
# Product_15296
# Product_61614
# Product_53127
# Product_19733
# Product_74383
# Product_71650
# Product_5368
# Product_74340
# Product_46408
# Product_45234
# Product_78375
# Product_37705
# Product_26636
# Product_67444
# Product_65521
# Product_49857
# Product_4185
# Product_45171
# Product_16929
# Product_17706
# Product_74904
# Product_69756
# Product_70950
# Product_51812
# Product_12925
# Product_39879
# Product_8004
# Product_23875
# Product_80988
# Product_32
# Product_32431
# Product_81733
# Product_53784
# Product_25197
# Product_29633
# Product_23112
# Product_43064
# Product_11054
# Product_15074
# Product_43088
# Product_23590
# Product_80423
# Product_1774
# Product_28639
# Product_69682
# Product_73656
# Product_69511
# Product_19260
# Product_13472
# Product_14625
# Product_5946
# Product_62651
# Product_60297
# Product_37054
# Product_77352
# Product_32276
# Product_74526
# Product_80952
# Product_68351
# Product_9889
# Product_51839
# Product_1913
# Product_61856
# Product_27778
# Product_51765
# Product_12629
# Product_50311
# Product_8679
# Product_60596
# Product_66870
# Product_43979
# Product_14412
# Product_69310
# Product_54153
# Product_48749
# Product_5834
# Product_63638
# Product_53997
# Product_42617
# Product_60214
# Product_35005
# Product_22532
# Product_25717
# Product_65782
# Product_6188
# Product_15110
# Product_58989
# Product_26226
# Product_67678
# Product_45119
# Product_79037
# Product_58956
# Product_50224
# Product_78637
# Product_12871
# Product_52073
# Product_51437
# Product_62538
# Product_79742
# Product_4338
# Product_23212
# Product_14583
# Product_78210
# Product_77428
# Product_54779
# Product_79868
# Product_22380
# Product_74896
# Product_54742
# Product_15198
# Product_44411
# Product_39442
# Product_5299
# Product_23234
# Product_25309
# Product_77541
# Product_55573
# Product_35438
# Product_65025
# Product_15288
# Product_31422
# Product_42211
# Product_3534
# Product_51942
# Product_48608
# Product_41044
# Product_6331
# Product_26357
# Product_22144
# Product_34781
# Product_59745
# Product_10589
# Product_78904
# Product_69058
# Product_6912
# Product_31649
# Product_3806
# Product_78886
# Product_39534
# Product_41803
# Product_10210
# Product_7298
# Product_59284
# Product_13283
# Product_58403
# Product_63621
# Product_36813
# Product_56628
# Product_65010
# Product_54013
# Product_6721
# Product_39866
# Product_75661
# Product_52177
# Product_47416
# Product_23989
# Product_30412
# Product_70173
# Product_8858
# Product_73064
# Product_35299
# Product_71628
# Product_25507
# Product_15055
# Product_54114
# Product_35373
# Product_44845
# Product_71550
# Product_13311
# Product_46210
# Product_42728
# Product_25323
# Product_22779
# Product_11731
# Product_53970
# Product_69551
# Product_60569
# Product_12227
# Product_36238
# Product_31616
# Product_60843
# Product_38189
# Product_78640
# Product_82641
# Product_1303
# Product_26912
# Product_49008
# Product_74975
# Product_59663
# Product_59631
# Product_22298
# Product_74871
# Product_19568
# Product_59577
# Product_53904
# Product_3602
# Product_33124
# Product_50795
# Product_62036
# Product_50597
# Product_66838
# Product_69176
# Product_61679
# Product_70059
# Product_82102
# Product_28720
# Product_65391
# Product_69533
# Product_18260
# Product_60815
# Product_32828
# Product_39005
# Product_23720
# Product_6130
# Product_48236
# Product_34699
# Product_14235
# Product_54507
# Product_13523
# Product_40734
# Product_78634
# Product_47201
# Product_59136
# Product_7925
# Product_18866
# Product_37242
# Product_62332
# Product_18676
# Product_61920
# Product_29513
# Product_5491
# Product_1807
# Product_50592
# Product_76188
# Product_22859
# Product_11301
# Product_23664
# Product_61260
# Product_52619
# Product_4813
# Product_71671
# Product_19287
# Product_14624
# Product_42858
# Product_49396
# Product_3674
# Product_57755
# Product_6696
# Product_10848
# Product_49026
# Product_20970
# Product_622
# Product_41717
# Product_42998
# Product_78646
# Product_5830
# Product_7184
# Product_61891
# Product_68255
# Product_48813
# Product_9607
# Product_28951
# Product_58573
# Product_81062
# Product_42959
# Product_46243
# Product_33537
# Product_32610
# Product_13208
# Product_56657
# Product_82602
# Product_10184
# Product_66925
# Product_61039
# Product_27707
# Product_13724
# Product_82339
# Product_15909
# Product_41522
# ...
# Product_20260
# Product_10651
# Product_49158
# Product_13315
# Product_49466
# Product_68618
# Product_10267
# Product_37520
# Product_61125
# Product_76508
# Product_32014
# Product_41339
# Product_71665
# Product_67236
# Product_77816
# Product_70515
# Product_19914
# Product_80709
# Product_14205
# Product_23582
# Product_52290
# Product_74040
# Product_26472
# Product_27324
# Product_68869
# Product_9030
# Product_63516
# Product_52584
# Product_56392
# Product_30914
# Product_31174
# Product_10348
# Product_29991
# Product_76552
# Product_71421
# Product_45783
# Product_20875
# Product_53153
# Product_18281
# Product_76620
# Product_2216
# Product_82246
# Product_72013
# Product_42615
# Product_36381
# Product_32482
# Product_63159
# Product_71277
# Product_18735
# Product_41722
# Product_17953
# Product_444
# Product_72052
# Product_46829
# Product_81333
# Product_4883
# Product_22742
# Product_71813
# Product_24735
# Product_72057
# Product_41263
# Product_9410
# Product_76018
# Product_14764
# Product_35809
# Product_4192
# Product_23591
# Product_41351
# Product_55417
# Product_11447
# Product_61753
# Product_75340
# Product_64788
# Product_32233
# Product_58522
# Product_56194
# Product_11017
# Product_39483
# Product_43836
# Product_1113
# Product_22497
# Product_56119
# Product_8946
# Product_24582
# Product_5436
# Product_29774
# Product_23953
# Product_39895
# Product_75128
# Product_35947
# Product_78848
# Product_79415
# Product_36352
# Product_31641
# Product_43546
# Product_15800
# Product_35896
# Product_29040
# Product_16744
# Product_49725
# Product_21470
# Product_77026
# Product_70782
# Product_70543
# Product_55740
# Product_15841
# Product_73572
# Product_34659
# Product_74922
# Product_78887
# Product_75610
# Product_31411
# Product_3373
# Product_9795
# Product_636
# Product_77317
# Product_8072
# Product_78912
# Product_22931
# Product_35277
# Product_54313
# Product_55973
# Product_9628
# Product_51504
# Product_46889
# Product_37462
# Product_80616
# Product_18457
# Product_36224
# Product_63616
# Product_22794
# Product_82401
# Product_411
# Product_82722
# Product_48895
# Product_62924
# Product_55085
# Product_8658
# Product_21344
# Product_48110
# Product_9630
# Product_2510
# Product_71841
# Product_329
# Product_6363
# Product_23160
# Product_74970
# Product_67182
# Product_70436
# Product_50662
# Product_4712
# Product_63605
# Product_21108
# Product_8341
# Product_26698
# Product_1902
# Product_12238
# Product_31698
# Product_26250
# Product_5672
# Product_71230
# Product_11492
# Product_1728
# Product_18081
# Product_18449
# Product_68208
# Product_77761
# Product_58094
# Product_41399
# Product_13458
# Product_23156
# Product_16088
# Product_45872
# Product_10743
# Product_38802
# Product_7158
# Product_4840
# Product_43448
# Product_69226
# Product_5358
# Product_52839
# Product_53006
# Product_52295
# Product_26662
# Product_22656
# Product_12723
# Product_19299
# Product_23738
# Product_43459
# Product_46769
# Product_28503
# Product_22374
# Product_72339
# Product_38345
# Product_67835
# Product_57106
# Product_39675
# Product_73113
# Product_55291
# Product_15351
# Product_2982
# Product_17788
# Product_32282
# Product_16876
# Product_42313
# Product_57172
# Product_21057
# Product_77941
# Product_38393
# Product_51832
# Product_14935
# Product_36241
# Product_62094
# Product_3959
# Product_26278
# Product_7936
# Product_79280
# Product_10732
# Product_66315
# Product_72856
# Product_42094
# Product_41102
# Product_409
# Product_50470
# Product_5067
# Product_3709
# Product_67636
# Product_56518
# Product_27127
# Product_58566
# Product_24751
# Product_24105
# Product_80890
# Product_65454
# Product_81917
# Product_9285
# Product_16393
# Product_41504
# Product_13390
# Product_31115
# Product_63578
# Product_32112
# Product_67445
# Product_72324
# Product_34694
# Product_46695
# Product_78738
# Product_26449
# Product_4862
# Product_12299
# Product_38311
# Product_34337
# Product_15452
# Product_21877
# Product_25204
# Product_2278
# Product_46919
# Product_57180
# Product_36142
# Product_23215
# Product_42093
# Product_14069
# Product_9434
# Product_27817
# Product_47055
# Product_14416
# Product_33249
# Product_45779
# Product_14333
# Product_43089
# Product_35535
# Product_47380
# Product_1039
# Product_24753
# Product_57236
# Product_64712
# Product_53209
# Product_50341
# Product_5305
# Product_12020
# Product_81144
# Product_9793
# Product_15727
# Product_67687
# Product_46834
# Product_71246
# Product_45706
# Product_74596
# Product_35788
# Product_57945
# Product_37272
# Product_9940
# Product_62784
# Product_73185
# Product_49004
# Product_53715
# Product_46274
# Product_68926
# Product_70366
# Product_10835
# Product_31693
# Product_81242
# Product_67785
# Product_74997
# Product_38373
# Product_51465
# Product_31824
# Product_57351
# Product_72961
# Product_38122
# Product_64548
# Product_4654
# Product_17321
# Product_13729
# Product_51598
# Product_80430
# Product_1551
# Product_40766
# Product_9600
# Product_4666
# Product_5200
# Product_68740
# Product_42544
# Product_65810
# Product_7043
# Product_23322
# Product_49510
# Product_11386
# Product_1168
# Product_66769
# Product_75335
# Product_71816
# Product_61988
# Product_45070
# Product_39221
# Product_64468
# Product_69020
# Product_72823
# Product_8431
# Product_17090
# Product_80949
# Product_25004
# Product_67828
# Product_35831
# Product_5746
# Product_33728
# Product_19617
# Product_60804
# Product_41040
# Product_67279
# Product_3302
# Product_12913
# Product_71862
# Product_47934
# Product_29361
# Product_70624
# Product_50866
# Product_19324
# Product_45008
# Product_32047
# Product_52864
# Product_7042
# Product_72519
# Product_8236
# Product_38132
# Product_28212
# Product_7896
# Product_6946
# Product_22664
# Product_47254
# Product_2290
# Product_42660
# Product_67669
# Product_62244
# Product_31160
# Product_67439
# Product_21677
# Product_11196
# Product_73238
# Product_61232
# Product_68713
# Product_70378
# Product_66966
# Product_48320
# Product_57531
# Product_1220
# Product_23903
# Product_47197
# Product_14443
# Product_62527
# Product_31748
# Product_16486
# Product_74689
# Product_23957
# Product_21824
# Product_18492
# Product_47523
# Product_19693
# Product_31167
# Product_59925
# Product_57309
# Product_63200
# Product_69944
# Product_31742
# Product_28378
# Product_6854
# Product_33601
# Product_53230
# Product_1906
# Product_22288
# Product_39027
# Product_70869
# Product_64116
# Product_40654
# Product_19074
# Product_65385
# Product_79848
# Product_27538
# Product_8567
# Product_62995
# Product_55329
# Product_5419
# Product_51245
# Product_80402
# Product_38998
# Product_38822
# Product_29369
# Product_37690
# Product_28305
# Product_50678
# Product_81774
# Product_80931
# Product_75082
# Product_65388
# Product_57191
# Product_18048
# Product_46322
# Product_45650
# Product_12833
# Product_41936
# Product_26503
# Product_10842
# Product_25784
# Product_77229
# Product_22128
# Product_43542
# Product_67536
# Product_71382
# Product_78695
# Product_15574
# Product_46568
# Product_71342
# Product_27302
# Product_2031
# Product_77537
# Product_70192
# Product_75095
# Product_15697
# Product_13416
# Product_20636
# Product_17095
# Product_58736
# Product_80720
# Product_61596
# Product_9974
# Product_64022
# Product_55736
# Product_75220
# Product_52214
# Product_16866
# Product_25932
# Product_12498
# Product_5308
# Product_14217
# Product_80350
# Product_58032
# Product_52166
# Product_74405
# Product_26359
# Product_46142
# Product_57219
# Product_38105
# Product_48924
# Product_26632
# Product_43201
# Product_56234
# Product_49001
# Product_37172
# Product_2914
# Product_39669
# Product_76443
# Product_45470
# Product_61144
# Product_36041
# Product_73933
# Product_11120
# Product_49390
# Product_70655
# Product_1509
# Product_30115
# Product_66997
# Product_31289
# Product_15510
# Product_62319
# Product_63766
# Product_5004
# Product_45141
# Product_41938
# Product_12548
# Product_58263
# Product_30739
# Product_63001
# Product_69251
# Product_29846
# Product_32634
# Product_21220
# Product_1311
# Product_63964
# Product_13865
# Product_31799
# Product_13657
# Product_17562
# Product_57190
# Product_68365
# Product_21351
# Product_23466
# Product_36351
# Product_45153
# Product_68312
# Product_68482
# Product_42139
# Product_62246
# Product_61695
# Product_47285
# Product_82611
# Product_74545
# Product_9505
# Product_37940
# Product_541
# Product_17560
# Product_15314
# Product_81279
# Product_67627
# Product_81552
# Product_61009
# Product_2862
# Product_67192
# Product_60915
# Product_80038
# Product_81075
# Product_62687
# Product_79755
# Product_10367
# Product_29390
# Product_54231
# Product_64103
# Product_77190
# Product_5611
# Product_42820
# Product_80574
# Product_10183
# Product_78692
# Product_14969
# Product_39974
# Product_64398
# Product_29763
# Product_16560
# Product_44365
# Product_27498
# Product_75771
# Product_31055
# Product_81620
# Product_10207
# Product_37166
# Product_64527
# Product_23067
# Product_51673
# Product_71617
# Product_17896
# Product_31118
# Product_30881
# Product_21892
# Product_72548
# Product_8984
# Product_16971
# Product_48651
# Product_58492
# Product_42530
# Product_69721
# Product_16506
# Product_78930
# Product_8476
# Product_53689
# Product_3145
# Product_27898
# Product_46344
# Product_35155
# Product_48067
# Product_40397
# Product_49020
# Product_16759
# Product_64591
# Product_39156
# Product_34543
# Product_65492
# Product_14594
# Product_67230
# Product_81679
# Product_42060
# Product_3693
# Product_61372
# Product_19611
# Product_64063
# Product_65090
# Product_69473
# Product_80045
# Product_5681
# Product_47086
# Product_10634
# Product_25347
# Product_24679
# Product_49860
# Product_9287
# Product_80114
# Product_55327
# Product_4099
# Product_45504
# Product_78399
# Product_69776
# Product_21128
# Product_44647
# Product_41043
# Product_79152
# Product_1469
# Product_57608
# Product_25011
# Product_31734
# Product_72592
# Product_60787
# Product_53303
# Product_66536
# Product_76707
# Product_35015
# Product_57260
# Product_16250
# Product_52556
# Product_28397
# Product_23512
# Product_23363
# Product_11514
# Product_47179
# Product_55341
# Product_72512
# Product_1861
# Product_61923
# Product_23697
# Product_28430
# Product_27544
# Product_6971
# Product_36502
# Product_82356
# Product_9292
# Product_8989
# Product_39970
# Product_16151
# Product_37856
# Product_73899
# Product_64272
# Product_26323
# Product_79103
# Product_9880
# Product_58248
# Product_31354
# Product_19753
# Product_36547
# Product_4004
# Product_12291
# Product_28292
# Product_8166
# Product_5048
# Product_67723
# Product_42516
# Product_45645
# Product_8157
# Product_16293
# Product_19157
# Product_41391
# Product_11613
# Product_1162
# Product_66971
# Product_47560
# Product_34522
# Product_37741
# Product_63029
# Product_19419
# Product_16696
# Product_12451
# Product_20388
# Product_20120
# Product_62045
# Product_69046
# Product_33521
# Product_73567
# Product_67580
# Product_46828
# Product_46909
# Product_34821
# Product_66360
# Product_6756
# Product_13576
# Product_70723
# Product_853
# Product_8344
# Product_6084
# Product_38383
# Product_54976
# Product_38413
# Product_21479
# Product_34535
# Product_61046
# Product_14108
# Product_32782
# Product_3086
# Product_25143
# Product_63133
# Product_81831
# Product_26781
# Product_14402
# Product_64471
# Product_60620
# Product_55187
# Product_8684
# Product_70176
# Product_80071
# Product_65920
# Product_51420
# Product_8125
# Product_22129
# Product_73802
# Product_26104
# Product_7722
# Product_67111
# Product_29155
# Product_66942
# Product_48627
# Product_14065
# Product_75519
# Product_31016
# Product_39494
# Product_78781
# Product_11088
# Product_33051
# Product_58300
# Product_15191
# Product_73626
# Product_73820
# Product_35205
# Product_25033
# Product_77793
# Product_2162
# Product_75827
# Product_82705
# Product_56117
# Product_63199
# Product_65094
# Product_24878
# Product_38147
# Product_40564
# Product_50296
# Product_9384
# Product_15113
# Product_16994
# Product_76226
# Product_42010
# Product_65619
# Product_75555
# Product_64902
# Product_4850
# Product_44370
# Product_44213
# Product_16442
# Product_27431
# Product_54926
# Product_7466
# Product_53634
# Product_55265
# Product_9947
# Product_57899
# Product_72769
# Product_60143
# Product_68561
# Product_49909
# Product_81294
# Product_56745
# Product_9247
# Product_62777
# Product_51147
# Product_36752
# Product_32742
# Product_36757
# Product_70838
# Product_21944
# Product_22302
# Product_53725
# Product_67102
# Product_27908
# Product_19613
# Product_34559
# Product_66701
# Product_60868
# Product_70698
# Product_19735
# Product_58318
# Product_66660
# Product_57384
# Product_43505
# Product_28492
# Product_39090
# Product_5921
# Product_22097
# Product_29819
# Product_62025
# Product_15499
# Product_55670
# Product_30505
# Product_12782
# Product_61974
# Product_46303
# Product_12606
# Product_65982
# Product_62560
# Product_15893
# Product_44715
# Product_20907
# Product_79949
# Product_55530
# Product_57734
# Product_16402
# Product_43722
# Product_43199
# Product_18242
# Product_65431
# Product_77952
# Product_73639
# Product_4005
# Product_66032
# Product_26110
# Product_2552
# Product_45135
# Product_29588
# Product_16452
# Product_56658
# Product_463
# Product_47013
# Product_74958
# Product_40454
# Product_3836
# Product_26861
# Product_38364
# Product_33245
# Product_26367
# Product_29871
# Product_72177
# Product_26626
# Product_72256
# Product_12051
# Product_73896
# Product_13832
# Product_44236
# Product_15616
# Product_6628
# Product_52750
# Product_56122
# Product_9576
# Product_30282
# Product_20035
# Product_41708
# Product_32738
# Product_34292
# Product_82429
# Product_56724
# Product_57926
# Product_50849
# Product_19563
# Product_1662
# Product_63949
# Product_6367
# Product_62652
# Product_72397
# Product_79473
# Product_1697
# Product_55734
# Product_35929
# Product_1646
# Product_50284
# Product_55434
# Product_80172
# Product_51615
# Product_17603
# Product_80010
# Product_48394
# Product_36800
# Product_72701
# Product_69946
# Product_52033
# Product_54084
# Product_62242
# Product_24518
# Product_42780
# Product_62487
# Product_65253
# Product_68037
# Product_42967
# Product_59645
# Product_81484
# Product_510
# Product_26947
# Product_20275
# Product_34382
# Product_39929
# Product_7343
# Product_82342
# Product_40887
# Product_36557
# Product_51560
# Product_35228
# Product_21243
# Product_17720
# Product_36076
# Product_38144
# Product_23194
# Product_47364
# Product_34787
# Product_13970
# Product_61842
# Product_46093
# Product_39481
# Product_64449
# Product_29217
# Product_35437
# Product_10383
# Product_28536
# Product_58126
# Product_3142
# Product_32005
# Product_30025
# Product_32052
# Product_41081
# Product_76173
# Product_52883
# Product_41378
# Product_16288
# Product_26948
# Product_76564
# Product_78555
# Product_10414
# Product_46602
# Product_46730
# Product_69602
# Product_17436
# Product_11415
# Product_54713
# Product_74681
# Product_45671
# Product_22888
# Product_19029
# Product_25835
# Product_64500
# Product_36099
# Product_32432
# Product_16624
# Product_16567
# Product_45289
# Product_34032
# Product_29385
# Product_41000
# Product_72432
# Product_53574
# Product_29979
# Product_50611
# Product_1673
# Product_49167
# Product_79129
# Product_66670
# Product_81711
# Product_27374
# Product_75449
# Product_59672
# Product_54579
# Product_6607
# Product_36764
# Product_26055
# Product_41141
# Product_12205
# Product_68089
# Product_79548
# Product_3055
# Product_80718
# Product_14023
# Product_76239
# Product_31807
# Product_67512
# Product_28520
# Product_17513
# Product_25430
# Product_77509
# Product_54852
# Product_46312
# Product_6849
# Product_32878
# Product_6837
# Product_36111
# Product_24671
# Product_41802
# Product_21223
# Product_73637
# Product_58022
# Product_72118
# Product_74712
# Product_77529
# Product_81920
# Product_55091
# Product_14942
# Product_50577
# Product_63592
# Product_1559
# Product_26067
# Product_56898
# Product_3749
# Product_28141
# Product_31789
# Product_28144
# Product_77699
# Product_31471
# Product_21390
# Product_14815
# Product_53799
# Product_80296
# Product_78655
# Product_46202
# Product_52224
# Product_59561
# Product_60956
# Product_63818
# Product_59182
# Product_77769
# Product_75529
# Product_29444
# Product_24798
# Product_72301
# Product_29464
# Product_71086
# Product_80195
# Product_74025
# Product_19479
# Product_12199
# Product_4855
# Product_78582
# Product_56361
# Product_68043
# Product_19640
# Product_24417
# Product_70201
# Product_12453
# Product_54759
# Product_22579
# Product_54133
# Product_74509
# Product_78337
# Product_57856
# Product_24010
# Product_77702
# Product_22839
# Product_31343
# Product_61238
# Product_40793
# Product_23943
# Product_73767
# Product_9900
# Product_74225
# Product_71863
# Product_17457
# Product_72198
# Product_31936
# Product_50161
# Product_52284
# Product_66176
# Product_2166
# Product_36626
# Product_16388
# Product_79674
# Product_45628
# Product_79425
# Product_32966
# Product_76667
# Product_39371
# Product_74757
# Product_21996
# Product_55615
# Product_36842
# Product_15706
# Product_2068
# Product_74211
# Product_78028
# Product_56231
# Product_15944
# Product_75617
# Product_34039
# Product_20470
# Product_56703
# Product_51282
# Product_77792
# Product_70664
# Product_20194
# Product_35469
# Product_62804
# Product_59609
# Product_18175
# Product_35692
# Product_1995
# Product_39437
# Product_77005
# Product_37911
# Product_78107
# Product_54934
# Product_51086
# Product_52400
# Product_36249
# Product_11938
# Product_66561
# Product_58441
# Product_17489
# Product_53643
# Product_42019
# Product_32606
# Product_62198
# Product_15135
# Product_9719
# Product_16476
# Product_74790
# Product_82043
# Product_1235
# Product_60744
# Product_27399
# Product_66667
# Product_61409
# Product_60939
# Product_33410
# Product_38425
# Product_48984
# Product_9279
# Product_2963
# Product_77408

# %%
missing_products_info = products_data[products_data["product_id"].isin(missing_from_train)]

# Display the missing products dataframe
missing_products_info
# Out:
#           product_id             product_description department_key  \
# 9      Product_47445         LORINA CRISTAL SS 1,25L  Department_10
# 13     Product_51620    33CL LIMONADE LA BEAUCERONNE  Department_10
# 18     Product_39850  75CL LORINA LIMONADE CITRON VT  Department_10
# 22     Product_62743     75 CL BELVOIR SUREAU ET ROS  Department_10
# 26     Product_63867                6X50CL LIMONETTE  Department_10
# ...              ...                             ...            ...
# 82960  Product_57956  885558 CUSHION 4 BLANC CAS2 TU  Department_65
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 9      Class_1000  SubClass_10000                      PGC      LORINA
# 13     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 18     Class_1000  SubClass_10000                      PGC      LORINA
# 22     Class_1000  SubClass_10000                      PGC     BELVOIR
# 26     Class_1000  SubClass_10000                      PGC   LIMONETTE
# ...           ...             ...                      ...         ...
# 82960  Class_6573  SubClass_65730                  TEXTILE    TEX HOME
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1                         shelf_level2  \
# 9                  Boissons  Colas, Thés glacés, Sirops et Sodas
# 13                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 18                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 22                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 26                 Boissons  Colas, Thés glacés, Sirops et Sodas
# ...                     ...                                  ...
# 82960  Maison et Décoration               Mobilier et Décoration
# 82961     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82963            Animalerie                               Chiens
# 82965  Maison et Décoration                    Bouteilles de gaz
#
#                              shelf_level3                     shelf_level4  \
# 9              Limonades, Limes et Tonics                              NaN
# 13             Limonades, Limes et Tonics                              NaN
# 18             Limonades, Limes et Tonics                              NaN
# 22             Limonades, Limes et Tonics                              NaN
# 26             Limonades, Limes et Tonics                              NaN
# ...                                   ...                              ...
# 82960  Décorations et Parfums d'intérieur   Coussins et galettes de chaise
# 82961                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82962                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82963      Colliers, Laisses et Vêtements          Vêtements et Chaussures
# 82965                                 NaN                              NaN
#
#        bio  sugar_free  aspartame_free  gluten_free  halal  casher  \
# 9        0           1               0            0      0       0
# 13       0           0               0            0      0       0
# 18       0           0               0            0      0       0
# 22       0           0               0            0      0       0
# 26       0           0               0            0      0       0
# ...    ...         ...             ...          ...    ...     ...
# 82960    0           0               0            0      0       0
# 82961    0           0               0            0      0       0
# 82962    0           0               0            0      0       0
# 82963    0           0               0            0      0       0
# 82965    0           0               0            0      0       0
#
#        eco_friendly  local_french  artificial_coloring_free  \
# 9                 0             0                         0
# 13                0             0                         0
# 18                0             0                         0
# 22                0             0                         0
# 26                0             0                         0
# ...             ...           ...                       ...
# 82960             0             0                         0
# 82961             0             0                         0
# 82962             0             0                         0
# 82963             0             0                         0
# 82965             0             0                         0
#
#        taste_enhancer_free  naturality  antibiotic_free  reduced_sugar  \
# 9                        0           0                0              1
# 13                       0           0                0              0
# 18                       0           0                0              0
# 22                       0           0                0              0
# 26                       0           0                0              0
# ...                    ...         ...              ...            ...
# 82960                    0           0                0              0
# 82961                    0           0                0              0
# 82962                    0           0                0              0
# 82963                    0           0                0              0
# 82965                    0           0                0              0
#
#        vegetarian  pesticide_free  grain_free  no_added_sugar  salt_reduced  \
# 9               0               0           0               0             0
# 13              0               0           0               0             0
# 18              0               0           0               0             0
# 22              0               0           0               0             0
# 26              0               0           0               0             0
# ...           ...             ...         ...             ...           ...
# 82960           0               0           0               0             0
# 82961           0               0           0               0             0
# 82962           0               0           0               0             0
# 82963           0               0           0               0             0
# 82965           0               0           0               0             0
#
#        nitrite_free  fed_without_ogm  no_added_salt  no_artificial_flavours  \
# 9                 0                0              0                       0
# 13                0                0              0                       0
# 18                0                0              0                       0
# 22                0                0              0                       0
# 26                0                0              0                       0
# ...             ...              ...            ...                     ...
# 82960             0                0              0                       0
# 82961             0                0              0                       0
# 82962             0                0              0                       0
# 82963             0                0              0                       0
# 82965             0                0              0                       0
#
#        porc  vegan  frozen  fat_free  reduced_fats  fresh  alcool  \
# 9         0      0       0         0             0      0       0
# 13        0      0       0         0             0      0       0
# 18        0      0       0         0             0      0       0
# 22        0      0       0         0             0      0       0
# 26        0      0       0         0             0      0       0
# ...     ...    ...     ...       ...           ...    ...     ...
# 82960     0      0       0         0             0      0       0
# 82961     0      0       0         0             0      0       0
# 82962     0      0       0         0             0      0       0
# 82963     0      0       0         0             0      0       0
# 82965     0      0       0         0             0      0       0
#
#        lactose_free  phenylalanine_free  palm_oil_free ecoscore  \
# 9                 0                   0              0      NaN
# 13                0                   0              0      NaN
# 18                0                   0              0      NaN
# 22                0                   0              0      NaN
# 26                0                   0              0      NaN
# ...             ...                 ...            ...      ...
# 82960             0                   0              0      NaN
# 82961             0                   0              0      NaN
# 82962             0                   0              0      NaN
# 82963             0                   0              0      NaN
# 82965             0                   0              0      NaN
#
#        produits_du_monde  regional_product  national_brand  first_price_brand  \
# 9                      0                 0               1                  0
# 13                     0                 0               1                  0
# 18                     0                 0               1                  0
# 22                     0                 0               1                  0
# 26                     0                 1               1                  0
# ...                  ...               ...             ...                ...
# 82960                  0                 0               0                  0
# 82961                  0                 0               0                  0
# 82962                  0                 0               0                  0
# 82963                  0                 0               0                  0
# 82965                  0                 0               0                  0
#
#        carrefour_brand
# 9                    0
# 13                   0
# 18                   0
# 22                   0
# 26                   0
# ...                ...
# 82960                1
# 82961                1
# 82962                1
# 82963                1
# 82965                1
#
# [29406 rows x 49 columns]

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %% [markdown]
# # Negative Sampling using Embeddings

# %%
train_data
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 0        Household_40549  Product_63337         0       1.0      700      1
# 1        Household_40549  Product_67694         0       2.0      554      6
# 2        Household_40549  Product_38531         0       1.0      693      2
# 3        Household_40549  Product_35862         0       1.0      672      2
# 4        Household_40549  Product_26610         0       4.0      554      6
# ...                  ...            ...       ...       ...      ...    ...
# 8750910  Household_46292  Product_34316         0       1.0       62     10
# 8750911  Household_46292  Product_37636         0       1.0       36     11
# 8750912  Household_46292  Product_42748         0       1.0       62     10
# 8750913  Household_46292  Product_77775         0       1.0       36     11
# 8750914  Household_46292  Product_64067         0       1.0       82     10
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 0                  6           1                       586
# 1                  5           1                       440
# 2                  6           1                       579
# 3                  6           1                       558
# 4                  5           1                       440
# ...              ...         ...                       ...
# 8750910            0           0                        59
# 8750911            5           1                        33
# 8750912            0           0                        59
# 8750913            5           1                        33
# 8750914            1           0                        79
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 0                      1204      1.460133     0.029070              293
# 1                      1204      1.460133     0.029070              293
# 2                      1204      1.460133     0.029070              293
# 3                      1204      1.460133     0.029070              293
# 4                      1204      1.460133     0.029070              293
# ...                     ...           ...          ...              ...
# 8750910                1189      1.339781     0.022708              645
# 8750911                1189      1.339781     0.022708              645
# 8750912                1189      1.339781     0.022708              645
# 8750913                1189      1.339781     0.022708              645
# 8750914                1189      1.339781     0.022708              645
#
# [8750915 rows x 13 columns]

# %%
len(train_data)
# Out:
# 8750915

# %%
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np
import pandas as pd

# Generate a list of all unique product IDs
all_product_ids = set(product_embedding_dict.keys())

# Prepare for storing negative samples
negative_samples = []

# Group by customer for efficient processing
customer_groups = train_data.groupby('customer_id')

for customer_id, group in tqdm(customer_groups, desc="Generating hard negative samples"):
    # Purchased products for the current customer
    purchased_products = set(group['product_id'])

    # Non-purchased products for the current customer
    non_purchased_products = list(all_product_ids - purchased_products)

    # Skip if there are no products to compare
    if len(non_purchased_products) == 0 or len(purchased_products) == 0:
        continue

    # Get embeddings for purchased and non-purchased products
    purchased_embeddings = np.array([product_embedding_dict[pid] for pid in purchased_products])
    non_purchased_embeddings = np.array([product_embedding_dict[pid] for pid in non_purchased_products])

    # Reshape to ensure 2D arrays
    purchased_embeddings = purchased_embeddings.reshape(-1, purchased_embeddings.shape[-1])
    non_purchased_embeddings = non_purchased_embeddings.reshape(-1, non_purchased_embeddings.shape[-1])

    # Compute cosine similarity between non-purchased and purchased products
    similarity_scores = cosine_similarity(non_purchased_embeddings, purchased_embeddings)

    # Identify the most similar non-purchased products (hard.  negatives)
    most_similar_indices = np.argsort(-similarity_scores, axis=0)[:len(group)]
    #hard_negatives = {non_purchased_products[i] for i in most_similar_indices.flatten()}[:len(group)]
    # Flatten and select up to len(group) unique hard negatives
    hard_negatives = list({non_purchased_products[i] for i in most_similar_indices.flatten()})[:len(group)]


    # Append hard negatives as negative samples
    negative_samples.extend([{
        'customer_id': customer_id,
        'product_id': product_id,
        'quantity': 0  # Indicating negative sample
    } for product_id in hard_negatives])

# Convert negative samples to a DataFrame
negative_samples_df = pd.DataFrame(negative_samples)

# Append negative samples to the original training data
train_data = pd.concat([train_data, negative_samples_df], ignore_index=True)

# Update relevance column (1 for purchased, 0 for negatives)
train_data['relevance'] = (train_data['quantity'] > 0).astype(int)
# Out:
# Generating hard negative samples: 100%|██████████| 9999/9999 [9:36:36<00:00,  3.46s/it]

# %%
train_data.tail()
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 17501825  Household_49999  Product_21623       NaN       0.0      NaN    NaN
# 17501826  Household_49999  Product_28539       NaN       0.0      NaN    NaN
# 17501827  Household_49999  Product_32098       NaN       0.0      NaN    NaN
# 17501828  Household_49999  Product_47992       NaN       0.0      NaN    NaN
# 17501829  Household_49999  Product_47395       NaN       0.0      NaN    NaN
#
#           day_of_week  is_weekend  days_since_last_purchase  \
# 17501825          NaN         NaN                       NaN
# 17501826          NaN         NaN                       NaN
# 17501827          NaN         NaN                       NaN
# 17501828          NaN         NaN                       NaN
# 17501829          NaN         NaN                       NaN
#
#           purchase_frequency  avg_quantity  promo_ratio  unique_products  \
# 17501825                 NaN           NaN          NaN              NaN
# 17501826                 NaN           NaN          NaN              NaN
# 17501827                 NaN           NaN          NaN              NaN
# 17501828                 NaN           NaN          NaN              NaN
# 17501829                 NaN           NaN          NaN              NaN
#
#           relevance
# 17501825          0
# 17501826          0
# 17501827          0
# 17501828          0
# 17501829          0

# %%
# Check for missing values
print("Missing values in train_data:")
print(train_data.isnull().sum())

print("Missing values in test_data:")
print(test_data.isnull().sum())

# Fill remaining missing values with zeros as a safety measure
train_data = train_data.fillna(0)
test_data = test_data.fillna(0)
# Out:
# Missing values in train_data:
# customer_id                       0
# product_id                        0
# is_promo                    8750915
# quantity                          0
# recency                     8750915
# month                       8750915
# day_of_week                 8750915
# is_weekend                  8750915
# days_since_last_purchase    8750915
# purchase_frequency          8750915
# avg_quantity                8750915
# promo_ratio                 8750915
# unique_products             8750915
# relevance                         0
# dtype: int64
# Missing values in test_data:
# transaction_id    0
# customer_id       0
# product_id        0
# dtype: int64

# %%
train_data = train_data.drop(columns=['day_of_week','is_weekend','unique_products'])

# %%
# prompt: in train_data for household Household_9247 count how manyrelevance 1 and how many are 0.

# Assuming 'train_data' DataFrame is already loaded as in the provided code.

household_9247_data = train_data[train_data['customer_id'] == 'Household_76806']

relevance_counts = household_9247_data['relevance'].value_counts()

print(f"Relevance counts for Household_9247:")
relevance_counts
# Out:
# Relevance counts for Household_9247:
# Series([], Name: count, dtype: int64)

# %%
train_data.to_csv(os.path.join(trainFolder, 'train_data_all_5.csv'), index=False)

# %%
len(train_data)
# Out:
# 17501830

# %%
train_data
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 0         Household_40549  Product_63337       0.0       1.0    700.0    1.0
# 1         Household_40549  Product_67694       0.0       2.0    554.0    6.0
# 2         Household_40549  Product_38531       0.0       1.0    693.0    2.0
# 3         Household_40549  Product_35862       0.0       1.0    672.0    2.0
# 4         Household_40549  Product_26610       0.0       4.0    554.0    6.0
# ...                   ...            ...       ...       ...      ...    ...
# 17501825  Household_49999  Product_21623       0.0       0.0      0.0    0.0
# 17501826  Household_49999  Product_28539       0.0       0.0      0.0    0.0
# 17501827  Household_49999  Product_32098       0.0       0.0      0.0    0.0
# 17501828  Household_49999  Product_47992       0.0       0.0      0.0    0.0
# 17501829  Household_49999  Product_47395       0.0       0.0      0.0    0.0
#
#           days_since_last_purchase  purchase_frequency  avg_quantity  \
# 0                            586.0              1204.0      1.460133
# 1                            440.0              1204.0      1.460133
# 2                            579.0              1204.0      1.460133
# 3                            558.0              1204.0      1.460133
# 4                            440.0              1204.0      1.460133
# ...                            ...                 ...           ...
# 17501825                       0.0                 0.0      0.000000
# 17501826                       0.0                 0.0      0.000000
# 17501827                       0.0                 0.0      0.000000
# 17501828                       0.0                 0.0      0.000000
# 17501829                       0.0                 0.0      0.000000
#
#           promo_ratio  relevance
# 0             0.02907          1
# 1             0.02907          1
# 2             0.02907          1
# 3             0.02907          1
# 4             0.02907          1
# ...               ...        ...
# 17501825      0.00000          0
# 17501826      0.00000          0
# 17501827      0.00000          0
# 17501828      0.00000          0
# 17501829      0.00000          0
#
# [17501830 rows x 11 columns]

# %%
products_data
