# %% [markdown]
# ## IMPORTS

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# !pip install tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.colab import drive
drive.mount('/content/gdrive')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Import necessary libraries

import torch

# Load pre-trained BERT model and tokenizer
trainFolder = "gdrive/My Drive/MLDM - Carrefour Project/data-train"

import os
for dirname, _, filenames in os.walk(f'{trainFolder}'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.67.1)
# Mounted at /content/gdrive
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/test_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_10.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_2.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_3.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_4.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_5.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_6.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_7.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_8.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_9.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe_fixed.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data_bert1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/submission_01.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations_combined.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_all.csv

# %%
# Import libraries
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Description
#
# This project uses three datasets:
#
# #### `train_data.csv`:
# This dataset contains two years (2022 & 2023) of historical transactions for 100,000 Carrefour customers. It has 10 columns:
#
# * ***date***: Date of the transaction
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: Product purchased
# * ***has_loyality_card***: Flag indicating whether the customer has a loyalty card
# * ***store_id***: Store where the purchase was made
# * ***is_promo***: Flag indicating whether there was a discount on the product
# * ***quantity***: Quantity purchased of the product
# * ***format***: Ecommerce activity format (clcv, lex, or DRIVE)
#   - clcv : courses livrées chez vous
#   - lex : livraison express
#   - DRIVE.
# * ***orderChannelCode***: Indicates whether the online activity was made through the website or mobile app

# %% [markdown]
# #### `products_data.csv`:
# This dataset contains detailed information about the products. The following columns are relevant to this project:
#
# * ***product_id*** : Product name
# * ***product_description*** : Product description
# * ***department_key***: Department key
# * ***class_key***: Class key
# * ***subclass_key***: Subclass key
# * ***sector***: sector name
# * ***brand_key***: Brand name
# * ***shelf_level1***: Top-level shelf category
# * ***shelf_level2***: Second-level shelf category
# * ***shelf_level3***: Third-level shelf category
# * ***shelf_level4***: Fourth-level shelf category
# * ***sector***: Sector
# * ***bio***: Flag indicating whether the product is organic
# * ***sugar_free***: Flag indicating whether the product is sugar-free
# * ***aspartame_free***: Flag indicating whether the product is aspartame-free
# * ***gluten_free***: Flag indicating whether the product is gluten-free
# * ***halal***: Flag indicating whether the product is halal
# * ***casher***: Flag indicating whether the product is kosher
# * ***eco_friendly***: Flag indicating whether the product is eco-friendly
# * ***local_french***: Flag indicating whether the product is locally produced in France
# * ***artificial_coloring_free***: Flag indicating whether the product is free of artificial coloring
# * ***taste_enhancer_free***: Flag indicating whether the product is free of taste enhancers
# * ***naturality***: Naturality score
# * ***antibiotic_free***: Flag indicating whether the product is antibiotic-free
# * ***reduced_sugar***: Flag indicating whether the product has reduced sugar content
# * ***vegetarian***: Flag indicating whether the product is vegetarian
# * ***pesticide_free***: Flag indicating whether the product is pesticide-free
# * ***grain_free***: Flag indicating whether the product is grain-free
# * ***no_added_sugar***: Flag indicating whether the product has no added sugar
# * ***salt_reduced***: Flag indicating whether the product has reduced salt content
# * ***nitrite_free***: Flag indicating whether the product is nitrite-free
# * ***fed_without_ogm***: Flag indicating whether the animals were fed without GMOs
# * ***no_added_salt***: Flag indicating whether the product has no added salt
# * ***no_artificial_flavours***: Flag indicating whether the product has no artificial flavors
# * ***porc***: Flag indicating whether the product contains pork
# * ***vegan***: Flag indicating whether the product is vegan
# * ***frozen***: Flag indicating whether the product is frozen
# * ***fat_free***: Flag indicating whether the product is fat-free
# * ***reduced_fats***: Flag indicating whether the product has reduced fat content
# * ***fresh***: Flag indicating whether the product is fresh
# * ***alcool***: Flag indicating whether the product contains alcohol
# * ***lactose_free***: Flag indicating whether the product is lactose-free
# * ***phenylalanine_free***: Flag indicating whether the product is phenylalanine-free
# * ***palm_oil_free***: Flag indicating whether the product is palm oil-free
# * ***ecoscore***: Ecoscore
# * ***produits_du_monde***: Flag indicating whether the product is an international product
# * ***regional_product***: Flag indicating whether the product is a regional product
# * ***national_brand***: Flag indicating whether the product is a national brand
# * ***first_price_brand***: Flag indicating whether the product is a first-price brand
# * ***carrefour_brand***: Flag indicating whether the product is a Carrefour brand

# %% [markdown]
# #### `test_data.csv`:
# This dataset contains the actual purchases of the first 80,000 customers in 2024. It has three columns:
#
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: the id of the purchased product

# %% [markdown]
# ### Load data
#
# * Load *train_data.csv*, *products_data.csv* and *test_data.csv* using pandas.

# %%
# This code reads the data from CSV files named "train_data_part_i.csv" for all i from 1 to 10
# and concatenates them into a single pandas DataFrame
train_dataframes = []
for i in tqdm(range(1, 11)): ## 1 - 11
    train_dataframes.append(pd.read_csv(f'{trainFolder}/train_data_part_{i}.csv'))
train_data = pd.concat(train_dataframes, ignore_index=True)

# free up memory by deleting the dataframes we no longer need
del train_dataframes
# Out:
# 100%|██████████| 10/10 [02:04<00:00, 12.42s/it]

# %%
#train_data = train_data.sample(frac=0.1, random_state=1)  # frac=0.1 takes 10% of the data

# %%
# This code reads the data from a CSV file named "products_data.csv" into a pandas DataFrame
products_data = pd.read_csv(f'{trainFolder}/products_data.csv')
# Out:
# <ipython-input-5-d8cc84ca7717>:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   products_data = pd.read_csv(f'{trainFolder}/products_data.csv')

# %%
# This code reads the data from a CSV file named "test_data.csv" into a pandas DataFrame
test_data = pd.read_csv(f'{trainFolder}/test_data.csv')

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 0         2023-11-15  Transaction_1730125     Household_39   Product_5362
# 1         2022-07-20  Transaction_1560535     Household_39  Product_67174
# 2         2022-07-20  Transaction_1560535     Household_39  Product_82254
# 3         2023-11-15  Transaction_1730125     Household_39   Product_3895
# 4         2022-07-20  Transaction_1560535     Household_39  Product_34014
# ...              ...                  ...              ...            ...
# 87037457  2022-01-07  Transaction_1162379  Household_96742  Product_28756
# 87037458  2023-08-17  Transaction_2306043  Household_96742  Product_62786
# 87037459  2022-10-12  Transaction_1524531  Household_96742  Product_16362
# 87037460  2023-03-10  Transaction_1972306  Household_96742  Product_78870
# 87037461  2022-05-12  Transaction_1971250  Household_96742  Product_10052
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 0                         0     Store_2         0       1.0  DRIVE
# 1                         0     Store_2         0       2.0  DRIVE
# 2                         0     Store_2         0       2.0  DRIVE
# 3                         0     Store_2         0       1.0  DRIVE
# 4                         0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 87037457                  0  Store_2542         0       1.0  DRIVE
# 87037458                  0  Store_2542         0       1.0  DRIVE
# 87037459                  0  Store_2542         0       1.0  DRIVE
# 87037460                  0  Store_2542         0       1.0  DRIVE
# 87037461                  0  Store_2542         0       1.0  DRIVE
#
#          order_channel
# 0           MOBILE_APP
# 1              WEBSITE
# 2              WEBSITE
# 3           MOBILE_APP
# 4              WEBSITE
# ...                ...
# 87037457    MOBILE_APP
# 87037458    MOBILE_APP
# 87037459    MOBILE_APP
# 87037460    MOBILE_APP
# 87037461    MOBILE_APP
#
# [87037462 rows x 10 columns]

# %%
# prompt: print from train_date rows with customer id Household_80001
import pandas as pd

# Create a list of customer IDs within the specified range
#customer_ids_new = [f'Household_{i}' for i in range(80001, 100002)]
#customer_ids_new = [f'Household_{i}' for i in range(10001, 20000)]
customer_ids_new = [f'Household_{i}' for i in range(10001, 20000)]

# prompt: keep in train_data and test_data the rows that have the cusomer_id in customer_ids

# Filter train_data
train_data = train_data[train_data['customer_id'].isin(customer_ids_new)]

# Filter test_data
test_data = test_data[test_data['customer_id'].isin(customer_ids_new)]

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 8757405   2023-01-14   Transaction_362590  Household_10188  Product_62613
# 8757406   2022-05-29  Transaction_2466178  Household_10188  Product_71119
# 8757407   2022-05-29  Transaction_2466178  Household_10188  Product_23971
# 8757408   2022-04-16  Transaction_1898817  Household_10188   Product_3907
# 8757409   2023-12-10   Transaction_147391  Household_10188  Product_37906
# ...              ...                  ...              ...            ...
# 17514309  2022-08-19  Transaction_1545017  Household_19505  Product_62926
# 17514310  2023-10-17   Transaction_318974  Household_11112  Product_75788
# 17514311  2023-11-25   Transaction_906692  Household_11112  Product_46620
# 17514312  2023-07-07  Transaction_1176748  Household_11112  Product_27326
# 17514313  2023-10-17   Transaction_318974  Household_11112   Product_5415
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 8757405                   0     Store_2         0       1.0  DRIVE
# 8757406                   0     Store_2         0       1.0  DRIVE
# 8757407                   0     Store_2         0       2.0  DRIVE
# 8757408                   0     Store_2         0       1.0  DRIVE
# 8757409                   0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 17514309                  0  Store_2542         0       1.0  DRIVE
# 17514310                  0  Store_2544         0       1.0    LEX
# 17514311                  0  Store_2544         0       1.0    LEX
# 17514312                  0  Store_2544         0       1.0    LEX
# 17514313                  0  Store_2544         0       1.0    LEX
#
#          order_channel
# 8757405        WEBSITE
# 8757406        WEBSITE
# 8757407        WEBSITE
# 8757408        WEBSITE
# 8757409        WEBSITE
# ...                ...
# 17514309    MOBILE_APP
# 17514310        LIVREE
# 17514311        LIVREE
# 17514312        LIVREE
# 17514313        LIVREE
#
# [8756546 rows x 10 columns]

# %%
test_data
# Out:
#                 transaction_id      customer_id     product_id
# 0           Transaction_2024_1  Household_16874   Product_9790
# 1           Transaction_2024_1  Household_16874  Product_68295
# 2           Transaction_2024_1  Household_16874  Product_19494
# 3           Transaction_2024_1  Household_16874  Product_11109
# 22          Transaction_2024_9  Household_17896  Product_74083
# ...                        ...              ...            ...
# 915448  Transaction_2024_55287  Household_19999  Product_52779
# 915449  Transaction_2024_55287  Household_19999  Product_34511
# 915450  Transaction_2024_55287  Household_19999  Product_53550
# 915451  Transaction_2024_55287  Household_19999   Product_1370
# 915452  Transaction_2024_55287  Household_19999  Product_65389
#
# [153198 rows x 3 columns]

# %%
train_data = train_data.drop(columns=['transaction_id','has_loyality_card', 'store_id','format','order_channel'])

# %% [markdown]
# ## Training Data Preproccesing

# %%
train_data['date'] = pd.to_datetime(train_data['date'])

# Add recency attribute
latest_date = train_data['date'].max()  # Find the latest date in the dataset
train_data['recency'] = (latest_date - train_data['date']).dt.days  # Calculate days since last purchase

# Group by customer_id and product_id to calculate quantity and most recent purchase
customer_product_data = train_data.groupby(['customer_id', 'product_id']).agg({
    'quantity': 'sum',
    'recency': 'min'  # Minimum days since purchase (most recent)
}).reset_index()

# Normalize quantity and recency scores
customer_product_data['quantity_score'] = customer_product_data['quantity'] / customer_product_data['quantity'].max()
customer_product_data['recency_score'] = 1 - (customer_product_data['recency'] / customer_product_data['recency'].max())  # Recent = higher score

best_alpha = 0.97

# Calculate the final score with this alpha value
customer_product_data['final_score'] = (
    best_alpha * customer_product_data['quantity_score'] +
    (1 - best_alpha) * customer_product_data['recency_score']
)

# Rank products for each customer with unique ranks
customer_product_data['rank'] = customer_product_data.sort_values(
    by=['customer_id', 'final_score', 'quantity', 'product_id'],  # Add secondary sort keys
    ascending=[True, False, False, True]  # Ensure consistent order
).groupby('customer_id').cumcount() + 1  # Assign unique incremental ranks


# Sort the DataFrame by customer_id and rank
customer_product_data = customer_product_data.sort_values(by=['customer_id', 'rank'])

# Filter out products with a rank greater than 200 for each customer
#customer_product_data = customer_product_data[customer_product_data['rank'] <= 20]

# %%
customer_product_data
# Out:
#              customer_id     product_id  quantity  recency  quantity_score  \
# 107      Household_10001  Product_57942      40.0       15        0.015649
# 127      Household_10001  Product_65600      39.0        8        0.015258
# 60       Household_10001  Product_35862      38.0        8        0.014867
# 51       Household_10001  Product_32175      29.0       15        0.011346
# 30       Household_10001  Product_21737      28.0        8        0.010955
# ...                  ...            ...       ...      ...             ...
# 3363809  Household_19999  Product_25509       1.0      620        0.000391
# 3364059  Household_19999  Product_53731       1.0      620        0.000391
# 3364120  Household_19999  Product_60476       1.0      620        0.000391
# 3364233  Household_19999   Product_7641       1.0      620        0.000391
# 3364258  Household_19999  Product_78394       1.0      620        0.000391
#
#          recency_score  final_score  rank
# 107           0.979424     0.044563     1
# 127           0.989026     0.044471     2
# 60            0.989026     0.044092     3
# 51            0.979424     0.040388     4
# 30            0.989026     0.040297     5
# ...                ...          ...   ...
# 3363809       0.149520     0.004865   616
# 3364059       0.149520     0.004865   617
# 3364120       0.149520     0.004865   618
# 3364233       0.149520     0.004865   619
# 3364258       0.149520     0.004865   620
#
# [3364315 rows x 8 columns]

# %%
# Extract temporal features
train_data['month'] = train_data['date'].dt.month
train_data['day_of_week'] = train_data['date'].dt.dayofweek
train_data['is_weekend'] = train_data['day_of_week'].isin([5, 6]).astype(int)

# Calculate recency: days since the last purchase for each customer
train_data['days_since_last_purchase'] = train_data.groupby('customer_id')['date'].transform(
    lambda x: (x.max() - x).dt.days
)

# Drop the 'date' column if it's no longer needed
train_data = train_data.drop(columns=['date'], errors='ignore')

# %%
# Aggregate customer-specific features
customer_features = train_data.groupby(['customer_id']).agg(
    purchase_frequency=('product_id', 'count'),  # Total number of purchases
    avg_quantity=('quantity', 'mean'),          # Average quantity purchased
    promo_ratio=('is_promo', 'mean'),           # Proportion of purchases made with promotions
    unique_products=('product_id', 'nunique')   # Number of unique products purchased
).reset_index()

# Merge these features into train_data and test_data
train_data = train_data.merge(customer_features, on='customer_id', how='left')

# %%
train_data.tail()
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 8756541  Household_19505  Product_62926         0       1.0      499      8
# 8756542  Household_11112  Product_75788         0       1.0       75     10
# 8756543  Household_11112  Product_46620         0       1.0       36     11
# 8756544  Household_11112  Product_27326         0       1.0      177      7
# 8756545  Household_11112   Product_5415         0       1.0       75     10
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 8756541            4           0                       490
# 8756542            1           0                        50
# 8756543            5           1                        11
# 8756544            4           0                       152
# 8756545            1           0                        50
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 8756541                 381      1.094488     0.028871              270
# 8756542                 370      1.186486     0.029730              227
# 8756543                 370      1.186486     0.029730              227
# 8756544                 370      1.186486     0.029730              227
# 8756545                 370      1.186486     0.029730              227

# %%
products_data.tail()
# Out:
#           product_id             product_description department_key  \
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82964  Product_31161              CHARGE BUT 13K CRF  Department_75
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82964  Class_7520  SubClass_75201  ACTIVITES PERIPHERIQUES   CARREFOUR
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1               shelf_level2  \
# 82961     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82963            Animalerie                     Chiens
# 82964  Maison et Décoration          Bouteilles de gaz
# 82965  Maison et Décoration          Bouteilles de gaz
#
#                          shelf_level3                     shelf_level4  bio  \
# 82961             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82962             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82963  Colliers, Laisses et Vêtements          Vêtements et Chaussures    0
# 82964                             NaN                              NaN    0
# 82965                             NaN                              NaN    0
#
#        sugar_free  aspartame_free  gluten_free  halal  casher  eco_friendly  \
# 82961           0               0            0      0       0             0
# 82962           0               0            0      0       0             0
# 82963           0               0            0      0       0             0
# 82964           0               0            0      0       0             0
# 82965           0               0            0      0       0             0
#
#        local_french  artificial_coloring_free  taste_enhancer_free  \
# 82961             0                         0                    0
# 82962             0                         0                    0
# 82963             0                         0                    0
# 82964             0                         0                    0
# 82965             0                         0                    0
#
#        naturality  antibiotic_free  reduced_sugar  vegetarian  pesticide_free  \
# 82961           0                0              0           0               0
# 82962           0                0              0           0               0
# 82963           0                0              0           0               0
# 82964           0                0              0           0               0
# 82965           0                0              0           0               0
#
#        grain_free  no_added_sugar  salt_reduced  nitrite_free  \
# 82961           0               0             0             0
# 82962           0               0             0             0
# 82963           0               0             0             0
# 82964           0               0             0             0
# 82965           0               0             0             0
#
#        fed_without_ogm  no_added_salt  no_artificial_flavours  porc  vegan  \
# 82961                0              0                       0     0      0
# 82962                0              0                       0     0      0
# 82963                0              0                       0     0      0
# 82964                0              0                       0     0      0
# 82965                0              0                       0     0      0
#
#        frozen  fat_free  reduced_fats  fresh  alcool  lactose_free  \
# 82961       0         0             0      0       0             0
# 82962       0         0             0      0       0             0
# 82963       0         0             0      0       0             0
# 82964       0         0             0      0       0             0
# 82965       0         0             0      0       0             0
#
#        phenylalanine_free  palm_oil_free ecoscore  produits_du_monde  \
# 82961                   0              0      NaN                  0
# 82962                   0              0      NaN                  0
# 82963                   0              0      NaN                  0
# 82964                   0              0      NaN                  0
# 82965                   0              0      NaN                  0
#
#        regional_product  national_brand  first_price_brand  carrefour_brand
# 82961                 0               0                  0                1
# 82962                 0               0                  0                1
# 82963                 0               0                  0                1
# 82964                 0               0                  0                1
# 82965                 0               0                  0                1

# %% [markdown]
# # Identifyng Missing Products

# %%
# Convert product_id columns to sets for quick set operations
train_product_ids = set(train_data["product_id"].unique())
products_product_ids = set(products_data["product_id"].unique())

# Find products in products_data that are not in train_data
missing_from_train = products_product_ids - train_product_ids

print(f"Number of products not in train_data: {len(missing_from_train)}")

if len(missing_from_train) > 0:
    print("These product IDs are in products_data but not in train_data:")
    for pid in missing_from_train:
        print(pid)
else:
    print("All products in products_data appear in train_data.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Product_41663
# Product_67055
# Product_6037
# Product_21420
# Product_40138
# Product_62962
# Product_57460
# Product_65025
# Product_69166
# Product_23440
# Product_65509
# Product_5729
# Product_76098
# Product_12992
# Product_49999
# Product_26162
# Product_81415
# Product_80068
# Product_59680
# Product_2955
# Product_17382
# Product_39052
# Product_24858
# Product_47331
# Product_27423
# Product_42335
# Product_3691
# Product_81377
# Product_76831
# Product_18475
# Product_7108
# Product_12216
# Product_78118
# Product_72779
# Product_43318
# Product_80261
# Product_42524
# Product_34942
# Product_3994
# Product_20280
# Product_56234
# Product_11354
# Product_52021
# Product_17112
# Product_26041
# Product_7989
# Product_6056
# Product_71795
# Product_66389
# Product_13000
# Product_36739
# Product_18716
# Product_710
# Product_19321
# Product_78113
# Product_29541
# Product_30087
# Product_19389
# Product_28771
# Product_70351
# Product_26077
# Product_17233
# Product_25846
# Product_52888
# Product_78157
# Product_25688
# Product_32667
# Product_52651
# Product_25833
# Product_80989
# Product_38854
# Product_30178
# Product_43980
# Product_28297
# Product_42559
# Product_44456
# Product_48881
# Product_11162
# Product_29720
# Product_55435
# Product_19775
# Product_1927
# Product_62459
# Product_56450
# Product_5790
# Product_42286
# Product_1172
# Product_25461
# Product_19874
# Product_103
# Product_50835
# Product_21722
# Product_55619
# Product_77264
# Product_26107
# Product_67718
# Product_69475
# Product_41370
# Product_48486
# Product_10921
# Product_80728
# Product_38154
# Product_38168
# Product_66779
# Product_29514
# Product_15126
# Product_55123
# Product_23369
# Product_22606
# Product_62290
# Product_43061
# Product_38393
# Product_20100
# Product_31161
# Product_3842
# Product_44927
# Product_28519
# Product_59289
# Product_21662
# Product_1193
# Product_66701
# Product_57440
# Product_78141
# Product_22680
# Product_39081
# Product_13208
# Product_75709
# Product_19575
# Product_42627
# Product_64753
# Product_67318
# Product_46806
# Product_76950
# Product_29729
# Product_6866
# Product_38242
# Product_62419
# Product_41294
# Product_47068
# Product_79931
# Product_7140
# Product_58896
# Product_45460
# Product_18081
# Product_12093
# Product_26487
# Product_9897
# Product_82410
# Product_53716
# Product_19218
# Product_44592
# Product_56783
# Product_41248
# Product_11849
# Product_15752
# Product_25923
# Product_62010
# Product_29937
# Product_51362
# Product_41484
# Product_40220
# Product_41698
# Product_22561
# Product_9371
# Product_17508
# Product_32697
# Product_5643
# Product_58724
# Product_47285
# Product_49463
# Product_77545
# Product_3883
# Product_26647
# Product_66390
# Product_37595
# Product_26672
# Product_73806
# Product_74307
# Product_76080
# Product_49097
# Product_78602
# Product_65158
# Product_30722
# Product_72434
# Product_34796
# Product_59348
# Product_71530
# Product_54087
# Product_19375
# Product_48879
# Product_80124
# Product_37192
# Product_58118
# Product_76105
# Product_72961
# Product_49834
# Product_4984
# Product_51663
# Product_69048
# Product_43620
# Product_67072
# Product_26322
# Product_39875
# Product_26402
# Product_27968
# Product_73024
# Product_39453
# Product_74902
# Product_25291
# Product_72522
# Product_17322
# Product_70229
# Product_38372
# Product_33606
# Product_27964
# Product_19012
# Product_48662
# Product_81226
# Product_58554
# Product_48440
# Product_25116
# Product_6543
# Product_43369
# Product_33287
# Product_6105
# Product_37591
# Product_15740
# Product_31434
# Product_20793
# Product_61990
# Product_62649
# Product_76799
# Product_10974
# Product_81569
# Product_20354
# Product_67095
# Product_57647
# Product_74200
# Product_6001
# Product_44513
# Product_79589
# Product_32815
# Product_7570
# Product_1891
# Product_34129
# Product_33857
# Product_65852
# Product_80402
# Product_50396
# Product_35478
# Product_39371
# Product_5158
# Product_15497
# Product_74035
# Product_81652
# Product_13783
# Product_59111
# Product_74320
# Product_15212
# Product_79789
# Product_7118
# Product_46474
# Product_51862
# Product_2102
# Product_11757
# Product_12885
# Product_1575
# Product_68214
# Product_80626
# Product_13911
# Product_8009
# Product_13711
# Product_18289
# Product_37449
# Product_67506
# Product_30513
# Product_30864
# Product_40900
# Product_52241
# Product_33882
# Product_33985
# Product_907
# Product_17791
# Product_48992
# Product_72512
# Product_37429
# Product_27055
# Product_17080
# Product_4408
# Product_11102
# Product_38696
# Product_29010
# Product_18305
# Product_67328
# Product_56912
# Product_35471
# Product_48122
# Product_8831
# Product_54138
# Product_44328
# Product_81304
# Product_56201
# Product_63814
# Product_5359
# Product_41717
# Product_29483
# Product_40990
# Product_20637
# Product_33414
# Product_59424
# Product_16536
# Product_42641
# Product_56535
# Product_80946
# Product_55079
# Product_73425
# Product_54577
# Product_66708
# Product_49161
# Product_43955
# Product_18223
# Product_66624
# Product_48357
# Product_67776
# Product_31156
# Product_42186
# Product_57844
# Product_63133
# Product_7162
# Product_52070
# Product_67743
# Product_47412
# Product_41451
# Product_65777
# Product_23266
# Product_37080
# Product_5152
# Product_74596
# Product_49561
# Product_78481
# Product_42842
# Product_72231
# Product_47239
# Product_24480
# Product_63927
# Product_77017
# Product_71815
# Product_66571
# Product_39199
# Product_80307
# Product_35248
# Product_54581
# Product_51593
# Product_37981
# Product_56862
# Product_54591
# Product_72138
# Product_35260
# Product_71787
# Product_22825
# Product_404
# Product_4378
# Product_28699
# Product_48282
# Product_62589
# Product_45544
# Product_1458
# Product_34341
# Product_23390
# Product_54278
# Product_59421
# Product_37583
# Product_51454
# Product_4133
# Product_15314
# Product_25198
# Product_72566
# Product_34443
# Product_41110
# Product_39400
# Product_37281
# Product_4940
# Product_42484
# Product_4484
# Product_60484
# Product_77262
# Product_79806
# Product_48483
# Product_48987
# Product_16023
# Product_40015
# Product_24746
# Product_74610
# Product_43195
# Product_82264
# Product_64563
# Product_68995
# Product_30097
# Product_78856
# Product_46023
# Product_23131
# Product_70505
# Product_70928
# Product_30805
# Product_26782
# Product_48573
# Product_19259
# Product_19521
# Product_40769
# Product_8778
# Product_41262
# Product_45146
# Product_8660
# Product_18072
# Product_52873
# Product_29832
# Product_11852
# Product_69778
# Product_2715
# Product_48355
# Product_27014
# Product_23245
# Product_81004
# Product_29225
# Product_11286
# Product_64012
# Product_50520
# Product_276
# Product_64517
# Product_24021
# Product_49508
# Product_79674
# Product_65504
# Product_41039
# Product_72055
# Product_40207
# Product_58895
# Product_80404
# Product_69407
# Product_56536
# Product_44086
# Product_24908
# Product_42921
# Product_79141
# Product_43900
# Product_39256
# Product_49082
# Product_8031
# Product_18593
# Product_63687
# Product_36045
# Product_82507
# Product_52096
# Product_48165
# Product_63772
# Product_19063
# Product_75712
# Product_11609
# Product_26067
# Product_44801
# Product_49465
# Product_61621
# Product_15186
# Product_21822
# Product_1740
# Product_23710
# Product_42979
# Product_74298
# Product_49752
# Product_18677
# Product_61376
# Product_59215
# Product_102
# Product_15770
# Product_76313
# Product_57789
# Product_34
# Product_61605
# Product_80816
# Product_69001
# Product_21327
# Product_80551
# Product_32575
# Product_76197
# Product_21820
# Product_2951
# Product_71755
# Product_82549
# Product_71316
# Product_59104
# Product_21642
# Product_43758
# Product_62026
# Product_56580
# Product_36769
# Product_39692
# Product_1194
# Product_36506
# Product_23704
# Product_25556
# Product_3331
# Product_58161
# Product_8215
# Product_66638
# Product_59591
# Product_3103
# Product_9527
# Product_61110
# Product_52609
# Product_17827
# Product_37987
# Product_19196
# Product_62119
# Product_35624
# Product_51981
# Product_25323
# Product_25346
# Product_9271
# Product_47549
# Product_35589
# Product_1277
# Product_67450
# Product_40565
# Product_20995
# Product_25180
# Product_62433
# Product_67509
# Product_26500
# Product_2934
# Product_19200
# Product_9426
# Product_41117
# Product_34283
# Product_6289
# Product_19601
# Product_48095
# Product_13991
# Product_40864
# Product_7389
# Product_62883
# Product_16573
# Product_53188
# Product_72235
# Product_21157
# Product_28445
# Product_62825
# Product_28873
# Product_77473
# Product_15935
# Product_66714
# Product_46015
# Product_12229
# Product_65530
# Product_54618
# Product_49246
# Product_65837
# Product_36212
# Product_67747
# Product_61759
# Product_40095
# Product_32998
# Product_53320
# Product_31783
# Product_71984
# Product_77436
# Product_64161
# Product_39892
# Product_61192
# Product_12945
# Product_20504
# Product_47501
# Product_31143
# Product_8419
# Product_21441
# Product_63400
# Product_80099
# Product_13318
# Product_44557
# Product_37378
# Product_26230
# Product_59182
# Product_33692
# Product_62356
# Product_42066
# Product_47711
# Product_21542
# Product_81960
# Product_54313
# Product_22189
# Product_6148
# Product_81587
# Product_46944
# Product_39126
# Product_79025
# Product_72592
# Product_19466
# Product_40466
# Product_45987
# Product_1943
# Product_72372
# Product_41136
# Product_77
# Product_23071
# Product_70874
# Product_71698
# Product_53823
# Product_40105
# Product_32686
# Product_37040
# Product_60187
# Product_23829
# Product_9908
# Product_39031
# Product_26218
# Product_62975
# Product_12763
# Product_53340
# Product_964
# Product_3348
# Product_57856
# Product_4233
# Product_56368
# Product_28444
# Product_76126
# Product_81251
# Product_28172
# Product_28942
# Product_53302
# Product_32828
# Product_55296
# Product_68237
# Product_8356
# Product_72358
# Product_18924
# Product_11909
# Product_59299
# Product_64342
# Product_65738
# Product_52486
# Product_2212
# Product_23689
# Product_35512
# Product_49341
# Product_37923
# Product_71746
# Product_47834
# Product_33696
# Product_43820
# Product_77673
# Product_32271
# Product_6683
# Product_21200
# Product_19785
# Product_54460
# Product_66445
# Product_26458
# Product_58925
# Product_6650
# Product_58978
# Product_17789
# Product_64701
# Product_61144
# Product_34363
# Product_51007
# Product_53060
# Product_57114
# Product_26293
# Product_45448
# Product_39242
# Product_6467
# Product_76053
# Product_39437
# Product_11734
# Product_52543
# Product_69053
# Product_47627
# Product_34230
# Product_52564
# Product_7135
# Product_58959
# Product_34612
# Product_48784
# Product_12631
# Product_4323
# Product_76822
# Product_15873
# Product_15525
# Product_68731
# Product_18266
# Product_12203
# Product_43500
# Product_15264
# Product_11148
# Product_69337
# Product_1481
# Product_68982
# Product_77715
# Product_64307
# Product_78832
# Product_22983
# Product_20609
# Product_79175
# Product_52173
# Product_60925
# Product_8321
# Product_52805
# Product_14764
# Product_78606
# Product_18065
# Product_81839
# Product_22839
# Product_74525
# Product_39191
# Product_55276
# Product_18427
# Product_31315
# Product_26134
# Product_14527
# Product_1514
# Product_9197
# Product_61645
# Product_54775
# Product_72094
# Product_5349
# Product_69638
# Product_38673
# Product_14471
# Product_60617
# Product_48776
# Product_3163
# Product_25859
# Product_9337
# Product_79054
# Product_29005
# Product_35572
# Product_12117
# Product_68553
# Product_30212
# Product_24155
# Product_10668
# Product_14593
# Product_64866
# Product_58675
# Product_37072
# Product_48512
# Product_2833
# Product_28273
# Product_25257
# Product_47553
# Product_55815
# Product_22646
# Product_3776
# Product_30040
# Product_31234
# Product_20173
# Product_65339
# Product_66041
# Product_6248
# Product_30213
# Product_21691
# Product_31127
# Product_24139
# Product_54062
# Product_24411
# Product_81400
# Product_70023
# Product_48945
# Product_6546
# Product_51443
# Product_55405
# Product_20906
# Product_50962
# Product_42190
# Product_22217
# Product_55133
# Product_49620
# Product_3151
# Product_68950
# Product_29846
# Product_61430
# Product_35042
# Product_78944
# Product_27613
# Product_81237
# Product_25574
# Product_56134
# Product_65867
# Product_51795
# Product_27538
# Product_78226
# Product_68531
# Product_78345
# Product_82547
# Product_80084
# Product_65356
# Product_33156
# Product_35091
# Product_45945
# Product_71251
# Product_33304
# Product_78262
# Product_27009
# Product_13066
# Product_18607
# Product_12735
# Product_10463
# Product_32361
# Product_79061
# Product_50185
# Product_51033
# Product_39949
# Product_78975
# Product_75819
# Product_5011
# Product_16042
# Product_57115
# Product_2391
# Product_7635
# Product_57332
# Product_75238
# Product_69129
# Product_36017
# Product_353
# Product_28291
# Product_18403
# Product_11993
# Product_29213
# Product_3514
# Product_61575
# Product_45559
# Product_61770
# Product_79706
# Product_36938
# Product_77902
# Product_16276
# Product_63823
# Product_29764
# Product_68606
# Product_72087
# Product_8926
# Product_32679
# Product_16108
# Product_14833
# Product_31004
# Product_43282
# Product_60384
# Product_28459
# Product_77987
# Product_57177
# Product_74575
# Product_10778
# Product_79743
# Product_32581
# Product_6773
# Product_81554
# Product_27239
# Product_7183
# Product_81198
# Product_20159
# Product_29401
# Product_47765
# Product_53502
# Product_55001
# Product_51211
# Product_42895
# Product_23650
# Product_62939
# Product_72302
# Product_73862
# Product_46834
# Product_9457
# Product_76183
# Product_1602
# Product_56042
# Product_27819
# Product_58221
# Product_70038
# Product_2067
# Product_33154
# Product_40933
# Product_12548
# Product_11069
# Product_78025
# Product_16471
# Product_20134
# Product_46142
# Product_21312
# Product_25362
# Product_64633
# Product_55240
# Product_15105
# Product_80779
# Product_50443
# Product_54491
# Product_78962
# Product_56143
# Product_67439
# Product_49479
# Product_38333
# Product_10219
# Product_34194
# Product_45203
# Product_15764
# Product_25904
# Product_61452
# Product_9905
# Product_39662
# Product_72675
# Product_53081
# Product_11864
# Product_71846
# Product_57119
# Product_79783
# Product_53658
# Product_70816
# Product_78051
# Product_78293
# Product_3583
# Product_17761
# Product_40832
# Product_47151
# Product_52678
# Product_46019
# Product_18967
# Product_28819
# Product_17505
# Product_71741
# Product_65710
# Product_59089
# Product_60342
# Product_47717
# Product_32796
# Product_8022
# Product_10681
# Product_36275
# Product_4030
# Product_71366
# Product_68301
# Product_59799
# Product_22222
# Product_4424
# Product_14818
# Product_35418
# Product_35123
# Product_61489
# Product_10853
# Product_62397
# Product_19301
# Product_72317
# Product_40984
# Product_29347
# Product_65986
# Product_17914
# Product_3124
# Product_7788
# Product_60715
# Product_22518
# Product_40707
# Product_40966
# Product_6355
# Product_71354
# Product_25496
# Product_19992
# Product_67580
# Product_44157
# Product_71602
# Product_33411
# Product_50455
# Product_24965
# Product_70508
# Product_28436
# Product_16130
# Product_54109
# Product_72177
# Product_10730
# Product_62886
# Product_40364
# Product_57078
# Product_5830
# Product_23461
# Product_9098
# Product_18073
# Product_74124
# Product_14872
# Product_14488
# Product_23869
# Product_22195
# Product_55952
# Product_82178
# Product_63003
# Product_68759
# Product_44198
# Product_64870
# Product_56863
# Product_67077
# Product_62190
# Product_51078
# Product_76433
# Product_18074
# Product_51426
# Product_45947
# Product_14678
# Product_21328
# Product_37392
# Product_28485
# Product_77513
# Product_723
# Product_15499
# Product_59978
# Product_24886
# Product_61188
# Product_49801
# Product_17186
# Product_55073
# Product_20729
# Product_65274
# Product_865
# Product_29964
# Product_50787
# Product_10757
# Product_65919
# Product_77449
# Product_69567
# Product_34718
# Product_5630
# Product_62789
# Product_54479
# Product_36528
# Product_42284
# Product_49871
# Product_54158
# Product_69072
# Product_28814
# Product_52405
# Product_51222
# Product_9030
# Product_75339
# Product_13494
# Product_3913
# Product_6114
# Product_64083
# Product_13727
# Product_51038
# Product_17012
# Product_37445
# Product_38299
# Product_4253
# Product_43803
# Product_47678
# Product_36666
# Product_17951
# Product_34899
# Product_14370
# Product_77169
# Product_44432
# Product_53647
# Product_10846
# Product_32069
# Product_16887
# Product_17255
# Product_54373
# Product_15680
# Product_63453
# Product_45032
# Product_31115
# Product_45504
# Product_50976
# Product_38509
# Product_58755
# Product_21584
# Product_60414
# Product_77462
# Product_15556
# Product_52132
# Product_68107
# Product_44118
# Product_39030
# Product_60613
# Product_33551
# Product_43542
# Product_60225
# Product_82740
# Product_46798
# Product_39143
# Product_16195
# Product_31387
# Product_42833
# Product_21923
# Product_1826
# Product_8418
# Product_52230
# Product_36358
# Product_32802
# Product_58022
# Product_50680
# Product_50226
# Product_75948
# Product_41608
# Product_30635
# Product_5155
# Product_69289
# Product_80388
# Product_80726
# Product_70192
# Product_78464
# Product_48429
# Product_69992
# Product_33236
# Product_82069
# Product_20301
# Product_20202
# Product_32354
# Product_7092
# Product_70872
# Product_73354
# Product_40200
# Product_1156
# Product_78510
# Product_1810
# Product_61404
# Product_37063
# Product_79778
# Product_76262
# Product_41074
# Product_48654
# Product_40668
# Product_3984
# Product_16717
# Product_80159
# Product_11021
# Product_38169
# Product_82669
# Product_63883
# Product_55165
# Product_29085
# Product_27886
# Product_29498
# Product_49735
# Product_53090
# Product_45143
# Product_45713
# Product_65776
# Product_16306
# Product_71962
# Product_898
# Product_31801
# Product_40172
# Product_45201
# Product_34459
# Product_17701
# Product_40526
# Product_40566
# Product_57060
# Product_16607
# Product_42620
# Product_16072
# Product_70063
# Product_39942
# Product_76446
# Product_50879
# Product_68217
# Product_67369
# Product_3535
# Product_25372
# Product_65042
# Product_3083
# Product_12748
# Product_54468
# Product_57688
# Product_9610
# Product_55397
# Product_62923
# Product_46461
# Product_69149
# Product_70914
# Product_80805
# Product_28503
# Product_25480
# Product_11785
# Product_69984
# Product_28354
# Product_72168
# Product_64115
# Product_57351
# Product_42087
# Product_65672
# Product_23233
# Product_35616
# Product_65396
# Product_61102
# Product_29985
# Product_4660
# Product_2860
# Product_49432
# Product_13163
# Product_39302
# Product_82107
# Product_68443
# Product_29558
# Product_7664
# Product_40949
# Product_21742
# Product_23155
# Product_7553
# Product_8164
# Product_20273
# Product_48713
# Product_17351
# Product_15257
# Product_75313
# Product_66955
# Product_16118
# Product_75042
# Product_44235
# Product_6470
# Product_49647
# Product_73633
# Product_9011
# Product_36062
# Product_8629
# Product_48599
# Product_68335
# Product_24845
# Product_64883
# Product_31549
# Product_38199
# Product_6792
# Product_215
# Product_40112
# Product_26278
# Product_39625
# Product_8586
# Product_35328
# Product_10131
# Product_41351
# Product_64499
# Product_56879
# Product_50094
# Product_14835
# Product_71223
# Product_71896
# Product_62669
# Product_28677
# Product_73361
# Product_48579
# Product_33824
# Product_29393
# Product_48224
# Product_34220
# Product_4404
# Product_42997
# Product_33211
# Product_9970
# Product_20166
# Product_47686
# Product_53096
# Product_71326
# Product_21603
# Product_31509
# Product_40438
# Product_4474
# Product_17587
# Product_27126
# Product_43958
# Product_26054
# Product_2680
# Product_63509
# Product_71285
# Product_63922
# Product_49947
# Product_72339
# Product_50377
# Product_67683
# Product_66382
# Product_40825
# Product_26733
# Product_19884
# Product_42786
# Product_27700
# Product_9541
# Product_82501
# Product_27419
# Product_46251
# Product_8873
# Product_46587
# Product_52775
# Product_69676
# Product_32398
# Product_4746
# Product_66202
# Product_63295
# Product_70906
# Product_50586
# Product_41082
# Product_26581
# Product_55013
# Product_1816
# Product_73029
# Product_76429
# Product_41384
# Product_20275
# Product_36857
# Product_73071
# Product_82562
# Product_26238
# Product_47942
# Product_37182
# Product_55369
# Product_28907
# Product_26958
# Product_14738
# Product_67111
# Product_26014
# Product_68682
# Product_59840
# Product_60186
# Product_33951
# Product_20061
# Product_39883
# Product_21740
# Product_55335
# Product_35927
# Product_47645
# Product_77138
# Product_42929
# Product_15784
# Product_1840
# Product_65959
# Product_5037
# Product_29777
# Product_16110
# Product_14650
# Product_53679
# Product_54751
# Product_50748
# Product_30065
# Product_29684
# Product_79188
# Product_2471
# Product_63987
# Product_8480
# Product_12062
# Product_466
# Product_71653
# Product_13915
# Product_35856
# Product_64994
# Product_12453
# Product_2374
# Product_15896
# Product_82386
# Product_75506
# Product_6909
# Product_13004
# Product_50792
# Product_48073
# Product_60692
# Product_46579
# Product_4045
# Product_33124
# Product_41851
# Product_71104
# Product_81745
# Product_47971
# Product_47665
# Product_27432
# Product_37563
# Product_52828
# Product_8035
# Product_26152
# Product_36478
# Product_33437
# Product_18151
# Product_45260
# Product_77164
# Product_44119
# Product_64476
# Product_72
# Product_21265
# Product_48865
# Product_34495
# Product_28701
# Product_3829
# Product_80415
# Product_1797
# Product_70893
# Product_9979
# Product_38960
# Product_56162
# Product_72808
# Product_31728
# Product_22316
# Product_35654
# Product_33196
# Product_6694
# Product_9326
# Product_75798
# Product_35511
# Product_58738
# Product_53383
# Product_67929
# Product_66268
# Product_81791
# Product_69535
# Product_15374
# Product_62418
# Product_41854
# Product_79702
# Product_19888
# Product_67641
# Product_18934
# Product_24068
# Product_9208
# Product_49937
# Product_27105
# Product_45783
# Product_72472
# Product_75124
# Product_42765
# Product_38869
# Product_12583
# Product_58211
# Product_44134
# Product_25210
# Product_5015
# Product_14258
# Product_24937
# Product_74660
# Product_65670
# Product_48711
# Product_54149
# Product_17161
# Product_81355
# Product_49841
# Product_34445
# Product_46240
# Product_14062
# Product_29116
# Product_62425
# Product_39674
# Product_71665
# Product_64064
# Product_6269
# Product_79018
# Product_29375
# Product_48588
# Product_27058
# Product_41892
# Product_60771
# Product_16481
# Product_18538
# Product_76263
# Product_58216
# Product_62393
# Product_14243
# Product_67231
# Product_15461
# Product_56199
# Product_72659
# Product_61266
# Product_27957
# Product_29369
# Product_4450
# Product_30442
# Product_58257
# Product_11478
# Product_8377
# Product_81328
# Product_72616
# Product_60985
# Product_41648
# Product_47806
# Product_6146
# Product_31848
# Product_36357
# Product_72239
# Product_67940
# Product_28851
# Product_64331
# Product_74410
# Product_17755
# Product_19258
# Product_38644
# Product_53133
# Product_41776
# Product_54971
# Product_17560
# Product_7828
# Product_80083
# Product_57430
# Product_48345
# Product_64213
# Product_10329
# Product_55756
# Product_75239
# Product_72787
# Product_16524
# Product_72136
# Product_49931
# Product_23008
# Product_78901
# Product_10098
# Product_53838
# Product_23988
# Product_69486
# Product_60662
# Product_61968
# Product_81206
# Product_28108
# Product_75827
# Product_77142
# Product_2181
# Product_4753
# Product_16658
# Product_65912
# Product_35966
# Product_65125
# Product_73685
# Product_49763
# Product_22302
# Product_72386
# Product_3206
# Product_67813
# Product_20068
# Product_74082
# Product_80093
# Product_43870
# Product_39026
# Product_8956
# Product_78954
# Product_7841
# Product_48928
# Product_14416
# Product_4225
# Product_25486
# Product_8304
# Product_2997
# Product_62242
# Product_45179
# Product_12017
# Product_68317
# Product_11742
# Product_25536
# Product_74228
# Product_50354
# Product_69014
# Product_9259
# Product_31229
# Product_70459
# Product_1649
# Product_27528
# Product_49069
# Product_37979
# Product_29612
# Product_33810
# Product_53295
# Product_9660
# Product_36473
# Product_902
# Product_65016
# Product_49408
# Product_18138
# Product_5781
# Product_5625
# Product_53285
# Product_64918
# Product_41154
# Product_35640
# Product_12578
# Product_6316
# Product_41426
# Product_12437
# Product_37465
# Product_7888
# Product_74915
# Product_41027
# Product_61565
# Product_70208
# Product_38842
# Product_69196
# Product_37587
# Product_49232
# Product_57685
# Product_21863
# Product_23242
# Product_79867
# Product_10917
# Product_12766
# Product_25268
# Product_5914
# Product_48068
# Product_73281
# Product_60073
# Product_19502
# Product_39677
# Product_40221
# Product_58263
# Product_15418
# Product_55167
# Product_65904
# Product_23386
# Product_57966
# Product_6096
# Product_68245
# Product_38409
# Product_6498
# Product_16359
# Product_8147
# Product_47621
# Product_24357
# Product_49550
# Product_7618
# Product_78428
# Product_5762
# Product_4820
# Product_18281
# Product_9411
# Product_75320
# Product_61745
# Product_56197
# Product_29072
# Product_63045
# Product_59408
# Product_23029
# Product_26530
# Product_14288
# Product_36628
# Product_57079
# Product_77536
# Product_43536
# Product_75784
# Product_43655
# Product_56809
# Product_400
# Product_38012
# Product_57736
# Product_73870
# Product_39569
# Product_46641
# Product_53800
# Product_50852
# Product_47733
# Product_31540
# Product_7061
# Product_27447
# Product_2410
# Product_36588
# Product_59274
# Product_54400
# Product_12509
# Product_78734
# Product_55404
# Product_39405
# Product_72503
# Product_72018
# Product_6898
# Product_11826
# Product_27859
# Product_53464
# Product_63617
# Product_58825
# Product_15700
# Product_23014
# Product_54140
# Product_24831
# Product_46236
# Product_19179
# Product_77177
# Product_78751
# Product_57810
# Product_22913
# Product_12185
# Product_79823
# Product_3471
# Product_47700
# Product_31899
# Product_27295
# Product_52557
# Product_38052
# Product_71605
# Product_36795
# Product_81921
# Product_82030
# Product_5832
# Product_12
# Product_45962
# Product_62023
# Product_7327
# Product_78966
# Product_17489
# Product_50127
# Product_22805
# Product_14074
# Product_78946
# Product_38822
# Product_28154
# Product_20363
# Product_25313
# Product_29041
# Product_27889
# Product_1545
# Product_53072
# Product_53656
# Product_66797
# Product_677
# Product_76821
# Product_80196
# Product_13428
# Product_33391
# Product_42532
# Product_8348
# Product_4429
# Product_22393
# Product_80754
# Product_29371
# Product_26725
# Product_12622
# Product_66524
# Product_30084
# Product_25600
# Product_82593
# Product_26913
# Product_8847
# Product_14829
# Product_45664
# Product_7371
# Product_26430
# Product_34020
# Product_57363
# Product_75234
# Product_3712
# Product_38459
# Product_60038
# Product_80466
# Product_22187
# Product_42121
# Product_16937
# Product_12471
# Product_79992
# Product_5614
# Product_25322
# Product_38134
# Product_12848
# Product_50650
# Product_28916
# Product_54445
# Product_40837
# Product_68483
# Product_30775
# Product_15558
# Product_22049
# Product_356
# Product_43888
# Product_77855
# Product_5119
# Product_45166
# Product_40224
# Product_29143
# Product_52112
# Product_47086
# Product_53916
# Product_82186
# Product_36407
# Product_1059
# Product_69211
# Product_65683
# Product_53368
# Product_54766
# Product_5500
# Product_43811
# Product_56656
# Product_30269
# Product_76782
# Product_80474
# Product_18300
# Product_24950
# Product_30546
# Product_55067
# Product_13539
# Product_25328
# Product_34580
# Product_80453
# Product_48250
# Product_60552
# Product_65381
# Product_13370
# Product_61131
# Product_76228
# Product_65079
# Product_70517
# Product_73059
# Product_55587
# Product_80220
# Product_77710
# Product_42789
# Product_20377
# Product_23154
# Product_47716
# Product_18746
# Product_62183
# Product_1567
# Product_41040
# Product_40609
# Product_24318
# Product_72461
# Product_14405
# Product_10389
# Product_20723
# Product_55099
# Product_76800
# Product_78415
# Product_65341
# Product_34336
# Product_63490
# Product_51769
# Product_61608
# Product_33467
# Product_70146
# Product_31601
# Product_38148
# Product_57620
# Product_58841
# Product_31817
# Product_26340
# Product_55962
# Product_66034
# Product_66602
# Product_34419
# Product_61118
# Product_12768
# Product_21007
# Product_82445
# Product_77377
# Product_29797
# Product_64468
# Product_71277
# Product_77719
# Product_42120
# Product_56040
# Product_17916
# Product_67836
# Product_15503
# Product_77283
# Product_73793
# Product_23767
# Product_42312
# Product_16194
# Product_74123
# Product_78422
# Product_1832
# Product_43153
# Product_2914
# Product_8413
# Product_70559
# Product_41708
# Product_49532
# Product_25824
# Product_47464
# Product_61522
# Product_48192
# Product_30894
# Product_73732
# Product_75942
# Product_14051
# Product_48849
# Product_81883
# Product_36311
# Product_30640
# Product_79736
# Product_33222
# Product_48045
# Product_15645
# Product_45320
# Product_8168
# Product_60450
# Product_35612
# Product_38943
# Product_32119
# Product_4546
# Product_2144
# Product_49179
# Product_71835
# Product_81113
# Product_35762
# Product_67542
# Product_69675
# Product_55840
# Product_37046
# Product_59301
# Product_63057
# Product_26988
# Product_55510
# Product_14973
# Product_80209
# Product_18230
# Product_19631
# Product_39743
# Product_4974
# Product_67372
# Product_35133
# Product_57189
# Product_67396
# Product_77685
# Product_46651
# Product_75092
# Product_62328
# Product_45818
# Product_24733
# Product_5267
# Product_66807
# Product_46268
# Product_37098
# Product_70476
# Product_18575
# Product_13167
# Product_66564
# Product_28082
# Product_64348
# Product_23227
# Product_49732
# Product_8238
# Product_46718
# Product_53007
# Product_6174
# Product_21459
# Product_27938
# Product_67512
# Product_29419
# Product_51788
# Product_38051
# Product_61557
# Product_51168
# Product_63243
# Product_80940
# Product_7642
# Product_19329
# Product_33057
# Product_8986
# Product_45928
# Product_29006
# Product_46469
# Product_2916
# Product_80734
# Product_56851
# Product_80897
# Product_34157
# Product_34070
# Product_16228
# Product_77363
# Product_43920
# Product_54470
# Product_19266
# Product_61583
# Product_16968
# Product_16445
# Product_16773
# Product_42320
# Product_80214
# Product_60300
# Product_45089
# Product_82272
# Product_5066
# Product_72245
# Product_50132
# Product_61746
# Product_11895
# Product_10100
# Product_40915
# Product_35676
# Product_25385
# Product_36650
# Product_5321
# Product_43872
# Product_81177
# Product_10897
# Product_37287
# Product_7181
# Product_69904
# Product_60101
# Product_29868
# Product_2413
# Product_35401
# Product_67216
# Product_75051
# Product_35377
# Product_34144
# Product_69709
# Product_70571
# Product_24952
# Product_55936
# Product_4020
# Product_38187
# Product_49020
# Product_17431
# Product_76987
# Product_14045
# Product_52949
# Product_63018
# Product_73780
# Product_20488
# Product_27156
# Product_20017
# Product_3543
# Product_9735
# Product_62895
# Product_15655
# Product_39232
# Product_19693
# Product_72146
# Product_76487
# Product_62645
# Product_80130
# Product_49078
# Product_8628
# Product_32087
# Product_63108
# Product_70959
# Product_4779
# Product_16026
# Product_30714
# Product_21359
# Product_65541
# Product_7851
# Product_3055
# Product_16950
# Product_42880
# Product_17307
# Product_11719
# Product_45815
# Product_80572
# Product_26679
# Product_2186
# Product_12678
# Product_30173
# Product_63128
# Product_77380
# Product_74186
# Product_32724
# Product_1547
# Product_19057
# Product_20857
# Product_76130
# Product_56742
# Product_45156
# Product_2539
# Product_81598
# Product_4169
# Product_20171
# Product_3724
# Product_31258
# Product_10941
# Product_21108
# Product_30304
# Product_30244
# Product_60270
# Product_5217
# Product_47432
# Product_3475
# Product_82362
# Product_13673
# Product_6233
# Product_23983
# Product_45208
# Product_16695
# Product_53387
# Product_67909
# Product_32319
# Product_79641
# Product_44033
# Product_64462
# Product_15515
# Product_55422
# Product_67236
# Product_27031
# Product_18426
# Product_28880
# Product_57774
# Product_73594
# Product_50807
# Product_62804
# Product_43576
# Product_14186
# Product_80078
# Product_78668
# Product_25636
# Product_55451
# Product_64915
# Product_62182
# Product_16077
# Product_58007
# Product_40829
# Product_82207
# Product_5016
# Product_76669
# Product_48698
# Product_56164
# Product_39559
# Product_78445
# Product_29314
# Product_23382
# Product_45134
# Product_70673
# Product_12391
# Product_81480
# Product_58723
# Product_42661
# Product_79009
# Product_10721
# Product_77600
# Product_45290
# Product_63205
# Product_52857
# Product_30025
# Product_20309
# Product_59586
# Product_44597
# Product_34236
# Product_16210
# Product_56938
# Product_46604
# Product_71202
# Product_38165
# Product_79338
# Product_54934
# Product_25080
# Product_5006
# Product_66082
# Product_9343
# Product_62881
# Product_31186
# Product_53943
# Product_13191
# Product_1588
# Product_71547
# Product_61614
# Product_41181
# Product_45193
# Product_73289
# Product_23183
# Product_74426
# Product_7068
# Product_28331
# Product_9783
# Product_52127
# Product_29584
# Product_224
# Product_73578
# Product_15762
# Product_11940
# Product_36215
# Product_43185
# Product_80444
# Product_37615
# Product_74128
# Product_81062
# Product_27563
# Product_42633
# Product_61471
# Product_59152
# Product_43989
# Product_75073
# Product_35814
# Product_22386
# Product_30620
# Product_55555
# Product_65604
# Product_66615
# Product_24522
# Product_17655
# Product_34822
# Product_69336
# Product_27301
# Product_25451
# Product_43051
# Product_82630
# Product_27551
# Product_26328
# Product_45738
# Product_51781
# Product_13305
# Product_31240
# Product_31800
# Product_16316
# Product_68641
# Product_49434
# Product_41512
# Product_66870
# Product_47266
# Product_46229
# Product_42098
# Product_67803
# Product_17850
# Product_41454
# Product_54523
# Product_58563
# Product_77338
# Product_29521
# Product_48867
# Product_13214
# Product_74220
# Product_54897
# Product_74702
# Product_51126
# Product_15804
# Product_8961
# Product_50870
# Product_57341
# Product_6848
# Product_80724
# Product_12320
# Product_13188
# Product_44063
# Product_7811
# Product_53145
# Product_30524
# Product_56371
# Product_41609
# Product_57528
# Product_39780
# Product_20662
# Product_63835
# Product_54969
# Product_28184
# Product_46970
# Product_61659
# Product_21336
# Product_26221
# Product_80181
# Product_67824
# Product_24792
# Product_17625
# Product_878
# Product_27585
# Product_12127
# Product_10654
# Product_15531
# Product_6030
# Product_61910
# Product_59555
# Product_70796
# Product_54092
# Product_38787
# Product_10656
# Product_27328
# Product_68811
# Product_4873
# Product_33919
# Product_33608
# Product_2443
# Product_63073
# Product_20015
# Product_44098
# Product_33710
# Product_39193
# Product_19872
# Product_45512
# Product_61164
# Product_60407
# Product_29580
# Product_2933
# Product_43120
# Product_66592
# Product_30512
# Product_41205
# Product_46336
# Product_73419
# Product_61161
# Product_46255
# Product_62848
# Product_21288
# Product_4498
# Product_20058
# Product_63930
# Product_69773
# Product_26680
# Product_22120
# Product_22528
# Product_72264
# Product_32835
# Product_81128
# Product_49425
# Product_65337
# Product_12059
# Product_4371
# Product_24811
# Product_48720
# Product_60824
# Product_37576
# Product_37996
# Product_42618
# Product_42
# Product_81036
# Product_53103
# Product_8504
# Product_47259
# Product_28766
# Product_3299
# Product_20040
# Product_72933
# Product_31322
# Product_25229
# Product_55517
# Product_51121
# Product_14905
# Product_40338
# Product_64602
# Product_42033
# Product_15110
# Product_48274
# Product_31818
# Product_8005
# Product_47987
# Product_2965
# Product_81279
# Product_50247
# Product_30437
# Product_62904
# Product_78136
# Product_46202
# Product_7936
# Product_56212
# Product_29315
# Product_25905
# Product_45321
# Product_78794
# Product_54200
# Product_76561
# Product_71947
# Product_17897
# Product_22999
# Product_82640
# Product_15629
# Product_58035
# Product_28109
# Product_56883
# Product_55292
# Product_34502
# Product_61081
# Product_63376
# Product_18352
# Product_75366
# Product_52741
# Product_22681
# Product_81288
# Product_24478
# Product_65294
# Product_65711
# Product_72765
# Product_15685
# Product_45006
# Product_44839
# Product_55308
# Product_8838
# Product_29504
# Product_24686
# Product_9917
# Product_72681
# Product_41720
# Product_28113
# Product_13851
# Product_74547
# Product_45224
# Product_55213
# Product_76907
# Product_25717
# Product_36056
# Product_46320
# Product_30716
# Product_13018
# Product_3302
# Product_39534
# Product_1042
# Product_9272
# Product_28705
# Product_11728
# Product_33581
# Product_11751
# Product_29454
# Product_48995
# Product_82156
# Product_54809
# Product_82128
# Product_55684
# Product_57323
# Product_21491
# Product_54253
# Product_47332
# Product_78375
# Product_40533
# Product_48714
# Product_11991
# Product_30473
# Product_18331
# Product_27291
# Product_64755
# Product_36624
# Product_29268
# Product_28501
# Product_79415
# Product_44751
# Product_33282
# Product_78826
# Product_42851
# Product_18517
# Product_63789
# Product_5678
# Product_64954
# Product_25460
# Product_18071
# Product_31799
# Product_19027
# Product_20525
# Product_52778
# Product_51481
# Product_26339
# Product_21064
# Product_60840
# Product_8404
# Product_19324
# Product_40261
# Product_24487
# Product_27124
# Product_41803
# Product_79332
# Product_59848
# Product_59399
# Product_61324
# Product_82088
# Product_2492
# Product_23268
# Product_4038
# Product_43962
# Product_11163
# Product_13298
# Product_16299
# Product_5700
# Product_45708
# Product_22186
# Product_41200
# Product_38828
# Product_50296
# Product_45131
# Product_16754
# Product_7177
# Product_17038
# Product_65353
# Product_71138
# Product_52705
# Product_73386
# Product_31200
# Product_43755
# Product_47639
# Product_2151
# Product_38683
# Product_22743
# Product_2022
# Product_81492
# Product_60924
# Product_8453
# Product_30406
# Product_80969
# Product_21886
# Product_57801
# Product_33264
# Product_27427
# Product_4113
# Product_45769
# Product_35671
# Product_19529
# Product_23119
# Product_33088
# Product_42544
# Product_64810
# Product_71832
# Product_27923
# Product_60490
# Product_49027
# Product_63668
# Product_81844
# Product_72361
# Product_9381
# Product_27159
# Product_73286
# Product_56431
# Product_24878
# Product_61585
# Product_14443
# Product_26421
# Product_26676
# Product_75991
# Product_60269
# Product_78802
# Product_35500
# Product_50839
# Product_49959
# Product_8207
# Product_81850
# Product_34428
# Product_23482
# Product_13795
# Product_39864
# Product_67011
# Product_68630
# Product_23935
# Product_6294
# Product_43877
# Product_10095
# Product_17242
# Product_82102
# Product_75413
# Product_26977
# Product_13921
# Product_5583
# Product_11363
# Product_25300
# Product_54798
# Product_21890
# Product_51686
# Product_69013
# Product_23719
# Product_4933
# Product_39362
# Product_56410
# Product_60011
# Product_79488
# Product_46038
# Product_50784
# Product_33601
# Product_56790
# Product_47324
# Product_30138
# Product_22295
# Product_75859
# Product_19417
# Product_3513
# Product_30844
# Product_29324
# Product_60961
# Product_67994
# Product_38776
# Product_69738
# Product_15594
# Product_18049
# Product_19864
# Product_70220
# Product_67258
# Product_82169
# Product_37043
# Product_10864
# Product_75531
# Product_71803
# Product_36539
# Product_42285
# Product_77051
# Product_63876
# Product_76255
# Product_47646
# Product_7985
# Product_54090
# Product_67633
# Product_51002
# Product_14591
# Product_37472
# Product_36723
# Product_38918
# Product_17898
# Product_72352
# Product_34022
# Product_43198
# Product_71708
# Product_14180
# Product_10983
# Product_46828
# Product_76081
# Product_79657
# Product_18964
# Product_6386
# Product_40444
# Product_76056
# Product_72156
# Product_34046
# Product_80842
# Product_71005
# Product_24052
# Product_37153
# Product_60355
# Product_24964
# Product_60594
# Product_28088
# Product_68464
# Product_42728
# Product_34543
# Product_15805
# Product_80277
# Product_37588
# Product_67976
# Product_60537
# Product_4539
# Product_34448
# Product_33100
# Product_72493
# Product_45236
# Product_34862
# Product_5981
# Product_9606
# Product_43116
# Product_21116
# Product_77241
# Product_24705
# Product_64443
# Product_69615
# Product_70518
# Product_12331
# Product_63733
# Product_30550
# Product_62527
# Product_20835
# Product_5996
# Product_55569
# Product_36423
# Product_13469
# Product_70267
# Product_19499
# Product_14884
# Product_9821
# Product_55390
# Product_5314
# Product_26058
# Product_8127
# Product_56473
# Product_8832
# Product_64089
# Product_26478
# Product_31189
# Product_7333
# Product_82369
# Product_4269
# Product_23775
# Product_17607
# Product_51506
# Product_2162
# Product_70266
# Product_16780
# Product_48241
# Product_38004
# Product_62852
# Product_52800
# Product_20936
# Product_29348
# Product_68314
# Product_229
# Product_19728
# Product_14424
# Product_14859
# Product_63495
# Product_49288
# Product_68488
# Product_64009
# Product_69018
# Product_59460
# Product_75455
# Product_30008
# Product_47443
# Product_69579
# Product_4849
# Product_40258
# Product_79885
# Product_6920
# Product_31491
# Product_56080
# Product_12842
# Product_68225
# Product_42074
# Product_73999
# Product_10254
# Product_58124
# Product_26863
# Product_33908
# Product_20727
# Product_30313
# Product_4222
# Product_48066
# Product_42402
# Product_69587
# Product_59251
# Product_52906
# Product_1497
# Product_68593
# Product_9483
# Product_12602
# Product_46478
# Product_76428
# Product_25458
# Product_3966
# Product_5290
# Product_44272
# Product_72791
# Product_29990
# Product_33624
# Product_64024
# Product_35066
# Product_65816
# Product_13259
# Product_27634
# Product_59947
# Product_19152
# Product_79967
# Product_76229
# Product_16910
# Product_81212
# Product_44280
# Product_68905
# Product_67961
# Product_931
# Product_14152
# Product_40344
# Product_67551
# Product_61283
# Product_58259
# Product_38063
# Product_58273
# Product_73956
# Product_47882
# Product_70544
# Product_15060
# Product_6178
# Product_38516
# Product_14023
# Product_555
# Product_55415
# Product_77803
# Product_7515
# Product_52726
# Product_6286
# Product_59915
# Product_74193
# Product_16508
# Product_32635
# Product_38826
# Product_27780
# Product_66589
# Product_19039
# Product_82244
# Product_3750
# Product_80844
# Product_70273
# Product_81998
# Product_71907
# Product_79815
# Product_21644
# Product_53169
# Product_11879
# Product_55631
# Product_31319
# Product_40571
# Product_20951
# Product_56433
# Product_81750
# Product_78724
# Product_2937
# Product_19748
# Product_76335
# Product_63794
# Product_72369
# Product_65819
# Product_36078
# Product_32105
# Product_60109
# Product_2123
# Product_75118
# Product_41530
# Product_29610
# Product_10315
# Product_7651
# Product_73027
# Product_70366
# Product_69165
# Product_18694
# Product_66115
# Product_456
# Product_18299
# Product_50164
# Product_57675
# Product_61623
# Product_11214
# Product_49101
# Product_8983
# Product_63427
# Product_5558
# Product_44768
# Product_71009
# Product_39804
# Product_37506
# Product_4794
# Product_45904
# Product_82731
# Product_77133
# Product_35096
# Product_49748
# Product_73707
# Product_1065
# Product_36216
# Product_48737
# Product_50195
# Product_70441
# Product_768
# Product_66320
# Product_48271
# Product_61182
# Product_11810
# Product_3282
# Product_22703
# Product_68316
# Product_54924
# Product_57208
# Product_24601
# Product_61280
# Product_16400
# Product_59820
# Product_19598
# Product_48532
# Product_4927
# Product_5311
# Product_40118
# Product_59528
# Product_58252
# Product_4096
# Product_41215
# Product_5642
# Product_47454
# Product_49541
# Product_18102
# Product_81193
# Product_74503
# Product_50293
# Product_43848
# Product_44317
# Product_9746
# Product_51963
# Product_48251
# Product_64294
# Product_16476
# Product_48552
# Product_32861
# Product_39145
# Product_30690
# Product_26739
# Product_74317
# Product_38180
# Product_57303
# Product_11499
# Product_28702
# Product_77504
# Product_627
# Product_46110
# Product_70927
# Product_30783
# Product_60645
# Product_59568
# Product_56132
# Product_8380
# Product_12899
# Product_72344
# Product_71295
# Product_22626
# Product_17256
# Product_108
# Product_40639
# Product_58547
# Product_57219
# Product_11298
# Product_34641
# Product_60772
# Product_9808
# Product_11267
# Product_48395
# Product_27547
# Product_6809
# Product_28686
# Product_70531
# Product_72145
# Product_82185
# Product_64968
# Product_37457
# Product_35482
# Product_65639
# Product_39586
# Product_7733
# Product_13883
# Product_13918
# Product_20949
# Product_9896
# Product_64765
# Product_55403
# Product_41525
# Product_23566
# Product_4720
# Product_35079
# Product_75205
# Product_7581
# Product_49219
# Product_33876
# Product_71333
# Product_15917
# Product_41647
# Product_77941
# Product_74860
# Product_8863
# Product_50841
# Product_50570
# Product_82682
# Product_13076
# Product_77636
# Product_23046
# Product_8006
# Product_35499
# Product_75520
# Product_39766
# Product_23769
# Product_39686
# Product_67575
# Product_22557
# Product_56806
# Product_83
# Product_19279
# Product_53592
# Product_46552
# Product_61696
# Product_40434
# Product_49140
# Product_7922
# Product_20123
# Product_27370
# Product_48927
# Product_59976
# Product_78043
# Product_21408
# Product_54788
# Product_41887
# Product_735
# Product_16779
# Product_20011
# Product_11444
# Product_35744
# Product_66841
# Product_77853
# Product_64899
# Product_35823
# Product_51780
# Product_6394
# Product_50753
# Product_15088
# Product_59004
# Product_45872
# Product_18898
# Product_17141
# Product_12624
# Product_67515
# Product_47543
# Product_60265
# Product_3765
# Product_49250
# Product_73582
# Product_6902
# Product_81150
# Product_39379
# Product_65146
# Product_50117
# Product_59761
# Product_74559
# Product_52534
# Product_51707
# Product_23067
# Product_5809
# Product_80648
# Product_36977
# Product_77890
# Product_22669
# Product_30634
# Product_21296
# Product_19766
# Product_73086
# Product_24997
# Product_58887
# Product_68208
# Product_65935
# Product_34997
# Product_32920
# Product_81270
# Product_52234
# Product_63234
# Product_1626
# Product_72639
# Product_77232
# Product_62407
# Product_31732
# Product_55134
# Product_15757
# Product_80230
# Product_49396
# Product_20237
# Product_71582
# Product_24901
# Product_9067
# Product_68790
# Product_10772
# Product_6645
# Product_50704
# Product_51469
# Product_6539
# Product_62502
# Product_32691
# Product_66473
# Product_58718
# Product_15334
# Product_42722
# Product_70729
# Product_62784
# Product_51197
# Product_71338
# Product_67734
# Product_76031
# Product_81073
# Product_21401
# Product_27492
# Product_72564
# Product_22221
# Product_38415
# Product_67745
# Product_27227
# Product_56539
# Product_75288
# Product_40809
# Product_54926
# Product_40674
# Product_42560
# Product_54151
# Product_19022
# Product_19682
# Product_9523
# Product_4691
# Product_59876
# Product_43584
# Product_47950
# Product_48083
# Product_8067
# Product_66989
# Product_71038
# Product_44671
# Product_10295
# Product_35111
# Product_24342
# Product_65133
# Product_45859
# Product_68048
# Product_26085
# Product_47541
# Product_46063
# Product_855
# Product_30316
# Product_74756
# Product_60609
# Product_13771
# Product_42986
# Product_73404
# Product_44331
# Product_11983
# Product_76704
# Product_2253
# Product_44727
# Product_29024
# Product_20251
# Product_22109
# Product_68235
# Product_66922
# Product_7232
# Product_8242
# Product_36854
# Product_3038
# Product_13372
# Product_25937
# Product_55652
# Product_31641
# Product_40125
# Product_69515
# Product_17127
# Product_30310
# Product_13487
# Product_3072
# Product_74512
# Product_67672
# Product_67950
# Product_44875
# Product_5703
# Product_23486
# Product_57444
# Product_23160
# Product_37776
# Product_29664
# Product_6886
# Product_58772
# Product_16440
# Product_65987
# Product_60292
# Product_60055
# Product_18194
# Product_44414
# Product_56370
# Product_74326
# Product_80410
# Product_55443
# Product_35677
# Product_4880
# Product_38316
# Product_70209
# Product_7093
# Product_43944
# Product_10982
# Product_26905
# Product_40502
# Product_45172
# Product_51124
# Product_63720
# Product_27919
# Product_81
# Product_72889
# Product_20320
# Product_79768
# Product_1325
# Product_18039
# Product_53821
# Product_48417
# Product_70111
# Product_18216
# Product_3639
# Product_32431
# Product_79708
# Product_63388
# Product_31466
# Product_35580
# Product_44035
# Product_5531
# Product_25684
# Product_39176
# Product_68381
# Product_55893
# Product_58190
# Product_27320
# Product_21149
# Product_71401
# Product_48639
# Product_34984
# Product_5654
# Product_3376
# Product_82762
# Product_19450
# Product_22284
# Product_30976
# Product_62727
# Product_73470
# Product_26734
# Product_32719
# Product_21196
# Product_75226
# Product_6307
# Product_3873
# Product_47531
# Product_34340
# Product_60841
# Product_1399
# Product_40870
# Product_65099
# Product_49734
# Product_18756
# Product_65227
# Product_48607
# Product_71627
# Product_15841
# Product_66179
# Product_26179
# Product_61981
# Product_13178
# Product_80285
# Product_52508
# Product_33272
# Product_31749
# Product_58116
# Product_74418
# Product_11636
# Product_64421
# Product_33159
# Product_13715
# Product_66952
# Product_7131
# Product_65908
# Product_44054
# Product_41913
# Product_19796
# Product_78002
# Product_77510
# Product_46815
# Product_28666
# Product_20769
# Product_48256
# Product_44011
# Product_20118
# Product_77643
# Product_10265
# Product_80991
# Product_36756
# Product_6325
# Product_62700
# Product_53699
# Product_39056
# Product_14040
# Product_75281
# Product_78100
# Product_44311
# Product_82043
# Product_41689
# Product_49988
# Product_64057
# Product_5536
# Product_7040
# Product_18199
# Product_52718
# Product_27351
# Product_76336
# Product_40474
# Product_16637
# Product_14007
# Product_44690
# Product_40082
# Product_58821
# Product_19467
# Product_15174
# Product_76554
# Product_74236
# Product_46052
# Product_22584
# Product_63951
# Product_47561
# Product_72516
# Product_64093
# Product_19744
# Product_58065
# Product_47513
# Product_19481
# Product_52670
# Product_20753
# Product_31097
# Product_66707
# Product_4562
# Product_18896
# Product_64
# Product_23088
# Product_15063
# Product_81135
# Product_79267
# Product_59957
# Product_55760
# Product_13816
# Product_28048
# Product_15073
# Product_20545
# Product_70346
# Product_29535
# Product_65063
# Product_65323
# Product_72478
# Product_61731
# Product_65342
# Product_78650
# Product_302
# Product_68502
# Product_72213
# Product_72278
# Product_79516
# Product_55121
# Product_17774
# Product_29011
# Product_41510
# Product_73567
# Product_18459
# Product_18665
# Product_13857
# Product_1683
# Product_36252
# Product_32293
# Product_33952
# Product_49822
# Product_64155
# Product_64053
# Product_54889
# Product_46480
# Product_25274
# Product_28189
# Product_24617
# Product_48685
# Product_32684
# Product_10110
# Product_71322
# Product_46422
# Product_16293
# Product_65234
# Product_44057
# Product_76996
# Product_46182
# Product_50524
# Product_45903
# Product_19725
# Product_79491
# Product_29194
# Product_44710
# Product_28253
# Product_51395
# Product_65228
# Product_80928
# Product_13317
# Product_19651
# Product_75790
# Product_38413
# Product_35604
# Product_39813
# Product_13449
# Product_52477
# Product_47221
# Product_52468
# Product_27834
# Product_81535
# Product_82430
# Product_48026
# Product_70069
# Product_43883
# Product_51095
# Product_35935
# Product_70844
# Product_52898
# Product_75096
# Product_1582
# Product_48037
# Product_42830
# Product_34785
# Product_48230
# Product_45313
# Product_6569
# Product_20683
# Product_329
# Product_55947
# Product_65481
# Product_59659
# Product_11416
# Product_46228
# Product_30049
# Product_63357
# Product_82687
# Product_75759
# Product_75381
# Product_48993
# Product_37200
# Product_5315
# Product_29916
# Product_56666
# Product_21220
# Product_37916
# Product_71975
# Product_33965
# Product_42587
# Product_63011
# Product_23876
# Product_39956
# Product_15490
# Product_51031
# Product_53475
# Product_67739
# Product_47867
# Product_12252
# Product_37666
# Product_2452
# Product_21024
# Product_12049
# Product_80890
# Product_66869
# Product_8401
# Product_34833
# Product_42762
# Product_78780
# Product_38724
# Product_51210
# Product_81666
# Product_71100
# Product_3218
# Product_72031
# Product_43089
# Product_39072
# Product_42901
# Product_52876
# Product_19100
# Product_5291
# Product_62801
# Product_73608
# Product_21610
# Product_68608
# Product_41026
# Product_15394
# Product_40788
# Product_75969
# Product_17449
# Product_44779
# Product_13419
# Product_13451
# Product_38733
# Product_30045
# Product_45925
# Product_54381
# Product_62556
# Product_39060
# Product_66741
# Product_26887
# Product_62304
# Product_7686
# Product_59569
# Product_71070
# Product_69666
# Product_13416
# Product_41322
# Product_73899
# Product_37117
# Product_23250
# Product_71481
# Product_57150
# Product_54145
# Product_9306
# Product_28845
# Product_39028
# Product_64997
# Product_37681
# Product_69513
# Product_65698
# Product_40716
# Product_67856
# Product_49453
# Product_32079
# Product_78356
# Product_21301
# Product_42972
# Product_2463
# Product_13672
# Product_47388
# Product_74483
# Product_22263
# Product_25826
# Product_32037
# Product_2767
# Product_74338
# ...
# Product_79485
# Product_45423
# Product_50152
# Product_5421
# Product_74799
# Product_80162
# Product_50694
# Product_52880
# Product_69851
# Product_60287
# Product_65145
# Product_39090
# Product_18946
# Product_333
# Product_74766
# Product_21898
# Product_4766
# Product_38045
# Product_42865
# Product_82586
# Product_57629
# Product_17060
# Product_45472
# Product_26582
# Product_64680
# Product_4138
# Product_69126
# Product_53693
# Product_24844
# Product_75074
# Product_82455
# Product_26837
# Product_73317
# Product_62366
# Product_12375
# Product_23034
# Product_14382
# Product_25709
# Product_74930
# Product_1402
# Product_81717
# Product_64837
# Product_43090
# Product_4389
# Product_32696
# Product_64693
# Product_75963
# Product_11923
# Product_20219
# Product_24218
# Product_42516
# Product_14090
# Product_59673
# Product_22755
# Product_22129
# Product_76342
# Product_11838
# Product_21831
# Product_20970
# Product_6086
# Product_22912
# Product_58453
# Product_62065
# Product_4124
# Product_23701
# Product_20919
# Product_4523
# Product_5305
# Product_21203
# Product_54118
# Product_22335
# Product_64614
# Product_18853
# Product_9172
# Product_8056
# Product_35009
# Product_71318
# Product_26563
# Product_31177
# Product_38446
# Product_71678
# Product_55264
# Product_33658
# Product_77324
# Product_63183
# Product_18206
# Product_17765
# Product_73629
# Product_18107
# Product_28463
# Product_9827
# Product_73644
# Product_76541
# Product_72089
# Product_33844
# Product_12325
# Product_38816
# Product_28648
# Product_11634
# Product_60831
# Product_71703
# Product_24721
# Product_957
# Product_31027
# Product_28181
# Product_71563
# Product_5525
# Product_5550
# Product_74949
# Product_60228
# Product_74554
# Product_44087
# Product_61009
# Product_35533
# Product_2461
# Product_5879
# Product_23224
# Product_4926
# Product_19252
# Product_48145
# Product_1204
# Product_17990
# Product_64518
# Product_18377
# Product_41414
# Product_23748
# Product_21837
# Product_6483
# Product_2816
# Product_47853
# Product_45316
# Product_78079
# Product_48882
# Product_16709
# Product_28475
# Product_29040
# Product_18265
# Product_82802
# Product_53220
# Product_48406
# Product_59622
# Product_1374
# Product_28961
# Product_24530
# Product_59583
# Product_45754
# Product_70669
# Product_4381
# Product_79775
# Product_61138
# Product_13036
# Product_57610
# Product_43489
# Product_40022
# Product_58128
# Product_37928
# Product_20984
# Product_29288
# Product_3253
# Product_61743
# Product_3660
# Product_73819
# Product_51947
# Product_34883
# Product_34381
# Product_25742
# Product_47564
# Product_69312
# Product_9492
# Product_77118
# Product_65861
# Product_9256
# Product_72342
# Product_13202
# Product_69305
# Product_76423
# Product_80529
# Product_46368
# Product_43117
# Product_81079
# Product_23135
# Product_48222
# Product_58530
# Product_32934
# Product_65374
# Product_56924
# Product_1874
# Product_49293
# Product_42471
# Product_35866
# Product_20533
# Product_52840
# Product_17380
# Product_73488
# Product_42637
# Product_32665
# Product_80283
# Product_55376
# Product_56071
# Product_9309
# Product_52625
# Product_21111
# Product_9252
# Product_49699
# Product_69993
# Product_7008
# Product_59938
# Product_41972
# Product_1798
# Product_64615
# Product_29908
# Product_55303
# Product_46359
# Product_65808
# Product_39013
# Product_54644
# Product_36048
# Product_18036
# Product_15249
# Product_31744
# Product_10405
# Product_28299
# Product_66621
# Product_31796
# Product_81780
# Product_18050
# Product_47995
# Product_59213
# Product_75564
# Product_33348
# Product_30457
# Product_33336
# Product_77222
# Product_8050
# Product_49067
# Product_79320
# Product_71954
# Product_72140
# Product_66561
# Product_57657
# Product_9598
# Product_63643
# Product_29019
# Product_65460
# Product_50826
# Product_50372
# Product_25411
# Product_7977
# Product_77427
# Product_76564
# Product_59028
# Product_22342
# Product_66899
# Product_59911
# Product_32896
# Product_24588
# Product_45644
# Product_23870
# Product_31600
# Product_3822
# Product_11333
# Product_2066
# Product_49459
# Product_79742
# Product_41661
# Product_80979
# Product_13660
# Product_28003
# Product_4951
# Product_6824
# Product_54999
# Product_44079
# Product_70900
# Product_37604
# Product_421
# Product_24704
# Product_22225
# Product_80065
# Product_17878
# Product_4999
# Product_5851
# Product_74434
# Product_52261
# Product_71809
# Product_46573
# Product_53431
# Product_64854
# Product_17051
# Product_42537
# Product_56413
# Product_1486
# Product_36368
# Product_76495
# Product_75018
# Product_524
# Product_56547
# Product_13240
# Product_5332
# Product_38781
# Product_41094
# Product_43283
# Product_270
# Product_34192
# Product_48632
# Product_51111
# Product_55012
# Product_15149
# Product_23760
# Product_5612
# Product_58848
# Product_65177
# Product_30016
# Product_19074
# Product_55534
# Product_36130
# Product_73486
# Product_52537
# Product_16470
# Product_36809
# Product_76720
# Product_2217
# Product_40792
# Product_82788
# Product_38884
# Product_65615
# Product_49504
# Product_67957
# Product_66562
# Product_74985
# Product_37467
# Product_7146
# Product_49910
# Product_36092
# Product_47575
# Product_28037
# Product_72529
# Product_16317
# Product_46489
# Product_62000
# Product_20452
# Product_57500
# Product_52905
# Product_21124
# Product_15761
# Product_39277
# Product_26061
# Product_80570
# Product_36499
# Product_36033
# Product_33227
# Product_56795
# Product_51988
# Product_65139
# Product_59611
# Product_61857
# Product_39879
# Product_13511
# Product_1189
# Product_37237
# Product_48235
# Product_31296
# Product_62671
# Product_15819
# Product_14523
# Product_72486
# Product_50221
# Product_54759
# Product_17468
# Product_10266
# Product_53908
# Product_61149
# Product_9508
# Product_51194
# Product_64562
# Product_5720
# Product_59015
# Product_64914
# Product_941
# Product_31061
# Product_40336
# Product_1063
# Product_72865
# Product_11526
# Product_13155
# Product_3108
# Product_59133
# Product_8978
# Product_16976
# Product_75289
# Product_59576
# Product_54106
# Product_13613
# Product_9279
# Product_10001
# Product_32208
# Product_9529
# Product_19680
# Product_52548
# Product_54379
# Product_38735
# Product_67070
# Product_42619
# Product_38204
# Product_77235
# Product_25172
# Product_15618
# Product_81340
# Product_12221
# Product_41949
# Product_41847
# Product_28315
# Product_68422
# Product_56509
# Product_13129
# Product_9161
# Product_11224
# Product_72944
# Product_43834
# Product_67201
# Product_28744
# Product_33327
# Product_75040
# Product_63531
# Product_8054
# Product_17015
# Product_43160
# Product_75140
# Product_3047
# Product_60461
# Product_71506
# Product_60348
# Product_22078
# Product_28321
# Product_33745
# Product_13232
# Product_18809
# Product_3111
# Product_51442
# Product_81632
# Product_73312
# Product_54931
# Product_45632
# Product_27805
# Product_82642
# Product_64816
# Product_50861
# Product_5212
# Product_76804
# Product_11797
# Product_8087
# Product_35479
# Product_9883
# Product_67545
# Product_73370
# Product_28875
# Product_3172
# Product_55125
# Product_38670
# Product_51201
# Product_61973
# Product_43525
# Product_29761
# Product_54698
# Product_15511
# Product_78411
# Product_38039
# Product_67321
# Product_81369
# Product_24250
# Product_23838
# Product_82105
# Product_38451
# Product_27822
# Product_7310
# Product_20261
# Product_48275
# Product_23700
# Product_69495
# Product_40925
# Product_36794
# Product_17865
# Product_57005
# Product_37704
# Product_14354
# Product_80556
# Product_37210
# Product_23491
# Product_10684
# Product_82042
# Product_39816
# Product_62953
# Product_12153
# Product_40675
# Product_32770
# Product_31483
# Product_59392
# Product_47608
# Product_47827
# Product_5132
# Product_43395
# Product_78536
# Product_45639
# Product_52946
# Product_18757
# Product_47739
# Product_24353
# Product_78083
# Product_66048
# Product_14183
# Product_19708
# Product_8585
# Product_24467
# Product_31150
# Product_53808
# Product_7917
# Product_60224
# Product_72649
# Product_34304
# Product_26882
# Product_22210
# Product_69685
# Product_327
# Product_40922
# Product_10195
# Product_57955
# Product_55066
# Product_44465
# Product_6982
# Product_53818
# Product_50571
# Product_16255
# Product_25307
# Product_39290
# Product_78282
# Product_61804
# Product_71539
# Product_33814
# Product_78304
# Product_68354
# Product_64346
# Product_28498
# Product_17854
# Product_74751
# Product_64806
# Product_68621
# Product_31276
# Product_80489
# Product_44940
# Product_31991
# Product_82062
# Product_27208
# Product_78531
# Product_6391
# Product_29301
# Product_2543
# Product_57846
# Product_37937
# Product_5428
# Product_13196
# Product_57285
# Product_47474
# Product_9104
# Product_19618
# Product_49317
# Product_33674
# Product_68581
# Product_28821
# Product_66846
# Product_82438
# Product_44966
# Product_5439
# Product_38301
# Product_1216
# Product_43966
# Product_37544
# Product_30922
# Product_29963
# Product_72799
# Product_8949
# Product_13995
# Product_61095
# Product_7481
# Product_27816
# Product_36475
# Product_12590
# Product_73467
# Product_43278
# Product_19668
# Product_7797
# Product_62546
# Product_81124
# Product_70290
# Product_73031
# Product_30847
# Product_19384
# Product_56457
# Product_32669
# Product_32518
# Product_66666
# Product_41068
# Product_76337
# Product_53668
# Product_5852
# Product_31084
# Product_43192
# Product_75443
# Product_48988
# Product_29855
# Product_19527
# Product_5760
# Product_31473
# Product_44934
# Product_31774
# Product_510
# Product_76825
# Product_9645
# Product_66525
# Product_79340
# Product_30706
# Product_45932
# Product_46390
# Product_16589
# Product_56605
# Product_25652
# Product_80707
# Product_5024
# Product_30090
# Product_33864
# Product_18464
# Product_2682
# Product_39062
# Product_45482
# Product_25243
# Product_35259
# Product_48258
# Product_71990
# Product_63482
# Product_25396
# Product_38345
# Product_61116
# Product_55082
# Product_39447
# Product_59604
# Product_78105
# Product_35363
# Product_37430
# Product_47794
# Product_73049
# Product_1968
# Product_65013
# Product_58704
# Product_3564
# Product_77245
# Product_26295
# Product_65115
# Product_58602
# Product_59010
# Product_63339
# Product_57387
# Product_650
# Product_76898
# Product_82696
# Product_32429
# Product_32904
# Product_32444
# Product_43910
# Product_73076
# Product_40897
# Product_18892
# Product_69122
# Product_48136
# Product_80828
# Product_48877
# Product_54185
# Product_81132
# Product_80855
# Product_1290
# Product_21941
# Product_77000
# Product_16851
# Product_61408
# Product_58796
# Product_57200
# Product_6367
# Product_70763
# Product_10957
# Product_54506
# Product_10369
# Product_53326
# Product_13213
# Product_5431
# Product_46165
# Product_19585
# Product_65207
# Product_67102
# Product_54784
# Product_56720
# Product_14442
# Product_80011
# Product_60532
# Product_2544
# Product_4835
# Product_56261
# Product_70406
# Product_34506
# Product_49106
# Product_79925
# Product_58886
# Product_72406
# Product_2913
# Product_38100
# Product_38276
# Product_40457
# Product_66750
# Product_26119
# Product_40366
# Product_13148
# Product_30214
# Product_34110
# Product_2064
# Product_8642
# Product_34657
# Product_7510
# Product_81838
# Product_32718
# Product_1700
# Product_77024
# Product_77276
# Product_50696
# Product_656
# Product_60080
# Product_47831
# Product_4966
# Product_61634
# Product_47906
# Product_37248
# Product_44876
# Product_73933
# Product_36171
# Product_51710
# Product_38547
# Product_71705
# Product_28692
# Product_37018
# Product_28839
# Product_70388
# Product_38182
# Product_46322
# Product_31456
# Product_79392
# Product_69626
# Product_14660
# Product_18758
# Product_47114
# Product_42954
# Product_51030
# Product_48994
# Product_77228
# Product_1363
# Product_14734
# Product_8323
# Product_46701
# Product_9987
# Product_7451
# Product_70939
# Product_11961
# Product_77508
# Product_39142
# Product_32526
# Product_77826
# Product_1896
# Product_71510
# Product_22908
# Product_28978
# Product_62768
# Product_13462
# Product_58254
# Product_58829
# Product_69783
# Product_31384
# Product_74391
# Product_13437
# Product_77478
# Product_78958
# Product_59751
# Product_13896
# Product_35398
# Product_77260
# Product_2920
# Product_46652
# Product_31212
# Product_35346
# Product_46253
# Product_60858
# Product_9135
# Product_32165
# Product_2236
# Product_28470
# Product_66407
# Product_62115
# Product_12084
# Product_38432
# Product_4194
# Product_19134
# Product_65859
# Product_17216
# Product_407
# Product_78106
# Product_22784
# Product_49633
# Product_23885
# Product_32282
# Product_18735
# Product_42214
# Product_45454
# Product_24087
# Product_25223
# Product_55442
# Product_60003
# Product_74897
# Product_5704
# Product_17354
# Product_60890
# Product_27108
# Product_41880
# Product_60939
# Product_14982
# Product_11115
# Product_74187
# Product_7299
# Product_35576
# Product_73148
# Product_51167
# Product_4301
# Product_24315
# Product_918
# Product_26153
# Product_9131
# Product_17577
# Product_42159
# Product_58418
# Product_42250
# Product_19244
# Product_328
# Product_43392
# Product_65093
# Product_54493
# Product_44961
# Product_81333
# Product_81870
# Product_15019
# Product_65072
# Product_52072
# Product_46691
# Product_69071
# Product_29122
# Product_7072
# Product_44249
# Product_56801
# Product_47230
# Product_50572
# Product_18771
# Product_43397
# Product_66840
# Product_58518
# Product_58497
# Product_39970
# Product_42670
# Product_29182
# Product_72612
# Product_29361
# Product_8602
# Product_81614
# Product_750
# Product_34130
# Product_2331
# Product_52854
# Product_63828
# Product_55421
# Product_77056
# Product_39946
# Product_58667
# Product_74594
# Product_5206
# Product_54467
# Product_9644
# Product_71989
# Product_42639
# Product_15203
# Product_19958
# Product_41772
# Product_74876
# Product_49792
# Product_62802
# Product_69478
# Product_4530
# Product_2952
# Product_18545
# Product_78752
# Product_28882
# Product_65035
# Product_53560
# Product_66735
# Product_54838
# Product_81050
# Product_37386
# Product_69272
# Product_81982
# Product_79953
# Product_29066
# Product_78621
# Product_75346
# Product_22838
# Product_73423
# Product_73399
# Product_73668
# Product_75815
# Product_14923
# Product_38980
# Product_67453
# Product_8391
# Product_59662
# Product_78350
# Product_40308
# Product_1785
# Product_11994
# Product_6115
# Product_37508
# Product_47246
# Product_72955
# Product_31289
# Product_69389
# Product_8946
# Product_3380
# Product_57316
# Product_43361
# Product_82368
# Product_34382
# Product_71648
# Product_15135
# Product_24219
# Product_62364
# Product_81512
# Product_45788
# Product_68276
# Product_26758
# Product_62467
# Product_5768
# Product_11789
# Product_43843
# Product_65652
# Product_9614
# Product_37402
# Product_3344
# Product_57734
# Product_26715
# Product_79056
# Product_82180
# Product_45135
# Product_70726
# Product_45114
# Product_43611
# Product_32376
# Product_33115
# Product_47097
# Product_48456
# Product_14928
# Product_17550
# Product_52680
# Product_37592
# Product_20140
# Product_34278
# Product_67014
# Product_63159
# Product_62301
# Product_17055
# Product_5508
# Product_48704
# Product_54050
# Product_9882
# Product_76570
# Product_43907
# Product_6143
# Product_81375
# Product_47213
# Product_29991
# Product_48612
# Product_47963
# Product_30409
# Product_72151
# Product_67794
# Product_64890
# Product_54475
# Product_76827
# Product_35460
# Product_40356
# Product_30418
# Product_318
# Product_16018
# Product_43197
# Product_19094
# Product_16566
# Product_18872
# Product_27375
# Product_13767
# Product_20989
# Product_38083
# Product_164
# Product_40794
# Product_46418
# Product_33937
# Product_60393
# Product_77605
# Product_40059
# Product_36027
# Product_62946
# Product_29064
# Product_75664
# Product_33163
# Product_60750
# Product_22114
# Product_2838
# Product_39168
# Product_44278
# Product_50005
# Product_37453
# Product_58574
# Product_55460
# Product_31231
# Product_14131
# Product_57776
# Product_68088
# Product_53176
# Product_7058
# Product_14526
# Product_23659
# Product_55138
# Product_2806
# Product_32192
# Product_2800
# Product_36915
# Product_34503
# Product_66435
# Product_69453
# Product_18954
# Product_81674
# Product_17603
# Product_38152
# Product_82024
# Product_2533
# Product_1126
# Product_27502
# Product_48112
# Product_78032
# Product_55618
# Product_3525
# Product_10084
# Product_21572
# Product_78730
# Product_41636
# Product_60705
# Product_41928
# Product_49926
# Product_61200
# Product_44707
# Product_727
# Product_5146
# Product_31273
# Product_31861
# Product_9513
# Product_24568
# Product_70539
# Product_53732
# Product_52394
# Product_46032
# Product_73456
# Product_30735
# Product_45117
# Product_40295
# Product_45620
# Product_48693
# Product_15826
# Product_8853
# Product_57040
# Product_729
# Product_51742
# Product_72769
# Product_13142
# Product_16403
# Product_38501
# Product_11357
# Product_51132
# Product_76768
# Product_23401
# Product_51876
# Product_36256
# Product_24196
# Product_13623
# Product_56690
# Product_33523
# Product_519
# Product_4295
# Product_7634
# Product_8407
# Product_46538
# Product_68596
# Product_21281
# Product_14435
# Product_19617
# Product_32002
# Product_24739
# Product_72333
# Product_61224
# Product_16326
# Product_3463
# Product_12784
# Product_72554
# Product_62098
# Product_54304
# Product_68279
# Product_64410
# Product_39795
# Product_10564
# Product_16037
# Product_71888
# Product_52674
# Product_76596
# Product_46130
# Product_76852
# Product_47903
# Product_43924
# Product_28783
# Product_13700
# Product_33670
# Product_46961
# Product_63144
# Product_53624
# Product_63161
# Product_25403
# Product_15448
# Product_26414
# Product_77646
# Product_24735
# Product_31849
# Product_3100
# Product_39258
# Product_16500
# Product_64700
# Product_15452
# Product_47854
# Product_67600
# Product_30486
# Product_43302
# Product_10361
# Product_46160

# %%
missing_products_info = products_data[products_data["product_id"].isin(missing_from_train)]

# Display the missing products dataframe
missing_products_info
# Out:
#           product_id             product_description department_key  \
# 13     Product_51620    33CL LIMONADE LA BEAUCERONNE  Department_10
# 17      Product_6916       PET 1,5L LIMONETTE MILLES  Department_10
# 18     Product_39850  75CL LORINA LIMONADE CITRON VT  Department_10
# 19     Product_31931   75CL BEAUCERONNE CITRON GLACE  Department_10
# 21      Product_1433        BELVOIR CITRONNADE 750ML  Department_10
# ...              ...                             ...            ...
# 82960  Product_57956  885558 CUSHION 4 BLANC CAS2 TU  Department_65
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82964  Product_31161              CHARGE BUT 13K CRF  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 13     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 17     Class_1000  SubClass_10000                      PGC   LIMONETTE
# 18     Class_1000  SubClass_10000                      PGC      LORINA
# 19     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 21     Class_1000  SubClass_10000                      PGC     BELVOIR
# ...           ...             ...                      ...         ...
# 82960  Class_6573  SubClass_65730                  TEXTILE    TEX HOME
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82964  Class_7520  SubClass_75201  ACTIVITES PERIPHERIQUES   CARREFOUR
#
#                shelf_level1                         shelf_level2  \
# 13                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 17                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 18                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 19                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 21                 Boissons  Colas, Thés glacés, Sirops et Sodas
# ...                     ...                                  ...
# 82960  Maison et Décoration               Mobilier et Décoration
# 82961     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82963            Animalerie                               Chiens
# 82964  Maison et Décoration                    Bouteilles de gaz
#
#                              shelf_level3                     shelf_level4  \
# 13             Limonades, Limes et Tonics                              NaN
# 17             Limonades, Limes et Tonics                              NaN
# 18             Limonades, Limes et Tonics                              NaN
# 19             Limonades, Limes et Tonics                              NaN
# 21             Limonades, Limes et Tonics                              NaN
# ...                                   ...                              ...
# 82960  Décorations et Parfums d'intérieur   Coussins et galettes de chaise
# 82961                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82962                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82963      Colliers, Laisses et Vêtements          Vêtements et Chaussures
# 82964                                 NaN                              NaN
#
#        bio  sugar_free  aspartame_free  gluten_free  halal  casher  \
# 13       0           0               0            0      0       0
# 17       0           0               0            0      0       0
# 18       0           0               0            0      0       0
# 19       0           0               0            0      0       0
# 21       0           0               0            0      0       0
# ...    ...         ...             ...          ...    ...     ...
# 82960    0           0               0            0      0       0
# 82961    0           0               0            0      0       0
# 82962    0           0               0            0      0       0
# 82963    0           0               0            0      0       0
# 82964    0           0               0            0      0       0
#
#        eco_friendly  local_french  artificial_coloring_free  \
# 13                0             0                         0
# 17                0             0                         0
# 18                0             0                         0
# 19                0             0                         0
# 21                0             0                         0
# ...             ...           ...                       ...
# 82960             0             0                         0
# 82961             0             0                         0
# 82962             0             0                         0
# 82963             0             0                         0
# 82964             0             0                         0
#
#        taste_enhancer_free  naturality  antibiotic_free  reduced_sugar  \
# 13                       0           0                0              0
# 17                       0           0                0              0
# 18                       0           0                0              0
# 19                       0           0                0              0
# 21                       0           0                0              0
# ...                    ...         ...              ...            ...
# 82960                    0           0                0              0
# 82961                    0           0                0              0
# 82962                    0           0                0              0
# 82963                    0           0                0              0
# 82964                    0           0                0              0
#
#        vegetarian  pesticide_free  grain_free  no_added_sugar  salt_reduced  \
# 13              0               0           0               0             0
# 17              0               0           0               0             0
# 18              0               0           0               0             0
# 19              0               0           0               0             0
# 21              0               0           0               0             0
# ...           ...             ...         ...             ...           ...
# 82960           0               0           0               0             0
# 82961           0               0           0               0             0
# 82962           0               0           0               0             0
# 82963           0               0           0               0             0
# 82964           0               0           0               0             0
#
#        nitrite_free  fed_without_ogm  no_added_salt  no_artificial_flavours  \
# 13                0                0              0                       0
# 17                0                0              0                       0
# 18                0                0              0                       0
# 19                0                0              0                       0
# 21                0                0              0                       0
# ...             ...              ...            ...                     ...
# 82960             0                0              0                       0
# 82961             0                0              0                       0
# 82962             0                0              0                       0
# 82963             0                0              0                       0
# 82964             0                0              0                       0
#
#        porc  vegan  frozen  fat_free  reduced_fats  fresh  alcool  \
# 13        0      0       0         0             0      0       0
# 17        0      0       0         0             0      0       0
# 18        0      0       0         0             0      0       0
# 19        0      0       0         0             0      0       0
# 21        0      0       0         0             0      0       0
# ...     ...    ...     ...       ...           ...    ...     ...
# 82960     0      0       0         0             0      0       0
# 82961     0      0       0         0             0      0       0
# 82962     0      0       0         0             0      0       0
# 82963     0      0       0         0             0      0       0
# 82964     0      0       0         0             0      0       0
#
#        lactose_free  phenylalanine_free  palm_oil_free ecoscore  \
# 13                0                   0              0      NaN
# 17                0                   0              0      NaN
# 18                0                   0              0      NaN
# 19                0                   0              0      NaN
# 21                0                   0              0      NaN
# ...             ...                 ...            ...      ...
# 82960             0                   0              0      NaN
# 82961             0                   0              0      NaN
# 82962             0                   0              0      NaN
# 82963             0                   0              0      NaN
# 82964             0                   0              0      NaN
#
#        produits_du_monde  regional_product  national_brand  first_price_brand  \
# 13                     0                 0               1                  0
# 17                     0                 1               1                  0
# 18                     0                 0               1                  0
# 19                     0                 1               1                  0
# 21                     0                 0               1                  0
# ...                  ...               ...             ...                ...
# 82960                  0                 0               0                  0
# 82961                  0                 0               0                  0
# 82962                  0                 0               0                  0
# 82963                  0                 0               0                  0
# 82964                  0                 0               0                  0
#
#        carrefour_brand
# 13                   0
# 17                   0
# 18                   0
# 19                   0
# 21                   0
# ...                ...
# 82960                1
# 82961                1
# 82962                1
# 82963                1
# 82964                1
#
# [29971 rows x 49 columns]

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %% [markdown]
# # Negative Sampling using Embeddings

# %%
train_data
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 0        Household_10188  Product_62613         0       1.0      351      1
# 1        Household_10188  Product_71119         0       1.0      581      5
# 2        Household_10188  Product_23971         0       2.0      581      5
# 3        Household_10188   Product_3907         0       1.0      624      4
# 4        Household_10188  Product_37906         0       1.0       21     12
# ...                  ...            ...       ...       ...      ...    ...
# 8756541  Household_19505  Product_62926         0       1.0      499      8
# 8756542  Household_11112  Product_75788         0       1.0       75     10
# 8756543  Household_11112  Product_46620         0       1.0       36     11
# 8756544  Household_11112  Product_27326         0       1.0      177      7
# 8756545  Household_11112   Product_5415         0       1.0       75     10
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 0                  5           1                       346
# 1                  6           1                       576
# 2                  6           1                       576
# 3                  5           1                       619
# 4                  6           1                        16
# ...              ...         ...                       ...
# 8756541            4           0                       490
# 8756542            1           0                        50
# 8756543            5           1                        11
# 8756544            4           0                       152
# 8756545            1           0                        50
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 0                       447      1.069351     0.013423              225
# 1                       447      1.069351     0.013423              225
# 2                       447      1.069351     0.013423              225
# 3                       447      1.069351     0.013423              225
# 4                       447      1.069351     0.013423              225
# ...                     ...           ...          ...              ...
# 8756541                 381      1.094488     0.028871              270
# 8756542                 370      1.186486     0.029730              227
# 8756543                 370      1.186486     0.029730              227
# 8756544                 370      1.186486     0.029730              227
# 8756545                 370      1.186486     0.029730              227
#
# [8756546 rows x 13 columns]

# %%
len(train_data)
# Out:
# 8756546

# %%
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np
import pandas as pd

# Generate a list of all unique product IDs
all_product_ids = set(product_embedding_dict.keys())

# Prepare for storing negative samples
negative_samples = []

# Group by customer for efficient processing
customer_groups = train_data.groupby('customer_id')

for customer_id, group in tqdm(customer_groups, desc="Generating hard negative samples"):
    # Purchased products for the current customer
    purchased_products = set(group['product_id'])

    # Non-purchased products for the current customer
    non_purchased_products = list(all_product_ids - purchased_products)

    # Skip if there are no products to compare
    if len(non_purchased_products) == 0 or len(purchased_products) == 0:
        continue

    # Get embeddings for purchased and non-purchased products
    purchased_embeddings = np.array([product_embedding_dict[pid] for pid in purchased_products])
    non_purchased_embeddings = np.array([product_embedding_dict[pid] for pid in non_purchased_products])

    # Reshape to ensure 2D arrays
    purchased_embeddings = purchased_embeddings.reshape(-1, purchased_embeddings.shape[-1])
    non_purchased_embeddings = non_purchased_embeddings.reshape(-1, non_purchased_embeddings.shape[-1])

    # Compute cosine similarity between non-purchased and purchased products
    similarity_scores = cosine_similarity(non_purchased_embeddings, purchased_embeddings)

    # Identify the most similar non-purchased products (hard.  negatives)
    most_similar_indices = np.argsort(-similarity_scores, axis=0)[:len(group)]
    #hard_negatives = {non_purchased_products[i] for i in most_similar_indices.flatten()}[:len(group)]
    # Flatten and select up to len(group) unique hard negatives
    hard_negatives = list({non_purchased_products[i] for i in most_similar_indices.flatten()})[:len(group)]


    # Append hard negatives as negative samples
    negative_samples.extend([{
        'customer_id': customer_id,
        'product_id': product_id,
        'quantity': 0  # Indicating negative sample
    } for product_id in hard_negatives])

# Convert negative samples to a DataFrame
negative_samples_df = pd.DataFrame(negative_samples)

# Append negative samples to the original training data
train_data = pd.concat([train_data, negative_samples_df], ignore_index=True)

# Update relevance column (1 for purchased, 0 for negatives)
train_data['relevance'] = (train_data['quantity'] > 0).astype(int)
# Out:
# Generating hard negative samples: 100%|██████████| 9999/9999 [9:50:43<00:00,  3.54s/it]

# %%
train_data.tail()
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 17513087  Household_19999  Product_56904       NaN       0.0      NaN    NaN
# 17513088  Household_19999  Product_29298       NaN       0.0      NaN    NaN
# 17513089  Household_19999  Product_81672       NaN       0.0      NaN    NaN
# 17513090  Household_19999  Product_31465       NaN       0.0      NaN    NaN
# 17513091  Household_19999  Product_72672       NaN       0.0      NaN    NaN
#
#           day_of_week  is_weekend  days_since_last_purchase  \
# 17513087          NaN         NaN                       NaN
# 17513088          NaN         NaN                       NaN
# 17513089          NaN         NaN                       NaN
# 17513090          NaN         NaN                       NaN
# 17513091          NaN         NaN                       NaN
#
#           purchase_frequency  avg_quantity  promo_ratio  unique_products  \
# 17513087                 NaN           NaN          NaN              NaN
# 17513088                 NaN           NaN          NaN              NaN
# 17513089                 NaN           NaN          NaN              NaN
# 17513090                 NaN           NaN          NaN              NaN
# 17513091                 NaN           NaN          NaN              NaN
#
#           relevance
# 17513087          0
# 17513088          0
# 17513089          0
# 17513090          0
# 17513091          0

# %%
# Check for missing values
print("Missing values in train_data:")
print(train_data.isnull().sum())

print("Missing values in test_data:")
print(test_data.isnull().sum())

# Fill remaining missing values with zeros as a safety measure
train_data = train_data.fillna(0)
test_data = test_data.fillna(0)
# Out:
# Missing values in train_data:
# customer_id                       0
# product_id                        0
# is_promo                    8756546
# quantity                          0
# recency                     8756546
# month                       8756546
# day_of_week                 8756546
# is_weekend                  8756546
# days_since_last_purchase    8756546
# purchase_frequency          8756546
# avg_quantity                8756546
# promo_ratio                 8756546
# unique_products             8756546
# relevance                         0
# dtype: int64
# Missing values in test_data:
# transaction_id    0
# customer_id       0
# product_id        0
# dtype: int64

# %%
train_data = train_data.drop(columns=['day_of_week','is_weekend','unique_products'])

# %%
# prompt: in train_data for household Household_9247 count how manyrelevance 1 and how many are 0.

# Assuming 'train_data' DataFrame is already loaded as in the provided code.

household_9247_data = train_data[train_data['customer_id'] == 'Household_76806']

relevance_counts = household_9247_data['relevance'].value_counts()

print(f"Relevance counts for Household_9247:")
relevance_counts
# Out:
# Relevance counts for Household_9247:
# Series([], Name: count, dtype: int64)

# %%
train_data.to_csv(os.path.join(trainFolder, 'train_data_all_2.csv'), index=False)

# %%
len(train_data)
# Out:
# 17513092

# %%
train_data
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 0         Household_10188  Product_62613       0.0       1.0    351.0    1.0
# 1         Household_10188  Product_71119       0.0       1.0    581.0    5.0
# 2         Household_10188  Product_23971       0.0       2.0    581.0    5.0
# 3         Household_10188   Product_3907       0.0       1.0    624.0    4.0
# 4         Household_10188  Product_37906       0.0       1.0     21.0   12.0
# ...                   ...            ...       ...       ...      ...    ...
# 17513087  Household_19999  Product_56904       0.0       0.0      0.0    0.0
# 17513088  Household_19999  Product_29298       0.0       0.0      0.0    0.0
# 17513089  Household_19999  Product_81672       0.0       0.0      0.0    0.0
# 17513090  Household_19999  Product_31465       0.0       0.0      0.0    0.0
# 17513091  Household_19999  Product_72672       0.0       0.0      0.0    0.0
#
#           days_since_last_purchase  purchase_frequency  avg_quantity  \
# 0                            346.0               447.0      1.069351
# 1                            576.0               447.0      1.069351
# 2                            576.0               447.0      1.069351
# 3                            619.0               447.0      1.069351
# 4                             16.0               447.0      1.069351
# ...                            ...                 ...           ...
# 17513087                       0.0                 0.0      0.000000
# 17513088                       0.0                 0.0      0.000000
# 17513089                       0.0                 0.0      0.000000
# 17513090                       0.0                 0.0      0.000000
# 17513091                       0.0                 0.0      0.000000
#
#           promo_ratio  relevance
# 0            0.013423          1
# 1            0.013423          1
# 2            0.013423          1
# 3            0.013423          1
# 4            0.013423          1
# ...               ...        ...
# 17513087     0.000000          0
# 17513088     0.000000          0
# 17513089     0.000000          0
# 17513090     0.000000          0
# 17513091     0.000000          0
#
# [17513092 rows x 11 columns]

# %%
products_data
