# %% [markdown]
# ## IMPORTS

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
# !pip install tqdm
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.colab import drive
drive.mount('/content/gdrive')

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# Import necessary libraries

import torch

# Load pre-trained BERT model and tokenizer
trainFolder = "gdrive/My Drive/MLDM - Carrefour Project/data-train"

import os
for dirname, _, filenames in os.walk(f'{trainFolder}'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.67.1)
# Mounted at /content/gdrive
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/test_data.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_10.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_2.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_3.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_4.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_5.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_6.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_7.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_8.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/train_data_part_9.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_embe_fixed.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/products_data_bert1.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/submission_01.csv
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_embeddings_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_ids_2.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations.npy
# gdrive/My Drive/MLDM - Carrefour Project/data-train/product_recommendations_combined.npy

# %%
# Import libraries
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Description
#
# This project uses three datasets:
#
# #### `train_data.csv`:
# This dataset contains two years (2022 & 2023) of historical transactions for 100,000 Carrefour customers. It has 10 columns:
#
# * ***date***: Date of the transaction
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: Product purchased
# * ***has_loyality_card***: Flag indicating whether the customer has a loyalty card
# * ***store_id***: Store where the purchase was made
# * ***is_promo***: Flag indicating whether there was a discount on the product
# * ***quantity***: Quantity purchased of the product
# * ***format***: Ecommerce activity format (clcv, lex, or DRIVE)
#   - clcv : courses livrées chez vous
#   - lex : livraison express
#   - DRIVE.
# * ***orderChannelCode***: Indicates whether the online activity was made through the website or mobile app

# %% [markdown]
# #### `products_data.csv`:
# This dataset contains detailed information about the products. The following columns are relevant to this project:
#
# * ***product_id*** : Product name
# * ***product_description*** : Product description
# * ***department_key***: Department key
# * ***class_key***: Class key
# * ***subclass_key***: Subclass key
# * ***sector***: sector name
# * ***brand_key***: Brand name
# * ***shelf_level1***: Top-level shelf category
# * ***shelf_level2***: Second-level shelf category
# * ***shelf_level3***: Third-level shelf category
# * ***shelf_level4***: Fourth-level shelf category
# * ***sector***: Sector
# * ***bio***: Flag indicating whether the product is organic
# * ***sugar_free***: Flag indicating whether the product is sugar-free
# * ***aspartame_free***: Flag indicating whether the product is aspartame-free
# * ***gluten_free***: Flag indicating whether the product is gluten-free
# * ***halal***: Flag indicating whether the product is halal
# * ***casher***: Flag indicating whether the product is kosher
# * ***eco_friendly***: Flag indicating whether the product is eco-friendly
# * ***local_french***: Flag indicating whether the product is locally produced in France
# * ***artificial_coloring_free***: Flag indicating whether the product is free of artificial coloring
# * ***taste_enhancer_free***: Flag indicating whether the product is free of taste enhancers
# * ***naturality***: Naturality score
# * ***antibiotic_free***: Flag indicating whether the product is antibiotic-free
# * ***reduced_sugar***: Flag indicating whether the product has reduced sugar content
# * ***vegetarian***: Flag indicating whether the product is vegetarian
# * ***pesticide_free***: Flag indicating whether the product is pesticide-free
# * ***grain_free***: Flag indicating whether the product is grain-free
# * ***no_added_sugar***: Flag indicating whether the product has no added sugar
# * ***salt_reduced***: Flag indicating whether the product has reduced salt content
# * ***nitrite_free***: Flag indicating whether the product is nitrite-free
# * ***fed_without_ogm***: Flag indicating whether the animals were fed without GMOs
# * ***no_added_salt***: Flag indicating whether the product has no added salt
# * ***no_artificial_flavours***: Flag indicating whether the product has no artificial flavors
# * ***porc***: Flag indicating whether the product contains pork
# * ***vegan***: Flag indicating whether the product is vegan
# * ***frozen***: Flag indicating whether the product is frozen
# * ***fat_free***: Flag indicating whether the product is fat-free
# * ***reduced_fats***: Flag indicating whether the product has reduced fat content
# * ***fresh***: Flag indicating whether the product is fresh
# * ***alcool***: Flag indicating whether the product contains alcohol
# * ***lactose_free***: Flag indicating whether the product is lactose-free
# * ***phenylalanine_free***: Flag indicating whether the product is phenylalanine-free
# * ***palm_oil_free***: Flag indicating whether the product is palm oil-free
# * ***ecoscore***: Ecoscore
# * ***produits_du_monde***: Flag indicating whether the product is an international product
# * ***regional_product***: Flag indicating whether the product is a regional product
# * ***national_brand***: Flag indicating whether the product is a national brand
# * ***first_price_brand***: Flag indicating whether the product is a first-price brand
# * ***carrefour_brand***: Flag indicating whether the product is a Carrefour brand

# %% [markdown]
# #### `test_data.csv`:
# This dataset contains the actual purchases of the first 80,000 customers in 2024. It has three columns:
#
# * ***transaction_id***: ID of the transaction
# * ***customer_id***: Customer ID
# * ***product_id***: the id of the purchased product

# %% [markdown]
# ### Load data
#
# * Load *train_data.csv*, *products_data.csv* and *test_data.csv* using pandas.

# %%
# This code reads the data from CSV files named "train_data_part_i.csv" for all i from 1 to 10
# and concatenates them into a single pandas DataFrame
train_dataframes = []
for i in tqdm(range(1, 11)): ## 1 - 11
    train_dataframes.append(pd.read_csv(f'{trainFolder}/train_data_part_{i}.csv'))
train_data = pd.concat(train_dataframes, ignore_index=True)

# free up memory by deleting the dataframes we no longer need
del train_dataframes
# Out:
# 100%|██████████| 10/10 [02:23<00:00, 14.33s/it]

# %%
#train_data = train_data.sample(frac=0.1, random_state=1)  # frac=0.1 takes 10% of the data

# %%
# This code reads the data from a CSV file named "products_data.csv" into a pandas DataFrame
products_data = pd.read_csv(f'{trainFolder}/products_data.csv')
# Out:
# <ipython-input-5-d8cc84ca7717>:2: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   products_data = pd.read_csv(f'{trainFolder}/products_data.csv')

# %%
# This code reads the data from a CSV file named "test_data.csv" into a pandas DataFrame
test_data = pd.read_csv(f'{trainFolder}/test_data.csv')

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 0         2023-11-15  Transaction_1730125     Household_39   Product_5362
# 1         2022-07-20  Transaction_1560535     Household_39  Product_67174
# 2         2022-07-20  Transaction_1560535     Household_39  Product_82254
# 3         2023-11-15  Transaction_1730125     Household_39   Product_3895
# 4         2022-07-20  Transaction_1560535     Household_39  Product_34014
# ...              ...                  ...              ...            ...
# 87037457  2022-01-07  Transaction_1162379  Household_96742  Product_28756
# 87037458  2023-08-17  Transaction_2306043  Household_96742  Product_62786
# 87037459  2022-10-12  Transaction_1524531  Household_96742  Product_16362
# 87037460  2023-03-10  Transaction_1972306  Household_96742  Product_78870
# 87037461  2022-05-12  Transaction_1971250  Household_96742  Product_10052
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 0                         0     Store_2         0       1.0  DRIVE
# 1                         0     Store_2         0       2.0  DRIVE
# 2                         0     Store_2         0       2.0  DRIVE
# 3                         0     Store_2         0       1.0  DRIVE
# 4                         0     Store_2         0       1.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 87037457                  0  Store_2542         0       1.0  DRIVE
# 87037458                  0  Store_2542         0       1.0  DRIVE
# 87037459                  0  Store_2542         0       1.0  DRIVE
# 87037460                  0  Store_2542         0       1.0  DRIVE
# 87037461                  0  Store_2542         0       1.0  DRIVE
#
#          order_channel
# 0           MOBILE_APP
# 1              WEBSITE
# 2              WEBSITE
# 3           MOBILE_APP
# 4              WEBSITE
# ...                ...
# 87037457    MOBILE_APP
# 87037458    MOBILE_APP
# 87037459    MOBILE_APP
# 87037460    MOBILE_APP
# 87037461    MOBILE_APP
#
# [87037462 rows x 10 columns]

# %%
# prompt: print from train_date rows with customer id Household_80001
import pandas as pd

# Create a list of customer IDs within the specified range
#customer_ids_new = [f'Household_{i}' for i in range(80001, 100002)]
#customer_ids_new = [f'Household_{i}' for i in range(10001, 20000)]
customer_ids_new = [f'Household_{i}' for i in range(30001, 40000)]

# prompt: keep in train_data and test_data the rows that have the cusomer_id in customer_ids

# Filter train_data
train_data = train_data[train_data['customer_id'].isin(customer_ids_new)]

# Filter test_data
test_data = test_data[test_data['customer_id'].isin(customer_ids_new)]

# %%
train_data
# Out:
#                 date       transaction_id      customer_id     product_id  \
# 26166783  2023-02-12  Transaction_2185825  Household_30946  Product_16061
# 26166784  2023-10-01  Transaction_1785368  Household_30946  Product_74944
# 26166785  2023-09-13  Transaction_2621264  Household_30946  Product_27979
# 26166786  2023-08-16  Transaction_1975138  Household_30946  Product_38506
# 26166787  2023-05-02   Transaction_198741  Household_30946  Product_59873
# ...              ...                  ...              ...            ...
# 34913159  2023-02-17   Transaction_173050  Household_36797  Product_59042
# 34913160  2023-08-28   Transaction_312631  Household_36797    Product_892
# 34913161  2023-12-20  Transaction_1059734  Household_38710  Product_41055
# 34913162  2023-12-20  Transaction_1059734  Household_38710  Product_80689
# 34913163  2023-06-03  Transaction_1572547  Household_38710  Product_30021
#
#           has_loyality_card    store_id  is_promo  quantity format  \
# 26166783                  0     Store_2         0       1.0  DRIVE
# 26166784                  0     Store_2         0       1.0  DRIVE
# 26166785                  0     Store_2         0       1.0  DRIVE
# 26166786                  0     Store_2         0       1.0  DRIVE
# 26166787                  0     Store_2         0       2.0  DRIVE
# ...                     ...         ...       ...       ...    ...
# 34913159                  0  Store_2542         0       2.0  DRIVE
# 34913160                  0  Store_2542         0       2.0  DRIVE
# 34913161                  1  Store_2542         0       1.0  DRIVE
# 34913162                  1  Store_2542         0       1.0  DRIVE
# 34913163                  1  Store_2542         0       1.0  DRIVE
#
#          order_channel
# 26166783    MOBILE_APP
# 26166784       WEBSITE
# 26166785       WEBSITE
# 26166786       WEBSITE
# 26166787       WEBSITE
# ...                ...
# 34913159       WEBSITE
# 34913160       WEBSITE
# 34913161       WEBSITE
# 34913162       WEBSITE
# 34913163       WEBSITE
#
# [8744887 rows x 10 columns]

# %%
test_data
# Out:
#                  transaction_id      customer_id     product_id
# 30          Transaction_2024_11  Household_39518  Product_56735
# 31          Transaction_2024_11  Household_39518  Product_22191
# 32          Transaction_2024_11  Household_39518   Product_5403
# 33          Transaction_2024_11  Household_39518  Product_20491
# 212         Transaction_2024_51  Household_36019   Product_1176
# ...                         ...              ...            ...
# 1016920  Transaction_2024_93475  Household_39999  Product_37011
# 1016921  Transaction_2024_93475  Household_39999  Product_72643
# 1016922  Transaction_2024_93475  Household_39999  Product_49176
# 1016923  Transaction_2024_93475  Household_39999  Product_47749
# 1016924  Transaction_2024_93475  Household_39999  Product_76754
#
# [152217 rows x 3 columns]

# %%
train_data = train_data.drop(columns=['transaction_id','has_loyality_card', 'store_id','format','order_channel'])

# %% [markdown]
# ## Training Data Preproccesing

# %%
train_data['date'] = pd.to_datetime(train_data['date'])

# Add recency attribute
latest_date = train_data['date'].max()  # Find the latest date in the dataset
train_data['recency'] = (latest_date - train_data['date']).dt.days  # Calculate days since last purchase

# Group by customer_id and product_id to calculate quantity and most recent purchase
customer_product_data = train_data.groupby(['customer_id', 'product_id']).agg({
    'quantity': 'sum',
    'recency': 'min'  # Minimum days since purchase (most recent)
}).reset_index()

# Normalize quantity and recency scores
customer_product_data['quantity_score'] = customer_product_data['quantity'] / customer_product_data['quantity'].max()
customer_product_data['recency_score'] = 1 - (customer_product_data['recency'] / customer_product_data['recency'].max())  # Recent = higher score

best_alpha = 0.97

# Calculate the final score with this alpha value
customer_product_data['final_score'] = (
    best_alpha * customer_product_data['quantity_score'] +
    (1 - best_alpha) * customer_product_data['recency_score']
)

# Rank products for each customer with unique ranks
customer_product_data['rank'] = customer_product_data.sort_values(
    by=['customer_id', 'final_score', 'quantity', 'product_id'],  # Add secondary sort keys
    ascending=[True, False, False, True]  # Ensure consistent order
).groupby('customer_id').cumcount() + 1  # Assign unique incremental ranks


# Sort the DataFrame by customer_id and rank
customer_product_data = customer_product_data.sort_values(by=['customer_id', 'rank'])

# Filter out products with a rank greater than 200 for each customer
#customer_product_data = customer_product_data[customer_product_data['rank'] <= 20]

# %%
customer_product_data
# Out:
#              customer_id     product_id  quantity  recency  quantity_score  \
# 254      Household_30001  Product_67660       9.0      206        0.001870
# 68       Household_30001  Product_22244       8.0      206        0.001663
# 261      Household_30001  Product_68705       8.0      206        0.001663
# 13       Household_30001  Product_13220       7.0      206        0.001455
# 75       Household_30001  Product_27452       7.0      206        0.001455
# ...                  ...            ...       ...      ...             ...
# 3363670  Household_39999  Product_33741       1.0      722        0.000208
# 3363784  Household_39999  Product_45266       1.0      722        0.000208
# 3363788  Household_39999   Product_4576       1.0      722        0.000208
# 3363872  Household_39999  Product_57572       1.0      722        0.000208
# 3363890  Household_39999  Product_59650       1.0      722        0.000208
#
#          recency_score  final_score  rank
# 254           0.717421     0.023337     1
# 68            0.717421     0.023135     2
# 261           0.717421     0.023135     3
# 13            0.717421     0.022934     4
# 75            0.717421     0.022934     5
# ...                ...          ...   ...
# 3363670       0.009602     0.000490   673
# 3363784       0.009602     0.000490   674
# 3363788       0.009602     0.000490   675
# 3363872       0.009602     0.000490   676
# 3363890       0.009602     0.000490   677
#
# [3364121 rows x 8 columns]

# %%
# Extract temporal features
train_data['month'] = train_data['date'].dt.month
train_data['day_of_week'] = train_data['date'].dt.dayofweek
train_data['is_weekend'] = train_data['day_of_week'].isin([5, 6]).astype(int)

# Calculate recency: days since the last purchase for each customer
train_data['days_since_last_purchase'] = train_data.groupby('customer_id')['date'].transform(
    lambda x: (x.max() - x).dt.days
)

# Drop the 'date' column if it's no longer needed
train_data = train_data.drop(columns=['date'], errors='ignore')

# %%
# Aggregate customer-specific features
customer_features = train_data.groupby(['customer_id']).agg(
    purchase_frequency=('product_id', 'count'),  # Total number of purchases
    avg_quantity=('quantity', 'mean'),          # Average quantity purchased
    promo_ratio=('is_promo', 'mean'),           # Proportion of purchases made with promotions
    unique_products=('product_id', 'nunique')   # Number of unique products purchased
).reset_index()

# Merge these features into train_data and test_data
train_data = train_data.merge(customer_features, on='customer_id', how='left')

# %%
train_data.tail()
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 8744882  Household_36797  Product_59042         0       2.0      317      2
# 8744883  Household_36797    Product_892         0       2.0      125      8
# 8744884  Household_38710  Product_41055         0       1.0       11     12
# 8744885  Household_38710  Product_80689         0       1.0       11     12
# 8744886  Household_38710  Product_30021         0       1.0      211      6
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 8744882            4           0                       192
# 8744883            0           0                         0
# 8744884            2           0                         2
# 8744885            2           0                         2
# 8744886            5           1                       202
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 8744882                 276      1.518116     0.036232              213
# 8744883                 276      1.518116     0.036232              213
# 8744884                 130      1.146154     0.038462              120
# 8744885                 130      1.146154     0.038462              120
# 8744886                 130      1.146154     0.038462              120

# %%
products_data.tail()
# Out:
#           product_id             product_description department_key  \
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82964  Product_31161              CHARGE BUT 13K CRF  Department_75
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82964  Class_7520  SubClass_75201  ACTIVITES PERIPHERIQUES   CARREFOUR
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1               shelf_level2  \
# 82961     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie  Bagagerie et Maroquinerie
# 82963            Animalerie                     Chiens
# 82964  Maison et Décoration          Bouteilles de gaz
# 82965  Maison et Décoration          Bouteilles de gaz
#
#                          shelf_level3                     shelf_level4  bio  \
# 82961             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82962             Accessoires de mode  Chapeaux, Casquettes et Bonnets    0
# 82963  Colliers, Laisses et Vêtements          Vêtements et Chaussures    0
# 82964                             NaN                              NaN    0
# 82965                             NaN                              NaN    0
#
#        sugar_free  aspartame_free  gluten_free  halal  casher  eco_friendly  \
# 82961           0               0            0      0       0             0
# 82962           0               0            0      0       0             0
# 82963           0               0            0      0       0             0
# 82964           0               0            0      0       0             0
# 82965           0               0            0      0       0             0
#
#        local_french  artificial_coloring_free  taste_enhancer_free  \
# 82961             0                         0                    0
# 82962             0                         0                    0
# 82963             0                         0                    0
# 82964             0                         0                    0
# 82965             0                         0                    0
#
#        naturality  antibiotic_free  reduced_sugar  vegetarian  pesticide_free  \
# 82961           0                0              0           0               0
# 82962           0                0              0           0               0
# 82963           0                0              0           0               0
# 82964           0                0              0           0               0
# 82965           0                0              0           0               0
#
#        grain_free  no_added_sugar  salt_reduced  nitrite_free  \
# 82961           0               0             0             0
# 82962           0               0             0             0
# 82963           0               0             0             0
# 82964           0               0             0             0
# 82965           0               0             0             0
#
#        fed_without_ogm  no_added_salt  no_artificial_flavours  porc  vegan  \
# 82961                0              0                       0     0      0
# 82962                0              0                       0     0      0
# 82963                0              0                       0     0      0
# 82964                0              0                       0     0      0
# 82965                0              0                       0     0      0
#
#        frozen  fat_free  reduced_fats  fresh  alcool  lactose_free  \
# 82961       0         0             0      0       0             0
# 82962       0         0             0      0       0             0
# 82963       0         0             0      0       0             0
# 82964       0         0             0      0       0             0
# 82965       0         0             0      0       0             0
#
#        phenylalanine_free  palm_oil_free ecoscore  produits_du_monde  \
# 82961                   0              0      NaN                  0
# 82962                   0              0      NaN                  0
# 82963                   0              0      NaN                  0
# 82964                   0              0      NaN                  0
# 82965                   0              0      NaN                  0
#
#        regional_product  national_brand  first_price_brand  carrefour_brand
# 82961                 0               0                  0                1
# 82962                 0               0                  0                1
# 82963                 0               0                  0                1
# 82964                 0               0                  0                1
# 82965                 0               0                  0                1

# %% [markdown]
# # Identifyng Missing Products

# %%
# Convert product_id columns to sets for quick set operations
train_product_ids = set(train_data["product_id"].unique())
products_product_ids = set(products_data["product_id"].unique())

# Find products in products_data that are not in train_data
missing_from_train = products_product_ids - train_product_ids

print(f"Number of products not in train_data: {len(missing_from_train)}")

if len(missing_from_train) > 0:
    print("These product IDs are in products_data but not in train_data:")
    for pid in missing_from_train:
        print(pid)
else:
    print("All products in products_data appear in train_data.")
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Product_50744
# Product_68442
# Product_8487
# Product_74530
# Product_30948
# Product_10725
# Product_18230
# Product_17780
# Product_42337
# Product_62713
# Product_72745
# Product_15960
# Product_42946
# Product_20716
# Product_63251
# Product_61097
# Product_26274
# Product_55794
# Product_27391
# Product_41550
# Product_17069
# Product_41889
# Product_47448
# Product_21315
# Product_49852
# Product_73256
# Product_7066
# Product_42670
# Product_66093
# Product_72228
# Product_49009
# Product_112
# Product_39882
# Product_59034
# Product_63564
# Product_20750
# Product_75446
# Product_47549
# Product_57936
# Product_39982
# Product_855
# Product_48083
# Product_68518
# Product_18367
# Product_7495
# Product_68396
# Product_9566
# Product_30151
# Product_24958
# Product_47937
# Product_41764
# Product_59480
# Product_570
# Product_11500
# Product_24661
# Product_76771
# Product_78762
# Product_18033
# Product_26837
# Product_40333
# Product_20545
# Product_55302
# Product_26712
# Product_33037
# Product_13398
# Product_79231
# Product_32710
# Product_27861
# Product_4163
# Product_72608
# Product_58986
# Product_74208
# Product_12602
# Product_10815
# Product_51014
# Product_78421
# Product_57049
# Product_47986
# Product_78657
# Product_33243
# Product_42560
# Product_49449
# Product_13186
# Product_9993
# Product_71511
# Product_70698
# Product_46834
# Product_13041
# Product_51502
# Product_8857
# Product_8271
# Product_80834
# Product_26203
# Product_10643
# Product_30897
# Product_61731
# Product_68863
# Product_22934
# Product_42993
# Product_40309
# Product_57839
# Product_24745
# Product_64052
# Product_43344
# Product_5966
# Product_77215
# Product_50488
# Product_57661
# Product_73774
# Product_73899
# Product_9306
# Product_11195
# Product_45783
# Product_63760
# Product_42902
# Product_64799
# Product_76785
# Product_45003
# Product_60740
# Product_46611
# Product_41822
# Product_76858
# Product_53970
# Product_23389
# Product_18221
# Product_5608
# Product_794
# Product_9169
# Product_68537
# Product_63099
# Product_24234
# Product_450
# Product_70360
# Product_12258
# Product_9520
# Product_59622
# Product_50580
# Product_61475
# Product_14501
# Product_55732
# Product_70826
# Product_27959
# Product_20986
# Product_68856
# Product_10836
# Product_72913
# Product_62861
# Product_21491
# Product_77883
# Product_12667
# Product_6328
# Product_76268
# Product_39545
# Product_61291
# Product_80954
# Product_2717
# Product_68713
# Product_19667
# Product_14479
# Product_26032
# Product_11743
# Product_60763
# Product_80127
# Product_7438
# Product_40207
# Product_42405
# Product_31390
# Product_9492
# Product_1362
# Product_69862
# Product_5006
# Product_55692
# Product_66438
# Product_55625
# Product_21879
# Product_42883
# Product_74773
# Product_77455
# Product_38805
# Product_15433
# Product_1379
# Product_50319
# Product_44356
# Product_52759
# Product_49247
# Product_28431
# Product_54673
# Product_79336
# Product_61411
# Product_26505
# Product_34209
# Product_18989
# Product_29826
# Product_54109
# Product_33731
# Product_46391
# Product_14758
# Product_81406
# Product_74804
# Product_6710
# Product_2754
# Product_9341
# Product_1175
# Product_23287
# Product_61628
# Product_68652
# Product_20210
# Product_8651
# Product_80044
# Product_71969
# Product_669
# Product_64426
# Product_1236
# Product_75934
# Product_29420
# Product_67095
# Product_20355
# Product_25598
# Product_21742
# Product_60009
# Product_74002
# Product_10670
# Product_24805
# Product_25468
# Product_37195
# Product_5047
# Product_52469
# Product_7582
# Product_62480
# Product_73288
# Product_13994
# Product_3542
# Product_59015
# Product_18219
# Product_26888
# Product_3760
# Product_2862
# Product_62080
# Product_50886
# Product_38082
# Product_24507
# Product_73187
# Product_60096
# Product_62622
# Product_23042
# Product_23566
# Product_78163
# Product_33100
# Product_48261
# Product_76022
# Product_1889
# Product_42801
# Product_24518
# Product_16322
# Product_35677
# Product_64648
# Product_35642
# Product_14470
# Product_69664
# Product_57144
# Product_6266
# Product_42477
# Product_27297
# Product_2405
# Product_48657
# Product_78249
# Product_21607
# Product_81074
# Product_55667
# Product_60307
# Product_20543
# Product_15186
# Product_74838
# Product_42060
# Product_61615
# Product_73756
# Product_34196
# Product_20445
# Product_9472
# Product_58236
# Product_68488
# Product_28235
# Product_77126
# Product_63925
# Product_16648
# Product_12694
# Product_24672
# Product_4766
# Product_58112
# Product_12890
# Product_4436
# Product_69235
# Product_26130
# Product_67742
# Product_14652
# Product_48850
# Product_72981
# Product_57251
# Product_30784
# Product_45070
# Product_61776
# Product_36392
# Product_44267
# Product_30330
# Product_82709
# Product_66735
# Product_61208
# Product_30919
# Product_41747
# Product_7379
# Product_35936
# Product_27971
# Product_14664
# Product_50205
# Product_25705
# Product_60569
# Product_55571
# Product_49405
# Product_45083
# Product_33341
# Product_74582
# Product_82507
# Product_17323
# Product_79884
# Product_48236
# Product_42363
# Product_25390
# Product_47975
# Product_7960
# Product_60239
# Product_15261
# Product_43281
# Product_9093
# Product_60147
# Product_52476
# Product_24338
# Product_69177
# Product_32456
# Product_29456
# Product_15641
# Product_59443
# Product_5150
# Product_52611
# Product_2646
# Product_18248
# Product_53370
# Product_43734
# Product_32386
# Product_24448
# Product_53164
# Product_46725
# Product_70320
# Product_54820
# Product_1367
# Product_8522
# Product_74203
# Product_2171
# Product_2441
# Product_3687
# Product_49042
# Product_1835
# Product_19206
# Product_74891
# Product_77300
# Product_29110
# Product_25108
# Product_45661
# Product_20087
# Product_3463
# Product_62273
# Product_67631
# Product_10507
# Product_45672
# Product_58172
# Product_47373
# Product_46132
# Product_69261
# Product_64387
# Product_25197
# Product_55844
# Product_25360
# Product_38491
# Product_74248
# Product_77946
# Product_34534
# Product_31470
# Product_33834
# Product_36535
# Product_49947
# Product_537
# Product_82272
# Product_36557
# Product_38564
# Product_37548
# Product_29057
# Product_63906
# Product_32515
# Product_38177
# Product_13816
# Product_79785
# Product_74331
# Product_39111
# Product_75544
# Product_22643
# Product_82212
# Product_65875
# Product_76640
# Product_1543
# Product_20296
# Product_8511
# Product_22687
# Product_71639
# Product_42188
# Product_6213
# Product_71013
# Product_76327
# Product_42721
# Product_6450
# Product_5167
# Product_41373
# Product_2971
# Product_29825
# Product_9486
# Product_16650
# Product_79880
# Product_38737
# Product_28941
# Product_74854
# Product_52601
# Product_76048
# Product_44774
# Product_20481
# Product_411
# Product_2085
# Product_1969
# Product_33922
# Product_33338
# Product_74009
# Product_1317
# Product_73366
# Product_78403
# Product_23667
# Product_40281
# Product_68152
# Product_52935
# Product_44899
# Product_75314
# Product_76917
# Product_25405
# Product_80449
# Product_23260
# Product_65912
# Product_2266
# Product_39182
# Product_61655
# Product_76176
# Product_5658
# Product_3155
# Product_32
# Product_28596
# Product_80149
# Product_40280
# Product_53725
# Product_63772
# Product_76297
# Product_25688
# Product_61519
# Product_70587
# Product_24702
# Product_44765
# Product_38204
# Product_36264
# Product_18668
# Product_43511
# Product_60409
# Product_44271
# Product_41501
# Product_59601
# Product_54208
# Product_34870
# Product_57505
# Product_43058
# Product_39189
# Product_68171
# Product_17361
# Product_76707
# Product_59769
# Product_76593
# Product_46509
# Product_10280
# Product_68465
# Product_71325
# Product_66598
# Product_1545
# Product_5816
# Product_38803
# Product_33630
# Product_8007
# Product_23379
# Product_47474
# Product_17855
# Product_17490
# Product_67479
# Product_17458
# Product_48550
# Product_35894
# Product_68758
# Product_74957
# Product_28052
# Product_31931
# Product_17313
# Product_16241
# Product_3678
# Product_19407
# Product_14521
# Product_55167
# Product_76499
# Product_12768
# Product_1608
# Product_24809
# Product_33104
# Product_63926
# Product_25938
# Product_16000
# Product_17757
# Product_452
# Product_47112
# Product_44719
# Product_22335
# Product_28641
# Product_36860
# Product_61751
# Product_76954
# Product_43592
# Product_38973
# Product_71323
# Product_14615
# Product_63764
# Product_74475
# Product_11510
# Product_2260
# Product_60302
# Product_33787
# Product_4922
# Product_43987
# Product_36717
# Product_65758
# Product_28263
# Product_64936
# Product_57895
# Product_11654
# Product_76151
# Product_27598
# Product_62732
# Product_94
# Product_19938
# Product_10065
# Product_78349
# Product_2994
# Product_75381
# Product_34993
# Product_32524
# Product_32463
# Product_58628
# Product_63543
# Product_37018
# Product_3740
# Product_32993
# Product_43521
# Product_34561
# Product_35320
# Product_67733
# Product_43302
# Product_20627
# Product_54380
# Product_51437
# Product_1015
# Product_51077
# Product_5235
# Product_74089
# Product_54828
# Product_43040
# Product_72944
# Product_78337
# Product_36986
# Product_25607
# Product_41890
# Product_70224
# Product_73416
# Product_12744
# Product_15443
# Product_20812
# Product_38202
# Product_35091
# Product_23713
# Product_18533
# Product_1863
# Product_25058
# Product_53105
# Product_71796
# Product_63796
# Product_38065
# Product_70778
# Product_68484
# Product_61472
# Product_30548
# Product_1517
# Product_3433
# Product_2816
# Product_44019
# Product_48737
# Product_45543
# Product_31036
# Product_15802
# Product_42761
# Product_70169
# Product_41349
# Product_18794
# Product_3626
# Product_64692
# Product_81119
# Product_80133
# Product_59058
# Product_2235
# Product_3810
# Product_34273
# Product_55382
# Product_66131
# Product_51996
# Product_7222
# Product_12657
# Product_7269
# Product_66840
# Product_5494
# Product_64966
# Product_68817
# Product_71547
# Product_47116
# Product_76826
# Product_70782
# Product_35826
# Product_29961
# Product_77654
# Product_36686
# Product_57920
# Product_16359
# Product_47285
# Product_27594
# Product_67931
# Product_43874
# Product_827
# Product_55018
# Product_39783
# Product_64135
# Product_44505
# Product_24798
# Product_55075
# Product_71803
# Product_43801
# Product_12058
# Product_39519
# Product_71550
# Product_59579
# Product_18555
# Product_19289
# Product_4392
# Product_30746
# Product_26345
# Product_42940
# Product_63568
# Product_51043
# Product_12390
# Product_74339
# Product_55880
# Product_22508
# Product_21511
# Product_17664
# Product_14537
# Product_52223
# Product_55873
# Product_43848
# Product_71264
# Product_60143
# Product_65495
# Product_43497
# Product_31206
# Product_20337
# Product_78387
# Product_18826
# Product_26340
# Product_26857
# Product_36752
# Product_32108
# Product_11944
# Product_17122
# Product_37830
# Product_56165
# Product_27500
# Product_45968
# Product_1164
# Product_26698
# Product_27334
# Product_35468
# Product_18524
# Product_76228
# Product_50710
# Product_14792
# Product_31521
# Product_34687
# Product_52314
# Product_70982
# Product_38130
# Product_43547
# Product_65607
# Product_31186
# Product_64979
# Product_51948
# Product_9574
# Product_54100
# Product_14034
# Product_30660
# Product_57889
# Product_79076
# Product_34596
# Product_41508
# Product_39366
# Product_54401
# Product_8183
# Product_46910
# Product_245
# Product_39010
# Product_60697
# Product_1520
# Product_33831
# Product_13437
# Product_2618
# Product_58436
# Product_31983
# Product_13348
# Product_36289
# Product_75514
# Product_27511
# Product_9725
# Product_79116
# Product_79629
# Product_27345
# Product_43991
# Product_32206
# Product_805
# Product_34393
# Product_70600
# Product_18046
# Product_46817
# Product_57606
# Product_65336
# Product_69794
# Product_46596
# Product_25657
# Product_5612
# Product_1437
# Product_38851
# Product_47356
# Product_24037
# Product_35818
# Product_82740
# Product_19488
# Product_64446
# Product_46815
# Product_31492
# Product_13765
# Product_49006
# Product_6343
# Product_14392
# Product_2239
# Product_49902
# Product_46107
# Product_55933
# Product_48151
# Product_37024
# Product_1389
# Product_10860
# Product_82751
# Product_40260
# Product_29760
# Product_55984
# Product_73289
# Product_60653
# Product_3970
# Product_81579
# Product_13586
# Product_55687
# Product_8762
# Product_73048
# Product_54165
# Product_33088
# Product_82804
# Product_74955
# Product_48670
# Product_9056
# Product_43899
# Product_39030
# Product_53083
# Product_61264
# Product_58617
# Product_27749
# Product_54409
# Product_74374
# Product_14803
# Product_78946
# Product_48844
# Product_56143
# Product_52847
# Product_57677
# Product_80466
# Product_37325
# Product_23170
# Product_20919
# Product_63427
# Product_35469
# Product_65425
# Product_18452
# Product_36271
# Product_11280
# Product_45239
# Product_10887
# Product_66779
# Product_74493
# Product_5529
# Product_57407
# Product_73923
# Product_73879
# Product_8781
# Product_40034
# Product_11096
# Product_35697
# Product_65757
# Product_54869
# Product_28145
# Product_71984
# Product_67304
# Product_33917
# Product_57569
# Product_59307
# Product_6708
# Product_72278
# Product_28099
# Product_54996
# Product_36574
# Product_46771
# Product_20707
# Product_67396
# Product_52720
# Product_68979
# Product_66321
# Product_81381
# Product_3356
# Product_9793
# Product_68621
# Product_19889
# Product_41182
# Product_50874
# Product_57261
# Product_3858
# Product_13969
# Product_74012
# Product_4963
# Product_49871
# Product_29549
# Product_78802
# Product_68944
# Product_56573
# Product_19042
# Product_12897
# Product_66589
# Product_69404
# Product_65403
# Product_30049
# Product_65381
# Product_70922
# Product_5301
# Product_75051
# Product_26542
# Product_19229
# Product_55851
# Product_59971
# Product_22407
# Product_79976
# Product_60613
# Product_35692
# Product_48948
# Product_12188
# Product_49895
# Product_79700
# Product_4357
# Product_75798
# Product_25079
# Product_33465
# Product_53389
# Product_24689
# Product_58132
# Product_56957
# Product_43470
# Product_26575
# Product_53844
# Product_39994
# Product_1399
# Product_47554
# Product_27857
# Product_70127
# Product_23546
# Product_49382
# Product_31025
# Product_35931
# Product_73241
# Product_75837
# Product_13510
# Product_1167
# Product_19505
# Product_8652
# Product_22944
# Product_22357
# Product_68164
# Product_77897
# Product_40796
# Product_4945
# Product_60844
# Product_71735
# Product_31154
# Product_72522
# Product_2639
# Product_26962
# Product_28246
# Product_8519
# Product_7679
# Product_9599
# Product_52905
# Product_19357
# Product_30718
# Product_25793
# Product_43924
# Product_56455
# Product_30894
# Product_65677
# Product_74263
# Product_39201
# Product_70134
# Product_81790
# Product_33286
# Product_75550
# Product_26263
# Product_75251
# Product_4247
# Product_77629
# Product_30147
# Product_32293
# Product_77244
# Product_54775
# Product_19994
# Product_60171
# Product_62132
# Product_38617
# Product_35760
# Product_53325
# Product_81071
# Product_57581
# Product_32378
# Product_81027
# Product_18172
# Product_49552
# Product_22624
# Product_9883
# Product_51126
# Product_62675
# Product_36165
# Product_27707
# Product_58680
# Product_49357
# Product_34766
# Product_27512
# Product_5934
# Product_19384
# Product_20379
# Product_62881
# Product_71210
# Product_66945
# Product_80822
# Product_61196
# Product_72138
# Product_35786
# Product_62894
# Product_566
# Product_30542
# Product_45284
# Product_23077
# Product_706
# Product_74938
# Product_52753
# Product_73554
# Product_64499
# Product_64696
# Product_35974
# Product_56774
# Product_30916
# Product_55308
# Product_16817
# Product_82062
# Product_70255
# Product_25709
# Product_17484
# Product_77394
# Product_13452
# Product_55335
# Product_36885
# Product_24722
# Product_64975
# Product_59886
# Product_37417
# Product_40374
# Product_14284
# Product_50908
# Product_54233
# Product_53345
# Product_29900
# Product_37589
# Product_76105
# Product_604
# Product_50257
# Product_71679
# Product_51424
# Product_32846
# Product_20869
# Product_60806
# Product_15801
# Product_61695
# Product_59489
# Product_16544
# Product_32983
# Product_45446
# Product_50755
# Product_48387
# Product_10999
# Product_41918
# Product_47351
# Product_57945
# Product_40336
# Product_22701
# Product_80989
# Product_41930
# Product_10248
# Product_7840
# Product_77197
# Product_45324
# Product_59751
# Product_68091
# Product_82355
# Product_10144
# Product_22439
# Product_28865
# Product_46827
# Product_21168
# Product_33223
# Product_72520
# Product_78390
# Product_71141
# Product_28695
# Product_35106
# Product_48652
# Product_45371
# Product_17936
# Product_63293
# Product_24461
# Product_63754
# Product_47680
# Product_66791
# Product_39487
# Product_35099
# Product_69883
# Product_36256
# Product_45645
# Product_22299
# Product_66315
# Product_4794
# Product_74121
# Product_53595
# Product_51002
# Product_79689
# Product_47396
# Product_4
# Product_9139
# Product_28120
# Product_45721
# Product_78780
# Product_27925
# Product_73470
# Product_34286
# Product_70906
# Product_78726
# Product_37571
# Product_42082
# Product_52678
# Product_56429
# Product_15043
# Product_59415
# Product_26481
# Product_60150
# Product_42269
# Product_41675
# Product_10273
# Product_39823
# Product_15265
# Product_41526
# Product_58901
# Product_69481
# Product_45183
# Product_6417
# Product_24464
# Product_26867
# Product_78232
# Product_19365
# Product_52927
# Product_66466
# Product_74501
# Product_15349
# Product_42986
# Product_29092
# Product_28922
# Product_73682
# Product_11991
# Product_27923
# Product_3688
# Product_71158
# Product_59513
# Product_81989
# Product_16326
# Product_13312
# Product_42107
# Product_63216
# Product_14781
# Product_24896
# Product_69790
# Product_61384
# Product_37113
# Product_16123
# Product_52652
# Product_38889
# Product_54488
# Product_27152
# Product_58177
# Product_46223
# Product_21869
# Product_19949
# Product_21024
# Product_30874
# Product_80546
# Product_6739
# Product_82675
# Product_47460
# Product_28822
# Product_29575
# Product_75556
# Product_71354
# Product_74287
# Product_64823
# Product_39080
# Product_2517
# Product_26327
# Product_82464
# Product_7576
# Product_47072
# Product_57934
# Product_187
# Product_3183
# Product_62036
# Product_58365
# Product_60385
# Product_4227
# Product_51121
# Product_48811
# Product_5048
# Product_74888
# Product_10313
# Product_21021
# Product_51717
# Product_35036
# Product_48056
# Product_25862
# Product_36476
# Product_5170
# Product_45142
# Product_12827
# Product_33817
# Product_59243
# Product_47331
# Product_29445
# Product_9110
# Product_3348
# Product_40055
# Product_12185
# Product_54523
# Product_75205
# Product_43110
# Product_68044
# Product_10316
# Product_18192
# Product_76190
# Product_15252
# Product_10501
# Product_28784
# Product_13913
# Product_58063
# Product_54169
# Product_38595
# Product_73031
# Product_36745
# Product_45169
# Product_34295
# Product_61992
# Product_31181
# Product_54057
# Product_22286
# Product_18786
# Product_17170
# Product_23890
# Product_10568
# Product_45551
# Product_56869
# Product_18123
# Product_15935
# Product_59455
# Product_17164
# Product_65272
# Product_60719
# Product_58364
# Product_81956
# Product_39525
# Product_58439
# Product_73062
# Product_8267
# Product_18065
# Product_44383
# Product_31930
# Product_36513
# Product_46166
# Product_4780
# Product_74673
# Product_30513
# Product_21215
# Product_64258
# Product_51338
# Product_58159
# Product_49676
# Product_41298
# Product_8356
# Product_29111
# Product_2175
# Product_28886
# Product_53361
# Product_38373
# Product_6960
# Product_35587
# Product_65652
# Product_42954
# Product_29121
# Product_1052
# Product_57243
# Product_11887
# Product_81849
# Product_43534
# Product_48647
# Product_69597
# Product_5746
# Product_24901
# Product_5063
# Product_82111
# Product_72580
# Product_33667
# Product_32388
# Product_80711
# Product_50229
# Product_31866
# Product_993
# Product_26366
# Product_43317
# Product_12835
# Product_61441
# Product_78961
# Product_17555
# Product_16886
# Product_58713
# Product_19293
# Product_63705
# Product_22741
# Product_29832
# Product_70427
# Product_53396
# Product_5096
# Product_3319
# Product_72566
# Product_17893
# Product_18814
# Product_26880
# Product_54835
# Product_52346
# Product_56100
# Product_14132
# Product_78473
# Product_18216
# Product_45372
# Product_82217
# Product_25361
# Product_64553
# Product_3016
# Product_48112
# Product_22231
# Product_43674
# Product_46709
# Product_24129
# Product_62640
# Product_54746
# Product_50681
# Product_81253
# Product_10243
# Product_59083
# Product_56378
# Product_30256
# Product_3776
# Product_79344
# Product_2437
# Product_15285
# Product_82316
# Product_69520
# Product_24420
# Product_73337
# Product_53478
# Product_50672
# Product_73469
# Product_1211
# Product_22211
# Product_52832
# Product_50559
# Product_16248
# Product_59868
# Product_39983
# Product_69422
# Product_12578
# Product_19792
# Product_16831
# Product_23231
# Product_41706
# Product_8628
# Product_47816
# Product_67132
# Product_72882
# Product_64415
# Product_36712
# Product_16338
# Product_81577
# Product_1168
# Product_24573
# Product_31880
# Product_34602
# Product_8497
# Product_36120
# Product_52669
# Product_10098
# Product_17585
# Product_60811
# Product_60394
# Product_34
# Product_76829
# Product_78181
# Product_19226
# Product_20197
# Product_12527
# Product_50911
# Product_42984
# Product_26938
# Product_73777
# Product_72147
# Product_55069
# Product_80194
# Product_56183
# Product_48107
# Product_23872
# Product_28516
# Product_33745
# Product_76921
# Product_80677
# Product_73200
# Product_66092
# Product_74722
# Product_78168
# Product_12539
# Product_56653
# Product_14647
# Product_74409
# Product_78404
# Product_43011
# Product_18686
# Product_16262
# Product_41654
# Product_53584
# Product_10352
# Product_9528
# Product_61797
# Product_42835
# Product_20784
# Product_36052
# Product_6537
# Product_62181
# Product_34734
# Product_15167
# Product_71174
# Product_35726
# Product_4231
# Product_72434
# Product_68893
# Product_43311
# Product_5222
# Product_1079
# Product_60215
# Product_31995
# Product_46312
# Product_36043
# Product_69338
# Product_47678
# Product_77562
# Product_61641
# Product_31822
# Product_75743
# Product_62164
# Product_27215
# Product_26307
# Product_18260
# Product_18034
# Product_61712
# Product_80437
# Product_73912
# Product_73161
# Product_9458
# Product_53767
# Product_75336
# Product_15871
# Product_74027
# Product_79257
# Product_7035
# Product_12192
# Product_22566
# Product_75600
# Product_11990
# Product_25623
# Product_40799
# Product_78635
# Product_49602
# Product_9311
# Product_52051
# Product_76581
# Product_10117
# Product_16637
# Product_18677
# Product_20596
# Product_30342
# Product_31798
# Product_18359
# Product_45671
# Product_67250
# Product_81899
# Product_36933
# Product_38554
# Product_71303
# Product_71774
# Product_68072
# Product_69012
# Product_78247
# Product_54494
# Product_56870
# Product_61970
# Product_38275
# Product_5373
# Product_38055
# Product_5031
# Product_63821
# Product_1572
# Product_35283
# Product_7997
# Product_25309
# Product_72129
# Product_6934
# Product_42660
# Product_27316
# Product_64185
# Product_61974
# Product_33755
# Product_61664
# Product_40261
# Product_20511
# Product_44146
# Product_56109
# Product_80782
# Product_51620
# Product_36217
# Product_60953
# Product_47114
# Product_58590
# Product_50774
# Product_24370
# Product_48611
# Product_40017
# Product_72021
# Product_67542
# Product_64108
# Product_25748
# Product_28310
# Product_59839
# Product_41392
# Product_66885
# Product_19825
# Product_68709
# Product_66643
# Product_26232
# Product_31184
# Product_32701
# Product_56320
# Product_52066
# Product_45119
# Product_58456
# Product_56345
# Product_23020
# Product_66420
# Product_23057
# Product_65829
# Product_22632
# Product_40970
# Product_61885
# Product_56826
# Product_5463
# Product_78492
# Product_38330
# Product_25380
# Product_59486
# Product_72718
# Product_13215
# Product_2743
# Product_61981
# Product_53754
# Product_63095
# Product_43503
# Product_48665
# Product_34653
# Product_30473
# Product_71890
# Product_42618
# Product_7095
# Product_31783
# Product_32379
# Product_73462
# Product_33568
# Product_32684
# Product_70577
# Product_9748
# Product_11918
# Product_78465
# Product_19833
# Product_43927
# Product_26978
# Product_17364
# Product_36158
# Product_16717
# Product_43356
# Product_16276
# Product_31283
# Product_77864
# Product_15626
# Product_30760
# Product_12301
# Product_48865
# Product_43585
# Product_64582
# Product_43946
# Product_45179
# Product_77922
# Product_52230
# Product_7116
# Product_9383
# Product_34727
# Product_1861
# Product_54254
# Product_27629
# Product_80027
# Product_9881
# Product_32330
# Product_56437
# Product_32232
# Product_9276
# Product_17475
# Product_22898
# Product_27617
# Product_466
# Product_24536
# Product_31589
# Product_20697
# Product_37259
# Product_54552
# Product_5827
# Product_80460
# Product_43092
# Product_40377
# Product_70296
# Product_29870
# Product_27721
# Product_30701
# Product_31795
# Product_59606
# Product_66747
# Product_9398
# Product_71130
# Product_63807
# Product_49918
# Product_23477
# Product_19671
# Product_77760
# Product_26387
# Product_55440
# Product_37592
# Product_1337
# Product_30307
# Product_19147
# Product_14352
# Product_77131
# Product_45302
# Product_49959
# Product_7004
# Product_48983
# Product_31189
# Product_18930
# Product_26473
# Product_16317
# Product_10541
# Product_71149
# Product_60690
# Product_21828
# Product_64206
# Product_33066
# Product_42514
# Product_48881
# Product_58342
# Product_81239
# Product_12857
# Product_2914
# Product_28264
# Product_57023
# Product_25742
# Product_14135
# Product_2217
# Product_56279
# Product_35186
# Product_70713
# Product_8614
# Product_49738
# Product_44786
# Product_8355
# Product_35177
# Product_25998
# Product_40933
# Product_17864
# Product_24844
# Product_17845
# Product_58078
# Product_18224
# Product_5945
# Product_51061
# Product_48101
# Product_12930
# Product_134
# Product_74468
# Product_80770
# Product_61217
# Product_30588
# Product_57060
# Product_55477
# Product_82036
# Product_36957
# Product_33342
# Product_36839
# Product_25969
# Product_1352
# Product_18646
# Product_28330
# Product_20332
# Product_29410
# Product_11543
# Product_72053
# Product_75070
# Product_43563
# Product_37239
# Product_5790
# Product_49508
# Product_76233
# Product_35328
# Product_46893
# Product_10687
# Product_5340
# Product_75901
# Product_21650
# Product_51194
# Product_70840
# Product_41388
# Product_80073
# Product_16938
# Product_26306
# Product_4181
# Product_32268
# Product_12812
# Product_64906
# Product_13135
# Product_4583
# Product_49915
# Product_67725
# Product_32774
# Product_37582
# Product_72527
# Product_57189
# Product_29621
# Product_46244
# Product_1945
# Product_61404
# Product_14462
# Product_989
# Product_79813
# Product_2488
# Product_15264
# Product_78325
# Product_18522
# Product_68203
# Product_57219
# Product_37437
# Product_52385
# Product_29194
# Product_74844
# Product_54138
# Product_45779
# Product_81400
# Product_10841
# Product_18467
# Product_66156
# Product_56439
# Product_31849
# Product_69428
# Product_10183
# Product_52369
# Product_5200
# Product_72912
# Product_23227
# Product_27167
# Product_27083
# Product_62777
# Product_58353
# Product_41259
# Product_76669
# Product_8250
# Product_80102
# Product_45829
# Product_50332
# Product_77680
# Product_32184
# Product_59436
# Product_61238
# Product_49900
# Product_47416
# Product_80792
# Product_69457
# Product_45506
# Product_76556
# Product_28217
# Product_82432
# Product_2986
# Product_637
# Product_28181
# Product_13379
# Product_28714
# Product_12083
# Product_34088
# Product_15005
# Product_25626
# Product_5426
# Product_78292
# Product_51893
# Product_67759
# Product_10154
# Product_82742
# Product_5358
# Product_52105
# Product_63605
# Product_26357
# Product_305
# Product_531
# Product_27738
# Product_78396
# Product_4434
# Product_59040
# Product_3869
# Product_44717
# Product_19284
# Product_55770
# Product_14793
# Product_18545
# Product_35301
# Product_25637
# Product_50293
# Product_52922
# Product_26391
# Product_1172
# Product_71749
# Product_14091
# Product_33644
# Product_11389
# Product_30017
# Product_20482
# Product_714
# Product_39126
# Product_46816
# Product_76178
# Product_75136
# Product_55142
# Product_23222
# Product_10528
# Product_7208
# Product_1527
# Product_13486
# Product_16590
# Product_43100
# Product_37328
# Product_7119
# Product_10210
# Product_67887
# Product_5398
# Product_59022
# Product_32322
# Product_81611
# Product_29846
# Product_9927
# Product_69418
# Product_45559
# Product_73898
# Product_8154
# Product_29375
# Product_45974
# Product_73287
# Product_55288
# Product_47888
# Product_67868
# Product_19434
# Product_18775
# Product_17929
# Product_23523
# Product_19133
# Product_49873
# Product_53028
# Product_64892
# Product_22646
# Product_53581
# Product_21824
# Product_76007
# Product_59424
# Product_6507
# Product_69312
# Product_74006
# Product_54322
# Product_8574
# Product_24445
# Product_10853
# Product_69154
# Product_33113
# Product_56760
# Product_57217
# Product_5217
# Product_62477
# Product_5536
# Product_81711
# Product_19851
# Product_42531
# Product_19760
# Product_52096
# Product_9614
# Product_17705
# Product_79423
# Product_12772
# Product_56447
# Product_30156
# Product_26446
# Product_56655
# Product_80747
# Product_33144
# Product_79083
# Product_65050
# Product_44789
# Product_34645
# Product_22665
# Product_54815
# Product_24278
# Product_43864
# Product_67678
# Product_66973
# Product_17920
# Product_43558
# Product_32697
# Product_57767
# Product_13544
# Product_62496
# Product_68065
# Product_4429
# Product_17575
# Product_44287
# Product_24549
# Product_22673
# Product_10145
# Product_12612
# Product_61626
# Product_70388
# Product_28616
# Product_77005
# Product_14928
# Product_62022
# Product_7713
# Product_4786
# Product_65168
# Product_71397
# Product_32122
# Product_15702
# Product_15975
# Product_17462
# Product_80307
# Product_64234
# Product_24025
# Product_45370
# Product_4711
# Product_58087
# Product_16514
# Product_71989
# Product_70249
# Product_50223
# Product_28144
# Product_81241
# Product_16211
# Product_50466
# Product_25959
# Product_3908
# Product_20374
# Product_11561
# Product_16451
# Product_25490
# Product_54459
# Product_56110
# Product_80255
# Product_34906
# Product_36697
# Product_11696
# Product_73227
# Product_41386
# Product_46831
# Product_81045
# Product_82600
# Product_9457
# Product_78646
# Product_22706
# Product_11351
# Product_66227
# Product_10092
# Product_39966
# Product_47029
# Product_13405
# Product_1785
# Product_64231
# Product_60230
# Product_14182
# Product_53738
# Product_25931
# Product_66059
# Product_78196
# Product_71394
# Product_73036
# Product_35720
# Product_24394
# Product_37624
# Product_48600
# Product_22648
# Product_24209
# Product_68808
# Product_41821
# Product_37287
# Product_69575
# Product_46528
# Product_76963
# Product_62801
# Product_42775
# Product_24983
# Product_37563
# Product_34585
# Product_46276
# Product_37181
# Product_1628
# Product_13476
# Product_77204
# Product_79272
# Product_67346
# Product_69299
# Product_35111
# Product_58599
# Product_81329
# Product_24522
# Product_47964
# Product_6669
# Product_8859
# Product_50940
# Product_32204
# Product_1216
# Product_18087
# Product_36942
# Product_66116
# Product_80201
# Product_31334
# Product_12362
# Product_33107
# Product_68466
# Product_81839
# Product_22902
# Product_66389
# Product_55359
# Product_56698
# Product_48860
# Product_54854
# Product_13048
# Product_47934
# Product_11819
# Product_15700
# Product_66895
# Product_18459
# Product_76118
# Product_68688
# Product_688
# Product_66682
# Product_59018
# Product_66445
# Product_61436
# Product_51895
# Product_9841
# Product_69037
# Product_4102
# Product_72202
# Product_56553
# Product_38856
# Product_13523
# Product_15399
# Product_82597
# Product_36059
# Product_16261
# Product_76435
# Product_5134
# Product_16964
# Product_36534
# Product_71352
# Product_9047
# Product_78366
# Product_80673
# Product_74512
# Product_17252
# Product_65225
# Product_81142
# Product_60647
# Product_46717
# Product_48364
# Product_69352
# Product_58828
# Product_14064
# Product_82806
# Product_78268
# Product_59591
# Product_78894
# Product_69417
# Product_74920
# Product_71817
# Product_27457
# Product_82388
# Product_16343
# Product_24245
# Product_58643
# Product_27410
# Product_58613
# Product_62848
# Product_20938
# Product_79415
# Product_7221
# Product_27591
# Product_22749
# Product_34948
# Product_49866
# Product_23483
# Product_56527
# Product_11842
# Product_25870
# Product_24903
# Product_18853
# Product_11615
# Product_39105
# Product_66130
# Product_62067
# Product_35873
# Product_65539
# Product_67036
# Product_26076
# Product_41210
# Product_18027
# Product_79435
# Product_35585
# Product_63675
# Product_304
# Product_24323
# Product_4509
# Product_73318
# Product_46420
# Product_79862
# Product_70695
# Product_49108
# Product_32458
# Product_23468
# Product_2023
# Product_34325
# Product_10610
# Product_24390
# Product_43254
# Product_23669
# Product_13854
# Product_15597
# Product_46574
# Product_55872
# Product_20930
# Product_13776
# Product_34680
# Product_16598
# Product_39346
# Product_57958
# Product_77558
# Product_31372
# Product_59066
# Product_9043
# Product_27625
# Product_15780
# Product_21722
# Product_82002
# Product_14063
# Product_82543
# Product_51051
# Product_2129
# Product_75380
# Product_24840
# Product_65276
# Product_36665
# Product_27301
# Product_4090
# Product_50132
# Product_3647
# Product_690
# Product_71229
# Product_77292
# Product_65608
# Product_44347
# Product_8788
# Product_42456
# Product_78185
# Product_79836
# Product_55229
# Product_16018
# Product_6539
# Product_20265
# Product_11878
# Product_60631
# Product_39768
# Product_70277
# Product_70210
# Product_53118
# Product_73783
# Product_51592
# Product_40201
# Product_19631
# Product_20184
# Product_8588
# Product_18492
# Product_74146
# Product_42037
# Product_63616
# Product_6628
# Product_67836
# Product_62752
# Product_13530
# Product_43209
# Product_4746
# Product_24033
# Product_62094
# Product_64779
# Product_45215
# Product_47064
# Product_30079
# Product_45219
# Product_72418
# Product_74710
# Product_71787
# Product_82383
# Product_12959
# Product_69072
# Product_15198
# Product_18939
# Product_26521
# Product_38638
# Product_39583
# Product_49847
# Product_63284
# Product_50231
# Product_55438
# Product_70063
# Product_74155
# Product_30193
# Product_35064
# Product_73969
# Product_14833
# Product_62879
# Product_14851
# Product_58245
# Product_34320
# Product_9657
# Product_6751
# Product_67234
# Product_46097
# Product_20956
# Product_6108
# Product_47224
# Product_55521
# Product_31324
# Product_38717
# Product_68450
# Product_48806
# Product_59010
# Product_22888
# Product_74757
# Product_51794
# Product_76949
# Product_29595
# Product_78069
# Product_16389
# Product_1610
# Product_63370
# Product_3160
# Product_53716
# Product_43912
# Product_16129
# Product_64728
# Product_36337
# Product_54901
# Product_72503
# Product_20949
# Product_53778
# Product_16083
# Product_76290
# Product_16017
# Product_28138
# Product_28170
# Product_46037
# Product_66651
# Product_59283
# Product_108
# Product_54900
# Product_26054
# Product_5968
# Product_75518
# Product_26278
# Product_22524
# Product_416
# Product_44822
# Product_47659
# Product_68154
# Product_13065
# Product_10121
# Product_29217
# Product_40784
# Product_48640
# Product_49034
# Product_21708
# Product_81647
# Product_9036
# Product_31231
# Product_34118
# Product_20
# Product_61372
# Product_37947
# Product_18654
# Product_25348
# Product_13996
# Product_57860
# Product_47657
# Product_19918
# Product_18499
# Product_49187
# Product_11995
# Product_73540
# Product_21458
# Product_57363
# Product_64795
# Product_10534
# Product_39211
# Product_45367
# Product_68092
# Product_39188
# Product_45990
# Product_74303
# Product_40335
# Product_24073
# Product_67217
# Product_56483
# Product_49059
# Product_16984
# Product_21910
# Product_64521
# Product_70607
# Product_81902
# Product_46028
# Product_8469
# Product_5116
# Product_48777
# Product_80325
# Product_28717
# Product_22181
# Product_45870
# Product_6953
# Product_80177
# Product_36524
# Product_37983
# Product_76541
# Product_46888
# Product_35908
# Product_37779
# Product_67605
# Product_65423
# Product_67551
# Product_56792
# Product_19772
# Product_13548
# Product_18207
# Product_15606
# Product_50733
# Product_27416
# Product_68249
# Product_31461
# Product_65777
# Product_78807
# Product_20741
# Product_79459
# Product_49782
# Product_46540
# Product_30923
# Product_63302
# Product_47467
# Product_8207
# Product_2047
# Product_81558
# Product_31903
# Product_69782
# Product_56733
# Product_60949
# Product_37254
# Product_23304
# Product_37881
# Product_68468
# Product_11243
# Product_45878
# Product_8984
# Product_50821
# Product_55870
# Product_13394
# Product_67428
# Product_17005
# Product_28923
# Product_31955
# Product_12572
# Product_65060
# Product_61353
# Product_78224
# Product_57844
# Product_75822
# Product_79188
# Product_5465
# Product_46228
# Product_75457
# Product_25180
# Product_16518
# Product_1351
# Product_2178
# Product_44279
# Product_74638
# Product_17788
# Product_32685
# Product_27469
# Product_55648
# Product_60122
# Product_44732
# Product_69257
# Product_67465
# Product_29483
# Product_58204
# Product_81056
# Product_3852
# Product_81691
# Product_37304
# Product_15479
# Product_33150
# Product_4180
# Product_9313
# Product_78398
# Product_81753
# Product_296
# Product_25150
# Product_30463
# Product_878
# Product_70694
# Product_61454
# Product_23238
# Product_38262
# Product_9661
# Product_12854
# Product_61109
# Product_22700
# Product_27192
# Product_54533
# Product_54541
# Product_27406
# Product_40966
# Product_26783
# Product_16772
# Product_41596
# Product_24374
# Product_39473
# Product_60474
# Product_37292
# Product_76469
# Product_35455
# Product_26052
# Product_33196
# Product_30094
# Product_63335
# Product_36649
# Product_19452
# Product_9339
# Product_49755
# Product_5881
# Product_55991
# Product_8793
# Product_53722
# Product_29612
# Product_69553
# Product_109
# Product_12256
# Product_21273
# Product_3273
# Product_22133
# Product_81561
# Product_38873
# Product_71642
# Product_56551
# Product_10943
# Product_49232
# Product_72005
# Product_2634
# Product_81011
# Product_31676
# Product_73869
# Product_49154
# Product_36939
# Product_82269
# Product_45471
# Product_24924
# Product_34590
# Product_35884
# Product_11057
# Product_15930
# Product_56130
# Product_77820
# Product_18282
# Product_62569
# Product_23235
# Product_55706
# Product_60710
# Product_74971
# Product_39005
# Product_9713
# Product_54434
# Product_24567
# Product_38696
# Product_62565
# Product_14101
# Product_45133
# Product_6025
# Product_34931
# Product_5573
# Product_30375
# Product_62130
# Product_6636
# Product_26928
# Product_12800
# Product_62950
# Product_65093
# Product_56595
# Product_41156
# Product_20366
# Product_69300
# Product_81887
# Product_52190
# Product_67850
# Product_27453
# Product_10344
# Product_4064
# Product_54303
# Product_45909
# Product_60366
# Product_5551
# Product_61009
# Product_17019
# Product_68921
# Product_44035
# Product_18720
# Product_2067
# Product_3658
# Product_30369
# Product_71214
# Product_43536
# Product_17825
# Product_58573
# Product_37687
# Product_53514
# Product_66618
# Product_78728
# Product_1793
# Product_64821
# Product_18126
# Product_37150
# Product_24677
# Product_7091
# Product_30108
# Product_2014
# Product_32319
# Product_35152
# Product_43884
# Product_17625
# Product_33233
# Product_80618
# Product_58749
# Product_22491
# Product_69714
# Product_27656
# Product_64218
# Product_69491
# Product_40151
# Product_79698
# Product_74007
# Product_12296
# Product_55321
# Product_69601
# Product_70084
# Product_7471
# Product_59155
# Product_24220
# Product_10632
# Product_18423
# Product_30715
# Product_7956
# Product_66133
# Product_49848
# Product_63531
# Product_33129
# Product_62728
# Product_47092
# Product_34502
# Product_66769
# Product_28890
# Product_3299
# Product_30008
# Product_67823
# Product_28102
# Product_10941
# Product_9022
# Product_61832
# Product_67502
# Product_60261
# Product_74756
# Product_55030
# Product_2468
# Product_62465
# Product_51636
# Product_26536
# Product_40329
# Product_60819
# Product_81323
# Product_25895
# Product_17488
# Product_61186
# Product_50144
# Product_64754
# Product_3496
# Product_54972
# Product_48135
# Product_29513
# Product_47074
# Product_22490
# Product_47757
# Product_60841
# Product_46443
# Product_25487
# Product_7058
# Product_41551
# Product_23878
# Product_2442
# Product_69385
# Product_50136
# Product_21288
# Product_27295
# Product_63175
# Product_19957
# Product_60894
# Product_37609
# Product_34543
# Product_66786
# Product_2656
# Product_21827
# Product_73986
# Product_10873
# Product_79288
# Product_45838
# Product_13482
# Product_7527
# Product_62746
# Product_50729
# Product_28387
# Product_15548
# Product_77585
# Product_78155
# Product_68497
# Product_17385
# Product_58190
# Product_65921
# Product_16553
# Product_6323
# Product_8579
# Product_33782
# Product_24646
# Product_54582
# Product_15495
# Product_58759
# Product_10608
# Product_51314
# Product_30191
# Product_63721
# Product_80667
# Product_48222
# Product_58195
# Product_37887
# Product_58494
# Product_9813
# Product_15512
# Product_6754
# Product_38816
# Product_68519
# Product_54611
# Product_23378
# Product_5065
# Product_31446
# Product_51780
# Product_77324
# Product_63430
# Product_62699
# Product_30143
# Product_68061
# Product_11348
# Product_57880
# Product_79503
# Product_38093
# Product_3062
# Product_6445
# Product_43373
# Product_41370
# Product_79040
# Product_55709
# Product_63400
# Product_20228
# Product_81672
# Product_52313
# Product_24466
# Product_37925
# Product_41861
# Product_45380
# Product_34862
# Product_57290
# Product_68371
# Product_45864
# Product_30212
# Product_69268
# Product_80371
# Product_47325
# Product_5314
# Product_35309
# Product_14541
# Product_82664
# Product_71365
# Product_2880
# Product_37606
# Product_24108
# Product_5904
# Product_34380
# Product_63144
# Product_1027
# Product_73398
# Product_42275
# Product_69144
# Product_26297
# Product_70965
# Product_33589
# Product_36361
# Product_69224
# Product_46752
# Product_30442
# Product_50053
# Product_16999
# Product_63462
# Product_76689
# Product_79292
# Product_16272
# Product_44647
# Product_75269
# Product_63746
# Product_41661
# Product_37742
# Product_63987
# Product_43586
# Product_65840
# Product_19832
# Product_3504
# Product_57851
# Product_44768
# Product_31320
# Product_51095
# Product_8673
# Product_77706
# Product_14605
# Product_78233
# Product_11381
# Product_78086
# Product_59894
# Product_26222
# Product_19668
# Product_21027
# Product_1143
# Product_8323
# Product_47717
# Product_25293
# Product_6797
# Product_53532
# Product_14756
# Product_52885
# Product_16225
# Product_3363
# Product_71455
# Product_72514
# Product_12941
# Product_44165
# Product_47070
# Product_74381
# Product_35222
# Product_53474
# Product_66775
# Product_53861
# Product_20701
# Product_53897
# Product_72921
# Product_40258
# Product_67589
# Product_19109
# Product_5206
# Product_67372
# Product_30618
# Product_67872
# Product_34480
# Product_28307
# Product_33988
# Product_7690
# Product_41838
# Product_62603
# Product_78243
# Product_6452
# Product_61301
# Product_38572
# Product_63791
# Product_41677
# Product_53397
# Product_75985
# Product_29390
# Product_72612
# Product_74322
# Product_38686
# Product_57755
# Product_18222
# Product_34132
# Product_81091
# Product_2472
# Product_80798
# Product_65240
# Product_19714
# Product_82459
# Product_3196
# Product_15144
# Product_36298
# Product_74718
# Product_29050
# Product_66524
# Product_55552
# Product_39901
# Product_20141
# Product_2153
# Product_47632
# Product_80095
# Product_119
# Product_81859
# Product_60540
# Product_50102
# Product_66912
# Product_9284
# Product_9522
# Product_22266
# Product_50049
# Product_13300
# Product_53317
# Product_20029
# Product_46957
# Product_68385
# Product_80345
# Product_35435
# Product_70881
# Product_60946
# Product_50761
# Product_33128
# Product_58487
# Product_36092
# Product_26106
# Product_31339
# Product_40439
# Product_51016
# Product_21808
# Product_23045
# Product_26080
# Product_51128
# Product_74987
# Product_69551
# Product_8503
# Product_27518
# Product_71856
# Product_11416
# Product_8006
# Product_33895
# Product_46707
# Product_47506
# Product_81528
# Product_62210
# Product_63489
# Product_2009
# Product_22983
# Product_66692
# Product_8769
# Product_24579
# Product_11022
# Product_59326
# Product_35849
# Product_28197
# Product_39703
# Product_79193
# Product_2181
# Product_4697
# Product_8865
# Product_4341
# Product_55375
# Product_39317
# Product_46135
# Product_65521
# Product_56511
# Product_32723
# Product_62050
# Product_16629
# Product_49197
# Product_32802
# Product_76443
# Product_67746
# Product_28450
# Product_72196
# Product_24790
# Product_65808
# Product_82079
# Product_19026
# Product_24845
# Product_73525
# Product_41502
# Product_44131
# Product_56680
# Product_15727
# Product_27212
# Product_47464
# Product_56955
# Product_81650
# Product_35532
# Product_17572
# Product_75259
# Product_43667
# Product_30293
# Product_18115
# Product_57708
# Product_70201
# Product_24290
# Product_74026
# Product_72684
# Product_26723
# Product_30621
# Product_57485
# Product_61999
# Product_55789
# Product_53269
# Product_37524
# Product_36209
# Product_72617
# Product_871
# Product_34150
# Product_3019
# Product_48598
# Product_63959
# Product_22358
# Product_77689
# Product_7819
# Product_39909
# Product_29095
# Product_52474
# Product_49161
# Product_82114
# Product_71442
# Product_58375
# Product_50808
# Product_8778
# Product_29699
# Product_33528
# Product_77164
# Product_16825
# Product_17240
# Product_48240
# Product_6470
# Product_78041
# Product_21662
# Product_61789
# Product_37851
# Product_11725
# Product_75520
# Product_44563
# Product_9803
# Product_5431
# Product_70739
# Product_53033
# Product_18269
# Product_56634
# Product_62883
# Product_11411
# Product_19111
# Product_24839
# Product_64615
# Product_26552
# Product_32034
# Product_30669
# Product_21300
# Product_26256
# Product_53704
# Product_51331
# Product_23361
# Product_69058
# Product_18805
# Product_37755
# Product_58793
# Product_6399
# Product_21093
# Product_46015
# Product_39468
# Product_59255
# Product_8314
# Product_76507
# Product_69913
# Product_1912
# Product_81892
# Product_30524
# Product_25528
# Product_51090
# Product_15150
# Product_39193
# Product_17607
# Product_5003
# Product_60395
# Product_59021
# Product_80046
# Product_59319
# Product_1251
# Product_60855
# Product_68982
# Product_30818
# Product_27507
# Product_82689
# Product_49699
# Product_9865
# Product_2007
# Product_26649
# Product_424
# Product_79878
# Product_21282
# Product_78252
# Product_80359
# Product_16649
# Product_15651
# Product_61134
# Product_81785
# Product_19479
# Product_53340
# Product_60977
# Product_3426
# Product_10064
# Product_37027
# Product_42175
# Product_28122
# Product_6513
# Product_9173
# Product_51560
# Product_62608
# Product_52323
# Product_66578
# Product_9829
# Product_18211
# Product_65735
# Product_60748
# Product_34989
# Product_61716
# Product_62611
# Product_74894
# Product_34447
# Product_56192
# Product_77233
# Product_67282
# Product_31180
# Product_35982
# Product_26200
# Product_11906
# Product_1094
# Product_18626
# Product_12410
# Product_49230
# Product_81255
# Product_42463
# Product_71739
# Product_51568
# Product_54015
# Product_24404
# Product_15544
# Product_77144
# Product_26485
# Product_3342
# Product_37573
# Product_43814
# Product_19015
# Product_30762
# Product_6853
# Product_71494
# Product_60141
# Product_48142
# Product_2413
# Product_76652
# Product_58736
# Product_17805
# Product_493
# Product_3507
# Product_50441
# Product_65726
# Product_11038
# Product_28835
# Product_44384
# Product_71815
# Product_79377
# Product_77984
# Product_38547
# Product_37515
# Product_13817
# Product_79950
# Product_69024
# Product_53902
# Product_26407
# Product_47557
# Product_78111
# Product_40450
# Product_1645
# Product_34733
# Product_55104
# Product_23034
# Product_71671
# Product_46583
# Product_44569
# Product_8524
# Product_7298
# Product_66073
# Product_79262
# Product_82315
# Product_4016
# Product_36791
# Product_48893
# Product_76059
# Product_7715
# Product_20678
# Product_280
# Product_36700
# Product_61856
# Product_47845
# Product_74066
# Product_33356
# Product_41574
# Product_57808
# Product_32291
# Product_35729
# Product_7351
# Product_74288
# Product_54779
# Product_57846
# Product_71582
# Product_10834
# Product_49825
# Product_35945
# Product_22784
# Product_7374
# Product_61857
# Product_59745
# Product_45932
# Product_21698
# Product_66624
# Product_64191
# Product_10150
# Product_55533
# Product_14310
# Product_11213
# Product_50076
# Product_30176
# Product_24357
# Product_19996
# Product_35260
# Product_65631
# Product_17233
# Product_75972
# Product_13897
# Product_55782
# Product_11439
# Product_15514
# Product_78735
# Product_81726
# Product_68684
# Product_73026
# Product_20613
# Product_69626
# Product_41171
# Product_16992
# Product_59440
# Product_41595
# Product_21616
# Product_46359
# Product_31487
# Product_50944
# Product_41163
# Product_43870
# Product_76637
# Product_40644
# Product_41891
# Product_72750
# Product_64834
# Product_373
# Product_79124
# Product_35883
# Product_64994
# Product_10893
# Product_47170
# Product_6398
# Product_19651
# Product_5171
# Product_38482
# Product_63867
# Product_33909
# Product_39374
# Product_40760
# Product_39602
# Product_40876
# Product_58263
# Product_54124
# Product_72451
# Product_2963
# Product_72823
# Product_26445
# Product_48922
# Product_71446
# Product_54536
# Product_61696
# Product_43787
# Product_29637
# Product_56642
# Product_25461
# Product_49157
# Product_49483
# Product_76315
# Product_32812
# Product_36506
# Product_65158
# Product_75498
# Product_17024
# Product_71781
# Product_3952
# Product_64985
# Product_81919
# Product_9449
# Product_9315
# Product_69076
# Product_69201
# Product_63069
# Product_53212
# Product_36590
# Product_45075
# Product_59903
# Product_62374
# Product_47400
# Product_11374
# Product_14955
# Product_34254
# Product_41236
# Product_23710
# Product_52707
# Product_7422
# Product_60126
# Product_10929
# Product_58581
# Product_39275
# Product_49026
# Product_20367
# Product_39586
# Product_20973
# Product_41510
# Product_13647
# Product_8001
# Product_17255
# Product_18770
# Product_15469
# Product_21096
# Product_241
# Product_61473
# Product_70676
# Product_26724
# Product_20334
# Product_12391
# Product_31386
# Product_6367
# Product_6663
# Product_21956
# Product_64636
# Product_60885
# Product_77291
# Product_8553
# Product_3206
# Product_2640
# Product_63083
# Product_41200
# Product_60324
# Product_25579
# Product_45180
# Product_31655
# Product_49926
# Product_51669
# Product_14699
# Product_15278
# Product_37780
# Product_51714
# Product_28282
# Product_77365
# Product_63227
# Product_52627
# Product_54934
# Product_5420
# Product_65353
# Product_50222
# Product_56430
# Product_28760
# Product_18084
# Product_15811
# Product_45619
# Product_31160
# Product_29401
# Product_47547
# Product_17563
# Product_55884
# Product_1602
# Product_47421
# Product_59094
# Product_59843
# Product_6052
# Product_65030
# Product_31066
# Product_28782
# Product_16250
# Product_5971
# Product_73938
# Product_13689
# Product_56315
# Product_49906
# Product_32023
# Product_29355
# Product_36259
# Product_31262
# Product_64793
# Product_21213
# Product_70978
# Product_21809
# Product_41577
# Product_74934
# Product_22012
# Product_29567
# Product_76407
# Product_11151
# Product_30743
# Product_30920
# Product_28382
# Product_46499
# Product_7308
# Product_60255
# Product_4777
# Product_47954
# Product_2906
# Product_64897
# Product_49328
# Product_14371
# Product_33844
# Product_39675
# Product_63163
# Product_25725
# Product_70544
# Product_4613
# Product_71911
# Product_45890
# Product_34179
# Product_41357
# Product_44402
# Product_10517
# Product_65415
# Product_50249
# Product_81408
# Product_23319
# Product_66063
# Product_37783
# Product_62738
# Product_40765
# Product_3146
# Product_25138
# Product_63596
# Product_52405
# Product_50426
# Product_47481
# Product_34823
# Product_74175
# Product_76433
# Product_5030
# Product_11482
# Product_46250
# Product_70915
# Product_73587
# Product_53029
# Product_78803
# Product_14230
# Product_55606
# Product_2580
# Product_41750
# Product_47651
# Product_30180
# Product_12344
# Product_28704
# Product_6466
# Product_81230
# Product_65312
# Product_18058
# Product_40214
# Product_79474
# Product_27606
# Product_58228
# Product_55134
# Product_18644
# Product_60084
# Product_81037
# Product_55338
# Product_10100
# Product_78857
# Product_42838
# Product_80600
# Product_15793
# Product_74608
# Product_5601
# Product_26122
# Product_5467
# Product_38575
# Product_71492
# Product_23908
# Product_8318
# Product_38682
# Product_17036
# Product_1827
# Product_9506
# Product_7807
# Product_48877
# Product_1466
# Product_20143
# Product_29844
# Product_34220
# Product_8343
# Product_31281
# Product_55422
# Product_62131
# Product_2536
# Product_22782
# Product_52034
# Product_53752
# Product_68348
# Product_52602
# Product_33086
# Product_10609
# Product_44567
# Product_57122
# Product_65196
# Product_81825
# Product_49785
# Product_14272
# Product_38997
# Product_60795
# Product_62021
# Product_36030
# Product_56743
# Product_35907
# Product_61474
# Product_19847
# Product_75475
# Product_68964
# Product_54291
# Product_44390
# Product_53588
# Product_35752
# Product_10621
# Product_4395
# ...
# Product_22913
# Product_18386
# Product_34054
# Product_31110
# Product_56117
# Product_8241
# Product_45441
# Product_80210
# Product_60134
# Product_8067
# Product_73786
# Product_8341
# Product_54104
# Product_69174
# Product_2622
# Product_33525
# Product_65838
# Product_39254
# Product_16646
# Product_36835
# Product_40817
# Product_12336
# Product_7756
# Product_35737
# Product_82713
# Product_32028
# Product_54658
# Product_40886
# Product_37911
# Product_38199
# Product_78105
# Product_5309
# Product_23140
# Product_48292
# Product_77552
# Product_38148
# Product_81775
# Product_52840
# Product_41146
# Product_59733
# Product_44956
# Product_76210
# Product_59320
# Product_21192
# Product_23830
# Product_15816
# Product_54780
# Product_20276
# Product_12992
# Product_49464
# Product_57866
# Product_13269
# Product_57983
# Product_31301
# Product_20722
# Product_46160
# Product_38590
# Product_5824
# Product_27886
# Product_17908
# Product_12331
# Product_47164
# Product_65069
# Product_33623
# Product_65441
# Product_19089
# Product_43333
# Product_45468
# Product_36192
# Product_22338
# Product_47700
# Product_24411
# Product_19029
# Product_7586
# Product_6995
# Product_56546
# Product_23542
# Product_19378
# Product_54713
# Product_76259
# Product_15515
# Product_79905
# Product_20619
# Product_17782
# Product_4736
# Product_17372
# Product_58625
# Product_21557
# Product_55038
# Product_11835
# Product_19893
# Product_19169
# Product_30253
# Product_42326
# Product_35023
# Product_340
# Product_79857
# Product_67334
# Product_11396
# Product_34781
# Product_59135
# Product_45892
# Product_25896
# Product_80891
# Product_82300
# Product_82732
# Product_11899
# Product_78353
# Product_27355
# Product_42328
# Product_14102
# Product_62063
# Product_4530
# Product_71509
# Product_35426
# Product_72126
# Product_10772
# Product_34978
# Product_70101
# Product_58549
# Product_56153
# Product_13075
# Product_40395
# Product_46376
# Product_65618
# Product_17691
# Product_1807
# Product_76102
# Product_34249
# Product_27700
# Product_50473
# Product_7135
# Product_59065
# Product_7799
# Product_26734
# Product_54112
# Product_59053
# Product_82169
# Product_34873
# Product_71609
# Product_18149
# Product_25305
# Product_55070
# Product_26151
# Product_37419
# Product_50522
# Product_59845
# Product_24266
# Product_75944
# Product_29622
# Product_54072
# Product_44918
# Product_50149
# Product_26207
# Product_42628
# Product_52699
# Product_35967
# Product_65227
# Product_43829
# Product_23848
# Product_49064
# Product_74519
# Product_6307
# Product_30628
# Product_78019
# Product_49181
# Product_50461
# Product_54317
# Product_62974
# Product_46828
# Product_50268
# Product_77059
# Product_61575
# Product_20551
# Product_22569
# Product_75513
# Product_65088
# Product_14208
# Product_81143
# Product_22532
# Product_53289
# Product_36372
# Product_66553
# Product_69861
# Product_38733
# Product_18539
# Product_1063
# Product_20325
# Product_57385
# Product_64187
# Product_57526
# Product_36979
# Product_8589
# Product_3893
# Product_19591
# Product_62979
# Product_57456
# Product_15099
# Product_4679
# Product_73112
# Product_79883
# Product_15601
# Product_41917
# Product_81821
# Product_1968
# Product_30724
# Product_45214
# Product_25652
# Product_2612
# Product_14561
# Product_4345
# Product_9930
# Product_60781
# Product_32353
# Product_4937
# Product_54847
# Product_80400
# Product_39911
# Product_26662
# Product_7564
# Product_46176
# Product_7396
# Product_43701
# Product_15338
# Product_1995
# Product_37072
# Product_7440
# Product_6482
# Product_37995
# Product_69772
# Product_43499
# Product_44331
# Product_39816
# Product_3434
# Product_6981
# Product_57133
# Product_76083
# Product_69399
# Product_50826
# Product_56064
# Product_68989
# Product_39371
# Product_7428
# Product_7599
# Product_3944
# Product_75508
# Product_81905
# Product_42674
# Product_6692
# Product_37923
# Product_11797
# Product_30474
# Product_55699
# Product_46979
# Product_36599
# Product_51325
# Product_47553
# Product_61159
# Product_44988
# Product_32687
# Product_54671
# Product_77237
# Product_23303
# Product_53789
# Product_57965
# Product_50069
# Product_63604
# Product_5223
# Product_30734
# Product_65243
# Product_80552
# Product_40705
# Product_57722
# Product_60868
# Product_75996
# Product_42526
# Product_54840
# Product_27980
# Product_390
# Product_29351
# Product_5178
# Product_11807
# Product_81335
# Product_30244
# Product_43383
# Product_21855
# Product_58682
# Product_34518
# Product_876
# Product_32242
# Product_7967
# Product_68723
# Product_23417
# Product_10320
# Product_44295
# Product_11133
# Product_65208
# Product_79961
# Product_70450
# Product_51819
# Product_44564
# Product_59216
# Product_47801
# Product_76261
# Product_77154
# Product_45403
# Product_7739
# Product_45199
# Product_64707
# Product_60346
# Product_31582
# Product_2643
# Product_2625
# Product_38098
# Product_35629
# Product_82156
# Product_76110
# Product_7559
# Product_33819
# Product_22567
# Product_76508
# Product_82741
# Product_43032
# Product_5907
# Product_43186
# Product_11490
# Product_50106
# Product_76490
# Product_24048
# Product_51583
# Product_3248
# Product_10473
# Product_70999
# Product_15517
# Product_24749
# Product_62509
# Product_71126
# Product_52089
# Product_53624
# Product_15946
# Product_66989
# Product_31824
# Product_18911
# Product_19635
# Product_951
# Product_5869
# Product_27552
# Product_10083
# Product_62256
# Product_54278
# Product_32948
# Product_14382
# Product_68333
# Product_55948
# Product_19646
# Product_19864
# Product_45248
# Product_81350
# Product_28690
# Product_9585
# Product_21677
# Product_7399
# Product_82371
# Product_58930
# Product_1913
# Product_23816
# Product_28294
# Product_6169
# Product_17501
# Product_38863
# Product_53834
# Product_64784
# Product_65884
# Product_77419
# Product_9025
# Product_15789
# Product_52728
# Product_25553
# Product_73703
# Product_57106
# Product_95
# Product_9711
# Product_16759
# Product_10927
# Product_43501
# Product_7080
# Product_70015
# Product_34347
# Product_39999
# Product_44344
# Product_79863
# Product_56411
# Product_18877
# Product_28651
# Product_48176
# Product_1619
# Product_36422
# Product_14975
# Product_79632
# Product_77644
# Product_51664
# Product_72154
# Product_47563
# Product_8313
# Product_67621
# Product_32543
# Product_7442
# Product_42641
# Product_47488
# Product_19041
# Product_8315
# Product_25534
# Product_48343
# Product_60589
# Product_30380
# Product_14569
# Product_58243
# Product_36231
# Product_16729
# Product_74966
# Product_55062
# Product_60607
# Product_37391
# Product_45536
# Product_53071
# Product_69955
# Product_29505
# Product_14876
# Product_66649
# Product_33994
# Product_22916
# Product_7138
# Product_667
# Product_17840
# Product_81398
# Product_29199
# Product_56983
# Product_80473
# Product_48398
# Product_77297
# Product_42762
# Product_53947
# Product_14273
# Product_62418
# Product_43879
# Product_49562
# Product_33842
# Product_35520
# Product_37868
# Product_17291
# Product_31109
# Product_65456
# Product_35437
# Product_66329
# Product_82140
# Product_22208
# Product_48415
# Product_9685
# Product_10611
# Product_62936
# Product_75993
# Product_77920
# Product_39240
# Product_53141
# Product_4911
# Product_56219
# Product_71637
# Product_33507
# Product_75044
# Product_32256
# Product_16994
# Product_64839
# Product_31740
# Product_50979
# Product_75596
# Product_30925
# Product_8439
# Product_6964
# Product_46656
# Product_48864
# Product_54553
# Product_53277
# Product_6765
# Product_43530
# Product_18887
# Product_41295
# Product_59644
# Product_63677
# Product_52556
# Product_14223
# Product_21066
# Product_47219
# Product_51081
# Product_77255
# Product_15361
# Product_60345
# Product_814
# Product_22814
# Product_43576
# Product_13149
# Product_82025
# Product_4206
# Product_79044
# Product_16207
# Product_43617
# Product_25067
# Product_5482
# Product_26289
# Product_27237
# Product_79571
# Product_20130
# Product_51618
# Product_34285
# Product_15644
# Product_52723
# Product_22636
# Product_6740
# Product_7411
# Product_24804
# Product_4546
# Product_42587
# Product_75734
# Product_32813
# Product_77875
# Product_35594
# Product_42299
# Product_31696
# Product_9722
# Product_14104
# Product_62521
# Product_39624
# Product_51466
# Product_61356
# Product_51910
# Product_28188
# Product_72671
# Product_42273
# Product_32839
# Product_60203
# Product_29399
# Product_80135
# Product_47756
# Product_80124
# Product_59986
# Product_54650
# Product_48250
# Product_14113
# Product_14769
# Product_51844
# Product_77390
# Product_18158
# Product_54672
# Product_56436
# Product_75551
# Product_5563
# Product_11678
# Product_62119
# Product_66713
# Product_18049
# Product_19920
# Product_68377
# Product_10289
# Product_18735
# Product_72151
# Product_27532
# Product_54276
# Product_51914
# Product_67535
# Product_81179
# Product_55133
# Product_20794
# Product_77997
# Product_5614
# Product_50208
# Product_74223
# Product_818
# Product_30815
# Product_3276
# Product_78538
# Product_45448
# Product_58674
# Product_42297
# Product_53446
# Product_69446
# Product_71746
# Product_42019
# Product_40707
# Product_18912
# Product_70058
# Product_17304
# Product_67151
# Product_55627
# Product_3612
# Product_22761
# Product_29020
# Product_39837
# Product_81147
# Product_47635
# Product_17284
# Product_36339
# Product_38483
# Product_39053
# Product_53596
# Product_29129
# Product_42098
# Product_61704
# Product_56936
# Product_8087
# Product_4086
# Product_75888
# Product_66943
# Product_6118
# Product_72431
# Product_73486
# Product_62539
# Product_8536
# Product_13582
# Product_56819
# Product_12102
# Product_78825
# Product_37746
# Product_26563
# Product_64035
# Product_54277
# Product_78204
# Product_24152
# Product_17108
# Product_19093
# Product_55894
# Product_39409
# Product_40445
# Product_44797
# Product_20524
# Product_57517
# Product_41265
# Product_76631
# Product_15678
# Product_53543
# Product_73981
# Product_40697
# Product_63139
# Product_72047
# Product_69453
# Product_28814
# Product_77952
# Product_1199
# Product_28680
# Product_20547
# Product_46853
# Product_64944
# Product_36685
# Product_77316
# Product_1547
# Product_31736
# Product_55665
# Product_77740
# Product_38270
# Product_78934
# Product_80732
# Product_37286
# Product_61064
# Product_64254
# Product_72992
# Product_45459
# Product_65778
# Product_38610
# Product_28171
# Product_38602
# Product_43913
# Product_33028
# Product_21600
# Product_81219
# Product_51470
# Product_71861
# Product_40328
# Product_56703
# Product_63623
# Product_63091
# Product_60833
# Product_49079
# Product_36616
# Product_43697
# Product_34423
# Product_49192
# Product_32436
# Product_49628
# Product_74251
# Product_20103
# Product_29099
# Product_33797
# Product_56406
# Product_76711
# Product_16400
# Product_40542
# Product_82311
# Product_51123
# Product_2526
# Product_65313
# Product_11962
# Product_52643
# Product_71398
# Product_46730
# Product_23619
# Product_45615
# Product_67125
# Product_70272
# Product_79112
# Product_41667
# Product_75069
# Product_60662
# Product_76977
# Product_44691
# Product_70725
# Product_68161
# Product_63931
# Product_67026
# Product_43191
# Product_11720
# Product_76078
# Product_57549
# Product_56879
# Product_3506
# Product_54717
# Product_59604
# Product_53790
# Product_8663
# Product_39508
# Product_71124
# Product_23165
# Product_73817
# Product_10254
# Product_75841
# Product_47529
# Product_30020
# Product_74446
# Product_33410
# Product_26440
# Product_31624
# Product_65157
# Product_43171
# Product_12018
# Product_50225
# Product_20351
# Product_53465
# Product_21118
# Product_26990
# Product_74219
# Product_46616
# Product_39158
# Product_52213
# Product_26782
# Product_49277
# Product_9923
# Product_28801
# Product_75858
# Product_44500
# Product_10549
# Product_60728
# Product_43782
# Product_10130
# Product_77182
# Product_10378
# Product_4352
# Product_26733
# Product_15048
# Product_22584
# Product_58737
# Product_4625
# Product_38888
# Product_5296
# Product_68690
# Product_10206
# Product_65580
# Product_45272
# Product_81553
# Product_27432
# Product_80748
# Product_37238
# Product_54922
# Product_58241
# Product_63742
# Product_57562
# Product_8275
# Product_25463
# Product_22366
# Product_61298
# Product_18244
# Product_1891
# Product_46723
# Product_62105
# Product_32788
# Product_43312
# Product_56304
# Product_54329
# Product_45840
# Product_19088
# Product_13155
# Product_42788
# Product_17123
# Product_65686
# Product_29177
# Product_30887
# Product_77359
# Product_5026
# Product_30595
# Product_45177
# Product_54119
# Product_17231
# Product_73519
# Product_36800
# Product_4759
# Product_20974
# Product_25910
# Product_68603
# Product_27509
# Product_6839
# Product_65878
# Product_45541
# Product_80648
# Product_10468
# Product_29066
# Product_22269
# Product_41520
# Product_13723
# Product_54889
# Product_55272
# Product_64142
# Product_25507
# Product_12782
# Product_38653
# Product_53420
# Product_2461
# Product_58897
# Product_30333
# Product_14012
# Product_66586
# Product_51848
# Product_52025
# Product_22925
# Product_19740
# Product_73458
# Product_57021
# Product_80588
# Product_61794
# Product_39192
# Product_78129
# Product_42727
# Product_38691
# Product_28655
# Product_55206
# Product_78653
# Product_52001
# Product_18645
# Product_8640
# Product_45460
# Product_59885
# Product_14011
# Product_12675
# Product_33484
# Product_65046
# Product_52639
# Product_64005
# Product_76773
# Product_34407
# Product_67141
# Product_52718
# Product_59524
# Product_47626
# Product_2322
# Product_75456
# Product_3362
# Product_11575
# Product_60195
# Product_43961
# Product_21579
# Product_72649
# Product_25457
# Product_5154
# Product_54676
# Product_26882
# Product_1047
# Product_81525
# Product_71834
# Product_74633
# Product_10981
# Product_7303
# Product_32326
# Product_35128
# Product_46201
# Product_76982
# Product_46461
# Product_72242
# Product_18998
# Product_64482
# Product_30581
# Product_7136
# Product_8831
# Product_64694
# Product_42538
# Product_37384
# Product_56017
# Product_53011
# Product_51399
# Product_49333
# Product_39724
# Product_32283
# Product_32753
# Product_28229
# Product_44823
# Product_40563
# Product_66573
# Product_1347
# Product_469
# Product_6130
# Product_19527
# Product_40444
# Product_76038
# Product_36550
# Product_30547
# Product_26159
# Product_81018
# Product_41748
# Product_43405
# Product_73198
# Product_40942
# Product_52220
# Product_76367
# Product_12861
# Product_16741
# Product_2030
# Product_82722
# Product_65594
# Product_47478
# Product_72889
# Product_46552
# Product_693
# Product_39470
# Product_47259
# Product_49116
# Product_12936
# Product_42771
# Product_11611
# Product_66935
# Product_77198
# Product_16112
# Product_64043
# Product_74032
# Product_17590
# Product_52202
# Product_14879
# Product_15431
# Product_16975
# Product_22319
# Product_69767
# Product_54032
# Product_61753
# Product_33959
# Product_24543
# Product_44919
# Product_44814
# Product_79425
# Product_6590
# Product_1054
# Product_38869
# Product_76203
# Product_24994
# Product_74727
# Product_11853
# Product_79901
# Product_60492
# Product_12012
# Product_24898
# Product_26512
# Product_62134
# Product_64159
# Product_42911
# Product_25811
# Product_17765
# Product_76818
# Product_9090
# Product_76942
# Product_43655
# Product_45852
# Product_75483
# Product_54037
# Product_14450
# Product_50471
# Product_80028
# Product_74509
# Product_50370
# Product_31060
# Product_6105
# Product_77230
# Product_2822
# Product_35780
# Product_14711
# Product_42421
# Product_79402
# Product_39860
# Product_35640
# Product_14146
# Product_38443
# Product_39536
# Product_17265
# Product_11674
# Product_55296
# Product_69435
# Product_24823
# Product_46669
# Product_78518
# Product_65460
# Product_77189
# Product_16496
# Product_2397
# Product_41816
# Product_52674
# Product_56391
# Product_8248
# Product_18364
# Product_17135
# Product_66229
# Product_52537
# Product_10302
# Product_81662
# Product_53729
# Product_7316
# Product_929
# Product_58471
# Product_11563
# Product_68534
# Product_28064
# Product_72954
# Product_52615
# Product_2762
# Product_72478
# Product_25118
# Product_68338
# Product_6832
# Product_1806
# Product_62393
# Product_70773
# Product_55292
# Product_3278
# Product_51196
# Product_26169
# Product_67885
# Product_16709
# Product_49000
# Product_25246
# Product_69009
# Product_56090
# Product_82803
# Product_64693
# Product_32595
# Product_40847
# Product_17981
# Product_75016
# Product_64995
# Product_43334
# Product_52215
# Product_78583
# Product_3942
# Product_71660
# Product_18494
# Product_47233
# Product_56479
# Product_69748
# Product_21264
# Product_19605
# Product_20847
# Product_41173
# Product_46001
# Product_35391
# Product_16136
# Product_74190
# Product_11872
# Product_60573
# Product_53201
# Product_65342
# Product_47755
# Product_7011
# Product_55468
# Product_35740
# Product_15994
# Product_5216
# Product_73180
# Product_33273
# Product_41977
# Product_4703
# Product_30849
# Product_11183
# Product_77601
# Product_66681
# Product_19896
# Product_45762
# Product_72986
# Product_34479
# Product_66388
# Product_12426
# Product_80162
# Product_69223
# Product_46076
# Product_30977
# Product_81642
# Product_43621
# Product_28575
# Product_70459
# Product_704
# Product_31790
# Product_32157
# Product_25178
# Product_44401
# Product_79782
# Product_57012
# Product_77781
# Product_58422
# Product_66155
# Product_61585
# Product_65136
# Product_44246
# Product_32207
# Product_56619
# Product_55451
# Product_57191
# Product_19321
# Product_8393
# Product_82721
# Product_30730
# Product_73404
# Product_68532
# Product_63166
# Product_16559
# Product_67528
# Product_28362
# Product_72691
# Product_12146
# Product_32574
# Product_31557
# Product_48207
# Product_72794
# Product_20626
# Product_59460
# Product_23941
# Product_77685
# Product_20251
# Product_8346
# Product_14643
# Product_56293
# Product_73139
# Product_26141
# Product_948
# Product_34281
# Product_43771

# %%
missing_products_info = products_data[products_data["product_id"].isin(missing_from_train)]

# Display the missing products dataframe
missing_products_info
# Out:
#           product_id             product_description department_key  \
# 9      Product_47445         LORINA CRISTAL SS 1,25L  Department_10
# 13     Product_51620    33CL LIMONADE LA BEAUCERONNE  Department_10
# 17      Product_6916       PET 1,5L LIMONETTE MILLES  Department_10
# 19     Product_31931   75CL BEAUCERONNE CITRON GLACE  Department_10
# 22     Product_62743     75 CL BELVOIR SUREAU ET ROS  Department_10
# ...              ...                             ...            ...
# 82960  Product_57956  885558 CUSHION 4 BLANC CAS2 TU  Department_65
# 82961  Product_18949   857699 BONNET POLAIRE NOIR TU  Department_66
# 82962  Product_66524  857699 BONNET PO BLANC CAS2 TU  Department_66
# 82963  Product_66126  876946 PULL DE NOEL PET ECRU S  Department_66
# 82965  Product_80183                CHARGE BUT 6K AZ  Department_75
#
#         class_key    subclass_key                   sector   brand_key  \
# 9      Class_1000  SubClass_10000                      PGC      LORINA
# 13     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 17     Class_1000  SubClass_10000                      PGC   LIMONETTE
# 19     Class_1000  SubClass_10000                      PGC  BEAUCERONN
# 22     Class_1000  SubClass_10000                      PGC     BELVOIR
# ...           ...             ...                      ...         ...
# 82960  Class_6573  SubClass_65730                  TEXTILE    TEX HOME
# 82961  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82962  Class_6620  SubClass_66204                  TEXTILE         TEX
# 82963  Class_6635  SubClass_66358                  TEXTILE         TEX
# 82965  Class_7520  SubClass_75203  ACTIVITES PERIPHERIQUES  ZZZZZZZZZZ
#
#                shelf_level1                         shelf_level2  \
# 9                  Boissons  Colas, Thés glacés, Sirops et Sodas
# 13                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 17                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 19                 Boissons  Colas, Thés glacés, Sirops et Sodas
# 22                 Boissons  Colas, Thés glacés, Sirops et Sodas
# ...                     ...                                  ...
# 82960  Maison et Décoration               Mobilier et Décoration
# 82961     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82962     Mode et Bagagerie            Bagagerie et Maroquinerie
# 82963            Animalerie                               Chiens
# 82965  Maison et Décoration                    Bouteilles de gaz
#
#                              shelf_level3                     shelf_level4  \
# 9              Limonades, Limes et Tonics                              NaN
# 13             Limonades, Limes et Tonics                              NaN
# 17             Limonades, Limes et Tonics                              NaN
# 19             Limonades, Limes et Tonics                              NaN
# 22             Limonades, Limes et Tonics                              NaN
# ...                                   ...                              ...
# 82960  Décorations et Parfums d'intérieur   Coussins et galettes de chaise
# 82961                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82962                 Accessoires de mode  Chapeaux, Casquettes et Bonnets
# 82963      Colliers, Laisses et Vêtements          Vêtements et Chaussures
# 82965                                 NaN                              NaN
#
#        bio  sugar_free  aspartame_free  gluten_free  halal  casher  \
# 9        0           1               0            0      0       0
# 13       0           0               0            0      0       0
# 17       0           0               0            0      0       0
# 19       0           0               0            0      0       0
# 22       0           0               0            0      0       0
# ...    ...         ...             ...          ...    ...     ...
# 82960    0           0               0            0      0       0
# 82961    0           0               0            0      0       0
# 82962    0           0               0            0      0       0
# 82963    0           0               0            0      0       0
# 82965    0           0               0            0      0       0
#
#        eco_friendly  local_french  artificial_coloring_free  \
# 9                 0             0                         0
# 13                0             0                         0
# 17                0             0                         0
# 19                0             0                         0
# 22                0             0                         0
# ...             ...           ...                       ...
# 82960             0             0                         0
# 82961             0             0                         0
# 82962             0             0                         0
# 82963             0             0                         0
# 82965             0             0                         0
#
#        taste_enhancer_free  naturality  antibiotic_free  reduced_sugar  \
# 9                        0           0                0              1
# 13                       0           0                0              0
# 17                       0           0                0              0
# 19                       0           0                0              0
# 22                       0           0                0              0
# ...                    ...         ...              ...            ...
# 82960                    0           0                0              0
# 82961                    0           0                0              0
# 82962                    0           0                0              0
# 82963                    0           0                0              0
# 82965                    0           0                0              0
#
#        vegetarian  pesticide_free  grain_free  no_added_sugar  salt_reduced  \
# 9               0               0           0               0             0
# 13              0               0           0               0             0
# 17              0               0           0               0             0
# 19              0               0           0               0             0
# 22              0               0           0               0             0
# ...           ...             ...         ...             ...           ...
# 82960           0               0           0               0             0
# 82961           0               0           0               0             0
# 82962           0               0           0               0             0
# 82963           0               0           0               0             0
# 82965           0               0           0               0             0
#
#        nitrite_free  fed_without_ogm  no_added_salt  no_artificial_flavours  \
# 9                 0                0              0                       0
# 13                0                0              0                       0
# 17                0                0              0                       0
# 19                0                0              0                       0
# 22                0                0              0                       0
# ...             ...              ...            ...                     ...
# 82960             0                0              0                       0
# 82961             0                0              0                       0
# 82962             0                0              0                       0
# 82963             0                0              0                       0
# 82965             0                0              0                       0
#
#        porc  vegan  frozen  fat_free  reduced_fats  fresh  alcool  \
# 9         0      0       0         0             0      0       0
# 13        0      0       0         0             0      0       0
# 17        0      0       0         0             0      0       0
# 19        0      0       0         0             0      0       0
# 22        0      0       0         0             0      0       0
# ...     ...    ...     ...       ...           ...    ...     ...
# 82960     0      0       0         0             0      0       0
# 82961     0      0       0         0             0      0       0
# 82962     0      0       0         0             0      0       0
# 82963     0      0       0         0             0      0       0
# 82965     0      0       0         0             0      0       0
#
#        lactose_free  phenylalanine_free  palm_oil_free ecoscore  \
# 9                 0                   0              0      NaN
# 13                0                   0              0      NaN
# 17                0                   0              0      NaN
# 19                0                   0              0      NaN
# 22                0                   0              0      NaN
# ...             ...                 ...            ...      ...
# 82960             0                   0              0      NaN
# 82961             0                   0              0      NaN
# 82962             0                   0              0      NaN
# 82963             0                   0              0      NaN
# 82965             0                   0              0      NaN
#
#        produits_du_monde  regional_product  national_brand  first_price_brand  \
# 9                      0                 0               1                  0
# 13                     0                 0               1                  0
# 17                     0                 1               1                  0
# 19                     0                 1               1                  0
# 22                     0                 0               1                  0
# ...                  ...               ...             ...                ...
# 82960                  0                 0               0                  0
# 82961                  0                 0               0                  0
# 82962                  0                 0               0                  0
# 82963                  0                 0               0                  0
# 82965                  0                 0               0                  0
#
#        carrefour_brand
# 9                    0
# 13                   0
# 17                   0
# 19                   0
# 22                   0
# ...                ...
# 82960                1
# 82961                1
# 82962                1
# 82963                1
# 82965                1
#
# [29625 rows x 49 columns]

# %%
# Load product embeddings
product_embeddings_np = np.load(f'{trainFolder}/product_embeddings.npy')

# Load product IDs
product_ids = np.load(f'{trainFolder}/product_ids.npy', allow_pickle=True)  # Use allow_pickle=True if product_ids is an array of objects (e.g., strings)

# Create the product embedding dictionary
product_embedding_dict = dict(zip(product_ids, product_embeddings_np))

# %% [markdown]
# # Negative Sampling using Embeddings

# %%
train_data
# Out:
#              customer_id     product_id  is_promo  quantity  recency  month  \
# 0        Household_30946  Product_16061         0       1.0      322      2
# 1        Household_30946  Product_74944         0       1.0       91     10
# 2        Household_30946  Product_27979         0       1.0      109      9
# 3        Household_30946  Product_38506         0       1.0      137      8
# 4        Household_30946  Product_59873         0       2.0      243      5
# ...                  ...            ...       ...       ...      ...    ...
# 8744882  Household_36797  Product_59042         0       2.0      317      2
# 8744883  Household_36797    Product_892         0       2.0      125      8
# 8744884  Household_38710  Product_41055         0       1.0       11     12
# 8744885  Household_38710  Product_80689         0       1.0       11     12
# 8744886  Household_38710  Product_30021         0       1.0      211      6
#
#          day_of_week  is_weekend  days_since_last_purchase  \
# 0                  6           1                       322
# 1                  6           1                        91
# 2                  2           0                       109
# 3                  2           0                       137
# 4                  1           0                       243
# ...              ...         ...                       ...
# 8744882            4           0                       192
# 8744883            0           0                         0
# 8744884            2           0                         2
# 8744885            2           0                         2
# 8744886            5           1                       202
#
#          purchase_frequency  avg_quantity  promo_ratio  unique_products
# 0                       268      1.417910     0.134328              212
# 1                       268      1.417910     0.134328              212
# 2                       268      1.417910     0.134328              212
# 3                       268      1.417910     0.134328              212
# 4                       268      1.417910     0.134328              212
# ...                     ...           ...          ...              ...
# 8744882                 276      1.518116     0.036232              213
# 8744883                 276      1.518116     0.036232              213
# 8744884                 130      1.146154     0.038462              120
# 8744885                 130      1.146154     0.038462              120
# 8744886                 130      1.146154     0.038462              120
#
# [8744887 rows x 13 columns]

# %%
len(train_data)
# Out:
# 8744887

# %%
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm
import numpy as np
import pandas as pd

# Generate a list of all unique product IDs
all_product_ids = set(product_embedding_dict.keys())

# Prepare for storing negative samples
negative_samples = []

# Group by customer for efficient processing
customer_groups = train_data.groupby('customer_id')

for customer_id, group in tqdm(customer_groups, desc="Generating hard negative samples"):
    # Purchased products for the current customer
    purchased_products = set(group['product_id'])

    # Non-purchased products for the current customer
    non_purchased_products = list(all_product_ids - purchased_products)

    # Skip if there are no products to compare
    if len(non_purchased_products) == 0 or len(purchased_products) == 0:
        continue

    # Get embeddings for purchased and non-purchased products
    purchased_embeddings = np.array([product_embedding_dict[pid] for pid in purchased_products])
    non_purchased_embeddings = np.array([product_embedding_dict[pid] for pid in non_purchased_products])

    # Reshape to ensure 2D arrays
    purchased_embeddings = purchased_embeddings.reshape(-1, purchased_embeddings.shape[-1])
    non_purchased_embeddings = non_purchased_embeddings.reshape(-1, non_purchased_embeddings.shape[-1])

    # Compute cosine similarity between non-purchased and purchased products
    similarity_scores = cosine_similarity(non_purchased_embeddings, purchased_embeddings)

    # Identify the most similar non-purchased products (hard.  negatives)
    most_similar_indices = np.argsort(-similarity_scores, axis=0)[:len(group)]
    #hard_negatives = {non_purchased_products[i] for i in most_similar_indices.flatten()}[:len(group)]
    # Flatten and select up to len(group) unique hard negatives
    hard_negatives = list({non_purchased_products[i] for i in most_similar_indices.flatten()})[:len(group)]


    # Append hard negatives as negative samples
    negative_samples.extend([{
        'customer_id': customer_id,
        'product_id': product_id,
        'quantity': 0  # Indicating negative sample
    } for product_id in hard_negatives])

# Convert negative samples to a DataFrame
negative_samples_df = pd.DataFrame(negative_samples)

# Append negative samples to the original training data
train_data = pd.concat([train_data, negative_samples_df], ignore_index=True)

# Update relevance column (1 for purchased, 0 for negatives)
train_data['relevance'] = (train_data['quantity'] > 0).astype(int)
# Out:
# Generating hard negative samples: 100%|██████████| 9999/9999 [10:03:31<00:00,  3.62s/it]

# %%
train_data.tail()
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 17489769  Household_39999  Product_28078       NaN       0.0      NaN    NaN
# 17489770  Household_39999  Product_30684       NaN       0.0      NaN    NaN
# 17489771  Household_39999  Product_27251       NaN       0.0      NaN    NaN
# 17489772  Household_39999  Product_47403       NaN       0.0      NaN    NaN
# 17489773  Household_39999  Product_18050       NaN       0.0      NaN    NaN
#
#           day_of_week  is_weekend  days_since_last_purchase  \
# 17489769          NaN         NaN                       NaN
# 17489770          NaN         NaN                       NaN
# 17489771          NaN         NaN                       NaN
# 17489772          NaN         NaN                       NaN
# 17489773          NaN         NaN                       NaN
#
#           purchase_frequency  avg_quantity  promo_ratio  unique_products  \
# 17489769                 NaN           NaN          NaN              NaN
# 17489770                 NaN           NaN          NaN              NaN
# 17489771                 NaN           NaN          NaN              NaN
# 17489772                 NaN           NaN          NaN              NaN
# 17489773                 NaN           NaN          NaN              NaN
#
#           relevance
# 17489769          0
# 17489770          0
# 17489771          0
# 17489772          0
# 17489773          0

# %%
# Check for missing values
print("Missing values in train_data:")
print(train_data.isnull().sum())

print("Missing values in test_data:")
print(test_data.isnull().sum())

# Fill remaining missing values with zeros as a safety measure
train_data = train_data.fillna(0)
test_data = test_data.fillna(0)
# Out:
# Missing values in train_data:
# customer_id                       0
# product_id                        0
# is_promo                    8744887
# quantity                          0
# recency                     8744887
# month                       8744887
# day_of_week                 8744887
# is_weekend                  8744887
# days_since_last_purchase    8744887
# purchase_frequency          8744887
# avg_quantity                8744887
# promo_ratio                 8744887
# unique_products             8744887
# relevance                         0
# dtype: int64
# Missing values in test_data:
# transaction_id    0
# customer_id       0
# product_id        0
# dtype: int64

# %%
train_data = train_data.drop(columns=['day_of_week','is_weekend','unique_products'])

# %%
# prompt: in train_data for household Household_9247 count how manyrelevance 1 and how many are 0.

# Assuming 'train_data' DataFrame is already loaded as in the provided code.

household_9247_data = train_data[train_data['customer_id'] == 'Household_76806']

relevance_counts = household_9247_data['relevance'].value_counts()

print(f"Relevance counts for Household_9247:")
relevance_counts
# Out:
# Relevance counts for Household_9247:
# Series([], Name: count, dtype: int64)

# %%
train_data.to_csv(os.path.join(trainFolder, 'train_data_all_4.csv'), index=False)

# %%
len(train_data)
# Out:
# 17489774

# %%
train_data
# Out:
#               customer_id     product_id  is_promo  quantity  recency  month  \
# 0         Household_30946  Product_16061       0.0       1.0    322.0    2.0
# 1         Household_30946  Product_74944       0.0       1.0     91.0   10.0
# 2         Household_30946  Product_27979       0.0       1.0    109.0    9.0
# 3         Household_30946  Product_38506       0.0       1.0    137.0    8.0
# 4         Household_30946  Product_59873       0.0       2.0    243.0    5.0
# ...                   ...            ...       ...       ...      ...    ...
# 17489769  Household_39999  Product_28078       0.0       0.0      0.0    0.0
# 17489770  Household_39999  Product_30684       0.0       0.0      0.0    0.0
# 17489771  Household_39999  Product_27251       0.0       0.0      0.0    0.0
# 17489772  Household_39999  Product_47403       0.0       0.0      0.0    0.0
# 17489773  Household_39999  Product_18050       0.0       0.0      0.0    0.0
#
#           days_since_last_purchase  purchase_frequency  avg_quantity  \
# 0                            322.0               268.0       1.41791
# 1                             91.0               268.0       1.41791
# 2                            109.0               268.0       1.41791
# 3                            137.0               268.0       1.41791
# 4                            243.0               268.0       1.41791
# ...                            ...                 ...           ...
# 17489769                       0.0                 0.0       0.00000
# 17489770                       0.0                 0.0       0.00000
# 17489771                       0.0                 0.0       0.00000
# 17489772                       0.0                 0.0       0.00000
# 17489773                       0.0                 0.0       0.00000
#
#           promo_ratio  relevance
# 0            0.134328          1
# 1            0.134328          1
# 2            0.134328          1
# 3            0.134328          1
# 4            0.134328          1
# ...               ...        ...
# 17489769     0.000000          0
# 17489770     0.000000          0
# 17489771     0.000000          0
# 17489772     0.000000          0
# 17489773     0.000000          0
#
# [17489774 rows x 11 columns]

# %%
products_data
